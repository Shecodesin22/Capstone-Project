# %%
import pandas as pd
import seaborn as sns
import numpy as np
pd.set_option('display.max_rows', None, 'display.max_columns', 500)

# %%
cinci_2016 = pd.read_csv('./data/cincidr2016.csv')
# Out:
# C:\Users\sarah\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3340: DtypeWarning: Columns (23,24,67,68,69,70,71,72) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_2016c = cinci_2016.convert_dtypes()

# %%
cinci_2016c['Date_of_Payment'] = pd.to_datetime(cinci_2016c['Date_of_Payment'])
cinci_2016c['Payment_Publication_Date'] = pd.to_datetime(cinci_2016c['Payment_Publication_Date'])

# %%
cinci_2016c.dtypes
# Out:
# Change_Type                                                                  string
# Covered_Recipient_Type                                                       string
# Teaching_Hospital_CCN                                                         Int64
# Teaching_Hospital_ID                                                          Int64
# Teaching_Hospital_Name                                                        Int64
# Physician_Profile_ID                                                          Int64
# Physician_First_Name                                                         string
# Physician_Middle_Name                                                        string
# Physician_Last_Name                                                          string
# Physician_Name_Suffix                                                        string
# Recipient_Primary_Business_Street_Address_Line1                              string
# ...

# %%
cinci_2016c.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                   <NA>
# 1   UNCHANGED  Covered Recipient Physician                   <NA>
#
#    Teaching_Hospital_ID  Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                  <NA>                    <NA>                389063
# 1                  <NA>                    <NA>                389063
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0               Arthur                  <NA>            Pancioli
# 1               Arthur                  <NA>            Pancioli
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                  <NA>                        8075 Muchmore Point Lane
# 1                  <NA>                       8075 Muchmore Point Lance
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                            <NA>     Cincinnati
# ...

# %%
cinci_2017 = pd.read_csv('./data/cincidr2017.csv')
# Out:
# C:\Users\sarah\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3340: DtypeWarning: Columns (24,72) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_2017c = cinci_2017.convert_dtypes()

# %%
cinci_2017c['Date_of_Payment'] = pd.to_datetime(cinci_2017c['Date_of_Payment'])
cinci_2017c['Payment_Publication_Date'] = pd.to_datetime(cinci_2017c['Payment_Publication_Date'])

# %%
cinci_2017c.dtypes
# Out:
# Change_Type                                                                  string
# Covered_Recipient_Type                                                       string
# Teaching_Hospital_CCN                                                         Int64
# Teaching_Hospital_ID                                                          Int64
# Teaching_Hospital_Name                                                        Int64
# Physician_Profile_ID                                                          Int64
# Physician_First_Name                                                         string
# Physician_Middle_Name                                                        string
# Physician_Last_Name                                                          string
# Physician_Name_Suffix                                                        string
# Recipient_Primary_Business_Street_Address_Line1                              string
# ...

# %%
cinci_2017c.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                   <NA>
# 1   UNCHANGED  Covered Recipient Physician                   <NA>
#
#    Teaching_Hospital_ID  Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                  <NA>                    <NA>                867378
# 1                  <NA>                    <NA>                867378
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0               PRATHA                     T              ATLURI
# 1               PRATHA                     T              ATLURI
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                  <NA>                              9050 MONTGOMERY RD
# 1                  <NA>                              9050 MONTGOMERY RD
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                         SUITE A     CINCINNATI
# ...

# %%
#Import 2018 Cincinnati data

# %%
cinci_2018 = pd.read_csv('./data/cincidr2018.csv')
# Out:
# C:\Users\sarah\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3340: DtypeWarning: Columns (24,67,68,69,70,71,72) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_2018c = cinci_2018.convert_dtypes()

# %%
cinci_2018c['Date_of_Payment'] = pd.to_datetime(cinci_2018c['Date_of_Payment'])
cinci_2018c['Payment_Publication_Date'] = pd.to_datetime(cinci_2018c['Payment_Publication_Date'])

# %%
cinci_2018c.dtypes
# Out:
# Change_Type                                                                  string
# Covered_Recipient_Type                                                       string
# Teaching_Hospital_CCN                                                         Int64
# Teaching_Hospital_ID                                                          Int64
# Teaching_Hospital_Name                                                        Int64
# Physician_Profile_ID                                                          Int64
# Physician_First_Name                                                         string
# Physician_Middle_Name                                                        string
# Physician_Last_Name                                                          string
# Physician_Name_Suffix                                                        string
# Recipient_Primary_Business_Street_Address_Line1                              string
# ...

# %%
cinci_2018c.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                   <NA>
# 1   UNCHANGED  Covered Recipient Physician                   <NA>
#
#    Teaching_Hospital_ID  Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                  <NA>                    <NA>               1216736
# 1                  <NA>                    <NA>               1216736
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0             CAROLINE                  <NA>             WURTZEL
# 1             CAROLINE                  <NA>             WURTZEL
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                  <NA>                              538 OAK ST STE 200
# 1                  <NA>                              538 OAK ST STE 200
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                            <NA>     CINCINNATI
# ...

# %%
#Import 2019 Cincinnati data

# %%
cinci_2019 = pd.read_csv('./data/cincidr2019.csv')
# Out:
# C:\Users\sarah\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3340: DtypeWarning: Columns (23,24,67,72) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_2019.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                    NaN
# 1   UNCHANGED  Covered Recipient Physician                    NaN
#
#    Teaching_Hospital_ID  Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                   NaN                     NaN             1394797.0
# 1                   NaN                     NaN              797863.0
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0               Justin                   NaN          Virojanapa
# 1                 JOHN                     S             CARDONE
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                   NaN                               3113 Bellevue Ave
# 1                   NaN                               5885 HARRISON AVE
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                             NaN     Cincinnati
# ...

# %%
cinci_2019c = cinci_2019.convert_dtypes()

# %%
cinci_2019c['Date_of_Payment'] = pd.to_datetime(cinci_2019c['Date_of_Payment'])
cinci_2019c['Payment_Publication_Date'] = pd.to_datetime(cinci_2019c['Payment_Publication_Date'])

# %%
cinci_2019c.dtypes
# Out:
# Change_Type                                                                  string
# Covered_Recipient_Type                                                       string
# Teaching_Hospital_CCN                                                         Int64
# Teaching_Hospital_ID                                                          Int64
# Teaching_Hospital_Name                                                        Int64
# Physician_Profile_ID                                                          Int64
# Physician_First_Name                                                         string
# Physician_Middle_Name                                                        string
# Physician_Last_Name                                                          string
# Physician_Name_Suffix                                                        string
# Recipient_Primary_Business_Street_Address_Line1                              string
# ...

# %%
#Import 2020 Cincinnati data

# %%
cinci_2020 = pd.read_csv('./data/cincidr2020.csv')
# Out:
# C:\Users\sarah\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3340: DtypeWarning: Columns (9,24,40,42,57,62,67,72) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_2020.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                    NaN
# 1   UNCHANGED  Covered Recipient Physician                    NaN
#
#    Teaching_Hospital_ID  Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                   NaN                     NaN             1054182.0
# 1                   NaN                     NaN             1054182.0
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0                 John                Herman           Greinwald
# 1                 John                Herman           Greinwald
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                   NaN                                1859 Madison Rd.
# 1                   NaN                                1859 Madison Rd.
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                             NaN     Cincinnati
# ...

# %%
cinci_2020c = cinci_2020.convert_dtypes()

# %%
cinci_2020c['Date_of_Payment'] = pd.to_datetime(cinci_2020c['Date_of_Payment'])
cinci_2020c['Payment_Publication_Date'] = pd.to_datetime(cinci_2020c['Payment_Publication_Date'])

# %%
cinci_2020c.dtypes
# Out:
# Change_Type                                                                  string
# Covered_Recipient_Type                                                       string
# Teaching_Hospital_CCN                                                         Int64
# Teaching_Hospital_ID                                                          Int64
# Teaching_Hospital_Name                                                        Int64
# Physician_Profile_ID                                                          Int64
# Physician_First_Name                                                         string
# Physician_Middle_Name                                                        string
# Physician_Last_Name                                                          string
# Physician_Name_Suffix                                                        string
# Recipient_Primary_Business_Street_Address_Line1                              string
# ...

# %%
cinci_1620 = pd.concat([cinci_2016c,cinci_2017c, cinci_2018c,cinci_2019c, cinci_2020c], ignore_index=True)

# %%
cinci_1620.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                   <NA>
# 1   UNCHANGED  Covered Recipient Physician                   <NA>
#
#    Teaching_Hospital_ID  Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                  <NA>                    <NA>                389063
# 1                  <NA>                    <NA>                389063
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0               Arthur                  <NA>            Pancioli
# 1               Arthur                  <NA>            Pancioli
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                  <NA>                        8075 Muchmore Point Lane
# 1                  <NA>                       8075 Muchmore Point Lance
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                            <NA>     Cincinnati
# ...

# %%
drop_col = ['Teaching_Hospital_CCN', 'Teaching_Hospital_ID', 'Teaching_Hospital_Name', 'Recipient_Province', 'Recipient_Postal_Code']

# %%
cinci_1620.drop(columns=drop_col, inplace = True)

# %%
cinci_1620.shape
# Out:
# (236603, 70)

# %%
cinci_1620['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'] = cinci_1620['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].fillna('Blank')

# %%
cinci_1620['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'] = cinci_1620['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].str.lower()

# %%
cinci_1620['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].value_counts()
# Out:
# blank                                                                                              16566
# xarelto                                                                                             7191
# humira                                                                                              4167
# victoza                                                                                             3531
# entresto                                                                                            3475
# chantix                                                                                             3451
# farxiga                                                                                             3031
# ozempic                                                                                             2777
# jardiance                                                                                           2401
# ...

# %%
cinci_1620['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].isna().sum()
# Out:
# 0

# %%
#cinci_1820['XARELTO'] = [1 if i == 'XARELTO' else 0 for i in cinci_1820['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1']]

# %%
#cinci_1820['XARELTO'].value_counts()

# %%
cinci_1620.to_csv('./data/cinci1620.csv', index=False)  #Gene told me about index=False to prevent getting an Unnamed:0 column in my csv/dataset (when I read it back in)

# %%
import pandas as pd
import seaborn as sns
import numpy as np
pd.set_option('display.max_rows', 300, 'display.max_columns', 300)

# %% [markdown]
# #Found this code to fix a data type Warning
# #https://www.roelpeters.be/solved-dtypewarning-columns-have-mixed-types-specify-dtype-option-on-import-or-set-low-memory-in-pandas/

# %%
def convert_dtype(x):
    if not x:
        return ''
    try:
        return str(x)   
    except:        
        return ''

# %%
#Read in core data file - this is pulled from the general payments file for 2015 and is Ohio only
ohio2015 = pd.read_csv('./data/ohiodr2015.csv',converters={
'Change_Type':convert_dtype,'Covered_Recipient_Type':convert_dtype,
'Teaching_Hospital_Name':convert_dtype,
'Physician_First_Name':convert_dtype,
'Physician_Middle_Name':convert_dtype,
'Physician_Last_Name':convert_dtype,
'Physician_Name_Suffix':convert_dtype,
'Recipient_Primary_Business_Street_Address_Line1':convert_dtype,
'Recipient_Primary_Business_Street_Address_Line2':convert_dtype,
'Recipient_City':convert_dtype,
'Recipient_State':convert_dtype,
'Recipient_Zip_Code':convert_dtype,
'Recipient_Country':convert_dtype,
'Recipient_Province':convert_dtype,
'Recipient_Postal_Code':convert_dtype,
'Physician_Primary_Type':convert_dtype,
'Physician_Specialty':convert_dtype,
'Physician_License_State_code1':convert_dtype,
'Physician_License_State_code2':convert_dtype,
'Physician_License_State_code3':convert_dtype,
'Physician_License_State_code4':convert_dtype,
'Physician_License_State_code5':convert_dtype,
'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name':convert_dtype,
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name':convert_dtype,
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State':convert_dtype,
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country':convert_dtype,
'Form_of_Payment_or_Transfer_of_Value':convert_dtype,
'City_of_Travel':convert_dtype,
'State_of_Travel':convert_dtype,
'Country_of_Travel':convert_dtype,
'Physician_Ownership_Indicator':convert_dtype,
'Third_Party_Payment_Recipient_Indicator':convert_dtype,
'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value':convert_dtype,
'Charity_Indicator':convert_dtype,
'Third_Party_Equals_Covered_Recipient_Indicator':convert_dtype,
'Contextual_Information':convert_dtype,
'Delay_in_Publication_Indicator':convert_dtype,
'Dispute_Status_for_Publication':convert_dtype,
'Product_Indicator':convert_dtype,    
'Name_of_Associated_Covered_Drug_or_Biological1':convert_dtype,
'Name_of_Associated_Covered_Drug_or_Biological2':convert_dtype,
'Name_of_Associated_Covered_Drug_or_Biological3':convert_dtype,
'Name_of_Associated_Covered_Drug_or_Biological4':convert_dtype,
'Name_of_Associated_Covered_Drug_or_Biological5':convert_dtype,
'NDC_of_Associated_Covered_Drug_or_Biological1':convert_dtype,
'NDC_of_Associated_Covered_Drug_or_Biological2':convert_dtype,
'NDC_of_Associated_Covered_Drug_or_Biological3':convert_dtype,
'NDC_of_Associated_Covered_Drug_or_Biological4':convert_dtype,
'NDC_of_Associated_Covered_Drug_or_Biological5':convert_dtype,
'Name_of_Associated_Covered_Device_or_Medical_Supply1':convert_dtype,
'Name_of_Associated_Covered_Device_or_Medical_Supply2':convert_dtype,
'Name_of_Associated_Covered_Device_or_Medical_Supply3':convert_dtype,
'Name_of_Associated_Covered_Device_or_Medical_Supply4':convert_dtype,
'Name_of_Associated_Covered_Device_or_Medical_Supply5':convert_dtype      
 })
ohio2015.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                    NaN
# 1   UNCHANGED  Covered Recipient Physician                    NaN
#
#    Teaching_Hospital_ID Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                   NaN                                    1354132.0
# 1                   NaN                                     238873.0
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0               ELLIOT                  BRIN                NAVO
# 1                 MARY                     K              MURRAY
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                                                       1121 KINNEYS LN
# 1                                                    2603 W. MARKET ST.
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                                     PORTSMOUTH
# 1                                       SUITE 210          AKRON
#
#   Recipient_State Recipient_Zip_Code Recipient_Country Recipient_Province  \
# 0              OH         45662-2806     United States
# 1              OH         44313-4234     United States
#
#   Recipient_Postal_Code Physician_Primary_Type  \
# 0                               Medical Doctor
# 1                               Medical Doctor
#
#                                  Physician_Specialty  \
# 0  Allopathic & Osteopathic Physicians|Radiology|...
# 1        Allopathic & Osteopathic Physicians|Surgery
#
#   Physician_License_State_code1 Physician_License_State_code2  \
# 0                            OH
# 1                            OH
#
#   Physician_License_State_code3 Physician_License_State_code4  \
# 0
# 1
#
#   Physician_License_State_code5  \
# 0
# 1
#
#   Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name  \
# 0                                 Cianna Medical Inc
# 1                                 Cianna Medical Inc
#
#    Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID  \
# 0                                       100000061318
# 1                                       100000061318
#
#   Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name  \
# 0                                 Cianna Medical Inc
# 1                                 Cianna Medical Inc
#
#   Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State  \
# 0                                                 CA
# 1                                                 CA
#
#   Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country  \
# 0                                      United States
# 1                                      United States
#
#    Total_Amount_of_Payment_USDollars Date_of_Payment  \
# 0                              12.40      09/30/2015
# 1                              15.47      04/15/2015
#
#    Number_of_Payments_Included_in_Total_Amount  \
# 0                                            1
# 1                                            1
#
#   Form_of_Payment_or_Transfer_of_Value Nature_of_Payment_or_Transfer_of_Value  \
# 0              Cash or cash equivalent                      Food and Beverage
# 1              Cash or cash equivalent                      Food and Beverage
#
#   City_of_Travel State_of_Travel Country_of_Travel  \
# 0
# 1
#
#   Physician_Ownership_Indicator Third_Party_Payment_Recipient_Indicator  \
# 0                            No                  No Third Party Payment
# 1                            No                  No Third Party Payment
#
#   Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value  \
# 0
# 1
#
#   Charity_Indicator Third_Party_Equals_Covered_Recipient_Indicator  \
# 0
# 1
#
#   Contextual_Information Delay_in_Publication_Indicator  Record_ID  \
# 0                                                    No  228289590
# 1                                                    No  228289802
#
#   Dispute_Status_for_Publication Product_Indicator  \
# 0                             No           Covered
# 1                             No           Covered
#
#   Name_of_Associated_Covered_Drug_or_Biological1  \
# 0
# 1
#
#   Name_of_Associated_Covered_Drug_or_Biological2  \
# 0
# 1
#
#   Name_of_Associated_Covered_Drug_or_Biological3  \
# 0
# 1
#
#   Name_of_Associated_Covered_Drug_or_Biological4  \
# 0
# 1
#
#   Name_of_Associated_Covered_Drug_or_Biological5  \
# 0
# 1
#
#   NDC_of_Associated_Covered_Drug_or_Biological1  \
# 0
# 1
#
#   NDC_of_Associated_Covered_Drug_or_Biological2  \
# 0
# 1
#
#   NDC_of_Associated_Covered_Drug_or_Biological3  \
# 0
# 1
#
#   NDC_of_Associated_Covered_Drug_or_Biological4  \
# 0
# 1
#
#   NDC_of_Associated_Covered_Drug_or_Biological5  \
# 0
# 1
#
#   Name_of_Associated_Covered_Device_or_Medical_Supply1  \
# 0                                               SAVI
# 1                                               SAVI
#
#   Name_of_Associated_Covered_Device_or_Medical_Supply2  \
# 0
# 1
#
#   Name_of_Associated_Covered_Device_or_Medical_Supply3  \
# 0
# 1
#
#   Name_of_Associated_Covered_Device_or_Medical_Supply4  \
# 0
# 1
#
#   Name_of_Associated_Covered_Device_or_Medical_Supply5  Program_Year  \
# 0                                                               2015
# 1                                                               2015
#
#   Payment_Publication_Date
# 0               01/21/2022
# 1               01/21/2022

# %%
ohio2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504776 entries, 0 to 504775
# Data columns (total 65 columns):
#  #   Column                                                             Non-Null Count   Dtype
# ---  ------                                                             --------------   -----
#  0   Change_Type                                                        504776 non-null  object
#  1   Covered_Recipient_Type                                             504776 non-null  object
#  2   Teaching_Hospital_CCN                                              0 non-null       float64
#  3   Teaching_Hospital_ID                                               0 non-null       float64
#  4   Teaching_Hospital_Name                                             504776 non-null  object
#  5   Physician_Profile_ID                                               504776 non-null  float64
#  6   Physician_First_Name                                               504776 non-null  object
#  7   Physician_Middle_Name                                              504776 non-null  object
#  8   Physician_Last_Name                                                504776 non-null  object
#  9   Physician_Name_Suffix                                              504776 non-null  object
#  10  Recipient_Primary_Business_Street_Address_Line1                    504776 non-null  object
#  11  Recipient_Primary_Business_Street_Address_Line2                    504776 non-null  object
#  12  Recipient_City                                                     504776 non-null  object
#  13  Recipient_State                                                    504776 non-null  object
#  14  Recipient_Zip_Code                                                 504776 non-null  object
#  15  Recipient_Country                                                  504776 non-null  object
#  16  Recipient_Province                                                 504776 non-null  object
#  17  Recipient_Postal_Code                                              504776 non-null  object
#  18  Physician_Primary_Type                                             504776 non-null  object
#  19  Physician_Specialty                                                504776 non-null  object
#  20  Physician_License_State_code1                                      504776 non-null  object
#  21  Physician_License_State_code2                                      504776 non-null  object
#  22  Physician_License_State_code3                                      504776 non-null  object
#  23  Physician_License_State_code4                                      504776 non-null  object
#  24  Physician_License_State_code5                                      504776 non-null  object
#  25  Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name          504776 non-null  object
#  26  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID        504776 non-null  int64
#  27  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name      504776 non-null  object
#  28  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State     504776 non-null  object
#  29  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country   504776 non-null  object
#  30  Total_Amount_of_Payment_USDollars                                  504776 non-null  float64
#  31  Date_of_Payment                                                    504776 non-null  object
#  32  Number_of_Payments_Included_in_Total_Amount                        504776 non-null  int64
#  33  Form_of_Payment_or_Transfer_of_Value                               504776 non-null  object
#  34  Nature_of_Payment_or_Transfer_of_Value                             504776 non-null  object
#  35  City_of_Travel                                                     504776 non-null  object
#  36  State_of_Travel                                                    504776 non-null  object
#  37  Country_of_Travel                                                  504776 non-null  object
#  38  Physician_Ownership_Indicator                                      504776 non-null  object
#  39  Third_Party_Payment_Recipient_Indicator                            504776 non-null  object
#  40  Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value  504776 non-null  object
#  41  Charity_Indicator                                                  504776 non-null  object
#  42  Third_Party_Equals_Covered_Recipient_Indicator                     504776 non-null  object
#  43  Contextual_Information                                             504776 non-null  object
#  44  Delay_in_Publication_Indicator                                     504776 non-null  object
#  45  Record_ID                                                          504776 non-null  int64
#  46  Dispute_Status_for_Publication                                     504776 non-null  object
#  47  Product_Indicator                                                  504776 non-null  object
#  48  Name_of_Associated_Covered_Drug_or_Biological1                     504776 non-null  object
#  49  Name_of_Associated_Covered_Drug_or_Biological2                     504776 non-null  object
#  50  Name_of_Associated_Covered_Drug_or_Biological3                     504776 non-null  object
#  51  Name_of_Associated_Covered_Drug_or_Biological4                     504776 non-null  object
#  52  Name_of_Associated_Covered_Drug_or_Biological5                     504776 non-null  object
#  53  NDC_of_Associated_Covered_Drug_or_Biological1                      504776 non-null  object
#  54  NDC_of_Associated_Covered_Drug_or_Biological2                      504776 non-null  object
#  55  NDC_of_Associated_Covered_Drug_or_Biological3                      504776 non-null  object
#  56  NDC_of_Associated_Covered_Drug_or_Biological4                      504776 non-null  object
#  57  NDC_of_Associated_Covered_Drug_or_Biological5                      504776 non-null  object
#  58  Name_of_Associated_Covered_Device_or_Medical_Supply1               504776 non-null  object
#  59  Name_of_Associated_Covered_Device_or_Medical_Supply2               504776 non-null  object
#  60  Name_of_Associated_Covered_Device_or_Medical_Supply3               504776 non-null  object
#  61  Name_of_Associated_Covered_Device_or_Medical_Supply4               504776 non-null  object
#  62  Name_of_Associated_Covered_Device_or_Medical_Supply5               504776 non-null  object
#  63  Program_Year                                                       504776 non-null  int64
#  64  Payment_Publication_Date                                           504776 non-null  object
# dtypes: float64(4), int64(4), object(57)
# memory usage: 250.3+ MB

# %%
cinci2015 = ohio2015[((ohio2015['Recipient_City']=='Cincinnati') | (ohio2015['Recipient_City']=='CINCINNATI'))].copy()

# %%
cinci2015['Recipient_City'].value_counts()
# Out:
# CINCINNATI    45784
# Cincinnati     8484
# Name: Recipient_City, dtype: int64

# %%
cinci2015['Covered_Recipient_Type'].value_counts()
# Out:
# Covered Recipient Physician    54268
# Name: Covered_Recipient_Type, dtype: int64

# %%
cinci_dr2015 = cinci2015[cinci2015['Covered_Recipient_Type']=='Covered Recipient Physician'].copy()

# %%
cinci_dr2015['Covered_Recipient_Type'].value_counts()
# Out:
# Covered Recipient Physician    54268
# Name: Covered_Recipient_Type, dtype: int64

# %%
cinci_dr2015['Physician_Ownership_Indicator'].value_counts()
# Out:
# No     54250
# Yes       18
# Name: Physician_Ownership_Indicator, dtype: int64

# %%
cinci_dr2015.rename(columns = {'Product_Indicator':'Related_Product_Indicator',
'Name_of_Associated_Covered_Drug_or_Biological1':'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Name_of_Associated_Covered_Drug_or_Biological2':'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Name_of_Associated_Covered_Drug_or_Biological3':'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Name_of_Associated_Covered_Drug_or_Biological4':'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Name_of_Associated_Covered_Drug_or_Biological5':'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'NDC_OF_Associated_Covered_Drug_or_Biological1':'Associated_Drug_or_Biological_NDC_1',                         
'NDC_OF_Associated_Covered_Drug_or_Biological2':'Associated_Drug_or_Biological_NDC_2',                         
'NDC_OF_Associated_Covered_Drug_or_Biological3':'Associated_Drug_or_Biological_NDC_3',                         
'NDC_OF_Associated_Covered_Drug_or_Biological4':'Associated_Drug_or_Biological_NDC_4',                         
'NDC_OF_Associated_Covered_Drug_or_Biological5':'Associated_Drug_or_Biological_NDC_5',}, inplace=True)

# %%
cinci_dr2015['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].value_counts()
# Out:
#                       12574
# Xarelto                1908
# Levemir                1772
# Humira                 1109
# TOUJEO                  974
#                       ...
# JENTADUETO                1
# Smoflipid                 1
# SANDOSTATIN               1
# VOTRIENT - SARCOMA        1
# Invokamet                 1
# Name: Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1, Length: 687, dtype: int64

# %%
cinci_dr2015['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2'].value_counts()
# Out:
#                                                    41802
# Xarelto                                             1029
# Invokana                                             983
# Victoza                                              949
# NovoLog                                              798
# CIALIS                                               491
# TRADJENTA                                            472
# ANORO                                                435
# LEVITRA                                              381
# GLYXAMBI                                             379
# VIIBRYD                                              354
# Viekira                                              305
# JARDIANCE                                            278
# INVOKANA                                             251
# Synthroid                                            221
# Repatha                                              210
# BREO                                                 202
# Invega                                               190
# LINZESS 290 mcg                                      178
# ARNUITY                                              175
# JANUMET                                              168
# OXYCONTIN                                            164
# TRULICITY                                            140
# Vesicare                                             139
# BUNAVAIL BUNAVAIL 2.1 mg single pouch                137
# TECFIDERA                                            121
# SIMPONI                                              121
# XARELTO                                              109
# Regranex                                              97
# NAMZARIC                                              96
# ZETIA                                                 94
# Oseni                                                 92
# SPIRIVA RESPIMAT                                      84
# PENTASA                                               83
# Skyla                                                 83
# HYSINGLA ER                                           79
# Prolia                                                79
# BUTRANS                                               78
# Invokamet                                             78
# BELSOMRA                                              62
# VENTAVIS ILOPROST                                     61
# VIMOVO                                                56
# Ilevro                                                55
# Colcrys                                               51
# Systane                                               51
# Gralise                                               48
# STIOLTO                                               44
# LINZESS                                               44
# Apokyn                                                43
# PRADAXA                                               41
# Stelara                                               40
# Simponi                                               39
# AXIRON                                                37
# INVOKAMET                                             37
# BYDUREON PEN                                          34
# PENTACEL                                              34
# FARXIGA                                               33
# COMBIVENT RESPIMAT                                    32
# Alinia for Oral Suspension                            32
# TUDORZA                                               31
# Technivie                                             30
# FLUZONE HIGH-DOSE                                     30
# Simponi Aria                                          29
# TRACLEER BOSENTAN                                     28
# CRESTOR                                               27
# MINOCIN                                               26
# NEXPLANON                                             26
# Actemra                                               26
# TYVASO                                                26
# GAZYVA                                                25
# Mycamine                                              23
# APRISO                                                23
# HUMALOG                                               22
# SYMBICORT                                             22
# invokana                                              22
# Moxeza                                                20
# Zipsor                                                19
# Livalo                                                19
# INVEGA TRINZA                                         19
# ZOSTAVAX                                              18
# SIMPONI ARIA                                          18
# SPIRIVA                                               17
# PNEUMOVAX 23                                          16
# Tarceva                                               16
# JENTADUETO                                            16
# PRAXBIND                                              15
# DIFICID                                               15
# GANIRELIX                                             15
# MYALEPT                                               14
# Aerospan                                              14
# ENTEREG                                               14
# Lupron                                                13
# ORACEA                                                12
# ALREX                                                 12
# Istodax                                               12
# BEPREVE                                               12
# SUMAVEL DOSEPRO                                       11
# STRIVERDI RESPIMAT                                    11
# JANUMET XR                                            11
# NINLARO                                               11
# ONGLYZA                                               11
# Travatan Z                                            11
# DeNovo NT                                             11
# Simbrinza                                             11
# ONEXTON                                               10
# Vitafol Ultra                                         10
# FLOVENT                                                9
# ZONTIVITY                                              9
# SOOLANTRA                                              9
# UCERIS TABLETS                                         9
# Evamist estradiol Transdermal Spray 153mg              9
# VOLTAREN GEL                                           9
# STELARA                                                8
# Asclera                                                8
# TASIGNA                                                8
# ZERBAXA                                                8
# Pomalyst                                               8
# CYRAMZA                                                8
# ZYLET                                                  8
# Xofigo                                                 8
# Lupaneta                                               8
# FIRAZYR                                                8
# ADVAIR                                                 8
# Ambisome                                               8
# Glyxambi                                               7
# BenzePro Creamy Wash                                   7
# FARESTON                                               7
# Aristada 662 mg                                        7
# EpiPen                                                 7
# Clindesse clindamycin phosphate Vaginal Cream 2        7
# GYNAZOLE1 BUTOCONAZOLE NITRATE VAGINAL CREAM 2         7
# TOUJEO                                                 7
# Vigamox                                                6
# SOLODYN                                                6
# Stivarga                                               6
# ADACEL                                                 6
# REMICADE                                               6
# RAGWITEK                                               6
# GARDASIL9                                              6
# XGEVA                                                  6
# YONDELIS                                               5
# Cathflo Activase                                       5
# Kadcyla                                                5
# BRILINTA                                               5
# DULERA                                                 5
# Prograf                                                5
# LUZU LULICONAZOLE                                      5
# MINASTRIN 24 FE                                        4
# MIRVASO                                                4
# TANZEUM                                                4
# Lexiscan                                               3
# NUVAIL                                                 3
# RETIN-A-MICRO                                          3
# Nplate                                                 3
# CINRYZE                                                3
# Onmel                                                  3
# Tresiba                                                3
# VELETRI EPOPROSTENOL                                   3
# LANTUS                                                 3
# IMBRUVICA                                              2
# Durezol                                                2
# ADCIRCA                                                2
# Zuplenz                                                2
# Respimat                                               2
# Pazeo                                                  2
# FORTESTA                                               2
# SANDOSTATIN LAR                                        2
# PROMACTA                                               2
# RAYOS                                                  2
# TAFINLAR                                               2
# EFFIENT                                                2
# CLEVIPREX                                              2
# NEUPOGEN                                               2
# FLUZONE QIV                                            2
# Nucynta                                                2
# XOMA                                                   2
# INTRON A                                               2
# Myobloc                                                2
# MOVANTIK                                               2
# FLUARIX                                                2
# Bromfed DM Pint bottle                                 2
# Omnipaque                                              2
# ZOVIRAX CREAM                                          2
# PREVNAR - 13                                           2
# INVEGA SUSTENNA                                        2
# JUBLIA EFINACONAZOLE                                   2
# DALVANCE                                               2
# NORITATE                                               2
# RELISTOR                                               1
# Vascepa                                                1
# Imbruvica                                              1
# Rituxan                                                1
# Cuvposa                                                1
# DALIRESP                                               1
# PULMICORT TURBUHALER                                   1
# NonCovered Product                                     1
# DARZALEX                                               1
# TRUMENBA                                               1
# Revlimid                                               1
# xarelto                                                1
# SERELAXIN                                              1
# REBETOL                                                1
# AUBAGIO                                                1
# FLUZONE INTRADERMAL                                    1
# JDR                                                    1
# SERETIDE                                               1
# VOTRIENT                                               1
# ANORO ELLIPTA                                          1
# PEDIARIX                                               1
# TROKENDI XR                                            1
# EPIDUO                                                 1
# GLUMETZA                                               1
# LOTEMAX GEL                                            1
# ZIANA                                                  1
# ZYCLARA                                                1
# DIVALPROEX SODIUM Delayed Release Tablets USP          1
# Vimizim                                                1
# Verdeso                                                1
# Trianex                                                1
# Vectibix                                               1
# TOPIRAMATE Extended Release Capsules                   1
# Name: Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2, dtype: int64

# %%
cinci_dr2015['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3'].value_counts()
# Out:
#                                                    50790
# Victoza                                              352
# TRULICITY                                            339
# Synthroid                                            299
# JARDIANCE                                            173
# GLYXAMBI                                             166
# BELSOMRA                                             164
# BUNAVAIL BUNAVAIL 4.2 mg 30-count box                137
# AXIRON                                               120
# BUTRANS                                              117
# PLEGRIDY                                             102
# Kazano                                                92
# ANORO                                                 90
# VELETRI EPOPROSTENOL                                  81
# OXYCONTIN                                             73
# Invokamet                                             59
# FLOVENT                                               55
# INCRUSE                                               49
# HYSINGLA ER                                           47
# JANUMET XR                                            43
# Stelara                                               36
# Simbrinza                                             35
# SPIRIVA RESPIMAT                                      33
# STRIVERDI RESPIMAT                                    33
# Remicade                                              32
# XARELTO                                               31
# Zipsor                                                30
# Cambia                                                30
# VIBERZI 75 mg                                         29
# Pazeo                                                 29
# FARXIGA                                               28
# BYDUREON PEN                                          28
# Ilevro                                                27
# ADACEL                                                26
# GARDASIL9                                             25
# INVOKAMET                                             24
# SYMBICORT                                             22
# CRESTOR                                               20
# UCERIS TABLETS                                        19
# PNEUMOVAX 23                                          18
# ORENITRAM                                             17
# PRAXBIND                                              15
# AVONEX                                                14
# QUADRACEL                                             13
# ALREX                                                 12
# BEPREVE                                               12
# Ambisome                                              11
# RETIN-A-MICRO                                         10
# VENTOLIN                                               9
# FLUZONE QIV                                            9
# GYNAZOLE1 BUTOCONAZOLE NITRATE VAGINAL CREAM 2         9
# ARNUITY                                                8
# SPIRIVA                                                8
# APRISO                                                 8
# ONGLYZA                                                8
# Evamist estradiol Transdermal Spray 153mg              8
# Fluocinonide Cream 0.1%                                7
# Aristada 882 mg                                        7
# Xofigo                                                 6
# ZIANA                                                  6
# Tresiba                                                6
# NO PRODUCT DISCUSSED                                   6
# REMICADE                                               6
# Pataday                                                6
# ORACEA                                                 6
# ZERBAXA                                                6
# Technivie                                              5
# SIMPONI ARIA                                           5
# Clindesse clindamycin phosphate Vaginal Cream 2        5
# Cresemba                                               5
# TNKase                                                 5
# MOVANTIK                                               5
# DULERA                                                 5
# LIPTRUZET                                              4
# NOXAFIL                                                4
# INVOKANA                                               4
# Lexiscan                                               4
# SKLICE                                                 4
# Prograf                                                3
# NORITATE                                               3
# BREO                                                   3
# ADVAIR                                                 3
# Mycamine                                               3
# TRADJENTA                                              3
# BIONECT                                                3
# FLUZONE INTRADERMAL                                    3
# SOOLANTRA                                              3
# XGEVA                                                  3
# SYLATRON                                               2
# Visipaque                                              2
# SUMAVEL DOSEPRO                                        2
# Herceptin                                              2
# Xarelto                                                2
# RAYOS                                                  2
# Systane                                                2
# TYVASO                                                 2
# ZYCLARA                                                2
# LAMOTRIGINE Tablets USP                                2
# MIRVASO                                                2
# Vectibix                                               2
# XIFAXAN - 550MG                                        2
# Gralise                                                2
# REMODULIN                                              1
# RELISTOR                                               1
# DALIRESP                                               1
# ZONTIVITY                                              1
# Invokana                                               1
# Cloderm Cream                                          1
# Acticlate                                              1
# SYNJARDY                                               1
# MOVIPREP                                               1
# SOLODYN                                                1
# FLUZONE HIGH-DOSE                                      1
# FLUZONE                                                1
# STIOLTO RESPIMAT                                       1
# PROLENSA                                               1
# TAFINLAR                                               1
# FLULAVAL                                               1
# VICTRELIS                                              1
# Risperdal Consta                                       1
# LUZU LULICONAZOLE                                      1
# Name: Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3, dtype: int64

# %%
cinci_dr2015['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4'].value_counts()
# Out:
#                                                   53482
# Androgel                                            299
# BUNAVAIL BUNAVAIL 4.2 mg single pouch               137
# GLYXAMBI                                             80
# VENTOLIN                                             34
# JANUMET XR                                           33
# VIBERZI 100 mg                                       29
# FARXIGA                                              17
# SYMBICORT                                            15
# CRESTOR                                              15
# GARDASIL9                                            14
# BYDUREON PEN                                         13
# MOVANTIK                                             11
# NO PRODUCT DISCUSSED                                 11
# FLUZONE QIV                                          11
# QUADRACEL                                             8
# ADVAIR                                                7
# Adapalene                                             7
# ONGLYZA                                               6
# RETIN-A-MICRO                                         5
# FLUZONE                                               3
# DALIRESP                                              3
# FLOVENT                                               3
# KEYTRUDA                                              2
# Omniscan                                              2
# ADCIRCA                                               2
# JENTADUETO                                            2
# JARDIANCE                                             2
# Kadcyla                                               1
# Fluoroplex                                            1
# MEKINIST                                              1
# TWINRIX                                               1
# KOMBIGLYZE XR                                         1
# Mycamine                                              1
# Lexiscan                                              1
# TRULICITY                                             1
# ADACEL                                                1
# SKLICE                                                1
# QUDEXY XR Topiramate Extended Release Capsules        1
# TOPIRAMATE Tablets USP                                1
# Zipsor                                                1
# Ambisome                                              1
# Cresemba                                              1
# Name: Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4, dtype: int64

# %%
cinci_dr2015['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5'].value_counts()
# Out:
#                                                   53767
# Lupron                                              299
# BUNAVAIL BUNAVAIL 6.3 mg 30-count box               137
# ONGLYZA                                              12
# SYMBICORT                                             9
# CRESTOR                                               7
# HPR Plus Cream                                        7
# BYDUREON PEN                                          5
# FARXIGA                                               5
# QUADRACEL                                             5
# FLUZONE QIV                                           4
# TRULICITY                                             2
# MOVANTIK                                              2
# DALIRESP                                              2
# QUDEXY XR Topiramate Extended Release Capsules        1
# TOPIRAMATE Tablets USP                                1
# BRILINTA                                              1
# SKLICE                                                1
# GAZYVA                                                1
# Name: Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5, dtype: int64

# %%
drop_cols = ['Name_of_Associated_Covered_Device_or_Medical_Supply1', 'Name_of_Associated_Covered_Device_or_Medical_Supply2', 'Name_of_Associated_Covered_Device_or_Medical_Supply3',
             'Name_of_Associated_Covered_Device_or_Medical_Supply4','Name_of_Associated_Covered_Device_or_Medical_Supply5']

# %%
cinci_dr2015.drop(columns=drop_cols, inplace = True)

# %%
cinci_dr2015.to_csv('./data/cincidr2015.csv', index=False)  #Gene told me about index=False to prevent getting an Unnamed:0 column in my csv/dataset (when I read it back in)

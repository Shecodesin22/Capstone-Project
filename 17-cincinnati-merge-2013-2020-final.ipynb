# %%
import pandas as pd
import seaborn as sns
import numpy as np
pd.set_option('display.max_rows', None, 'display.max_columns', 500)

# %%
# Import concatenated Cincinnati 2013 through 2015 file

# %%
cinci_1315 = pd.read_csv('./data/cinci1315.csv')
# Out:
# C:\Users\sarah\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3340: DtypeWarning: Columns (19,50,51,52,55,56,57,58,59) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_1315c = cinci_1315.convert_dtypes()

# %%
cinci_1315c['Date_of_Payment'] = pd.to_datetime(cinci_1315c['Date_of_Payment'])
cinci_1315c['Payment_Publication_Date'] = pd.to_datetime(cinci_1315c['Payment_Publication_Date'])

# %%
cinci_1315c.dtypes
# Out:
# Change_Type                                                                  string
# Covered_Recipient_Type                                                       string
# Physician_Profile_ID                                                          Int64
# Physician_First_Name                                                         string
# Physician_Middle_Name                                                        string
# Physician_Last_Name                                                          string
# Physician_Name_Suffix                                                        string
# Recipient_Primary_Business_Street_Address_Line1                              string
# Recipient_Primary_Business_Street_Address_Line2                              string
# Recipient_City                                                               string
# Recipient_State                                                              string
# ...

# %%
cinci_1315c.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Physician_Profile_ID  \
# 0   UNCHANGED  Covered Recipient Physician                109571
# 1   UNCHANGED  Covered Recipient Physician                109571
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0               EDWARD                     Y               CHANG
# 1               EDWARD                     Y               CHANG
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                  <NA>                              4803 MONTGOMERY RD
# 1                  <NA>                              4803 MONTGOMERY RD
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                         STE 120     CINCINNATI
# 1                                         STE 120     CINCINNATI
#
#   Recipient_State Recipient_Zip_Code Recipient_Country Physician_Primary_Type  \
# ...

# %%
cinci_1315c.shape
# Out:
# (128810, 60)

# %%
cinci_1315c['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].value_counts()
# Out:
# blank                                                                    31881
# levemir                                                                   5040
# xarelto                                                                   4540
# invokana                                                                  3095
# victoza                                                                   2862
# humira                                                                    2058
# brintellix                                                                1437
# myrbetriq                                                                 1406
# symbicort                                                                 1261
# humalog                                                                   1253
# linzess                                                                   1130
# tanzeum                                                                   1120
# ...

# %%
cinci_1315c['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].isna().sum()
# Out:
# 0

# %%
# Import concatenated Cincinnati 2016 through 2020 file

# %%
cinci_1620 = pd.read_csv('./data/cinci1620.csv')
# Out:
# C:\Users\sarah\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3340: DtypeWarning: Columns (18,19,62,67) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_1620.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Physician_Profile_ID  \
# 0   UNCHANGED  Covered Recipient Physician                389063
# 1   UNCHANGED  Covered Recipient Physician                389063
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0               Arthur                   NaN            Pancioli
# 1               Arthur                   NaN            Pancioli
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                   NaN                        8075 Muchmore Point Lane
# 1                   NaN                       8075 Muchmore Point Lance
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                             NaN     Cincinnati
# 1                                             NaN     Cincinnati
#
#   Recipient_State Recipient_Zip_Code Recipient_Country Physician_Primary_Type  \
# ...

# %%
cinci_1620c = cinci_1620.convert_dtypes()

# %%
cinci_1620c['Date_of_Payment'] = pd.to_datetime(cinci_1620c['Date_of_Payment'])
cinci_1620c['Payment_Publication_Date'] = pd.to_datetime(cinci_1620c['Payment_Publication_Date'])

# %%
cinci_1620c.dtypes
# Out:
# Change_Type                                                                  string
# Covered_Recipient_Type                                                       string
# Physician_Profile_ID                                                          Int64
# Physician_First_Name                                                         string
# Physician_Middle_Name                                                        string
# Physician_Last_Name                                                          string
# Physician_Name_Suffix                                                        string
# Recipient_Primary_Business_Street_Address_Line1                              string
# Recipient_Primary_Business_Street_Address_Line2                              string
# Recipient_City                                                               string
# Recipient_State                                                              string
# ...

# %%
cinci_1620c.shape
# Out:
# (236603, 70)

# %%
cinci_1620c['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'] = cinci_1620c['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].str.lower()

# %%
cinci_1620c['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].isna().sum()
# Out:
# 0

# %%
cinci_1620c['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].value_counts()
# Out:
# blank                                                                                              16566
# xarelto                                                                                             7191
# humira                                                                                              4167
# victoza                                                                                             3531
# entresto                                                                                            3475
# chantix                                                                                             3451
# farxiga                                                                                             3031
# ozempic                                                                                             2777
# jardiance                                                                                           2401
# ...

# %%
# Concatenate both files to create Cincinnati 2013 through 2020 file

# %%
cinci_1320 = pd.concat([cinci_1315c,cinci_1620c], ignore_index=True)

# %%
cinci_1320.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Physician_Profile_ID  \
# 0   UNCHANGED  Covered Recipient Physician                109571
# 1   UNCHANGED  Covered Recipient Physician                109571
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0               EDWARD                     Y               CHANG
# 1               EDWARD                     Y               CHANG
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                  <NA>                              4803 MONTGOMERY RD
# 1                  <NA>                              4803 MONTGOMERY RD
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                         STE 120     CINCINNATI
# 1                                         STE 120     CINCINNATI
#
#   Recipient_State Recipient_Zip_Code Recipient_Country Physician_Primary_Type  \
# ...

# %%
cinci_1320.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365413 entries, 0 to 365412
# Data columns (total 80 columns):
#  #   Column                                                             Non-Null Count   Dtype
# ---  ------                                                             --------------   -----
#  0   Change_Type                                                        365413 non-null  string
#  1   Covered_Recipient_Type                                             365413 non-null  string
#  2   Physician_Profile_ID                                               365413 non-null  Int64
#  3   Physician_First_Name                                               365413 non-null  string
#  4   Physician_Middle_Name                                              224550 non-null  string
#  5   Physician_Last_Name                                                365413 non-null  string
#  6   Physician_Name_Suffix                                              6659 non-null    string
# ...

# %%
cinci_1320.shape
# Out:
# (365413, 80)

# %%
cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'] = cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].fillna('Blank')

# %%
cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].value_counts()
# Out:
# blank                                                                                              48447
# xarelto                                                                                            11731
# victoza                                                                                             6393
# humira                                                                                              6225
# levemir                                                                                             5546
# invokana                                                                                            4876
# entresto                                                                                            3739
# farxiga                                                                                             3711
# chantix                                                                                             3451
# ...

# %%
cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].isna().sum()
# Out:
# 0

# %%
cinci_1320['xarelto'] = [1 if i == 'xarelto' else 0 for i in cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1']]
cinci_1320['xarelto'].value_counts()
# Out:
# 0    353682
# 1     11731
# Name: xarelto, dtype: int64

# %%
cinci_1320['victoza'] = [1 if i == 'victoza' else 0 for i in cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1']]
cinci_1320['victoza'].value_counts()
# Out:
# 0    359020
# 1      6393
# Name: victoza, dtype: int64

# %%
cinci_1320['humira'] = [1 if i == 'humira' else 0 for i in cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1']]
cinci_1320['humira'].value_counts()
# Out:
# 0    359188
# 1      6225
# Name: humira, dtype: int64

# %%
cinci_1320['levemir'] = [1 if i == 'levemir' else 0 for i in cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1']]
cinci_1320['levemir'].value_counts()
# Out:
# 0    359867
# 1      5546
# Name: levemir, dtype: int64

# %%
cinci_1320['invokana'] = [1 if i == 'invokana' else 0 for i in cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1']]
cinci_1320['invokana'].value_counts()
# Out:
# 0    360537
# 1      4876
# Name: invokana, dtype: int64

# %%
cinci_1320['entresto'] = [1 if i == 'entresto' else 0 for i in cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1']]
cinci_1320['entresto'].value_counts()
# Out:
# 0    361674
# 1      3739
# Name: entresto, dtype: int64

# %%
cinci_1320['farxiga'] = [1 if i == 'farxiga' else 0 for i in cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1']]
cinci_1320['farxiga'].value_counts()
# Out:
# 0    361702
# 1      3711
# Name: farxiga, dtype: int64

# %%
cinci_1320['chantix'] = [1 if i == 'chantix' else 0 for i in cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1']]
cinci_1320['chantix'].value_counts()
# Out:
# 0    361962
# 1      3451
# Name: chantix, dtype: int64

# %%
cinci_1320['myrbetriq'] = [1 if i == 'myrbetriq' else 0 for i in cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1']]
cinci_1320['myrbetriq'].value_counts()
# Out:
# 0    362015
# 1      3398
# Name: myrbetriq, dtype: int64

# %%
cinci_1320['toujeo'] = [1 if i == 'toujeo' else 0 for i in cinci_1320['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1']]
cinci_1320['toujeo'].value_counts()
# Out:
# 0    362195
# 1      3218
# Name: toujeo, dtype: int64

# %%
cinci_1320.to_csv('./data/cinci1320.csv', index=False)  #Gene told me about index=False to prevent getting an Unnamed:0 column in my csv/dataset (when I read it back in)

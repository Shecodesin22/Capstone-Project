# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cinci_1320 = pd.read_csv('./data/cinci1320.csv', index_col='Date_of_Payment', parse_dates=True).sort_index()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,18,19,47,48,49,50,51,52,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_1320.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     148974               RODNEY
# 2013-08-01                      58931                 PAUL
# 2013-08-01                     812462               ALFRED
# 2013-08-01                     108863                 MARK
# 2013-08-01                     195441           MANOJKUMAR
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                        NaN              VIVIAN
# 2013-08-01                     JOSEPH            FAVORITO
# ...

# %%
cinci_1320['Change_Type'].value_counts()
# Out:
# UNCHANGED    364686
# CHANGED         726
# ADD               1
# Name: Change_Type, dtype: int64

# %%
cinci_1320['invokana'].value_counts()
# Out:
# 0    360537
# 1      4876
# Name: invokana, dtype: int64

# %%
invokana = cinci_1320[(cinci_1320['invokana']==1) & (cinci_1320['Number_of_Payments_Included_in_Total_Amount']==1)].copy()

# %%
invokana.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-05        UNCHANGED  Covered Recipient Physician
# 2013-08-05        UNCHANGED  Covered Recipient Physician
# 2013-08-06        UNCHANGED  Covered Recipient Physician
# 2013-08-06        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                      46042              MICHAEL
# 2013-08-05                      24837               ROBERT
# 2013-08-05                     162829              MICHAEL
# 2013-08-06                     329818                 MARC
# 2013-08-06                     171600                BRUCE
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                        NaN              JUSTIN
# 2013-08-05                     JOSEPH              THALER
# ...

# %%
invokana['invokana'].value_counts()
# Out:
# 1    4876
# Name: invokana, dtype: int64

# %%
invokana['Change_Type'].value_counts()
# Out:
# UNCHANGED    4876
# Name: Change_Type, dtype: int64

# %%
invokana['invok_dollars'] = [k if ((i ==1) & (j ==1)) else 0 for i, j, k in zip(invokana['invokana'], invokana['Number_of_Payments_Included_in_Total_Amount'], invokana['Total_Amount_of_Payment_USDollars'])]

#Ben Peck helped me with this during office hours.  I was oh-so-close but not quite there!

# %%
invokana['invok_dollars'].sum()
# Out:
# 415760.88

# %%
invokana.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-05        UNCHANGED  Covered Recipient Physician
# 2013-08-05        UNCHANGED  Covered Recipient Physician
# 2013-08-06        UNCHANGED  Covered Recipient Physician
# 2013-08-06        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                      46042              MICHAEL
# 2013-08-05                      24837               ROBERT
# 2013-08-05                     162829              MICHAEL
# 2013-08-06                     329818                 MARC
# 2013-08-06                     171600                BRUCE
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                        NaN              JUSTIN
# 2013-08-05                     JOSEPH              THALER
# ...

# %%
drop_cols = ['Change_Type','Covered_Recipient_Type',
'Physician_First_Name',
'Physician_Middle_Name',
'Physician_Last_Name',
'Physician_Name_Suffix',
'Recipient_Primary_Business_Street_Address_Line1',
'Recipient_Primary_Business_Street_Address_Line2',
'Recipient_City',
'Recipient_State',
'Recipient_Zip_Code',
'Recipient_Country',
'Physician_Primary_Type',
'Physician_Specialty',
'Physician_License_State_code1',
'Physician_License_State_code2',
'Physician_License_State_code3',
'Physician_License_State_code4',
'Physician_License_State_code5',
'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
'Form_of_Payment_or_Transfer_of_Value',
'City_of_Travel',
'State_of_Travel',
'Country_of_Travel',
'Physician_Ownership_Indicator',
'Third_Party_Payment_Recipient_Indicator',
'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
'Charity_Indicator',
'Third_Party_Equals_Covered_Recipient_Indicator',
'Contextual_Information',
'Delay_in_Publication_Indicator',
'Dispute_Status_for_Publication',
'Related_Product_Indicator',
'Covered_or_Noncovered_Indicator_1',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Product_Category_or_Therapeutic_Area_1',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Associated_Drug_or_Biological_NDC_1',
'Covered_or_Noncovered_Indicator_2',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Product_Category_or_Therapeutic_Area_2',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Associated_Drug_or_Biological_NDC_2',
'Covered_or_Noncovered_Indicator_3',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Product_Category_or_Therapeutic_Area_3',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Associated_Drug_or_Biological_NDC_3',
'Covered_or_Noncovered_Indicator_4',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Product_Category_or_Therapeutic_Area_4',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Associated_Drug_or_Biological_NDC_4',
'Covered_or_Noncovered_Indicator_5',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Product_Category_or_Therapeutic_Area_5',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Associated_Drug_or_Biological_NDC_5', 
'Physician_Profile_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
'Total_Amount_of_Payment_USDollars','Number_of_Payments_Included_in_Total_Amount', 
'Nature_of_Payment_or_Transfer_of_Value', 'Record_ID', 
'Payment_Publication_Date', 'Program_Year',
'NDC_of_Associated_Covered_Drug_or_Biological1',
'NDC_of_Associated_Covered_Drug_or_Biological2',
'NDC_of_Associated_Covered_Drug_or_Biological3',
'NDC_of_Associated_Covered_Drug_or_Biological4',
'NDC_of_Associated_Covered_Drug_or_Biological5',
'Name_of_Associated_Covered_Device_or_Medical_Supply1',
'Name_of_Associated_Covered_Device_or_Medical_Supply2',
'Name_of_Associated_Covered_Device_or_Medical_Supply3',
'Name_of_Associated_Covered_Device_or_Medical_Supply4',
'Name_of_Associated_Covered_Device_or_Medical_Supply5',
'xarelto', 'farxiga', 'victoza', 'humira', 'levemir',
'entresto', 'chantix', 'myrbetriq', 'toujeo']

# %%
invokana.drop(columns = drop_cols, inplace = True)

# %%
invokana.head()
# Out:
#                  invokana  invok_dollars
# Date_of_Payment
# 2013-08-01              1           6.67
# 2013-08-05              1          11.20
# 2013-08-05              1        1500.00
# 2013-08-06              1          17.32
# 2013-08-06              1          11.86

# %% [markdown]
# Was reminded of the importance of checking data for outliers by this article, and modeled my filtering code below on this article:
# https://www.analyticsvidhya.com/blog/2021/08/holt-winters-method-for-time-series-analysis/

# %%
sns.boxplot(x = invokana['invok_dollars']);

# %%
invokana['z_score'] = [ ((i - invokana['invok_dollars'].mean())/invokana['invok_dollars'].std()) for i in invokana['invok_dollars']]

# %%
invokana.shape
# Out:
# (4876, 3)

# %% [markdown]
# Add chart to see data before dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(invokana.index, invokana['invok_dollars'], label='Before Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Invokana Drug - Before Outliers Dropped");

# %%
invokanab = invokana[(np.abs(invokana['z_score']) < 3)].copy()

# %%
invokanab.shape
# Out:
# (4709, 3)

# %% [markdown]
# Add chart to see data after dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(invokanab.index, invokanab['invok_dollars'], label='After Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Invokana Drug - After Outliers Dropped");

# %% [markdown]
# Drop Z-score before aggregating

# %%
invokanab.drop(columns='z_score', inplace=True)

# %%
invokana_monthly = invokanab.resample('m').sum()

# %%
invokana_monthly.head()
# Out:
#                  invokana  invok_dollars
# Date_of_Payment
# 2013-08-31             77        1820.43
# 2013-09-30             87        2295.95
# 2013-10-31            116        2604.18
# 2013-11-30            106        4221.13
# 2013-12-31             77        1275.38

# %%
invokana_monthly.sort_index()
# Out:
#                  invokana  invok_dollars
# Date_of_Payment
# 2013-08-31             77        1820.43
# 2013-09-30             87        2295.95
# 2013-10-31            116        2604.18
# 2013-11-30            106        4221.13
# 2013-12-31             77        1275.38
# ...                   ...            ...
# 2019-11-30             28        2158.66
# 2019-12-31              8        1394.63
# 2020-01-31             11         522.69
# 2020-02-29              8         362.19
# 2020-03-31              3         193.05
#
# [80 rows x 2 columns]

# %% [markdown]
# Look at some plots

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf

# %%
plot_acf(invokana_monthly['invok_dollars'], alpha=None, lags=24);

# %%
plot_pacf(invokana_monthly['invok_dollars'], alpha=None, lags=24);
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# Adding 1 to the weekly sales for each observation so that Holt_winters will work.

# %%
invokana_monthly['invok_dollars'] = [i+1 for i in invokana_monthly['invok_dollars']]

# %% [markdown]
# Set up Train and Test Sets using 2013 - 2020 Data

# %%
train = invokana_monthly.loc[:'2019-12-31']
train
# Out:
#                  invokana  invok_dollars
# Date_of_Payment
# 2013-08-31             77        1821.43
# 2013-09-30             87        2296.95
# 2013-10-31            116        2605.18
# 2013-11-30            106        4222.13
# 2013-12-31             77        1276.38
# ...                   ...            ...
# 2019-08-31             20         630.62
# 2019-09-30             25         274.79
# 2019-10-31             29         621.88
# 2019-11-30             28        2159.66
# 2019-12-31              8        1395.63
#
# [77 rows x 2 columns]

# %%
train['invok_dollars'].max()
# Out:
# 5479.06

# %%
train.describe()
# Out:
#          invokana  invok_dollars
# count   77.000000      77.000000
# mean    60.870130    1404.135065
# std     43.422451    1153.755223
# min      1.000000      12.500000
# 25%     24.000000     558.340000
# 50%     64.000000    1143.590000
# 75%     85.000000    1962.150000
# max    163.000000    5479.060000

# %%
train.index.freq = 'M'

# %%
train.shape
# Out:
# (77, 2)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 77 entries, 2013-08-31 to 2019-12-31
# Freq: M
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   invokana       77 non-null     int64
#  1   invok_dollars  77 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.8 KB

# %%
train.index
# Out:
# DatetimeIndex(['2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30',
#                '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31',
#                '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31',
#                '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30',
#                '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31',
#                '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31',
#                '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30',
#                '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31',
#                '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31',
#                '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30',
#                '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31',
#                '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31',
#                '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30',
# ...

# %%
test = invokana_monthly.loc['2020-01-01':]
test
# Out:
#                  invokana  invok_dollars
# Date_of_Payment
# 2020-01-31             11         523.69
# 2020-02-29              8         363.19
# 2020-03-31              3         194.05

# %%
test.describe()
# Out:
#         invokana  invok_dollars
# count   3.000000        3.00000
# mean    7.333333      360.31000
# std     4.041452      164.83887
# min     3.000000      194.05000
# 25%     5.500000      278.62000
# 50%     8.000000      363.19000
# 75%     9.500000      443.44000
# max    11.000000      523.69000

# %%
test.shape
# Out:
# (3, 2)

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')

plt.legend(loc='best')
plt.title("Monthly Payments for Invokana Drug");

# %% [markdown]
# Baseline - Simple Mean (Naive Model)

# %%
df_preds = test.copy(deep=True)
df_preds
# Out:
#                  invokana  invok_dollars
# Date_of_Payment
# 2020-01-31             11         523.69
# 2020-02-29              8         363.19
# 2020-03-31              3         194.05

# %%
df_preds['simple_mean'] = train['invok_dollars'].mean()
df_preds
# Out:
#                  invokana  invok_dollars  simple_mean
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065
# 2020-02-29              8         363.19  1404.135065
# 2020-03-31              3         194.05  1404.135065

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['simple_mean'], label="Baseline (Mean)")

plt.legend(loc='best')
plt.title("Baseline (Mean) Forecast for Monthly Invokana Payments");

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['simple_mean'], squared=False))
# Out:
# MAE for Simple Mean Baseline Model: 1043.8250649350655
# RMSE for Simple Mean Baseline Model: 1052.466310618394

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 4

# %%
df_preds['seasonal_4'] = train['invok_dollars'].shift(4, freq='M') 
df_preds.head(2)
# Out:
#                  invokana  invok_dollars  simple_mean  seasonal_4
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065      274.79
# 2020-02-29              8         363.19  1404.135065      621.88

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_4'], label='Seasonal 4')

plt.legend(loc='best')
plt.title("Seasonal 4 Forecast for Monthly Invokana Payments");

# %%
df_preds['seasonal_4'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_4'], squared=False))
# Out:
# MAE for Seasonal Baseline 4 Shift Model: 824.4
# RMSE for Seasonal Baseline 4 Shift Model: 1153.6166894019289

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 6

# %%
df_preds['seasonal_6'] = train['invok_dollars'].shift(6, freq='M') 
df_preds.head(2)
# Out:
#                  invokana  invok_dollars  simple_mean  seasonal_4  seasonal_6
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065      274.79      266.24
# 2020-02-29              8         363.19  1404.135065      621.88      630.62

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_6'], label='Seasonal 6')

plt.legend(loc='best')
plt.title("Seasonal 6 Forecast for Monthly Invokana Payments");

# %%
df_preds['seasonal_6'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_6'], squared=False))
# Out:
# MAE for Seasonal Baseline 6 Shift Model: 201.87333333333336
# RMSE for Seasonal Baseline 6 Shift Model: 219.33099416179195

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 12

# %%
df_preds['seasonal_12'] = train['invok_dollars'].shift(12, freq='M') 
df_preds.head(2)
# Out:
#                  invokana  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065      274.79      266.24
# 2020-02-29              8         363.19  1404.135065      621.88      630.62
#
#                  seasonal_12
# Date_of_Payment
# 2020-01-31             30.05
# 2020-02-29             23.08

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_12'], label='Seasonal 12')

plt.legend(loc='best')
plt.title("Seasonal 12 Forecast for Monthly Invokana Payments");

# %%
df_preds['seasonal_12'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_12'], squared=False))
# Out:
# MAE for Seasonal Baseline 12 Shift Model: 369.4433333333333
# RMSE for Seasonal Baseline 12 Shift Model: 380.6789715320071

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 18

# %%
df_preds['seasonal_18'] = train['invok_dollars'].shift(18, freq='M') 
df_preds.head(2)
# Out:
#                  invokana  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065      274.79      266.24
# 2020-02-29              8         363.19  1404.135065      621.88      630.62
#
#                  seasonal_12  seasonal_18
# Date_of_Payment
# 2020-01-31             30.05      1617.83
# 2020-02-29             23.08        12.50

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_18'], label='Seasonal 18')

plt.legend(loc='best')
plt.title("Seasonal 18 Forecast for Monthly Invokana Payments");

# %%
df_preds['seasonal_18'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_18'], squared=False))
# Out:
# MAE for Seasonal Baseline 18 Shift Model: 494.61999999999995
# RMSE for Seasonal Baseline 18 Shift Model: 663.7391949151915

# %% [markdown]
# Simple Exponential Smoothing Model

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing

# %%
ses = SimpleExpSmoothing(train['invok_dollars']).fit(smoothing_level=.5)

# %%
ses.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ...
# Dep. Variable:          invok_dollars   No. Observations:                   77
# Model:             SimpleExpSmoothing   SSE                       93762047.438
# Optimized:                       True   AIC                           1082.960
# Trend:                           None   BIC                           1087.647
# Seasonal:                        None   AICC                          1083.515
# Seasonal Periods:                None   Date:                 Tue, 15 Mar 2022
# Box-Cox:                        False   Time:                         18:38:55
# Box-Cox Coeff.:                  None
# ...
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.5000000                alpha                False
# ...

# %%
ses_forecast = ses.forecast(len(test))

# %%
df_preds['ses'] = ses_forecast

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['ses'], label='Simple Exponential Smoothing')

plt.legend(loc='best')
plt.title("Simple Exponential Smoothing for Invokana Monthly Payments");

# %%
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['ses'], squared=False))
# Out:
# MAE for Simple Exponential Smoothing Model: 998.1349606518843
# RMSE for Simple Exponential Smoothing Model: 1007.1682920324381

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 4.

# %%
hw_a4 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=4, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:            invok_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                       83001262.521
# Optimized:                         True   AIC                           1085.573
# Trend:                         Additive   BIC                           1104.324
# Seasonal:                      Additive   AICC                          1088.907
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:38:55
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1461015                alpha                 True
# ...

# %%
df_preds['hw_a4'] = hw_a4.forecast(len(test))
df_preds.head(2)
# Out:
#                  invokana  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065      274.79      266.24
# 2020-02-29              8         363.19  1404.135065      621.88      630.62
#
#                  seasonal_12  seasonal_18          ses       hw_a4
# Date_of_Payment
# 2020-01-31             30.05      1617.83  1358.444961  642.089256
# 2020-02-29             23.08        12.50  1358.444961  928.465771

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a4'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 4 for Monthly Payments for Invokana");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a4'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 384.57293145156314
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 429.9210097891508

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 6.

# %%
hw_a6 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=6, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:            invok_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                       87729685.202
# Optimized:                         True   AIC                           1093.839
# Trend:                         Additive   BIC                           1117.277
# Seasonal:                      Additive   AICC                          1098.714
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:38:56
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1108917                alpha                 True
# ...

# %%
df_preds['hw_a6'] = hw_a6.forecast(len(test))
df_preds.head(2)
# Out:
#                  invokana  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065      274.79      266.24
# 2020-02-29              8         363.19  1404.135065      621.88      630.62
#
#                  seasonal_12  seasonal_18          ses       hw_a4       hw_a6
# Date_of_Payment
# 2020-01-31             30.05      1617.83  1358.444961  642.089256  629.058468
# 2020-02-29             23.08        12.50  1358.444961  928.465771  813.902150

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a6'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 6 for Monthly Payments for Invokana");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a6'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 197.29251809861248
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 268.03319244424864

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 12.

# %%
hw_a12 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=12, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:            invok_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                       66316927.174
# Optimized:                         True   AIC                           1084.294
# Trend:                         Additive   BIC                           1121.794
# Seasonal:                      Additive   AICC                          1096.087
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:38:56
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0760234                alpha                 True
# ...

# %%
df_preds['hw_a12'] = hw_a12.forecast(len(test))
df_preds.head(2)
# Out:
#                  invokana  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065      274.79      266.24
# 2020-02-29              8         363.19  1404.135065      621.88      630.62
#
#                  seasonal_12  seasonal_18          ses       hw_a4  \
# Date_of_Payment
# 2020-01-31             30.05      1617.83  1358.444961  642.089256
# 2020-02-29             23.08        12.50  1358.444961  928.465771
#
#                       hw_a6       hw_a12
# Date_of_Payment
# 2020-01-31       629.058468  1332.059834
# 2020-02-29       813.902150  2462.414180

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a12'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 12 for Monthly Payments for Invokana");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a12'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 1137.4134942038102
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 1331.0236669885066

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 18.

# %%
hw_a18 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=18, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:            invok_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                       72604587.854
# Optimized:                         True   AIC                           1103.268
# Trend:                         Additive   BIC                           1154.832
# Seasonal:                      Additive   AICC                          1126.345
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:38:57
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0756857                alpha                 True
# ...

# %%
df_preds['hw_a18'] = hw_a18.forecast(len(test))
df_preds.head(2)
# Out:
#                  invokana  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065      274.79      266.24
# 2020-02-29              8         363.19  1404.135065      621.88      630.62
#
#                  seasonal_12  seasonal_18          ses       hw_a4  \
# Date_of_Payment
# 2020-01-31             30.05      1617.83  1358.444961  642.089256
# 2020-02-29             23.08        12.50  1358.444961  928.465771
#
#                       hw_a6       hw_a12      hw_a18
# Date_of_Payment
# 2020-01-31       629.058468  1332.059834  583.730055
# 2020-02-29       813.902150  2462.414180  852.040665

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a18'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 18 for Monthly Payments for Invokana");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a18'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 18 Model: 324.40363032805715
# RMSE for Holt-Winters Additive with Seasonality of 18 Model: 375.33424582033643

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 4.

# %%
hw_m4 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=4, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:            invok_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                       74200935.680
# Optimized:                         True   AIC                           1076.943
# Trend:                   Multiplicative   BIC                           1095.694
# Seasonal:                Multiplicative   AICC                          1080.276
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:38:57
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0757143                alpha                 True
# ...

# %%
df_preds['hw_m4'] = hw_m4.forecast(len(test))
df_preds.head(2)
# Out:
#                  invokana  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065      274.79      266.24
# 2020-02-29              8         363.19  1404.135065      621.88      630.62
#
#                  seasonal_12  seasonal_18          ses       hw_a4  \
# Date_of_Payment
# 2020-01-31             30.05      1617.83  1358.444961  642.089256
# 2020-02-29             23.08        12.50  1358.444961  928.465771
#
#                       hw_a6       hw_a12      hw_a18       hw_m4
# Date_of_Payment
# 2020-01-31       629.058468  1332.059834  583.730055  561.037185
# 2020-02-29       813.902150  2462.414180  852.040665  651.800152

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m4'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 4 Model for Invokana Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m4'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 4 Model: 249.35810326914725
# RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model: 296.0142848563568

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 6.

# %%
hw_m6 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=6, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:            invok_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                       76974329.700
# Optimized:                         True   AIC                           1083.769
# Trend:                   Multiplicative   BIC                           1107.207
# Seasonal:                Multiplicative   AICC                          1088.644
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:38:58
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0757143                alpha                 True
# ...

# %%
df_preds['hw_m6'] = hw_m6.forecast(len(test))
df_preds.head(2)
# Out:
#                  invokana  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065      274.79      266.24
# 2020-02-29              8         363.19  1404.135065      621.88      630.62
#
#                  seasonal_12  seasonal_18          ses       hw_a4  \
# Date_of_Payment
# 2020-01-31             30.05      1617.83  1358.444961  642.089256
# 2020-02-29             23.08        12.50  1358.444961  928.465771
#
#                       hw_a6       hw_a12      hw_a18       hw_m4       hw_m6
# Date_of_Payment
# 2020-01-31       629.058468  1332.059834  583.730055  561.037185  716.694065
# 2020-02-29       813.902150  2462.414180  852.040665  651.800152  807.241147

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m6'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 6 Model for Invokana Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m6'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 6 Model: 303.6074118043987
# RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model: 321.133603222625

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 12.

# %%
hw_m12 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=12, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:            invok_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                       94486829.557
# Optimized:                         True   AIC                           1111.553
# Trend:                   Multiplicative   BIC                           1149.054
# Seasonal:                Multiplicative   AICC                          1123.346
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:38:58
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0403571                alpha                 True
# ...

# %%
df_preds['hw_m12'] = hw_m12.forecast(len(test))
df_preds.head(2)
# Out:
#                  invokana  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065      274.79      266.24
# 2020-02-29              8         363.19  1404.135065      621.88      630.62
#
#                  seasonal_12  seasonal_18          ses       hw_a4  \
# Date_of_Payment
# 2020-01-31             30.05      1617.83  1358.444961  642.089256
# 2020-02-29             23.08        12.50  1358.444961  928.465771
#
#                       hw_a6       hw_a12      hw_a18       hw_m4       hw_m6  \
# Date_of_Payment
# 2020-01-31       629.058468  1332.059834  583.730055  561.037185  716.694065
# 2020-02-29       813.902150  2462.414180  852.040665  651.800152  807.241147
#
#                       hw_m12
# Date_of_Payment
# 2020-01-31       1847.753852
# 2020-02-29       2607.899274

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m12'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 12 Model for Invokana Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m12'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 12 Model: 1357.2469809273894
# RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model: 1532.4100229086125

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 18.

# %%
hw_m18 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=18, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:            invok_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                       77850617.313
# Optimized:                         True   AIC                           1108.640
# Trend:                   Multiplicative   BIC                           1160.204
# Seasonal:                Multiplicative   AICC                          1131.717
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:38:59
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0403571                alpha                 True
# ...

# %%
df_preds['hw_m18'] = hw_m18.forecast(len(test))
df_preds.head(2)
# Out:
#                  invokana  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             11         523.69  1404.135065      274.79      266.24
# 2020-02-29              8         363.19  1404.135065      621.88      630.62
#
#                  seasonal_12  seasonal_18          ses       hw_a4  \
# Date_of_Payment
# 2020-01-31             30.05      1617.83  1358.444961  642.089256
# 2020-02-29             23.08        12.50  1358.444961  928.465771
#
#                       hw_a6       hw_a12      hw_a18       hw_m4       hw_m6  \
# Date_of_Payment
# 2020-01-31       629.058468  1332.059834  583.730055  561.037185  716.694065
# 2020-02-29       813.902150  2462.414180  852.040665  651.800152  807.241147
#
#                       hw_m12      hw_m18
# Date_of_Payment
# 2020-01-31       1847.753852  968.340995
# 2020-02-29       2607.899274  840.676196

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m18'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 18 Model for Invokana Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m18'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 348.8060874196779
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 383.4724497462142

# %% [markdown]
# Try a SARIMA Model

# %%
from pmdarima.utils import tsdisplay

# %%
traina = train['invok_dollars']

# %%
tsdisplay(traina)
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\pmdarima\utils\visualization.py:220: FutureWarning: the 'unbiased'' keyword is deprecated, use 'adjusted' instead
#   res = tsaplots.plot_acf(

# %% [markdown]
# SARIMA Model with Seasonality of 4

# %%
import pmdarima as pmd
model_s4 = pmd.auto_arima(train['invok_dollars'], m=4, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[4] intercept   : AIC=inf, Time=0.26 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=1312.539, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=1299.615, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=1310.546, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=1298.467, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=1299.785, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=1301.360, Time=0.05 sec
#  ARIMA(2,1,0)(0,0,0)[4] intercept   : AIC=1289.562, Time=0.02 sec
#  ARIMA(2,1,0)(1,0,0)[4] intercept   : AIC=1290.979, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,1)[4] intercept   : AIC=1291.069, Time=0.02 sec
#  ARIMA(2,1,0)(1,0,1)[4] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(3,1,0)(0,0,0)[4] intercept   : AIC=1290.740, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[4] intercept   : AIC=inf, Time=0.11 sec
# ...

# %%
model_s4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   77
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -636.108
# Date:                Tue, 15 Mar 2022   AIC                           1276.216
# Time:                        18:39:02   BIC                           1280.877
# Sample:                             0   HQIC                          1278.079
#                                  - 77
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8736      0.087    -10.019      0.000      -1.045      -0.703
# sigma2      1.064e+06   1.81e+05      5.866      0.000    7.08e+05    1.42e+06
# ...
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):                31.05
# ...

# %%
preds_sar4 = model_s4.predict(test.shape[0])
preds_sar4
# Out:
# array([741.40041883, 741.40041883, 741.40041883])

# %%
df_preds['sarima4_auto'] = preds_sar4
df_preds['sarima4_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    741.400419
# 2020-02-29    741.400419
# Freq: M, Name: sarima4_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['invok_dollars'], label='Train')
plt.plot(test['invok_dollars'], label='Test')
plt.plot(df_preds['sarima4_auto'], label='SARIMA_4_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 4 Model for Invokana Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima4_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 4 Model: 381.09041882814086
# RMSE for SARIMA with Seasonality of 4 Model: 404.1589738241721

# %% [markdown]
# SARIMA Model with Seasonality of 6

# %%
model_s6 = pmd.auto_arima(train['invok_dollars'], m=6, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[6] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,1,0)(0,0,0)[6] intercept   : AIC=1312.539, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[6] intercept   : AIC=1300.355, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[6] intercept   : AIC=inf, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[6]             : AIC=1310.546, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[6] intercept   : AIC=1298.467, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,1)[6] intercept   : AIC=1300.381, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,1)[6] intercept   : AIC=1301.414, Time=0.10 sec
#  ARIMA(2,1,0)(0,0,0)[6] intercept   : AIC=1289.562, Time=0.02 sec
#  ARIMA(2,1,0)(1,0,0)[6] intercept   : AIC=1291.561, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,1)[6] intercept   : AIC=1291.561, Time=0.02 sec
#  ARIMA(2,1,0)(1,0,1)[6] intercept   : AIC=1293.250, Time=0.15 sec
#  ARIMA(3,1,0)(0,0,0)[6] intercept   : AIC=1290.740, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[6] intercept   : AIC=inf, Time=0.11 sec
# ...

# %%
model_s6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   77
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -636.108
# Date:                Tue, 15 Mar 2022   AIC                           1276.216
# Time:                        18:39:05   BIC                           1280.877
# Sample:                             0   HQIC                          1278.079
#                                  - 77
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8736      0.087    -10.019      0.000      -1.045      -0.703
# sigma2      1.064e+06   1.81e+05      5.866      0.000    7.08e+05    1.42e+06
# ...
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):                31.05
# ...

# %%
preds_sar6 = model_s6.predict(test.shape[0])
preds_sar6
# Out:
# array([741.40041883, 741.40041883, 741.40041883])

# %%
df_preds['sarima6_auto'] = preds_sar6
df_preds['sarima6_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    741.400419
# 2020-02-29    741.400419
# Freq: M, Name: sarima6_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['invok_dollars'], label='Train')
plt.plot(test['invok_dollars'], label='Test')
plt.plot(df_preds['sarima6_auto'], label='SARIMA_6_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 6 Model for Invokana Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima6_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 6 Model: 381.09041882814086
# RMSE for SARIMA with Seasonality of 6 Model: 404.1589738241721

# %% [markdown]
# Try a SARIMA Model with m = 12

# %%
model_s12 = pmd.auto_arima(train['invok_dollars'], m=12, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1312.539, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1298.878, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1310.546, Time=0.00 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1298.467, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=1299.395, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=1298.894, Time=0.22 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=1289.562, Time=0.02 sec
#  ARIMA(2,1,0)(1,0,0)[12] intercept   : AIC=1290.652, Time=0.04 sec
#  ARIMA(2,1,0)(0,0,1)[12] intercept   : AIC=1290.966, Time=0.04 sec
#  ARIMA(2,1,0)(1,0,1)[12] intercept   : AIC=1290.564, Time=0.20 sec
#  ARIMA(3,1,0)(0,0,0)[12] intercept   : AIC=1290.740, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.11 sec
# ...

# %%
model_s12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                                   y   No. Observations:                   77
# Model:             SARIMAX(0, 1, 1)x(2, 0, [], 12)   Log Likelihood                -631.564
# Date:                             Tue, 15 Mar 2022   AIC                           1271.127
# Time:                                     18:39:13   BIC                           1280.450
# Sample:                                          0   HQIC                          1274.853
#                                               - 77
# Covariance Type:                               opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8970      0.066    -13.686      0.000      -1.026      -0.769
# ...

# %%
preds_sar12 = model_s12.predict(test.shape[0])
preds_sar12
# Out:
# array([730.41362993, 314.13677613, 372.70268008])

# %%
df_preds['sarima12_auto'] = preds_sar12
df_preds['sarima12_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    730.413630
# 2020-02-29    314.136776
# Freq: M, Name: sarima12_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['invok_dollars'], label='Train')
plt.plot(test['invok_dollars'], label='Test')
plt.plot(df_preds['sarima12_auto'], label='SARIMA_12_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 12 Model for Invokana Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima12_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 12 Model: 144.80984462563643
# RMSE for SARIMA with Seasonality of 12 Model: 160.26816906060836

# %% [markdown]
# Try a SARIMA Model with m = 18

# %%
model_s18 = pmd.auto_arima(train['invok_dollars'], m=18, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[18] intercept   : AIC=inf, Time=0.84 sec
#  ARIMA(0,1,0)(0,0,0)[18] intercept   : AIC=1312.539, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[18] intercept   : AIC=1300.054, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,1)[18] intercept   : AIC=inf, Time=0.51 sec
#  ARIMA(0,1,0)(0,0,0)[18]             : AIC=1310.546, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[18] intercept   : AIC=1298.467, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,1)[18] intercept   : AIC=1300.065, Time=0.06 sec
#  ARIMA(1,1,0)(1,0,1)[18] intercept   : AIC=inf, Time=0.41 sec
#  ARIMA(2,1,0)(0,0,0)[18] intercept   : AIC=1289.562, Time=0.02 sec
#  ARIMA(2,1,0)(1,0,0)[18] intercept   : AIC=1290.475, Time=0.11 sec
#  ARIMA(2,1,0)(0,0,1)[18] intercept   : AIC=1290.462, Time=0.07 sec
#  ARIMA(2,1,0)(1,0,1)[18] intercept   : AIC=1292.460, Time=0.22 sec
#  ARIMA(3,1,0)(0,0,0)[18] intercept   : AIC=1290.740, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[18] intercept   : AIC=inf, Time=0.12 sec
# ...

# %%
model_s18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   77
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -636.108
# Date:                Tue, 15 Mar 2022   AIC                           1276.216
# Time:                        18:39:19   BIC                           1280.877
# Sample:                             0   HQIC                          1278.079
#                                  - 77
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8736      0.087    -10.019      0.000      -1.045      -0.703
# sigma2      1.064e+06   1.81e+05      5.866      0.000    7.08e+05    1.42e+06
# ...
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):                31.05
# ...

# %%
preds_sar18 = model_s18.predict(test.shape[0])
preds_sar18
# Out:
# array([741.40041883, 741.40041883, 741.40041883])

# %%
df_preds['sarima18_auto'] = preds_sar18
df_preds['sarima18_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    741.400419
# 2020-02-29    741.400419
# Freq: M, Name: sarima18_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['invok_dollars'], label='Train')
plt.plot(test['invok_dollars'], label='Test')
plt.plot(df_preds['sarima18_auto'], label='SARIMA_18_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 18 Model for Invokana Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 18 Model: 381.09041882814086
# RMSE for SARIMA with Seasonality of 18 Model: 404.1589738241721

# %%
print("Summary of Metrics for Monthly Invokana CMS Payments")
print("_________________________________________________")
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['simple_mean'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_4'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_6'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_12'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_18'], squared=False))
print("_________________________________________________")
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['ses'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m12'], squared=False))
print("_________________________________________________")
# Out:
# Summary of Metrics for Monthly Invokana CMS Payments
# _________________________________________________
# MAE for Simple Mean Baseline Model: 1043.8250649350655
# RMSE for Simple Mean Baseline Model: 1052.466310618394
# _________________________________________________
# MAE for Seasonal Baseline 4 Shift Model: 824.4
# RMSE for Seasonal Baseline 4 Shift Model: 1153.6166894019289
# _________________________________________________
# MAE for Seasonal Baseline 6 Shift Model: 201.87333333333336
# RMSE for Seasonal Baseline 6 Shift Model: 219.33099416179195
# _________________________________________________
# MAE for Seasonal Baseline 12 Shift Model: 369.4433333333333
# RMSE for Seasonal Baseline 12 Shift Model: 380.6789715320071
# _________________________________________________
# MAE for Seasonal Baseline 18 Shift Model: 494.61999999999995
# RMSE for Seasonal Baseline 18 Shift Model: 663.7391949151915
# _________________________________________________
# ...

# %%
print("Continued Summary of Metrics for Monthly Invokana CMS Payments")
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m18'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a12'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a18'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima4_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima6_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima12_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# Continued Summary of Metrics for Monthly Invokana CMS Payments
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 348.8060874196779
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 383.4724497462142
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 384.57293145156314
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 429.9210097891508
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 197.29251809861248
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 268.03319244424864
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 1137.4134942038102
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 1331.0236669885066
# _________________________________________________
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cinci_1320 = pd.read_csv('./data/cinci1320.csv', index_col='Date_of_Payment', parse_dates=True).sort_index()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,18,19,47,48,49,50,51,52,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_1320.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     148974               RODNEY
# 2013-08-01                      58931                 PAUL
# 2013-08-01                     812462               ALFRED
# 2013-08-01                     108863                 MARK
# 2013-08-01                     195441           MANOJKUMAR
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                        NaN              VIVIAN
# 2013-08-01                     JOSEPH            FAVORITO
# ...

# %%
cinci_1320['Change_Type'].value_counts()
# Out:
# UNCHANGED    364686
# CHANGED         726
# ADD               1
# Name: Change_Type, dtype: int64

# %%
cinci_1320['entresto'].value_counts()
# Out:
# 0    361674
# 1      3739
# Name: entresto, dtype: int64

# %%
entresto = cinci_1320[(cinci_1320['entresto']==1) & (cinci_1320['Number_of_Payments_Included_in_Total_Amount']==1)].copy()

# %%
entresto.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-10-10        UNCHANGED  Covered Recipient Physician
# 2013-10-11        UNCHANGED  Covered Recipient Physician
# 2013-10-11        UNCHANGED  Covered Recipient Physician
# 2013-10-11        UNCHANGED  Covered Recipient Physician
# 2013-10-11        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-10-10                     797979             KIMBERLY
# 2013-10-11                     797979             KIMBERLY
# 2013-10-11                     797979             KIMBERLY
# 2013-10-11                     797979             KIMBERLY
# 2013-10-11                     797979             KIMBERLY
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-10-10                          A              BAILEY
# 2013-10-11                          A              BAILEY
# ...

# %%
entresto['entresto'].value_counts()
# Out:
# 1    3739
# Name: entresto, dtype: int64

# %%
entresto['Change_Type'].value_counts()
# Out:
# UNCHANGED    3739
# Name: Change_Type, dtype: int64

# %%
entresto['entr_dollars'] = [k if ((i ==1) & (j ==1)) else 0 for i, j, k in zip(entresto['entresto'], entresto['Number_of_Payments_Included_in_Total_Amount'], entresto['Total_Amount_of_Payment_USDollars'])]

#Ben Peck helped me with this during office hours.  I was oh-so-close but not quite there!

# %%
entresto['entr_dollars'].sum()
# Out:
# 169227.83

# %%
entresto.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-10-10        UNCHANGED  Covered Recipient Physician
# 2013-10-11        UNCHANGED  Covered Recipient Physician
# 2013-10-11        UNCHANGED  Covered Recipient Physician
# 2013-10-11        UNCHANGED  Covered Recipient Physician
# 2013-10-11        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-10-10                     797979             KIMBERLY
# 2013-10-11                     797979             KIMBERLY
# 2013-10-11                     797979             KIMBERLY
# 2013-10-11                     797979             KIMBERLY
# 2013-10-11                     797979             KIMBERLY
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-10-10                          A              BAILEY
# 2013-10-11                          A              BAILEY
# ...

# %%
drop_cols = ['Change_Type','Covered_Recipient_Type',
'Physician_First_Name',
'Physician_Middle_Name',
'Physician_Last_Name',
'Physician_Name_Suffix',
'Recipient_Primary_Business_Street_Address_Line1',
'Recipient_Primary_Business_Street_Address_Line2',
'Recipient_City',
'Recipient_State',
'Recipient_Zip_Code',
'Recipient_Country',
'Physician_Primary_Type',
'Physician_Specialty',
'Physician_License_State_code1',
'Physician_License_State_code2',
'Physician_License_State_code3',
'Physician_License_State_code4',
'Physician_License_State_code5',
'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
'Form_of_Payment_or_Transfer_of_Value',
'City_of_Travel',
'State_of_Travel',
'Country_of_Travel',
'Physician_Ownership_Indicator',
'Third_Party_Payment_Recipient_Indicator',
'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
'Charity_Indicator',
'Third_Party_Equals_Covered_Recipient_Indicator',
'Contextual_Information',
'Delay_in_Publication_Indicator',
'Dispute_Status_for_Publication',
'Related_Product_Indicator',
'Covered_or_Noncovered_Indicator_1',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Product_Category_or_Therapeutic_Area_1',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Associated_Drug_or_Biological_NDC_1',
'Covered_or_Noncovered_Indicator_2',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Product_Category_or_Therapeutic_Area_2',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Associated_Drug_or_Biological_NDC_2',
'Covered_or_Noncovered_Indicator_3',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Product_Category_or_Therapeutic_Area_3',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Associated_Drug_or_Biological_NDC_3',
'Covered_or_Noncovered_Indicator_4',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Product_Category_or_Therapeutic_Area_4',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Associated_Drug_or_Biological_NDC_4',
'Covered_or_Noncovered_Indicator_5',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Product_Category_or_Therapeutic_Area_5',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Associated_Drug_or_Biological_NDC_5', 
'Physician_Profile_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
'Total_Amount_of_Payment_USDollars','Number_of_Payments_Included_in_Total_Amount', 
'Nature_of_Payment_or_Transfer_of_Value', 'Record_ID', 
'Payment_Publication_Date', 'Program_Year',
'NDC_of_Associated_Covered_Drug_or_Biological1',
'NDC_of_Associated_Covered_Drug_or_Biological2',
'NDC_of_Associated_Covered_Drug_or_Biological3',
'NDC_of_Associated_Covered_Drug_or_Biological4',
'NDC_of_Associated_Covered_Drug_or_Biological5',
'Name_of_Associated_Covered_Device_or_Medical_Supply1',
'Name_of_Associated_Covered_Device_or_Medical_Supply2',
'Name_of_Associated_Covered_Device_or_Medical_Supply3',
'Name_of_Associated_Covered_Device_or_Medical_Supply4',
'Name_of_Associated_Covered_Device_or_Medical_Supply5',
'xarelto', 'farxiga', 'victoza', 'humira', 'levemir',
'invokana', 'chantix', 'myrbetriq', 'toujeo']

# %%
entresto.drop(columns = drop_cols, inplace = True)

# %%
entresto.head()
# Out:
#                  entresto  entr_dollars
# Date_of_Payment
# 2013-10-10              1        789.00
# 2013-10-11              1        231.64
# 2013-10-11              1         27.00
# 2013-10-11              1        114.70
# 2013-10-11              1         57.32

# %% [markdown]
# Was reminded of the importance of checking data for outliers by this article, and modeled my filtering code below on this article:
# https://www.analyticsvidhya.com/blog/2021/08/holt-winters-method-for-time-series-analysis/

# %%
sns.boxplot(x = entresto['entr_dollars']);

# %%
entresto['z_score'] = [ ((i - entresto['entr_dollars'].mean())/entresto['entr_dollars'].std()) for i in entresto['entr_dollars']]

# %%
entresto.shape
# Out:
# (3739, 3)

# %% [markdown]
# Add chart to see data before dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(entresto.index, entresto['entr_dollars'], label='Before Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Entresto Drug - Before Outliers Dropped");

# %%
entrestob = entresto[(np.abs(entresto['z_score']) < 3)].copy()

# %%
entrestob.shape
# Out:
# (3699, 3)

# %% [markdown]
# Add chart to see data after dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(entrestob.index, entrestob['entr_dollars'], label='After Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Entresto Drug - After Outliers Dropped");

# %% [markdown]
# Drop Z-score before aggregating

# %%
entrestob.drop(columns='z_score', inplace=True)

# %%
entresto_monthly = entrestob.resample('m').sum()

# %%
entresto_monthly.head()
# Out:
#                  entresto  entr_dollars
# Date_of_Payment
# 2013-10-31              6       1277.46
# 2013-11-30              0          0.00
# 2013-12-31              0          0.00
# 2014-01-31              0          0.00
# 2014-02-28              0          0.00

# %%
entresto_monthly.sort_index()
# Out:
#                  entresto  entr_dollars
# Date_of_Payment
# 2013-10-31              6       1277.46
# 2013-11-30              0          0.00
# 2013-12-31              0          0.00
# 2014-01-31              0          0.00
# 2014-02-28              0          0.00
# ...                   ...           ...
# 2020-08-31             15        177.98
# 2020-09-30             24        336.06
# 2020-10-31             20        296.87
# 2020-11-30             11        149.65
# 2020-12-31             16        236.89
#
# [87 rows x 2 columns]

# %% [markdown]
# Look at some plots

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf

# %%
plot_acf(entresto_monthly['entr_dollars'], alpha=None, lags=24);

# %%
plot_pacf(entresto_monthly['entr_dollars'], alpha=None, lags=24);
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# Adding 1 to the weekly sales for each observation so that Holt_winters will work.

# %%
entresto_monthly['entr_dollars'] = [i+1 for i in entresto_monthly['entr_dollars']]

# %% [markdown]
# Set up Train and Test Sets using 2013 - 2020 Data

# %%
train = entresto_monthly.loc[:'2019-12-31']
train
# Out:
#                  entresto  entr_dollars
# Date_of_Payment
# 2013-10-31              6       1278.46
# 2013-11-30              0          1.00
# 2013-12-31              0          1.00
# 2014-01-31              0          1.00
# 2014-02-28              0          1.00
# ...                   ...           ...
# 2019-08-31             58        972.96
# 2019-09-30             80       2018.31
# 2019-10-31             88       2394.66
# 2019-11-30             71        996.87
# 2019-12-31             38       1017.10
#
# [75 rows x 2 columns]

# %%
train['entr_dollars'].max()
# Out:
# 3067.23

# %%
train.describe()
# Out:
#          entresto  entr_dollars
# count   75.000000     75.000000
# mean    45.826667    991.745467
# std     32.616267    798.885643
# min      0.000000      1.000000
# 25%      1.000000     60.290000
# 50%     57.000000   1051.650000
# 75%     72.000000   1426.875000
# max    106.000000   3067.230000

# %%
train.index.freq = 'M'

# %%
train.shape
# Out:
# (75, 2)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 75 entries, 2013-10-31 to 2019-12-31
# Freq: M
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   entresto      75 non-null     int64
#  1   entr_dollars  75 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.8 KB

# %%
train.index
# Out:
# DatetimeIndex(['2013-10-31', '2013-11-30', '2013-12-31', '2014-01-31',
#                '2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31',
#                '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30',
#                '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31',
#                '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31',
#                '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30',
#                '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31',
#                '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31',
#                '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30',
#                '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31',
#                '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31',
#                '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30',
#                '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31',
# ...

# %%
test = entresto_monthly.loc['2020-01-01':]
test
# Out:
#                  entresto  entr_dollars
# Date_of_Payment
# 2020-01-31             61        995.55
# 2020-02-29             50       1460.36
# 2020-03-31             29        445.91
# 2020-04-30              0          1.00
# 2020-05-31              0          1.00
# 2020-06-30             20        268.05
# 2020-07-31             16        235.60
# 2020-08-31             15        178.98
# 2020-09-30             24        337.06
# 2020-10-31             20        297.87
# 2020-11-30             11        150.65
# 2020-12-31             16        237.89

# %%
test.describe()
# Out:
#         entresto  entr_dollars
# count  12.000000     12.000000
# mean   21.833333    384.160000
# std    18.029437    425.620088
# min     0.000000      1.000000
# 25%    14.000000    171.897500
# 50%    18.000000    252.970000
# 75%    25.250000    364.272500
# max    61.000000   1460.360000

# %%
test.shape
# Out:
# (12, 2)

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')

plt.legend(loc='best')
plt.title("Monthly Payments for Entresto Drug");

# %% [markdown]
# Baseline - Simple Mean (Naive Model)

# %%
df_preds = test.copy(deep=True)
df_preds
# Out:
#                  entresto  entr_dollars
# Date_of_Payment
# 2020-01-31             61        995.55
# 2020-02-29             50       1460.36
# 2020-03-31             29        445.91
# 2020-04-30              0          1.00
# 2020-05-31              0          1.00
# 2020-06-30             20        268.05
# 2020-07-31             16        235.60
# 2020-08-31             15        178.98
# 2020-09-30             24        337.06
# 2020-10-31             20        297.87
# 2020-11-30             11        150.65
# 2020-12-31             16        237.89

# %%
df_preds['simple_mean'] = train['entr_dollars'].mean()
df_preds
# Out:
#                  entresto  entr_dollars  simple_mean
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467
# 2020-02-29             50       1460.36   991.745467
# 2020-03-31             29        445.91   991.745467
# 2020-04-30              0          1.00   991.745467
# 2020-05-31              0          1.00   991.745467
# 2020-06-30             20        268.05   991.745467
# 2020-07-31             16        235.60   991.745467
# 2020-08-31             15        178.98   991.745467
# 2020-09-30             24        337.06   991.745467
# 2020-10-31             20        297.87   991.745467
# 2020-11-30             11        150.65   991.745467
# 2020-12-31             16        237.89   991.745467

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['simple_mean'], label="Baseline (Mean)")

plt.legend(loc='best')
plt.title("Baseline (Mean) Forecast for Monthly Entresto Payments");

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['simple_mean'], squared=False))
# Out:
# MAE for Simple Mean Baseline Model: 686.3219777777776
# RMSE for Simple Mean Baseline Model: 731.5849371202346

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 4

# %%
df_preds['seasonal_4'] = train['entr_dollars'].shift(4, freq='M') 
df_preds.head(2)
# Out:
#                  entresto  entr_dollars  simple_mean  seasonal_4
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467     2018.31
# 2020-02-29             50       1460.36   991.745467     2394.66

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_4'], label='Seasonal 4')

plt.legend(loc='best')
plt.title("Seasonal 4 Forecast for Monthly Entresto Payments");

# %%
df_preds['seasonal_4'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['seasonal_4'], squared=False))
# Out:
# MAE for Seasonal Baseline 4 Shift Model: 435.93499999999995
# RMSE for Seasonal Baseline 4 Shift Model: 554.9764782703257

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 6

# %%
df_preds['seasonal_6'] = train['entr_dollars'].shift(6, freq='M') 
df_preds.head(2)
# Out:
#                  entresto  entr_dollars  simple_mean  seasonal_4  seasonal_6
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467     2018.31     1298.70
# 2020-02-29             50       1460.36   991.745467     2394.66      972.96

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_6'], label='Seasonal 6')

plt.legend(loc='best')
plt.title("Seasonal 6 Forecast for Monthly Entresto Payments");

# %%
df_preds['seasonal_6'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['seasonal_6'], squared=False))
# Out:
# MAE for Seasonal Baseline 6 Shift Model: 661.6316666666667
# RMSE for Seasonal Baseline 6 Shift Model: 933.3410350723898

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 12

# %%
df_preds['seasonal_12'] = train['entr_dollars'].shift(12, freq='M') 
df_preds.head(2)
# Out:
#                  entresto  entr_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467     2018.31     1298.70
# 2020-02-29             50       1460.36   991.745467     2394.66      972.96
#
#                  seasonal_12
# Date_of_Payment
# 2020-01-31           1051.65
# 2020-02-29           1317.65

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_12'], label='Seasonal 12')

plt.legend(loc='best')
plt.title("Seasonal 12 Forecast for Monthly Entresto Payments");

# %%
df_preds['seasonal_12'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['seasonal_12'], squared=False))
# Out:
# MAE for Seasonal Baseline 12 Shift Model: 1085.7916666666667
# RMSE for Seasonal Baseline 12 Shift Model: 1263.4942758939064

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 18

# %%
df_preds['seasonal_18'] = train['entr_dollars'].shift(18, freq='M') 
df_preds.head(2)
# Out:
#                  entresto  entr_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467     2018.31     1298.70
# 2020-02-29             50       1460.36   991.745467     2394.66      972.96
#
#                  seasonal_12  seasonal_18
# Date_of_Payment
# 2020-01-31           1051.65       681.21
# 2020-02-29           1317.65      1280.32

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_18'], label='Seasonal 18')

plt.legend(loc='best')
plt.title("Seasonal 18 Forecast for Monthly Entresto Payments");

# %%
df_preds['seasonal_18'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['seasonal_18'], squared=False))
# Out:
# MAE for Seasonal Baseline 18 Shift Model: 1059.6183333333333
# RMSE for Seasonal Baseline 18 Shift Model: 1174.8947106514127

# %% [markdown]
# Simple Exponential Smoothing Model

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing

# %%
ses = SimpleExpSmoothing(train['entr_dollars']).fit(smoothing_level=.5)

# %%
ses.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ...
# Dep. Variable:           entr_dollars   No. Observations:                   75
# Model:             SimpleExpSmoothing   SSE                       33458839.985
# Optimized:                       True   AIC                            979.625
# Trend:                           None   BIC                            984.260
# Seasonal:                        None   AICC                           980.197
# Seasonal Periods:                None   Date:                 Tue, 15 Mar 2022
# Box-Cox:                        False   Time:                         19:18:55
# Box-Cox Coeff.:                  None
# ...
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.5000000                alpha                False
# ...

# %%
ses_forecast = ses.forecast(len(test))

# %%
df_preds['ses'] = ses_forecast

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['ses'], label='Simple Exponential Smoothing')

plt.legend(loc='best')
plt.title("Simple Exponential Smoothing for Entresto Monthly Payments");

# %%
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['ses'], squared=False))
# Out:
# MAE for Simple Exponential Smoothing Model: 908.5275910213963
# RMSE for Simple Exponential Smoothing Model: 965.230211974885

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 4.

# %%
hw_a4 = ExponentialSmoothing(
    train['entr_dollars'],
    seasonal_periods=4, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             entr_dollars   No. Observations:                   75
# Model:             ExponentialSmoothing   SSE                       29175545.353
# Optimized:                         True   AIC                            981.351
# Trend:                         Additive   BIC                            999.891
# Seasonal:                      Additive   AICC                           984.789
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:18:55
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2382228                alpha                 True
# ...

# %%
df_preds['hw_a4'] = hw_a4.forecast(len(test))
df_preds.head(2)
# Out:
#                  entresto  entr_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467     2018.31     1298.70
# 2020-02-29             50       1460.36   991.745467     2394.66      972.96
#
#                  seasonal_12  seasonal_18          ses        hw_a4
# Date_of_Payment
# 2020-01-31           1051.65       681.21  1259.153109  1420.109312
# 2020-02-29           1317.65      1280.32  1259.153109  1753.615350

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a4'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 4 for Monthly Payments for Entresto");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_a4'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 1203.7152384752858
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 1280.8702987136062

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 6.

# %%
hw_a6 = ExponentialSmoothing(
    train['entr_dollars'],
    seasonal_periods=6, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             entr_dollars   No. Observations:                   75
# Model:             ExponentialSmoothing   SSE                       28726535.879
# Optimized:                         True   AIC                            984.188
# Trend:                         Additive   BIC                           1007.363
# Seasonal:                      Additive   AICC                           989.221
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:18:56
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2402052                alpha                 True
# ...

# %%
df_preds['hw_a6'] = hw_a6.forecast(len(test))
df_preds.head(2)
# Out:
#                  entresto  entr_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467     2018.31     1298.70
# 2020-02-29             50       1460.36   991.745467     2394.66      972.96
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1051.65       681.21  1259.153109  1420.109312
# 2020-02-29           1317.65      1280.32  1259.153109  1753.615350
#
#                        hw_a6
# Date_of_Payment
# 2020-01-31       1192.041436
# 2020-02-29       1612.238051

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a6'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 6 for Monthly Payments for Entresto");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_a6'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 1180.4900994904597
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 1275.590362968361

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 12.

# %%
hw_a12 = ExponentialSmoothing(
    train['entr_dollars'],
    seasonal_periods=12, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             entr_dollars   No. Observations:                   75
# Model:             ExponentialSmoothing   SSE                       25964626.100
# Optimized:                         True   AIC                            988.607
# Trend:                         Additive   BIC                           1025.687
# Seasonal:                      Additive   AICC                          1000.821
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:18:57
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2581357                alpha                 True
# ...

# %%
df_preds['hw_a12'] = hw_a12.forecast(len(test))
df_preds.head(2)
# Out:
#                  entresto  entr_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467     2018.31     1298.70
# 2020-02-29             50       1460.36   991.745467     2394.66      972.96
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1051.65       681.21  1259.153109  1420.109312
# 2020-02-29           1317.65      1280.32  1259.153109  1753.615350
#
#                        hw_a6       hw_a12
# Date_of_Payment
# 2020-01-31       1192.041436  1041.650002
# 2020-02-29       1612.238051  1679.175575

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a12'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 12 for Monthly Payments for Entresto");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_a12'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 1158.8323447571493
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 1269.4351707834019

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 18.

# %%
hw_a18 = ExponentialSmoothing(
    train['entr_dollars'],
    seasonal_periods=18, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             entr_dollars   No. Observations:                   75
# Model:             ExponentialSmoothing   SSE                       23555639.282
# Optimized:                         True   AIC                            993.304
# Trend:                         Additive   BIC                           1044.289
# Seasonal:                      Additive   AICC                          1017.304
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:18:58
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2548308                alpha                 True
# ...

# %%
df_preds['hw_a18'] = hw_a18.forecast(len(test))
df_preds.head(2)
# Out:
#                  entresto  entr_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467     2018.31     1298.70
# 2020-02-29             50       1460.36   991.745467     2394.66      972.96
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1051.65       681.21  1259.153109  1420.109312
# 2020-02-29           1317.65      1280.32  1259.153109  1753.615350
#
#                        hw_a6       hw_a12       hw_a18
# Date_of_Payment
# 2020-01-31       1192.041436  1041.650002  1228.074599
# 2020-02-29       1612.238051  1679.175575  1928.431767

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a18'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 18 for Monthly Payments for Entresto");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_a18'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 18 Model: 1417.9254671014453
# RMSE for Holt-Winters Additive with Seasonality of 18 Model: 1550.1775447682826

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 4.

# %%
hw_m4 = ExponentialSmoothing(
    train['entr_dollars'],
    seasonal_periods=4, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             entr_dollars   No. Observations:                   75
# Model:             ExponentialSmoothing   SSE                       31478679.504
# Optimized:                         True   AIC                            987.050
# Trend:                   Multiplicative   BIC                           1005.590
# Seasonal:                Multiplicative   AICC                           990.487
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:18:58
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0403571                alpha                 True
# ...

# %%
df_preds['hw_m4'] = hw_m4.forecast(len(test))
df_preds.head(2)
# Out:
#                  entresto  entr_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467     2018.31     1298.70
# 2020-02-29             50       1460.36   991.745467     2394.66      972.96
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1051.65       681.21  1259.153109  1420.109312
# 2020-02-29           1317.65      1280.32  1259.153109  1753.615350
#
#                        hw_a6       hw_a12       hw_a18        hw_m4
# Date_of_Payment
# 2020-01-31       1192.041436  1041.650002  1228.074599  1142.634993
# 2020-02-29       1612.238051  1679.175575  1928.431767  1530.031113

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m4'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 4 Model for Entresto Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_m4'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 4 Model: 870.8530141611867
# RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model: 956.7228084260053

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 6.

# %%
hw_m6 = ExponentialSmoothing(
    train['entr_dollars'],
    seasonal_periods=6, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             entr_dollars   No. Observations:                   75
# Model:             ExponentialSmoothing   SSE                       37625009.787
# Optimized:                         True   AIC                           1004.427
# Trend:                   Multiplicative   BIC                           1027.602
# Seasonal:                Multiplicative   AICC                          1009.459
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:18:59
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0403571                alpha                 True
# ...

# %%
df_preds['hw_m6'] = hw_m6.forecast(len(test))
df_preds.head(2)
# Out:
#                  entresto  entr_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467     2018.31     1298.70
# 2020-02-29             50       1460.36   991.745467     2394.66      972.96
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1051.65       681.21  1259.153109  1420.109312
# 2020-02-29           1317.65      1280.32  1259.153109  1753.615350
#
#                        hw_a6       hw_a12       hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31       1192.041436  1041.650002  1228.074599  1142.634993
# 2020-02-29       1612.238051  1679.175575  1928.431767  1530.031113
#
#                        hw_m6
# Date_of_Payment
# 2020-01-31        922.873281
# 2020-02-29       1723.491728

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m6'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 6 Model for Entresto Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_m6'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 6 Model: 1012.2529417942075
# RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model: 1137.92000012864

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 12.

# %%
hw_m12 = ExponentialSmoothing(
    train['entr_dollars'],
    seasonal_periods=12, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             entr_dollars   No. Observations:                   75
# Model:             ExponentialSmoothing   SSE                       59027886.917
# Optimized:                         True   AIC                           1050.202
# Trend:                   Multiplicative   BIC                           1087.282
# Seasonal:                Multiplicative   AICC                          1062.417
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:19:00
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0757143                alpha                 True
# ...

# %%
df_preds['hw_m12'] = hw_m12.forecast(len(test))
df_preds.head(2)
# Out:
#                  entresto  entr_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467     2018.31     1298.70
# 2020-02-29             50       1460.36   991.745467     2394.66      972.96
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1051.65       681.21  1259.153109  1420.109312
# 2020-02-29           1317.65      1280.32  1259.153109  1753.615350
#
#                        hw_a6       hw_a12       hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31       1192.041436  1041.650002  1228.074599  1142.634993
# 2020-02-29       1612.238051  1679.175575  1928.431767  1530.031113
#
#                        hw_m6      hw_m12
# Date_of_Payment
# 2020-01-31        922.873281  340.541847
# 2020-02-29       1723.491728  691.374024

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m12'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 12 Model for Entresto Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_m12'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 12 Model: 431.7044902450345
# RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model: 522.821995119008

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 18.

# %%
hw_m18 = ExponentialSmoothing(
    train['entr_dollars'],
    seasonal_periods=18, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                                                                  ExponentialSmoothing Model Results
# ...
# Dep. Variable:             entr_dollars   No. Observations:                                                                                                                                      75
# Model:             ExponentialSmoothing   SSE                 850301385313558931276622495957215216926215361743981788434171702062164911997086561806398652896356174295875890097870285999678947328.000
# Optimized:                         True   AIC                                                                                                                                             21985.537
# Trend:                   Multiplicative   BIC                                                                                                                                             22036.522
# ...

# %%
df_preds['hw_m18'] = hw_m18.forecast(len(test))
df_preds.head(2)
# Out:
#                  entresto  entr_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31             61        995.55   991.745467     2018.31     1298.70
# 2020-02-29             50       1460.36   991.745467     2394.66      972.96
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1051.65       681.21  1259.153109  1420.109312
# 2020-02-29           1317.65      1280.32  1259.153109  1753.615350
#
#                        hw_a6       hw_a12       hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31       1192.041436  1041.650002  1228.074599  1142.634993
# 2020-02-29       1612.238051  1679.175575  1928.431767  1530.031113
#
#                        hw_m6      hw_m12        hw_m18
# Date_of_Payment
# 2020-01-31        922.873281  340.541847  1.514229e+65
# 2020-02-29       1723.491728  691.374024  3.646318e+66

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['entr_dollars'], label='Train')
plt.plot(test.index, test['entr_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m18'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 18 Model for Entresto Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_m18'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 1.102715834235578e+75
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 3.4063346876294866e+75

# %% [markdown]
# Try a SARIMA Model

# %%
from pmdarima.utils import tsdisplay

# %%
traina = train['entr_dollars']

# %%
tsdisplay(traina)
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\pmdarima\utils\visualization.py:220: FutureWarning: the 'unbiased'' keyword is deprecated, use 'adjusted' instead
#   res = tsaplots.plot_acf(

# %% [markdown]
# SARIMA Model with Seasonality of 4

# %%
import pmdarima as pmd
model_s4 = pmd.auto_arima(train['entr_dollars'], m=4, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[4] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=1209.997, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=1181.846, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=1169.205, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=1207.998, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[4] intercept   : AIC=1170.507, Time=0.05 sec
#  ARIMA(0,1,1)(1,0,1)[4] intercept   : AIC=1171.044, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,2)[4] intercept   : AIC=1170.767, Time=0.13 sec
#  ARIMA(0,1,1)(1,0,0)[4] intercept   : AIC=1170.201, Time=0.09 sec
#  ARIMA(0,1,1)(1,0,2)[4] intercept   : AIC=1173.320, Time=0.27 sec
#  ARIMA(0,1,0)(0,0,1)[4] intercept   : AIC=1208.217, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,1)[4] intercept   : AIC=1170.748, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,1)[4] intercept   : AIC=1170.857, Time=0.13 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=1181.137, Time=0.02 sec
# ...

# %%
model_s4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                                 y   No. Observations:                   75
# Model:             SARIMAX(0, 1, 1)x(0, 0, 1, 4)   Log Likelihood                -581.033
# Date:                           Tue, 15 Mar 2022   AIC                           1168.065
# Time:                                   19:19:04   BIC                           1174.977
# Sample:                                        0   HQIC                          1170.822
#                                             - 75
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7936      0.073    -10.858      0.000      -0.937      -0.650
# ma.S.L4        0.2492      0.124      2.013      0.044       0.007       0.492
# ...

# %%
preds_sar4 = model_s4.predict(test.shape[0])
preds_sar4
# Out:
# array([1614.31296111, 1657.61771451, 1345.692719  , 1383.13558251,
#        1451.96374981, 1451.96374981, 1451.96374981, 1451.96374981,
#        1451.96374981, 1451.96374981, 1451.96374981, 1451.96374981])

# %%
df_preds['sarima4_auto'] = preds_sar4
df_preds['sarima4_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    1614.312961
# 2020-02-29    1657.617715
# Freq: M, Name: sarima4_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['entr_dollars'], label='Train')
plt.plot(test['entr_dollars'], label='Test')
plt.plot(df_preds['sarima4_auto'], label='SARIMA_4_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 4 Model for Entresto Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['sarima4_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 4 Model: 1083.8790813002595
# RMSE for SARIMA with Seasonality of 4 Model: 1136.185034347672

# %% [markdown]
# SARIMA Model with Seasonality of 6

# %%
model_s6 = pmd.auto_arima(train['entr_dollars'], m=6, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[6] intercept   : AIC=inf, Time=0.30 sec
#  ARIMA(0,1,0)(0,0,0)[6] intercept   : AIC=1209.997, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[6] intercept   : AIC=1183.044, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[6] intercept   : AIC=1172.507, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[6]             : AIC=1207.998, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[6] intercept   : AIC=1170.507, Time=0.05 sec
#  ARIMA(0,1,1)(1,0,0)[6] intercept   : AIC=1172.507, Time=0.09 sec
#  ARIMA(0,1,1)(1,0,1)[6] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[6] intercept   : AIC=1170.902, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[6] intercept   : AIC=1171.011, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[6] intercept   : AIC=1181.044, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[6] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[6]             : AIC=1169.376, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,0)[6]             : AIC=1171.371, Time=0.04 sec
# ...

# %%
model_s6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   75
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -582.688
# Date:                Tue, 15 Mar 2022   AIC                           1169.376
# Time:                        19:19:06   BIC                           1173.984
# Sample:                             0   HQIC                          1171.214
#                                  - 75
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7575      0.063    -12.095      0.000      -0.880      -0.635
# sigma2      4.043e+05   5.27e+04      7.673      0.000    3.01e+05    5.08e+05
# ...
# Ljung-Box (L1) (Q):                   0.87   Jarque-Bera (JB):                18.27
# ...

# %%
preds_sar6 = model_s6.predict(test.shape[0])
preds_sar6
# Out:
# array([1413.50842063, 1413.50842063, 1413.50842063, 1413.50842063,
#        1413.50842063, 1413.50842063, 1413.50842063, 1413.50842063,
#        1413.50842063, 1413.50842063, 1413.50842063, 1413.50842063])

# %%
df_preds['sarima6_auto'] = preds_sar6
df_preds['sarima6_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    1413.508421
# 2020-02-29    1413.508421
# Freq: M, Name: sarima6_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['entr_dollars'], label='Train')
plt.plot(test['entr_dollars'], label='Test')
plt.plot(df_preds['sarima6_auto'], label='SARIMA_6_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 6 Model for Entresto Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['sarima6_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 6 Model: 1037.1570171905578
# RMSE for SARIMA with Seasonality of 6 Model: 1107.074790593392

# %% [markdown]
# Try a SARIMA Model with m = 12

# %%
model_s12 = pmd.auto_arima(train['entr_dollars'], m=12, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.42 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1209.997, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1181.794, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1171.773, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1207.998, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=1170.507, Time=0.05 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=1171.806, Time=0.16 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=inf, Time=0.15 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=1170.902, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=1171.011, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1181.044, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=1169.376, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,0)[12]             : AIC=1170.881, Time=0.06 sec
# ...

# %%
model_s12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   75
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -582.688
# Date:                Tue, 15 Mar 2022   AIC                           1169.376
# Time:                        19:19:08   BIC                           1173.984
# Sample:                             0   HQIC                          1171.214
#                                  - 75
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7575      0.063    -12.095      0.000      -0.880      -0.635
# sigma2      4.043e+05   5.27e+04      7.673      0.000    3.01e+05    5.08e+05
# ...
# Ljung-Box (L1) (Q):                   0.87   Jarque-Bera (JB):                18.27
# ...

# %%
preds_sar12 = model_s12.predict(test.shape[0])
preds_sar12
# Out:
# array([1413.50842063, 1413.50842063, 1413.50842063, 1413.50842063,
#        1413.50842063, 1413.50842063, 1413.50842063, 1413.50842063,
#        1413.50842063, 1413.50842063, 1413.50842063, 1413.50842063])

# %%
df_preds['sarima12_auto'] = preds_sar12
df_preds['sarima12_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    1413.508421
# 2020-02-29    1413.508421
# Freq: M, Name: sarima12_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['entr_dollars'], label='Train')
plt.plot(test['entr_dollars'], label='Test')
plt.plot(df_preds['sarima12_auto'], label='SARIMA_12_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 12 Model for Entresto Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['sarima12_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 12 Model: 1037.1570171905578
# RMSE for SARIMA with Seasonality of 12 Model: 1107.074790593392

# %% [markdown]
# Try a SARIMA Model with m = 18

# %%
model_s18 = pmd.auto_arima(train['entr_dollars'], m=18, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[18] intercept   : AIC=inf, Time=0.77 sec
#  ARIMA(0,1,0)(0,0,0)[18] intercept   : AIC=1209.997, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[18] intercept   : AIC=1182.545, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,1)[18] intercept   : AIC=1172.498, Time=0.34 sec
#  ARIMA(0,1,0)(0,0,0)[18]             : AIC=1207.998, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[18] intercept   : AIC=1170.507, Time=0.05 sec
#  ARIMA(0,1,1)(1,0,0)[18] intercept   : AIC=1172.496, Time=0.31 sec
#  ARIMA(0,1,1)(1,0,1)[18] intercept   : AIC=inf, Time=0.56 sec
#  ARIMA(1,1,1)(0,0,0)[18] intercept   : AIC=1170.902, Time=0.07 sec
#  ARIMA(0,1,2)(0,0,0)[18] intercept   : AIC=1171.011, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[18] intercept   : AIC=1181.044, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[18] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(0,1,1)(0,0,0)[18]             : AIC=1169.376, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,0)[18]             : AIC=1171.319, Time=0.14 sec
# ...

# %%
model_s18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   75
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -582.688
# Date:                Tue, 15 Mar 2022   AIC                           1169.376
# Time:                        19:19:12   BIC                           1173.984
# Sample:                             0   HQIC                          1171.214
#                                  - 75
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7575      0.063    -12.095      0.000      -0.880      -0.635
# sigma2      4.043e+05   5.27e+04      7.673      0.000    3.01e+05    5.08e+05
# ...
# Ljung-Box (L1) (Q):                   0.87   Jarque-Bera (JB):                18.27
# ...

# %%
preds_sar18 = model_s18.predict(test.shape[0])
preds_sar18
# Out:
# array([1413.50842063, 1413.50842063, 1413.50842063, 1413.50842063,
#        1413.50842063, 1413.50842063, 1413.50842063, 1413.50842063,
#        1413.50842063, 1413.50842063, 1413.50842063, 1413.50842063])

# %%
df_preds['sarima18_auto'] = preds_sar18
df_preds['sarima18_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    1413.508421
# 2020-02-29    1413.508421
# Freq: M, Name: sarima18_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['entr_dollars'], label='Train')
plt.plot(test['entr_dollars'], label='Test')
plt.plot(df_preds['sarima18_auto'], label='SARIMA_18_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 18 Model for Entresto Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 18 Model: 1037.1570171905578
# RMSE for SARIMA with Seasonality of 18 Model: 1107.074790593392

# %%
print("Summary of Metrics for Monthly Entresto CMS Payments")
print("_________________________________________________")
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['simple_mean'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['seasonal_4'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['seasonal_6'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['seasonal_12'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['seasonal_18'], squared=False))
print("_________________________________________________")
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['ses'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_m4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_m6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_m12'], squared=False))
print("_________________________________________________")
# Out:
# Summary of Metrics for Monthly Entresto CMS Payments
# _________________________________________________
# MAE for Simple Mean Baseline Model: 686.3219777777776
# RMSE for Simple Mean Baseline Model: 731.5849371202346
# _________________________________________________
# MAE for Seasonal Baseline 4 Shift Model: 435.93499999999995
# RMSE for Seasonal Baseline 4 Shift Model: 554.9764782703257
# _________________________________________________
# MAE for Seasonal Baseline 6 Shift Model: 661.6316666666667
# RMSE for Seasonal Baseline 6 Shift Model: 933.3410350723898
# _________________________________________________
# MAE for Seasonal Baseline 12 Shift Model: 1085.7916666666667
# RMSE for Seasonal Baseline 12 Shift Model: 1263.4942758939064
# _________________________________________________
# MAE for Seasonal Baseline 18 Shift Model: 1059.6183333333333
# RMSE for Seasonal Baseline 18 Shift Model: 1174.8947106514127
# _________________________________________________
# ...

# %%
print("Continued Summary of Metrics for Monthly Entresto CMS Payments")
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_m18'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_a4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_a6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_a12'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['hw_a18'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['sarima4_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['sarima6_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['sarima12_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['entr_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['entr_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# Continued Summary of Metrics for Monthly Entresto CMS Payments
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 1.102715834235578e+75
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 3.4063346876294866e+75
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 1203.7152384752858
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 1280.8702987136062
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 1180.4900994904597
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 1275.590362968361
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 1158.8323447571493
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 1269.4351707834019
# _________________________________________________
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cinci_1320 = pd.read_csv('./data/cinci1320.csv', index_col='Date_of_Payment', parse_dates=True).sort_index()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,18,19,47,48,49,50,51,52,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_1320.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     148974               RODNEY
# 2013-08-01                      58931                 PAUL
# 2013-08-01                     812462               ALFRED
# 2013-08-01                     108863                 MARK
# 2013-08-01                     195441           MANOJKUMAR
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                        NaN              VIVIAN
# 2013-08-01                     JOSEPH            FAVORITO
# ...

# %%
cinci_1320['Change_Type'].value_counts()
# Out:
# UNCHANGED    364686
# CHANGED         726
# ADD               1
# Name: Change_Type, dtype: int64

# %%
cinci_1320['myrbetriq'].value_counts()
# Out:
# 0    362015
# 1      3398
# Name: myrbetriq, dtype: int64

# %%
myrbetriq = cinci_1320[(cinci_1320['myrbetriq']==1) & (cinci_1320['Number_of_Payments_Included_in_Total_Amount']==1)].copy()

# %%
myrbetriq.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-02        UNCHANGED  Covered Recipient Physician
# 2013-08-02        UNCHANGED  Covered Recipient Physician
# 2013-08-06        UNCHANGED  Covered Recipient Physician
# 2013-08-06        UNCHANGED  Covered Recipient Physician
# 2013-08-06        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-02                     475055                JAMES
# 2013-08-02                     238858                 MARK
# 2013-08-06                     308204                 ERIC
# 2013-08-06                     358689                 DIRK
# 2013-08-06                     341692              REBECCA
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-02                        NaN           WHITESIDE
# 2013-08-02                        NaN            DELWORTH
# ...

# %%
myrbetriq['myrbetriq'].value_counts()
# Out:
# 1    3398
# Name: myrbetriq, dtype: int64

# %%
myrbetriq['Change_Type'].value_counts()
# Out:
# UNCHANGED    3398
# Name: Change_Type, dtype: int64

# %%
myrbetriq['myrb_dollars'] = [k if ((i ==1) & (j ==1)) else 0 for i, j, k in zip(myrbetriq['myrbetriq'], myrbetriq['Number_of_Payments_Included_in_Total_Amount'], myrbetriq['Total_Amount_of_Payment_USDollars'])]

#Ben Peck helped me with this during office hours.  I was oh-so-close but not quite there!

# %%
myrbetriq['myrb_dollars'].sum()
# Out:
# 87438.68

# %%
myrbetriq.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-02        UNCHANGED  Covered Recipient Physician
# 2013-08-02        UNCHANGED  Covered Recipient Physician
# 2013-08-06        UNCHANGED  Covered Recipient Physician
# 2013-08-06        UNCHANGED  Covered Recipient Physician
# 2013-08-06        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-02                     475055                JAMES
# 2013-08-02                     238858                 MARK
# 2013-08-06                     308204                 ERIC
# 2013-08-06                     358689                 DIRK
# 2013-08-06                     341692              REBECCA
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-02                        NaN           WHITESIDE
# 2013-08-02                        NaN            DELWORTH
# ...

# %%
drop_cols = ['Change_Type','Covered_Recipient_Type',
'Physician_First_Name',
'Physician_Middle_Name',
'Physician_Last_Name',
'Physician_Name_Suffix',
'Recipient_Primary_Business_Street_Address_Line1',
'Recipient_Primary_Business_Street_Address_Line2',
'Recipient_City',
'Recipient_State',
'Recipient_Zip_Code',
'Recipient_Country',
'Physician_Primary_Type',
'Physician_Specialty',
'Physician_License_State_code1',
'Physician_License_State_code2',
'Physician_License_State_code3',
'Physician_License_State_code4',
'Physician_License_State_code5',
'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
'Form_of_Payment_or_Transfer_of_Value',
'City_of_Travel',
'State_of_Travel',
'Country_of_Travel',
'Physician_Ownership_Indicator',
'Third_Party_Payment_Recipient_Indicator',
'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
'Charity_Indicator',
'Third_Party_Equals_Covered_Recipient_Indicator',
'Contextual_Information',
'Delay_in_Publication_Indicator',
'Dispute_Status_for_Publication',
'Related_Product_Indicator',
'Covered_or_Noncovered_Indicator_1',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Product_Category_or_Therapeutic_Area_1',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Associated_Drug_or_Biological_NDC_1',
'Covered_or_Noncovered_Indicator_2',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Product_Category_or_Therapeutic_Area_2',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Associated_Drug_or_Biological_NDC_2',
'Covered_or_Noncovered_Indicator_3',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Product_Category_or_Therapeutic_Area_3',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Associated_Drug_or_Biological_NDC_3',
'Covered_or_Noncovered_Indicator_4',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Product_Category_or_Therapeutic_Area_4',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Associated_Drug_or_Biological_NDC_4',
'Covered_or_Noncovered_Indicator_5',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Product_Category_or_Therapeutic_Area_5',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Associated_Drug_or_Biological_NDC_5', 
'Physician_Profile_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
'Total_Amount_of_Payment_USDollars','Number_of_Payments_Included_in_Total_Amount', 
'Nature_of_Payment_or_Transfer_of_Value', 'Record_ID', 
'Payment_Publication_Date', 'Program_Year',
'NDC_of_Associated_Covered_Drug_or_Biological1',
'NDC_of_Associated_Covered_Drug_or_Biological2',
'NDC_of_Associated_Covered_Drug_or_Biological3',
'NDC_of_Associated_Covered_Drug_or_Biological4',
'NDC_of_Associated_Covered_Drug_or_Biological5',
'Name_of_Associated_Covered_Device_or_Medical_Supply1',
'Name_of_Associated_Covered_Device_or_Medical_Supply2',
'Name_of_Associated_Covered_Device_or_Medical_Supply3',
'Name_of_Associated_Covered_Device_or_Medical_Supply4',
'Name_of_Associated_Covered_Device_or_Medical_Supply5',
'xarelto', 'farxiga', 'victoza', 'humira', 'levemir',
'entresto', 'chantix', 'invokana', 'toujeo']

# %%
myrbetriq.drop(columns = drop_cols, inplace = True)

# %%
myrbetriq.head()
# Out:
#                  myrbetriq  myrb_dollars
# Date_of_Payment
# 2013-08-02               1         10.48
# 2013-08-02               1         10.94
# 2013-08-06               1         16.25
# 2013-08-06               1         16.25
# 2013-08-06               1         16.25

# %% [markdown]
# Was reminded of the importance of checking data for outliers by this article, and modeled my filtering code below on this article:
# https://www.analyticsvidhya.com/blog/2021/08/holt-winters-method-for-time-series-analysis/

# %%
sns.boxplot(x = myrbetriq['myrb_dollars']);

# %%
myrbetriq['z_score'] = [ ((i - myrbetriq['myrb_dollars'].mean())/myrbetriq['myrb_dollars'].std()) for i in myrbetriq['myrb_dollars']]

# %%
myrbetriq.shape
# Out:
# (3398, 3)

# %% [markdown]
# Add chart to see data before dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(myrbetriq.index, myrbetriq['myrb_dollars'], label='Before Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Myrbetriq Drug - Before Outliers Dropped");

# %%
myrbetriqb = myrbetriq[(np.abs(myrbetriq['z_score']) < 3)].copy()

# %%
myrbetriqb.shape
# Out:
# (3378, 3)

# %% [markdown]
# Add chart to see data after dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(myrbetriqb.index, myrbetriqb['myrb_dollars'], label='After Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Myrbetriq Drug - After Outliers Dropped");

# %% [markdown]
# Drop Z-score before aggregating

# %%
myrbetriqb.drop(columns='z_score', inplace=True)

# %%
myrbetriq_monthly = myrbetriqb.resample('m').sum()

# %%
myrbetriq_monthly.head()
# Out:
#                  myrbetriq  myrb_dollars
# Date_of_Payment
# 2013-08-31              41        598.15
# 2013-09-30              42        722.05
# 2013-10-31              42       2103.12
# 2013-11-30              46       1409.08
# 2013-12-31              41        568.65

# %%
myrbetriq_monthly.sort_index()
# Out:
#                  myrbetriq  myrb_dollars
# Date_of_Payment
# 2013-08-31              41        598.15
# 2013-09-30              42        722.05
# 2013-10-31              42       2103.12
# 2013-11-30              46       1409.08
# 2013-12-31              41        568.65
# ...                    ...           ...
# 2020-08-31              20        326.98
# 2020-09-30               9        141.90
# 2020-10-31              17        248.05
# 2020-11-30              29        495.67
# 2020-12-31              18        300.22
#
# [89 rows x 2 columns]

# %% [markdown]
# Look at some plots

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf

# %%
plot_acf(myrbetriq_monthly['myrb_dollars'], alpha=None, lags=24);

# %%
plot_pacf(myrbetriq_monthly['myrb_dollars'], alpha=None, lags=24);
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# Adding 1 to the weekly sales for each observation so that Holt_winters will work.

# %%
myrbetriq_monthly['myrb_dollars'] = [i+1 for i in myrbetriq_monthly['myrb_dollars']]

# %% [markdown]
# Set up Train and Test Sets using 2013 - 2020 Data

# %%
train = myrbetriq_monthly.loc[:'2019-12-31']
train
# Out:
#                  myrbetriq  myrb_dollars
# Date_of_Payment
# 2013-08-31              41        599.15
# 2013-09-30              42        723.05
# 2013-10-31              42       2104.12
# 2013-11-30              46       1410.08
# 2013-12-31              41        569.65
# ...                    ...           ...
# 2019-08-31               8        129.46
# 2019-09-30              16        224.60
# 2019-10-31              22        316.52
# 2019-11-30              26        338.67
# 2019-12-31              20        315.41
#
# [77 rows x 2 columns]

# %%
train['myrb_dollars'].max()
# Out:
# 2441.83

# %%
train.describe()
# Out:
#        myrbetriq  myrb_dollars
# count  77.000000     77.000000
# mean   41.363636    672.000000
# std    19.426589    444.675502
# min     8.000000    124.570000
# 25%    29.000000    365.310000
# 50%    39.000000    568.500000
# 75%    54.000000    827.310000
# max    87.000000   2441.830000

# %%
train.index.freq = 'M'

# %%
train.shape
# Out:
# (77, 2)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 77 entries, 2013-08-31 to 2019-12-31
# Freq: M
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   myrbetriq     77 non-null     int64
#  1   myrb_dollars  77 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.8 KB

# %%
train.index
# Out:
# DatetimeIndex(['2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30',
#                '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31',
#                '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31',
#                '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30',
#                '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31',
#                '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31',
#                '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30',
#                '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31',
#                '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31',
#                '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30',
#                '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31',
#                '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31',
#                '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30',
# ...

# %%
test = myrbetriq_monthly.loc['2020-01-01':]
test
# Out:
#                  myrbetriq  myrb_dollars
# Date_of_Payment
# 2020-01-31              30        428.77
# 2020-02-29              39        646.74
# 2020-03-31              13        208.01
# 2020-04-30               0          1.00
# 2020-05-31               3         66.30
# 2020-06-30               3         44.74
# 2020-07-31              12        175.80
# 2020-08-31              20        327.98
# 2020-09-30               9        142.90
# 2020-10-31              17        249.05
# 2020-11-30              29        496.67
# 2020-12-31              18        301.22

# %%
test.describe()
# Out:
#        myrbetriq  myrb_dollars
# count  12.000000     12.000000
# mean   16.083333    257.431667
# std    11.995896    194.204090
# min     0.000000      1.000000
# 25%     7.500000    123.750000
# 50%    15.000000    228.530000
# 75%    22.250000    353.177500
# max    39.000000    646.740000

# %%
test.shape
# Out:
# (12, 2)

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')

plt.legend(loc='best')
plt.title("Monthly Payments for Myrbetriq Drug");

# %% [markdown]
# Baseline - Simple Mean (Naive Model)

# %%
df_preds = test.copy(deep=True)
df_preds
# Out:
#                  myrbetriq  myrb_dollars
# Date_of_Payment
# 2020-01-31              30        428.77
# 2020-02-29              39        646.74
# 2020-03-31              13        208.01
# 2020-04-30               0          1.00
# 2020-05-31               3         66.30
# 2020-06-30               3         44.74
# 2020-07-31              12        175.80
# 2020-08-31              20        327.98
# 2020-09-30               9        142.90
# 2020-10-31              17        249.05
# 2020-11-30              29        496.67
# 2020-12-31              18        301.22

# %%
df_preds['simple_mean'] = train['myrb_dollars'].mean()
df_preds
# Out:
#                  myrbetriq  myrb_dollars  simple_mean
# Date_of_Payment
# 2020-01-31              30        428.77        672.0
# 2020-02-29              39        646.74        672.0
# 2020-03-31              13        208.01        672.0
# 2020-04-30               0          1.00        672.0
# 2020-05-31               3         66.30        672.0
# 2020-06-30               3         44.74        672.0
# 2020-07-31              12        175.80        672.0
# 2020-08-31              20        327.98        672.0
# 2020-09-30               9        142.90        672.0
# 2020-10-31              17        249.05        672.0
# 2020-11-30              29        496.67        672.0
# 2020-12-31              18        301.22        672.0

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['simple_mean'], label="Baseline (Mean)")

plt.legend(loc='best')
plt.title("Baseline (Mean) Forecast for Monthly Myrbetriq Payments");

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['simple_mean'], squared=False))
# Out:
# MAE for Simple Mean Baseline Model: 414.5683333333332
# RMSE for Simple Mean Baseline Model: 454.3558029782385

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 4

# %%
df_preds['seasonal_4'] = train['myrb_dollars'].shift(4, freq='M') 
df_preds.head(2)
# Out:
#                  myrbetriq  myrb_dollars  simple_mean  seasonal_4
# Date_of_Payment
# 2020-01-31              30        428.77        672.0      224.60
# 2020-02-29              39        646.74        672.0      316.52

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_4'], label='Seasonal 4')

plt.legend(loc='best')
plt.title("Seasonal 4 Forecast for Monthly Myrbetriq Payments");

# %%
df_preds['seasonal_4'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['seasonal_4'], squared=False))
# Out:
# MAE for Seasonal Baseline 4 Shift Model: 232.01
# RMSE for Seasonal Baseline 4 Shift Model: 263.2158633770642

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 6

# %%
df_preds['seasonal_6'] = train['myrb_dollars'].shift(6, freq='M') 
df_preds.head(2)
# Out:
#                  myrbetriq  myrb_dollars  simple_mean  seasonal_4  seasonal_6
# Date_of_Payment
# 2020-01-31              30        428.77        672.0      224.60      208.57
# 2020-02-29              39        646.74        672.0      316.52      129.46

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_6'], label='Seasonal 6')

plt.legend(loc='best')
plt.title("Seasonal 6 Forecast for Monthly Myrbetriq Payments");

# %%
df_preds['seasonal_6'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['seasonal_6'], squared=False))
# Out:
# MAE for Seasonal Baseline 6 Shift Model: 275.5208333333333
# RMSE for Seasonal Baseline 6 Shift Model: 305.73406375748624

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 12

# %%
df_preds['seasonal_12'] = train['myrb_dollars'].shift(12, freq='M') 
df_preds.head(2)
# Out:
#                  myrbetriq  myrb_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31              30        428.77        672.0      224.60      208.57
# 2020-02-29              39        646.74        672.0      316.52      129.46
#
#                  seasonal_12
# Date_of_Payment
# 2020-01-31            455.79
# 2020-02-29            298.72

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_12'], label='Seasonal 12')

plt.legend(loc='best')
plt.title("Seasonal 12 Forecast for Monthly Myrbetriq Payments");

# %%
df_preds['seasonal_12'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['seasonal_12'], squared=False))
# Out:
# MAE for Seasonal Baseline 12 Shift Model: 202.92499999999995
# RMSE for Seasonal Baseline 12 Shift Model: 290.3480380508882

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 18

# %%
df_preds['seasonal_18'] = train['myrb_dollars'].shift(18, freq='M') 
df_preds.head(2)
# Out:
#                  myrbetriq  myrb_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31              30        428.77        672.0      224.60      208.57
# 2020-02-29              39        646.74        672.0      316.52      129.46
#
#                  seasonal_12  seasonal_18
# Date_of_Payment
# 2020-01-31            455.79       188.18
# 2020-02-29            298.72       295.23

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_18'], label='Seasonal 18')

plt.legend(loc='best')
plt.title("Seasonal 18 Forecast for Monthly Myrbetriq Payments");

# %%
df_preds['seasonal_18'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['seasonal_18'], squared=False))
# Out:
# MAE for Seasonal Baseline 18 Shift Model: 245.44083333333333
# RMSE for Seasonal Baseline 18 Shift Model: 273.34645792168834

# %% [markdown]
# Simple Exponential Smoothing Model

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing

# %%
ses = SimpleExpSmoothing(train['myrb_dollars']).fit(smoothing_level=.5)

# %%
ses.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ...
# Dep. Variable:           myrb_dollars   No. Observations:                   77
# Model:             SimpleExpSmoothing   SSE                       13429021.021
# Optimized:                       True   AIC                            933.322
# Trend:                           None   BIC                            938.010
# Seasonal:                        None   AICC                           933.878
# Seasonal Periods:                None   Date:                 Tue, 15 Mar 2022
# Box-Cox:                        False   Time:                         20:10:07
# Box-Cox Coeff.:                  None
# ...
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.5000000                alpha                False
# ...

# %%
ses_forecast = ses.forecast(len(test))

# %%
df_preds['ses'] = ses_forecast

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['ses'], label='Simple Exponential Smoothing')

plt.legend(loc='best')
plt.title("Simple Exponential Smoothing for Myrbetriq Monthly Payments");

# %%
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['ses'], squared=False))
# Out:
# MAE for Simple Exponential Smoothing Model: 162.29112767930846
# RMSE for Simple Exponential Smoothing Model: 192.9785196426869

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 4.

# %%
hw_a4 = ExponentialSmoothing(
    train['myrb_dollars'],
    seasonal_periods=4, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             myrb_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                       12172539.847
# Optimized:                         True   AIC                            937.758
# Trend:                         Additive   BIC                            956.509
# Seasonal:                      Additive   AICC                           941.092
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         20:10:08
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0356789                alpha                 True
# ...

# %%
df_preds['hw_a4'] = hw_a4.forecast(len(test))
df_preds.head(2)
# Out:
#                  myrbetriq  myrb_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31              30        428.77        672.0      224.60      208.57
# 2020-02-29              39        646.74        672.0      316.52      129.46
#
#                  seasonal_12  seasonal_18         ses       hw_a4
# Date_of_Payment
# 2020-01-31            455.79       188.18  309.088383  311.452984
# 2020-02-29            298.72       295.23  309.088383  290.750809

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a4'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 4 for Monthly Payments for Myrbetriq");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_a4'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 167.59072670298886
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 194.649233729855

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 6.

# %%
hw_a6 = ExponentialSmoothing(
    train['myrb_dollars'],
    seasonal_periods=6, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             myrb_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                       12134577.834
# Optimized:                         True   AIC                            941.518
# Trend:                         Additive   BIC                            964.956
# Seasonal:                      Additive   AICC                           946.393
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         20:10:08
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2792230                alpha                 True
# ...

# %%
df_preds['hw_a6'] = hw_a6.forecast(len(test))
df_preds.head(2)
# Out:
#                  myrbetriq  myrb_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31              30        428.77        672.0      224.60      208.57
# 2020-02-29              39        646.74        672.0      316.52      129.46
#
#                  seasonal_12  seasonal_18         ses       hw_a4       hw_a6
# Date_of_Payment
# 2020-01-31            455.79       188.18  309.088383  311.452984  152.929337
# 2020-02-29            298.72       295.23  309.088383  290.750809  174.279039

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a6'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 6 for Monthly Payments for Myrbetriq");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_a6'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 217.85106407623059
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 253.66839230338448

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 12.

# %%
hw_a12 = ExponentialSmoothing(
    train['myrb_dollars'],
    seasonal_periods=12, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             myrb_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                        9998959.232
# Optimized:                         True   AIC                            938.612
# Trend:                         Additive   BIC                            976.113
# Seasonal:                      Additive   AICC                           950.405
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         20:10:09
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0700281                alpha                 True
# ...

# %%
df_preds['hw_a12'] = hw_a12.forecast(len(test))
df_preds.head(2)
# Out:
#                  myrbetriq  myrb_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31              30        428.77        672.0      224.60      208.57
# 2020-02-29              39        646.74        672.0      316.52      129.46
#
#                  seasonal_12  seasonal_18         ses       hw_a4       hw_a6  \
# Date_of_Payment
# 2020-01-31            455.79       188.18  309.088383  311.452984  152.929337
# 2020-02-29            298.72       295.23  309.088383  290.750809  174.279039
#
#                      hw_a12
# Date_of_Payment
# 2020-01-31       198.483680
# 2020-02-29       106.284136

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a12'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 12 for Monthly Payments for Myrbetriq");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_a12'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 234.8334586246389
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 267.5262566446579

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 18.

# %%
hw_a18 = ExponentialSmoothing(
    train['myrb_dollars'],
    seasonal_periods=18, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             myrb_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                        8198708.792
# Optimized:                         True   AIC                            935.327
# Trend:                         Additive   BIC                            986.891
# Seasonal:                      Additive   AICC                           958.404
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         20:10:09
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0744886                alpha                 True
# ...

# %%
df_preds['hw_a18'] = hw_a18.forecast(len(test))
df_preds.head(2)
# Out:
#                  myrbetriq  myrb_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31              30        428.77        672.0      224.60      208.57
# 2020-02-29              39        646.74        672.0      316.52      129.46
#
#                  seasonal_12  seasonal_18         ses       hw_a4       hw_a6  \
# Date_of_Payment
# 2020-01-31            455.79       188.18  309.088383  311.452984  152.929337
# 2020-02-29            298.72       295.23  309.088383  290.750809  174.279039
#
#                      hw_a12     hw_a18
# Date_of_Payment
# 2020-01-31       198.483680  88.450881
# 2020-02-29       106.284136  94.827368

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a18'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 18 for Monthly Payments for Myrbetriq");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_a18'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 18 Model: 267.8461631543061
# RMSE for Holt-Winters Additive with Seasonality of 18 Model: 323.03297722587183

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 4.

# %%
hw_m4 = ExponentialSmoothing(
    train['myrb_dollars'],
    seasonal_periods=4, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err

# %%
hw_m4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             myrb_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                       11785361.026
# Optimized:                         True   AIC                            935.269
# Trend:                   Multiplicative   BIC                            954.020
# Seasonal:                Multiplicative   AICC                           938.603
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         20:10:10
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0403573                alpha                 True
# ...

# %%
df_preds['hw_m4'] = hw_m4.forecast(len(test))
df_preds.head(2)
# Out:
#                  myrbetriq  myrb_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31              30        428.77        672.0      224.60      208.57
# 2020-02-29              39        646.74        672.0      316.52      129.46
#
#                  seasonal_12  seasonal_18         ses       hw_a4       hw_a6  \
# Date_of_Payment
# 2020-01-31            455.79       188.18  309.088383  311.452984  152.929337
# 2020-02-29            298.72       295.23  309.088383  290.750809  174.279039
#
#                      hw_a12     hw_a18       hw_m4
# Date_of_Payment
# 2020-01-31       198.483680  88.450881  351.597495
# 2020-02-29       106.284136  94.827368  358.740322

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m4'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 4 Model for Myrbetriq Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_m4'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 4 Model: 169.9061559981374
# RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model: 193.11752435705833

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 6.

# %%
hw_m6 = ExponentialSmoothing(
    train['myrb_dollars'],
    seasonal_periods=6, 
    trend='mul',
    seasonal='mul'
).fit()

# %%
hw_m6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             myrb_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                       13356425.314
# Optimized:                         True   AIC                            948.905
# Trend:                   Multiplicative   BIC                            972.343
# Seasonal:                Multiplicative   AICC                           953.780
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         20:10:11
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2525000                alpha                 True
# ...

# %%
df_preds['hw_m6'] = hw_m6.forecast(len(test))
df_preds.head(2)
# Out:
#                  myrbetriq  myrb_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31              30        428.77        672.0      224.60      208.57
# 2020-02-29              39        646.74        672.0      316.52      129.46
#
#                  seasonal_12  seasonal_18         ses       hw_a4       hw_a6  \
# Date_of_Payment
# 2020-01-31            455.79       188.18  309.088383  311.452984  152.929337
# 2020-02-29            298.72       295.23  309.088383  290.750809  174.279039
#
#                      hw_a12     hw_a18       hw_m4       hw_m6
# Date_of_Payment
# 2020-01-31       198.483680  88.450881  351.597495  261.089085
# 2020-02-29       106.284136  94.827368  358.740322  227.765941

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m6'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 6 Model for Myrbetriq Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_m6'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 6 Model: 207.28188823008915
# RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model: 234.53848224893784

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 12.

# %%
hw_m12 = ExponentialSmoothing(
    train['myrb_dollars'],
    seasonal_periods=12, 
    trend='mul',
    seasonal='mul'
).fit()

# %%
hw_m12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             myrb_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                        9542687.985
# Optimized:                         True   AIC                            935.016
# Trend:                   Multiplicative   BIC                            972.517
# Seasonal:                Multiplicative   AICC                           946.809
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         20:10:11
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2525000                alpha                 True
# ...

# %%
df_preds['hw_m12'] = hw_m12.forecast(len(test))
df_preds.head(2)
# Out:
#                  myrbetriq  myrb_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31              30        428.77        672.0      224.60      208.57
# 2020-02-29              39        646.74        672.0      316.52      129.46
#
#                  seasonal_12  seasonal_18         ses       hw_a4       hw_a6  \
# Date_of_Payment
# 2020-01-31            455.79       188.18  309.088383  311.452984  152.929337
# 2020-02-29            298.72       295.23  309.088383  290.750809  174.279039
#
#                      hw_a12     hw_a18       hw_m4       hw_m6      hw_m12
# Date_of_Payment
# 2020-01-31       198.483680  88.450881  351.597495  261.089085  345.366766
# 2020-02-29       106.284136  94.827368  358.740322  227.765941  263.798459

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m12'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 12 Model for Myrbetriq Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_m12'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 12 Model: 202.31970503492337
# RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model: 232.89045302825642

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 18.

# %%
hw_m18 = ExponentialSmoothing(
    train['myrb_dollars'],
    seasonal_periods=18, 
    trend='mul',
    seasonal='mul'
).fit()

# %%
hw_m18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             myrb_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                        8472378.827
# Optimized:                         True   AIC                            937.856
# Trend:                   Multiplicative   BIC                            989.419
# Seasonal:                Multiplicative   AICC                           960.933
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         20:10:12
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1110714                alpha                 True
# ...

# %%
df_preds['hw_m18'] = hw_m18.forecast(len(test))
df_preds.head(2)
# Out:
#                  myrbetriq  myrb_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31              30        428.77        672.0      224.60      208.57
# 2020-02-29              39        646.74        672.0      316.52      129.46
#
#                  seasonal_12  seasonal_18         ses       hw_a4       hw_a6  \
# Date_of_Payment
# 2020-01-31            455.79       188.18  309.088383  311.452984  152.929337
# 2020-02-29            298.72       295.23  309.088383  290.750809  174.279039
#
#                      hw_a12     hw_a18       hw_m4       hw_m6      hw_m12  \
# Date_of_Payment
# 2020-01-31       198.483680  88.450881  351.597495  261.089085  345.366766
# 2020-02-29       106.284136  94.827368  358.740322  227.765941  263.798459
#
#                      hw_m18
# Date_of_Payment
# 2020-01-31       296.958269
# 2020-02-29       329.145318

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['myrb_dollars'], label='Train')
plt.plot(test.index, test['myrb_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m18'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 18 Model for Myrbetriq Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_m18'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 252.6963368645664
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 286.006736815454

# %% [markdown]
# Try a SARIMA Model

# %%
from pmdarima.utils import tsdisplay

# %%
traina = train['myrb_dollars']

# %%
tsdisplay(traina)
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\pmdarima\utils\visualization.py:220: FutureWarning: the 'unbiased'' keyword is deprecated, use 'adjusted' instead
#   res = tsaplots.plot_acf(

# %% [markdown]
# SARIMA Model with Seasonality of 4

# %%
import pmdarima as pmd
model_s4 = pmd.auto_arima(train['myrb_dollars'], m=4, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[4] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=1157.679, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=1145.372, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=inf, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=1155.684, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=1145.112, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,1)[4] intercept   : AIC=1143.241, Time=0.05 sec
#  ARIMA(1,1,0)(1,0,1)[4] intercept   : AIC=1143.303, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,2)[4] intercept   : AIC=1141.104, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,2)[4] intercept   : AIC=1142.138, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,2)[4] intercept   : AIC=1155.340, Time=0.06 sec
#  ARIMA(2,1,0)(0,0,2)[4] intercept   : AIC=1142.388, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,2)[4] intercept   : AIC=inf, Time=0.22 sec
#  ARIMA(0,1,1)(0,0,2)[4] intercept   : AIC=inf, Time=0.14 sec
# ...

# %%
model_s4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                        SARIMAX Results
# ...
# Dep. Variable:                                      y   No. Observations:                   77
# Model:             SARIMAX(0, 1, 1)x(0, 0, [1, 2], 4)   Log Likelihood                -561.181
# Date:                                Tue, 15 Mar 2022   AIC                           1130.363
# Time:                                        20:10:16   BIC                           1139.686
# Sample:                                             0   HQIC                          1134.089
#                                                  - 77
# Covariance Type:                                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7585      0.092     -8.267      0.000      -0.938      -0.579
# ...

# %%
preds_sar4 = model_s4.predict(test.shape[0])
preds_sar4
# Out:
# array([195.29766677, 403.09301277, 389.50665006, 428.09365435,
#        355.42267564, 376.63086923, 363.99816432, 376.01608845,
#        364.01110893, 364.01110893, 364.01110893, 364.01110893])

# %%
df_preds['sarima4_auto'] = preds_sar4
df_preds['sarima4_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    195.297667
# 2020-02-29    403.093013
# Freq: M, Name: sarima4_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['myrb_dollars'], label='Train')
plt.plot(test['myrb_dollars'], label='Test')
plt.plot(df_preds['sarima4_auto'], label='SARIMA_4_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 4 Model for Myrbetriq Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['sarima4_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 4 Model: 206.20663669767612
# RMSE for SARIMA with Seasonality of 4 Model: 231.72181195637575

# %% [markdown]
# SARIMA Model with Seasonality of 6

# %%
model_s6 = pmd.auto_arima(train['myrb_dollars'], m=6, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[6] intercept   : AIC=inf, Time=0.24 sec
#  ARIMA(0,1,0)(0,0,0)[6] intercept   : AIC=1157.679, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[6] intercept   : AIC=1145.913, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[6] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[6]             : AIC=1155.684, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[6] intercept   : AIC=1145.112, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,1)[6] intercept   : AIC=1146.118, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,1)[6] intercept   : AIC=1144.584, Time=0.15 sec
#  ARIMA(1,1,0)(2,0,1)[6] intercept   : AIC=1146.560, Time=0.33 sec
#  ARIMA(1,1,0)(1,0,2)[6] intercept   : AIC=1146.562, Time=0.32 sec
#  ARIMA(1,1,0)(0,0,2)[6] intercept   : AIC=1147.486, Time=0.10 sec
#  ARIMA(1,1,0)(2,0,0)[6] intercept   : AIC=1147.131, Time=0.11 sec
#  ARIMA(1,1,0)(2,0,2)[6] intercept   : AIC=inf, Time=0.34 sec
#  ARIMA(0,1,0)(1,0,1)[6] intercept   : AIC=1161.552, Time=0.04 sec
# ...

# %%
model_s6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   77
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -563.169
# Date:                Tue, 15 Mar 2022   AIC                           1132.338
# Time:                        20:10:22   BIC                           1139.330
# Sample:                             0   HQIC                          1135.132
#                                  - 77
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2618      0.149      1.761      0.078      -0.029       0.553
# ma.L1         -0.9104      0.102     -8.907      0.000      -1.111      -0.710
# sigma2      1.569e+05   2.03e+04      7.746      0.000    1.17e+05    1.97e+05
# ...

# %%
preds_sar6 = model_s6.predict(test.shape[0])
preds_sar6
# Out:
# array([358.33415008, 369.57136352, 372.51317986, 373.28332482,
#        373.48494287, 373.53772493, 373.55154287, 373.5551603 ,
#        373.55610732, 373.55635524, 373.55642014, 373.55643713])

# %%
df_preds['sarima6_auto'] = preds_sar6
df_preds['sarima6_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    358.334150
# 2020-02-29    369.571364
# Freq: M, Name: sarima6_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['myrb_dollars'], label='Train')
plt.plot(test['myrb_dollars'], label='Test')
plt.plot(df_preds['sarima6_auto'], label='SARIMA_6_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 6 Model for Myrbetriq Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['sarima6_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 6 Model: 192.85940346683086
# RMSE for SARIMA with Seasonality of 6 Model: 219.88381764348006

# %% [markdown]
# Try a SARIMA Model with m = 12

# %%
model_s12 = pmd.auto_arima(train['myrb_dollars'], m=12, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1157.679, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1146.184, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1155.684, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1145.112, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,1)[12] intercept   : AIC=1146.338, Time=0.08 sec
#  ARIMA(1,1,0)(1,0,1)[12] intercept   : AIC=1146.649, Time=0.24 sec
#  ARIMA(2,1,0)(0,0,0)[12] intercept   : AIC=1146.446, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.13 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=1143.122, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12]             : AIC=1144.178, Time=0.02 sec
# ...

# %%
model_s12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   77
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -563.169
# Date:                Tue, 15 Mar 2022   AIC                           1132.338
# Time:                        20:10:24   BIC                           1139.330
# Sample:                             0   HQIC                          1135.132
#                                  - 77
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2618      0.149      1.761      0.078      -0.029       0.553
# ma.L1         -0.9104      0.102     -8.907      0.000      -1.111      -0.710
# sigma2      1.569e+05   2.03e+04      7.746      0.000    1.17e+05    1.97e+05
# ...

# %%
preds_sar12 = model_s12.predict(test.shape[0])
preds_sar12
# Out:
# array([358.33415008, 369.57136352, 372.51317986, 373.28332482,
#        373.48494287, 373.53772493, 373.55154287, 373.5551603 ,
#        373.55610732, 373.55635524, 373.55642014, 373.55643713])

# %%
df_preds['sarima12_auto'] = preds_sar12
df_preds['sarima12_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    358.334150
# 2020-02-29    369.571364
# Freq: M, Name: sarima12_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['myrb_dollars'], label='Train')
plt.plot(test['myrb_dollars'], label='Test')
plt.plot(df_preds['sarima12_auto'], label='SARIMA_12_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 12 Model for Myrbetriq Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['sarima12_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 12 Model: 192.85940346683086
# RMSE for SARIMA with Seasonality of 12 Model: 219.88381764348006

# %% [markdown]
# Try a SARIMA Model with m = 18

# %%
model_s18 = pmd.auto_arima(train['myrb_dollars'], m=18, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[18] intercept   : AIC=inf, Time=0.87 sec
#  ARIMA(0,1,0)(0,0,0)[18] intercept   : AIC=1157.679, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[18] intercept   : AIC=1146.406, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,1)[18] intercept   : AIC=inf, Time=0.38 sec
#  ARIMA(0,1,0)(0,0,0)[18]             : AIC=1155.684, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[18] intercept   : AIC=1145.112, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,1)[18] intercept   : AIC=1146.537, Time=0.16 sec
#  ARIMA(1,1,0)(1,0,1)[18] intercept   : AIC=1147.323, Time=0.49 sec
#  ARIMA(2,1,0)(0,0,0)[18] intercept   : AIC=1146.446, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[18] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[18] intercept   : AIC=inf, Time=0.04 sec
#  ARIMA(2,1,1)(0,0,0)[18] intercept   : AIC=inf, Time=0.12 sec
#  ARIMA(1,1,0)(0,0,0)[18]             : AIC=1143.122, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[18]             : AIC=1144.414, Time=0.04 sec
# ...

# %%
model_s18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   77
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -563.169
# Date:                Tue, 15 Mar 2022   AIC                           1132.338
# Time:                        20:10:29   BIC                           1139.330
# Sample:                             0   HQIC                          1135.132
#                                  - 77
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.2618      0.149      1.761      0.078      -0.029       0.553
# ma.L1         -0.9104      0.102     -8.907      0.000      -1.111      -0.710
# sigma2      1.569e+05   2.03e+04      7.746      0.000    1.17e+05    1.97e+05
# ...

# %%
preds_sar18 = model_s18.predict(test.shape[0])
preds_sar18
# Out:
# array([358.33415008, 369.57136352, 372.51317986, 373.28332482,
#        373.48494287, 373.53772493, 373.55154287, 373.5551603 ,
#        373.55610732, 373.55635524, 373.55642014, 373.55643713])

# %%
df_preds['sarima18_auto'] = preds_sar18
df_preds['sarima18_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    358.334150
# 2020-02-29    369.571364
# Freq: M, Name: sarima18_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['myrb_dollars'], label='Train')
plt.plot(test['myrb_dollars'], label='Test')
plt.plot(df_preds['sarima18_auto'], label='SARIMA_18_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 18 Model for Myrbetriq Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 18 Model: 192.85940346683086
# RMSE for SARIMA with Seasonality of 18 Model: 219.88381764348006

# %%
print("Summary of Metrics for Monthly Myrbetriq CMS Payments")
print("_________________________________________________")
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['simple_mean'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['seasonal_4'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['seasonal_6'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['seasonal_12'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['seasonal_18'], squared=False))
print("_________________________________________________")
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['ses'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_m4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_m6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_m12'], squared=False))
print("_________________________________________________")
# Out:
# Summary of Metrics for Monthly Myrbetriq CMS Payments
# _________________________________________________
# MAE for Simple Mean Baseline Model: 414.5683333333332
# RMSE for Simple Mean Baseline Model: 454.3558029782385
# _________________________________________________
# MAE for Seasonal Baseline 4 Shift Model: 232.01
# RMSE for Seasonal Baseline 4 Shift Model: 263.2158633770642
# _________________________________________________
# MAE for Seasonal Baseline 6 Shift Model: 275.5208333333333
# RMSE for Seasonal Baseline 6 Shift Model: 305.73406375748624
# _________________________________________________
# MAE for Seasonal Baseline 12 Shift Model: 202.92499999999995
# RMSE for Seasonal Baseline 12 Shift Model: 290.3480380508882
# _________________________________________________
# MAE for Seasonal Baseline 18 Shift Model: 245.44083333333333
# RMSE for Seasonal Baseline 18 Shift Model: 273.34645792168834
# _________________________________________________
# ...

# %%
print("Continued Summary of Metrics for Monthly Myrbetriq CMS Payments")
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_m18'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_a4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_a6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_a12'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['hw_a18'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['sarima4_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['sarima6_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['sarima12_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['myrb_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['myrb_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# Continued Summary of Metrics for Monthly Myrbetriq CMS Payments
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 252.6963368645664
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 286.006736815454
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 167.59072670298886
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 194.649233729855
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 217.85106407623059
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 253.66839230338448
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 234.8334586246389
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 267.5262566446579
# _________________________________________________
# ...

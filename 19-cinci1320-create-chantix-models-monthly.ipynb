# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cinci_1320 = pd.read_csv('./data/cinci1320.csv', index_col='Date_of_Payment', parse_dates=True).sort_index()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,18,19,47,48,49,50,51,52,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_1320.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     148974               RODNEY
# 2013-08-01                      58931                 PAUL
# 2013-08-01                     812462               ALFRED
# 2013-08-01                     108863                 MARK
# 2013-08-01                     195441           MANOJKUMAR
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                        NaN              VIVIAN
# 2013-08-01                     JOSEPH            FAVORITO
# 2013-08-01                      JAMES            SUGAWARA
# 2013-08-01                          A            MANEGOLD
# 2013-08-01                          S               SINGH
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2013-08-01                                       8000 5 MILE RD
# 2013-08-01                                       7575 5 MILE RD
# 2013-08-01                                     8477 FOXCROFT DR
# 2013-08-01                                     2450 KIPLING AVE
# 2013-08-01                                  10600 MONTGOMERY RD
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2013-08-01                                                  240
# 2013-08-01                                                  NaN
# 2013-08-01                                                  NaN
# 2013-08-01                                            SUITE 104
# 2013-08-01                                            SUITE 200
#
#                 Recipient_City  ... xarelto victoza humira levemir invokana  \
# Date_of_Payment                 ...
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
#
#                 farxiga entresto chantix myrbetriq toujeo
# Date_of_Payment
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
#
# [5 rows x 89 columns]

# %%
cinci_1320['Change_Type'].value_counts()
# Out:
# UNCHANGED    364686
# CHANGED         726
# ADD               1
# Name: Change_Type, dtype: int64

# %%
cinci_1320['chantix'].value_counts()
# Out:
# 0    361962
# 1      3451
# Name: chantix, dtype: int64

# %%
chantix = cinci_1320[(cinci_1320['chantix']==1) & (cinci_1320['Number_of_Payments_Included_in_Total_Amount']==1)].copy()

# %%
chantix.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2017-01-05        UNCHANGED  Covered Recipient Physician
# 2017-01-05        UNCHANGED  Covered Recipient Physician
# 2017-01-18        UNCHANGED  Covered Recipient Physician
# 2017-01-23        UNCHANGED  Covered Recipient Physician
# 2017-01-23        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2017-01-05                     276239               AMADOR
# 2017-01-05                     276239               AMADOR
# 2017-01-18                     226669                 JOHN
# 2017-01-23                     150863                 JOYA
# 2017-01-23                     498994              STEPHEN
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2017-01-05                     SANTOS          DELAMERCED
# 2017-01-05                     SANTOS          DELAMERCED
# 2017-01-18                          M           GALLAGHER
# 2017-01-23                          K               SYKES
# 2017-01-23                      EDWIN              WILSON
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2017-01-05                        NaN
# 2017-01-05                        NaN
# 2017-01-18                        NaN
# 2017-01-23                        NaN
# 2017-01-23                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2017-01-05                                 5885 HARRISON AVENUE
# 2017-01-05                                 5885 HARRISON AVENUE
# 2017-01-18                               3301 MERCY HEALTH BLVD
# 2017-01-23                                      11550 WINTON RD
# 2017-01-23                                     1230 W KEMPER RD
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2017-01-05                                                  NaN
# 2017-01-05                                                  NaN
# 2017-01-18                                            SUITE 450
# 2017-01-23                                                  NaN
# 2017-01-23                                1230 WEST KEMPER ROAD
#
#                 Recipient_City  ... xarelto victoza humira levemir invokana  \
# Date_of_Payment                 ...
# 2017-01-05          CINCINNATI  ...       0       0      0       0        0
# 2017-01-05          CINCINNATI  ...       0       0      0       0        0
# 2017-01-18          CINCINNATI  ...       0       0      0       0        0
# 2017-01-23          CINCINNATI  ...       0       0      0       0        0
# 2017-01-23          CINCINNATI  ...       0       0      0       0        0
#
#                 farxiga entresto chantix myrbetriq toujeo
# Date_of_Payment
# 2017-01-05            0        0       1         0      0
# 2017-01-05            0        0       1         0      0
# 2017-01-18            0        0       1         0      0
# 2017-01-23            0        0       1         0      0
# 2017-01-23            0        0       1         0      0
#
# [5 rows x 89 columns]

# %%
chantix['chantix'].value_counts()
# Out:
# 1    3451
# Name: chantix, dtype: int64

# %%
chantix['Change_Type'].value_counts()
# Out:
# UNCHANGED    3451
# Name: Change_Type, dtype: int64

# %%
chantix['invok_dollars'] = [k if ((i ==1) & (j ==1)) else 0 for i, j, k in zip(chantix['chantix'], chantix['Number_of_Payments_Included_in_Total_Amount'], chantix['Total_Amount_of_Payment_USDollars'])]

#Ben Peck helped me with this during office hours.  I was oh-so-close but not quite there!

# %%
chantix['invok_dollars'].sum()
# Out:
# 32087.03

# %%
chantix.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2017-01-05        UNCHANGED  Covered Recipient Physician
# 2017-01-05        UNCHANGED  Covered Recipient Physician
# 2017-01-18        UNCHANGED  Covered Recipient Physician
# 2017-01-23        UNCHANGED  Covered Recipient Physician
# 2017-01-23        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2017-01-05                     276239               AMADOR
# 2017-01-05                     276239               AMADOR
# 2017-01-18                     226669                 JOHN
# 2017-01-23                     150863                 JOYA
# 2017-01-23                     498994              STEPHEN
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2017-01-05                     SANTOS          DELAMERCED
# 2017-01-05                     SANTOS          DELAMERCED
# 2017-01-18                          M           GALLAGHER
# 2017-01-23                          K               SYKES
# 2017-01-23                      EDWIN              WILSON
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2017-01-05                        NaN
# 2017-01-05                        NaN
# 2017-01-18                        NaN
# 2017-01-23                        NaN
# 2017-01-23                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2017-01-05                                 5885 HARRISON AVENUE
# 2017-01-05                                 5885 HARRISON AVENUE
# 2017-01-18                               3301 MERCY HEALTH BLVD
# 2017-01-23                                      11550 WINTON RD
# 2017-01-23                                     1230 W KEMPER RD
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2017-01-05                                                  NaN
# 2017-01-05                                                  NaN
# 2017-01-18                                            SUITE 450
# 2017-01-23                                                  NaN
# 2017-01-23                                1230 WEST KEMPER ROAD
#
#                 Recipient_City  ... victoza humira levemir invokana farxiga  \
# Date_of_Payment                 ...
# 2017-01-05          CINCINNATI  ...       0      0       0        0       0
# 2017-01-05          CINCINNATI  ...       0      0       0        0       0
# 2017-01-18          CINCINNATI  ...       0      0       0        0       0
# 2017-01-23          CINCINNATI  ...       0      0       0        0       0
# 2017-01-23          CINCINNATI  ...       0      0       0        0       0
#
#                 entresto chantix myrbetriq toujeo invok_dollars
# Date_of_Payment
# 2017-01-05             0       1         0      0         10.00
# 2017-01-05             0       1         0      0          0.31
# 2017-01-18             0       1         0      0         12.69
# 2017-01-23             0       1         0      0          2.50
# 2017-01-23             0       1         0      0          2.50
#
# [5 rows x 90 columns]

# %%
drop_cols = ['Change_Type','Covered_Recipient_Type',
'Physician_First_Name',
'Physician_Middle_Name',
'Physician_Last_Name',
'Physician_Name_Suffix',
'Recipient_Primary_Business_Street_Address_Line1',
'Recipient_Primary_Business_Street_Address_Line2',
'Recipient_City',
'Recipient_State',
'Recipient_Zip_Code',
'Recipient_Country',
'Physician_Primary_Type',
'Physician_Specialty',
'Physician_License_State_code1',
'Physician_License_State_code2',
'Physician_License_State_code3',
'Physician_License_State_code4',
'Physician_License_State_code5',
'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
'Form_of_Payment_or_Transfer_of_Value',
'City_of_Travel',
'State_of_Travel',
'Country_of_Travel',
'Physician_Ownership_Indicator',
'Third_Party_Payment_Recipient_Indicator',
'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
'Charity_Indicator',
'Third_Party_Equals_Covered_Recipient_Indicator',
'Contextual_Information',
'Delay_in_Publication_Indicator',
'Dispute_Status_for_Publication',
'Related_Product_Indicator',
'Covered_or_Noncovered_Indicator_1',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Product_Category_or_Therapeutic_Area_1',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Associated_Drug_or_Biological_NDC_1',
'Covered_or_Noncovered_Indicator_2',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Product_Category_or_Therapeutic_Area_2',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Associated_Drug_or_Biological_NDC_2',
'Covered_or_Noncovered_Indicator_3',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Product_Category_or_Therapeutic_Area_3',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Associated_Drug_or_Biological_NDC_3',
'Covered_or_Noncovered_Indicator_4',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Product_Category_or_Therapeutic_Area_4',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Associated_Drug_or_Biological_NDC_4',
'Covered_or_Noncovered_Indicator_5',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Product_Category_or_Therapeutic_Area_5',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Associated_Drug_or_Biological_NDC_5', 
'Physician_Profile_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
'Total_Amount_of_Payment_USDollars','Number_of_Payments_Included_in_Total_Amount', 
'Nature_of_Payment_or_Transfer_of_Value', 'Record_ID', 
'Payment_Publication_Date', 'Program_Year',
'NDC_of_Associated_Covered_Drug_or_Biological1',
'NDC_of_Associated_Covered_Drug_or_Biological2',
'NDC_of_Associated_Covered_Drug_or_Biological3',
'NDC_of_Associated_Covered_Drug_or_Biological4',
'NDC_of_Associated_Covered_Drug_or_Biological5',
'Name_of_Associated_Covered_Device_or_Medical_Supply1',
'Name_of_Associated_Covered_Device_or_Medical_Supply2',
'Name_of_Associated_Covered_Device_or_Medical_Supply3',
'Name_of_Associated_Covered_Device_or_Medical_Supply4',
'Name_of_Associated_Covered_Device_or_Medical_Supply5',
'xarelto', 'farxiga', 'victoza', 'humira', 'levemir',
'entresto', 'invokana', 'myrbetriq', 'toujeo']

# %%
chantix.drop(columns = drop_cols, inplace = True)

# %%
chantix.head()
# Out:
#                  chantix  invok_dollars
# Date_of_Payment
# 2017-01-05             1          10.00
# 2017-01-05             1           0.31
# 2017-01-18             1          12.69
# 2017-01-23             1           2.50
# 2017-01-23             1           2.50

# %% [markdown]
# Was reminded of the importance of checking data for outliers by this article, and modeled my filtering code below on this article:
# https://www.analyticsvidhya.com/blog/2021/08/holt-winters-method-for-time-series-analysis/

# %%
sns.boxplot(x = chantix['invok_dollars']);

# %%
chantix['z_score'] = [ ((i - chantix['invok_dollars'].mean())/chantix['invok_dollars'].std()) for i in chantix['invok_dollars']]

# %%
chantix.shape
# Out:
# (3451, 3)

# %% [markdown]
# Add chart to see data before dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(chantix.index, chantix['invok_dollars'], label='Before Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Chantix Drug - Before Outliers Dropped");

# %%
chantixb = chantix[(np.abs(chantix['z_score']) < 3)].copy()

# %%
chantixb.shape
# Out:
# (3435, 3)

# %% [markdown]
# Add chart to see data after dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(chantixb.index, chantixb['invok_dollars'], label='After Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Chantix Drug - After Outliers Dropped");

# %% [markdown]
# Drop Z-score before aggregating

# %%
chantixb.drop(columns='z_score', inplace=True)

# %%
chantix_monthly = chantixb.resample('m').sum()

# %%
chantix_monthly.head()
# Out:
#                  chantix  invok_dollars
# Date_of_Payment
# 2017-01-31            14          89.69
# 2017-02-28            52         326.97
# 2017-03-31            24         155.86
# 2017-04-30            55         465.86
# 2017-05-31            47         379.03

# %%
chantix_monthly.sort_index()
# Out:
#                  chantix  invok_dollars
# Date_of_Payment
# 2017-01-31            14          89.69
# 2017-02-28            52         326.97
# 2017-03-31            24         155.86
# 2017-04-30            55         465.86
# 2017-05-31            47         379.03
# 2017-06-30            20         185.82
# 2017-07-31            11          67.45
# 2017-08-31            17         162.55
# 2017-09-30            28         227.30
# 2017-10-31            50         469.89
# 2017-11-30            34         285.62
# 2017-12-31            28         250.36
# 2018-01-31            66         458.03
# 2018-02-28           121         971.28
# 2018-03-31           160        1465.60
# 2018-04-30           113         853.12
# 2018-05-31           121         923.55
# 2018-06-30           122        1043.28
# 2018-07-31           113         898.50
# 2018-08-31           137        1087.07
# 2018-09-30           111         932.22
# 2018-10-31           101         848.03
# 2018-11-30           113         837.34
# 2018-12-31            65         550.91
# 2019-01-31            92         757.99
# 2019-02-28            94         926.54
# 2019-03-31            93         787.80
# 2019-04-30            83         678.54
# 2019-05-31            74         668.44
# 2019-06-30            43         331.03
# 2019-07-31           160        1356.03
# 2019-08-31           128         991.59
# 2019-09-30           133        1041.40
# 2019-10-31           119        1025.20
# 2019-11-30           134        1293.10
# 2019-12-31            90         719.23
# 2020-01-31            93         962.37
# 2020-02-29           120        1305.83
# 2020-03-31            29         368.95
# 2020-04-30            15         204.90
# 2020-05-31            25         368.28
# 2020-06-30            26         375.97
# 2020-07-31            30         374.87
# 2020-08-31            36         463.83
# 2020-09-30            32         420.50
# 2020-10-31            32         433.79
# 2020-11-30            20         283.12
# 2020-12-31            11         156.68

# %% [markdown]
# Adding 1 to the weekly sales for each observation so that Holt_winters will work.

# %%
chantix_monthly['invok_dollars'] = [i+1 for i in chantix_monthly['invok_dollars']]

# %% [markdown]
# Set up Train and Test Sets using 2013 - 2020 Data

# %%
train = chantix_monthly.loc[:'2019-12-31']
train
# Out:
#                  chantix  invok_dollars
# Date_of_Payment
# 2017-01-31            14          90.69
# 2017-02-28            52         327.97
# 2017-03-31            24         156.86
# 2017-04-30            55         466.86
# 2017-05-31            47         380.03
# 2017-06-30            20         186.82
# 2017-07-31            11          68.45
# 2017-08-31            17         163.55
# 2017-09-30            28         228.30
# 2017-10-31            50         470.89
# 2017-11-30            34         286.62
# 2017-12-31            28         251.36
# 2018-01-31            66         459.03
# 2018-02-28           121         972.28
# 2018-03-31           160        1466.60
# 2018-04-30           113         854.12
# 2018-05-31           121         924.55
# 2018-06-30           122        1044.28
# 2018-07-31           113         899.50
# 2018-08-31           137        1088.07
# 2018-09-30           111         933.22
# 2018-10-31           101         849.03
# 2018-11-30           113         838.34
# 2018-12-31            65         551.91
# 2019-01-31            92         758.99
# 2019-02-28            94         927.54
# 2019-03-31            93         788.80
# 2019-04-30            83         679.54
# 2019-05-31            74         669.44
# 2019-06-30            43         332.03
# 2019-07-31           160        1357.03
# 2019-08-31           128         992.59
# 2019-09-30           133        1042.40
# 2019-10-31           119        1026.20
# 2019-11-30           134        1294.10
# 2019-12-31            90         720.23

# %%
train['invok_dollars'].max()
# Out:
# 1466.6

# %%
train.describe()
# Out:
#           chantix  invok_dollars
# count   36.000000      36.000000
# mean    82.388889     681.895000
# std     44.199727     380.285338
# min     11.000000      68.450000
# 25%     46.000000     331.015000
# 50%     91.000000     739.610000
# 75%    119.500000     942.985000
# max    160.000000    1466.600000

# %%
train.index.freq = 'M'

# %%
train.shape
# Out:
# (36, 2)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 36 entries, 2017-01-31 to 2019-12-31
# Freq: M
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   chantix        36 non-null     int64
#  1   invok_dollars  36 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 864.0 bytes

# %%
train.index
# Out:
# DatetimeIndex(['2017-01-31', '2017-02-28', '2017-03-31', '2017-04-30',
#                '2017-05-31', '2017-06-30', '2017-07-31', '2017-08-31',
#                '2017-09-30', '2017-10-31', '2017-11-30', '2017-12-31',
#                '2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30',
#                '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31',
#                '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31',
#                '2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
#                '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#                '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31'],
#               dtype='datetime64[ns]', name='Date_of_Payment', freq='M')

# %%
test = chantix_monthly.loc['2020-01-01':]
test
# Out:
#                  chantix  invok_dollars
# Date_of_Payment
# 2020-01-31            93         963.37
# 2020-02-29           120        1306.83
# 2020-03-31            29         369.95
# 2020-04-30            15         205.90
# 2020-05-31            25         369.28
# 2020-06-30            26         376.97
# 2020-07-31            30         375.87
# 2020-08-31            36         464.83
# 2020-09-30            32         421.50
# 2020-10-31            32         434.79
# 2020-11-30            20         284.12
# 2020-12-31            11         157.68

# %%
test.describe()
# Out:
#           chantix  invok_dollars
# count   12.000000      12.000000
# mean    39.083333     477.590833
# std     32.823103     328.376060
# min     11.000000     157.680000
# 25%     23.750000     347.990000
# 50%     29.500000     376.420000
# 75%     33.000000     442.300000
# max    120.000000    1306.830000

# %%
test.shape
# Out:
# (12, 2)

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')

plt.legend(loc='best')
plt.title("Monthly Payments for Chantix Drug");

# %% [markdown]
# Baseline - Simple Mean (Naive Model)

# %%
df_preds = test.copy(deep=True)
df_preds
# Out:
#                  chantix  invok_dollars
# Date_of_Payment
# 2020-01-31            93         963.37
# 2020-02-29           120        1306.83
# 2020-03-31            29         369.95
# 2020-04-30            15         205.90
# 2020-05-31            25         369.28
# 2020-06-30            26         376.97
# 2020-07-31            30         375.87
# 2020-08-31            36         464.83
# 2020-09-30            32         421.50
# 2020-10-31            32         434.79
# 2020-11-30            20         284.12
# 2020-12-31            11         157.68

# %%
df_preds['simple_mean'] = train['invok_dollars'].mean()
df_preds
# Out:
#                  chantix  invok_dollars  simple_mean
# Date_of_Payment
# 2020-01-31            93         963.37      681.895
# 2020-02-29           120        1306.83      681.895
# 2020-03-31            29         369.95      681.895
# 2020-04-30            15         205.90      681.895
# 2020-05-31            25         369.28      681.895
# 2020-06-30            26         376.97      681.895
# 2020-07-31            30         375.87      681.895
# 2020-08-31            36         464.83      681.895
# 2020-09-30            32         421.50      681.895
# 2020-10-31            32         434.79      681.895
# 2020-11-30            20         284.12      681.895
# 2020-12-31            11         157.68      681.895

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['simple_mean'], label="Baseline (Mean)")

plt.legend(loc='best')
plt.title("Baseline (Mean) Forecast for Monthly Chantix Payments");

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['simple_mean'], squared=False))
# Out:
# MAE for Simple Mean Baseline Model: 355.37249999999995
# RMSE for Simple Mean Baseline Model: 374.9468312863394

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 4

# %%
df_preds['seasonal_4'] = train['invok_dollars'].shift(4, freq='M') 
df_preds.head(2)
# Out:
#                  chantix  invok_dollars  simple_mean  seasonal_4
# Date_of_Payment
# 2020-01-31            93         963.37      681.895      1042.4
# 2020-02-29           120        1306.83      681.895      1026.2

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_4'], label='Seasonal 4')

plt.legend(loc='best')
plt.title("Seasonal 4 Forecast for Monthly Chantix Payments");

# %%
df_preds['seasonal_4'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_4'], squared=False))
# Out:
# MAE for Seasonal Baseline 4 Shift Model: 390.26500000000004
# RMSE for Seasonal Baseline 4 Shift Model: 438.9094957201693

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 6

# %%
df_preds['seasonal_6'] = train['invok_dollars'].shift(6, freq='M') 
df_preds.head(2)
# Out:
#                  chantix  invok_dollars  simple_mean  seasonal_4  seasonal_6
# Date_of_Payment
# 2020-01-31            93         963.37      681.895      1042.4     1357.03
# 2020-02-29           120        1306.83      681.895      1026.2      992.59

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_6'], label='Seasonal 6')

plt.legend(loc='best')
plt.title("Seasonal 6 Forecast for Monthly Chantix Payments");

# %%
df_preds['seasonal_6'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_6'], squared=False))
# Out:
# MAE for Seasonal Baseline 6 Shift Model: 467.2933333333333
# RMSE for Seasonal Baseline 6 Shift Model: 514.9071487818621

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 12

# %%
df_preds['seasonal_12'] = train['invok_dollars'].shift(12, freq='M') 
df_preds.head(2)
# Out:
#                  chantix  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            93         963.37      681.895      1042.4     1357.03
# 2020-02-29           120        1306.83      681.895      1026.2      992.59
#
#                  seasonal_12
# Date_of_Payment
# 2020-01-31            758.99
# 2020-02-29            927.54

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_12'], label='Seasonal 12')

plt.legend(loc='best')
plt.title("Seasonal 12 Forecast for Monthly Chantix Payments");

# %%
df_preds['seasonal_12'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_12'], squared=False))
# Out:
# MAE for Seasonal Baseline 12 Shift Model: 509.585
# RMSE for Seasonal Baseline 12 Shift Model: 576.6662924372581

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 18

# %%
df_preds['seasonal_18'] = train['invok_dollars'].shift(18, freq='M') 
df_preds.head(2)
# Out:
#                  chantix  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            93         963.37      681.895      1042.4     1357.03
# 2020-02-29           120        1306.83      681.895      1026.2      992.59
#
#                  seasonal_12  seasonal_18
# Date_of_Payment
# 2020-01-31            758.99       899.50
# 2020-02-29            927.54      1088.07

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_18'], label='Seasonal 18')

plt.legend(loc='best')
plt.title("Seasonal 18 Forecast for Monthly Chantix Payments");

# %%
df_preds['seasonal_18'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_18'], squared=False))
# Out:
# MAE for Seasonal Baseline 18 Shift Model: 345.88166666666666
# RMSE for Seasonal Baseline 18 Shift Model: 383.8411832385889

# %% [markdown]
# Simple Exponential Smoothing Model

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing

# %%
ses = SimpleExpSmoothing(train['invok_dollars']).fit(smoothing_level=.5)

# %%
ses.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ==============================================================================
# Dep. Variable:          invok_dollars   No. Observations:                   36
# Model:             SimpleExpSmoothing   SSE                        2709130.456
# Optimized:                       True   AIC                            408.230
# Trend:                           None   BIC                            411.397
# Seasonal:                        None   AICC                           409.521
# Seasonal Periods:                None   Date:                 Tue, 15 Mar 2022
# Box-Cox:                        False   Time:                         19:52:00
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.5000000                alpha                False
# initial_level              193.38578                  l.0                 True
# ------------------------------------------------------------------------------
# """

# %%
ses_forecast = ses.forecast(len(test))

# %%
df_preds['ses'] = ses_forecast

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['ses'], label='Simple Exponential Smoothing')

plt.legend(loc='best')
plt.title("Simple Exponential Smoothing for Chantix Monthly Payments");

# %%
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['ses'], squared=False))
# Out:
# MAE for Simple Exponential Smoothing Model: 525.7131457771462
# RMSE for Simple Exponential Smoothing Model: 557.0232422933949

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 4.

# %%
hw_a4 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=4, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:            invok_dollars   No. Observations:                   36
# Model:             ExponentialSmoothing   SSE                        2452610.428
# Optimized:                         True   AIC                            416.649
# Trend:                         Additive   BIC                            429.317
# Seasonal:                      Additive   AICC                           425.449
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:52:01
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.4747071                alpha                 True
# smoothing_trend               0.0119871                 beta                 True
# smoothing_seasonal            0.0132501                gamma                 True
# initial_level                 226.25849                  l.0                 True
# initial_trend                 18.399068                  b.0                 True
# initial_seasons.0            -43.027490                  s.0                 True
# initial_seasons.1             26.309478                  s.1                 True
# initial_seasons.2             85.462420                  s.2                 True
# initial_seasons.3            -76.587215                  s.3                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a4'] = hw_a4.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            93         963.37      681.895      1042.4     1357.03
# 2020-02-29           120        1306.83      681.895      1026.2      992.59
#
#                  seasonal_12  seasonal_18         ses        hw_a4
# Date_of_Payment
# 2020-01-31            758.99       899.50  937.405969   955.789348
# 2020-02-29            927.54      1088.07  937.405969  1041.763279

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a4'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 4 for Monthly Payments for Chantix");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a4'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 670.4250920873711
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 722.1309748375982

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 6.

# %%
hw_a6 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=6, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:            invok_dollars   No. Observations:                   36
# Model:             ExponentialSmoothing   SSE                        2075000.014
# Optimized:                         True   AIC                            414.630
# Trend:                         Additive   BIC                            430.465
# Seasonal:                      Additive   AICC                           428.196
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:52:01
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.4508655                alpha                 True
# smoothing_trend               0.0148233                 beta                 True
# smoothing_seasonal            0.0246718                gamma                 True
# initial_level                 123.76764                  l.0                 True
# initial_trend                 27.979312                  b.0                 True
# initial_seasons.0            -20.304910                  s.0                 True
# initial_seasons.1             98.578293                  s.1                 True
# initial_seasons.2             106.42957                  s.2                 True
# initial_seasons.3             36.319157                  s.3                 True
# initial_seasons.4             15.732113                  s.4                 True
# initial_seasons.5            -231.20387                  s.5                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a6'] = hw_a6.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            93         963.37      681.895      1042.4     1357.03
# 2020-02-29           120        1306.83      681.895      1026.2      992.59
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            758.99       899.50  937.405969   955.789348
# 2020-02-29            927.54      1088.07  937.405969  1041.763279
#
#                        hw_a6
# Date_of_Payment
# 2020-01-31       1077.457298
# 2020-02-29       1219.454286

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a6'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 6 for Monthly Payments for Chantix");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a6'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 780.5912701828323
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 844.9990293364119

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 12.

# %%
hw_a12 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=12, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:            invok_dollars   No. Observations:                   36
# Model:             ExponentialSmoothing   SSE                        1911270.604
# Optimized:                         True   AIC                            423.671
# Trend:                         Additive   BIC                            449.008
# Seasonal:                      Additive   AICC                           463.907
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:52:02
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.5186911                alpha                 True
# smoothing_trend               0.0562428                 beta                 True
# smoothing_seasonal            0.0347693                gamma                 True
# initial_level                 157.39719                  l.0                 True
# initial_trend                 30.558843                  b.0                 True
# initial_seasons.0            -77.744308                  s.0                 True
# initial_seasons.1             208.12727                  s.1                 True
# initial_seasons.2             229.84717                  s.2                 True
# initial_seasons.3             58.011592                  s.3                 True
# initial_seasons.4             2.2041205                  s.4                 True
# initial_seasons.5            -173.37735                  s.5                 True
# initial_seasons.6             56.092059                  s.6                 True
# initial_seasons.7            -1.7122421                  s.7                 True
# initial_seasons.8            -29.037087                  s.8                 True
# initial_seasons.9            -3.8211264                  s.9                 True
# initial_seasons.10            5.7041686                 s.10                 True
# initial_seasons.11           -319.51592                 s.11                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a12'] = hw_a12.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            93         963.37      681.895      1042.4     1357.03
# 2020-02-29           120        1306.83      681.895      1026.2      992.59
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            758.99       899.50  937.405969   955.789348
# 2020-02-29            927.54      1088.07  937.405969  1041.763279
#
#                        hw_a6       hw_a12
# Date_of_Payment
# 2020-01-31       1077.457298  1071.950298
# 2020-02-29       1219.454286  1384.682978

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a12'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 12 for Monthly Payments for Chantix");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a12'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 816.4045821215763
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 884.0088688412732

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 18.

# %%
hw_a18 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=18, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:            invok_dollars   No. Observations:                   36
# Model:             ExponentialSmoothing   SSE                        1090902.385
# Optimized:                         True   AIC                            415.484
# Trend:                         Additive   BIC                            450.321
# Seasonal:                      Additive   AICC                           524.575
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:52:02
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.3589880                alpha                 True
# smoothing_trend               0.1017077                 beta                 True
# smoothing_seasonal            0.0051508                gamma                 True
# initial_level                 200.36744                  l.0                 True
# initial_trend                 44.269442                  b.0                 True
# initial_seasons.0            -57.413327                  s.0                 True
# initial_seasons.1             137.17826                  s.1                 True
# initial_seasons.2            -45.193848                  s.2                 True
# initial_seasons.3             46.630803                  s.3                 True
# initial_seasons.4            -19.796674                  s.4                 True
# initial_seasons.5            -275.03858                  s.5                 True
# initial_seasons.6            -243.38494                  s.6                 True
# initial_seasons.7            -126.40740                  s.7                 True
# initial_seasons.8            -181.16052                  s.8                 True
# initial_seasons.9            -132.81408                  s.9                 True
# initial_seasons.10           -249.30531                 s.10                 True
# initial_seasons.11           -452.87319                 s.11                 True
# initial_seasons.12            144.42234                 s.12                 True
# initial_seasons.13            209.43771                 s.13                 True
# initial_seasons.14            471.04484                 s.14                 True
# initial_seasons.15            139.24830                 s.15                 True
# initial_seasons.16            291.63376                 s.16                 True
# initial_seasons.17            52.013840                 s.17                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a18'] = hw_a18.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            93         963.37      681.895      1042.4     1357.03
# 2020-02-29           120        1306.83      681.895      1026.2      992.59
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            758.99       899.50  937.405969   955.789348
# 2020-02-29            927.54      1088.07  937.405969  1041.763279
#
#                        hw_a6       hw_a12      hw_a18
# Date_of_Payment
# 2020-01-31       1077.457298  1071.950298  756.286884
# 2020-02-29       1219.454286  1384.682978  946.630361

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a18'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 18 for Monthly Payments for Chantix");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a18'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 18 Model: 274.675576030541
# RMSE for Holt-Winters Additive with Seasonality of 18 Model: 309.18879530733255

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 4.

# %%
hw_m4 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=4, 
    trend='mul',
    seasonal='mul'
).fit()

# %%
hw_m4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:            invok_dollars   No. Observations:                   36
# Model:             ExponentialSmoothing   SSE                        3663866.062
# Optimized:                         True   AIC                            431.098
# Trend:                   Multiplicative   BIC                            443.767
# Seasonal:                Multiplicative   AICC                           439.898
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:52:03
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2878571                alpha                 True
# smoothing_trend                  0.0001                 beta                 True
# smoothing_seasonal            0.1186905                gamma                 True
# initial_level                 234.10008                  l.0                 True
# initial_trend                 1.0387921                  b.0                 True
# initial_seasons.0             1.0018649                  s.0                 True
# initial_seasons.1             1.1934639                  s.1                 True
# initial_seasons.2             0.8409841                  s.2                 True
# initial_seasons.3             0.9636871                  s.3                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m4'] = hw_m4.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            93         963.37      681.895      1042.4     1357.03
# 2020-02-29           120        1306.83      681.895      1026.2      992.59
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            758.99       899.50  937.405969   955.789348
# 2020-02-29            927.54      1088.07  937.405969  1041.763279
#
#                        hw_a6       hw_a12      hw_a18        hw_m4
# Date_of_Payment
# 2020-01-31       1077.457298  1071.950298  756.286884  1029.731897
# 2020-02-29       1219.454286  1384.682978  946.630361  1261.449023

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m4'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 4 Model for Chantix Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m4'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 4 Model: 910.385995047317
# RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model: 1005.9122280495674

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 6.

# %%
hw_m6 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=6, 
    trend='mul',
    seasonal='mul'
).fit()

# %%
hw_m6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:            invok_dollars   No. Observations:                   36
# Model:             ExponentialSmoothing   SSE                        3589007.381
# Optimized:                         True   AIC                            434.355
# Trend:                   Multiplicative   BIC                            450.190
# Seasonal:                Multiplicative   AICC                           447.920
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:52:03
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.4651782                alpha                 True
# smoothing_trend               0.1712102                 beta                 True
# smoothing_seasonal            0.0001006                gamma                 True
# initial_level                 118.09356                  l.0                 True
# initial_trend                 1.3380307                  b.0                 True
# initial_seasons.0             2.0987661                  s.0                 True
# initial_seasons.1             2.4547593                  s.1                 True
# initial_seasons.2             2.5854481                  s.2                 True
# initial_seasons.3             2.1419332                  s.3                 True
# initial_seasons.4             2.2031687                  s.4                 True
# initial_seasons.5             1.8026531                  s.5                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m6'] = hw_m6.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            93         963.37      681.895      1042.4     1357.03
# 2020-02-29           120        1306.83      681.895      1026.2      992.59
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            758.99       899.50  937.405969   955.789348
# 2020-02-29            927.54      1088.07  937.405969  1041.763279
#
#                        hw_a6       hw_a12      hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31       1077.457298  1071.950298  756.286884  1029.731897
# 2020-02-29       1219.454286  1384.682978  946.630361  1261.449023
#
#                        hw_m6
# Date_of_Payment
# 2020-01-31       1089.215182
# 2020-02-29       1334.975817

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m6'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 6 Model for Chantix Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m6'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 6 Model: 1020.9044495536219
# RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model: 1124.226447361893

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 12.

# %%
hw_m12 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=12, 
    trend='mul',
    seasonal='mul'
).fit()

# %%
hw_m12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:            invok_dollars   No. Observations:                   36
# Model:             ExponentialSmoothing   SSE                        2483569.495
# Optimized:                         True   AIC                            433.101
# Trend:                   Multiplicative   BIC                            458.437
# Seasonal:                Multiplicative   AICC                           473.336
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:52:04
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.5000000                alpha                 True
# smoothing_trend               0.1500006                 beta                 True
# smoothing_seasonal            0.0001013                gamma                 True
# initial_level                 202.61348                  l.0                 True
# initial_trend                 1.3131644                  b.0                 True
# initial_seasons.0             1.3871158                  s.0                 True
# initial_seasons.1             2.0313975                  s.1                 True
# initial_seasons.2             2.3276471                  s.2                 True
# initial_seasons.3             1.6898996                  s.3                 True
# initial_seasons.4             1.6433565                  s.4                 True
# initial_seasons.5             1.5321887                  s.5                 True
# initial_seasons.6             1.6284711                  s.6                 True
# initial_seasons.7             1.6377906                  s.7                 True
# initial_seasons.8             1.4824604                  s.8                 True
# initial_seasons.9             1.3941710                  s.9                 True
# initial_seasons.10            1.4726552                 s.10                 True
# initial_seasons.11            0.9533647                 s.11                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m12'] = hw_m12.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            93         963.37      681.895      1042.4     1357.03
# 2020-02-29           120        1306.83      681.895      1026.2      992.59
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            758.99       899.50  937.405969   955.789348
# 2020-02-29            927.54      1088.07  937.405969  1041.763279
#
#                        hw_a6       hw_a12      hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31       1077.457298  1071.950298  756.286884  1029.731897
# 2020-02-29       1219.454286  1384.682978  946.630361  1261.449023
#
#                        hw_m6       hw_m12
# Date_of_Payment
# 2020-01-31       1089.215182  1245.683381
# 2020-02-29       1334.975817  1964.508811

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m12'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 12 Model for Chantix Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m12'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 12 Model: 1672.5537393636587
# RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model: 1773.1565847400611

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 18.

# %%
hw_m18 = ExponentialSmoothing(
    train['invok_dollars'],
    seasonal_periods=18, 
    trend='mul',
    seasonal='mul'
).fit()

# %%
hw_m18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:            invok_dollars   No. Observations:                   36
# Model:             ExponentialSmoothing   SSE                        2843823.724
# Optimized:                         True   AIC                            449.977
# Trend:                   Multiplicative   BIC                            484.814
# Seasonal:                Multiplicative   AICC                           559.068
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:52:04
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2525001                alpha                 True
# smoothing_trend               0.2524999                 beta                 True
# smoothing_seasonal            0.2093003                gamma                 True
# initial_level                 492.12314                  l.0                 True
# initial_trend                 1.1696197                  b.0                 True
# initial_seasons.0             1.2374928                  s.0                 True
# initial_seasons.1             1.3758833                  s.1                 True
# initial_seasons.2             1.2054248                  s.2                 True
# initial_seasons.3             0.9763907                  s.3                 True
# initial_seasons.4             0.9499604                  s.4                 True
# initial_seasons.5             0.8984164                  s.5                 True
# initial_seasons.6             1.0013905                  s.6                 True
# initial_seasons.7             1.0464773                  s.7                 True
# initial_seasons.8             0.8487672                  s.8                 True
# initial_seasons.9             0.8876981                  s.9                 True
# initial_seasons.10            0.7235140                 s.10                 True
# initial_seasons.11            0.6033456                 s.11                 True
# initial_seasons.12            1.2542214                 s.12                 True
# initial_seasons.13            1.4186815                 s.13                 True
# initial_seasons.14            2.0762638                 s.14                 True
# initial_seasons.15            1.3840962                 s.15                 True
# initial_seasons.16            1.6292621                 s.16                 True
# initial_seasons.17            1.3858943                 s.17                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m18'] = hw_m18.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  invok_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            93         963.37      681.895      1042.4     1357.03
# 2020-02-29           120        1306.83      681.895      1026.2      992.59
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            758.99       899.50  937.405969   955.789348
# 2020-02-29            927.54      1088.07  937.405969  1041.763279
#
#                        hw_a6       hw_a12      hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31       1077.457298  1071.950298  756.286884  1029.731897
# 2020-02-29       1219.454286  1384.682978  946.630361  1261.449023
#
#                        hw_m6       hw_m12      hw_m18
# Date_of_Payment
# 2020-01-31       1089.215182  1245.683381  618.372504
# 2020-02-29       1334.975817  1964.508811  698.498099

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['invok_dollars'], label='Train')
plt.plot(test.index, test['invok_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m18'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 18 Model for Chantix Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m18'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 145.29564200482955
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 229.98877792550033

# %% [markdown]
# Try a SARIMA Model

# %% [markdown]
# SARIMA Model with Seasonality of 4

# %%
import pmdarima as pmd
model_s4 = pmd.auto_arima(train['invok_dollars'], m=4, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[4] intercept   : AIC=inf, Time=0.20 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=503.741, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=503.093, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=500.612, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=501.863, Time=0.00 sec
#  ARIMA(0,1,1)(0,0,0)[4] intercept   : AIC=498.616, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,0)[4] intercept   : AIC=500.613, Time=0.05 sec
#  ARIMA(0,1,1)(1,0,1)[4] intercept   : AIC=502.497, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[4] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,2)(0,0,0)[4] intercept   : AIC=500.217, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=501.098, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[4] intercept   : AIC=502.398, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[4]             : AIC=497.609, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,0)[4]             : AIC=499.567, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[4]             : AIC=499.558, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,1)[4]             : AIC=501.472, Time=0.05 sec
#  ARIMA(1,1,1)(0,0,0)[4]             : AIC=499.440, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,0)[4]             : AIC=499.459, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[4]             : AIC=499.440, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[4]             : AIC=501.338, Time=0.05 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[4]
# Total fit time: 0.920 seconds

# %%
model_s4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   36
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -246.805
# Date:                Tue, 15 Mar 2022   AIC                            497.609
# Time:                        19:52:06   BIC                            500.720
# Sample:                             0   HQIC                           498.683
#                                  - 36
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.4951      0.106     -4.661      0.000      -0.703      -0.287
# sigma2      7.744e+04   1.27e+04      6.095      0.000    5.25e+04    1.02e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                11.74
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.76   Skew:                             1.14
# Prob(H) (two-sided):                  0.03   Kurtosis:                         4.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
preds_sar4 = model_s4.predict(test.shape[0])
preds_sar4
# Out:
# array([936.12137338, 936.12137338, 936.12137338, 936.12137338,
#        936.12137338, 936.12137338, 936.12137338, 936.12137338,
#        936.12137338, 936.12137338, 936.12137338, 936.12137338])

# %%
df_preds['sarima4_auto'] = preds_sar4
df_preds['sarima4_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    936.121373
# 2020-02-29    936.121373
# Freq: M, Name: sarima4_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['invok_dollars'], label='Train')
plt.plot(test['invok_dollars'], label='Test')
plt.plot(df_preds['sarima4_auto'], label='SARIMA_4_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 4 Model for Chantix Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima4_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 4 Model: 524.8567489229813
# RMSE for SARIMA with Seasonality of 4 Model: 555.9632990889726

# %% [markdown]
# SARIMA Model with Seasonality of 6

# %%
model_s6 = pmd.auto_arima(train['invok_dollars'], m=6, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[6] intercept   : AIC=inf, Time=0.21 sec
#  ARIMA(0,1,0)(0,0,0)[6] intercept   : AIC=503.741, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[6] intercept   : AIC=501.802, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[6] intercept   : AIC=499.890, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[6]             : AIC=501.863, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[6] intercept   : AIC=498.616, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,0)[6] intercept   : AIC=499.883, Time=0.06 sec
#  ARIMA(0,1,1)(1,0,1)[6] intercept   : AIC=inf, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[6] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,2)(0,0,0)[6] intercept   : AIC=500.217, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[6] intercept   : AIC=501.098, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[6] intercept   : AIC=502.398, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[6]             : AIC=497.609, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,0)[6]             : AIC=498.549, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[6]             : AIC=498.577, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,1)[6]             : AIC=500.526, Time=0.07 sec
#  ARIMA(1,1,1)(0,0,0)[6]             : AIC=499.440, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,0)[6]             : AIC=499.459, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[6]             : AIC=499.440, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[6]             : AIC=501.338, Time=0.05 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[6]
# Total fit time: 0.985 seconds

# %%
model_s6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   36
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -246.805
# Date:                Tue, 15 Mar 2022   AIC                            497.609
# Time:                        19:52:07   BIC                            500.720
# Sample:                             0   HQIC                           498.683
#                                  - 36
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.4951      0.106     -4.661      0.000      -0.703      -0.287
# sigma2      7.744e+04   1.27e+04      6.095      0.000    5.25e+04    1.02e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                11.74
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.76   Skew:                             1.14
# Prob(H) (two-sided):                  0.03   Kurtosis:                         4.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
preds_sar6 = model_s6.predict(test.shape[0])
preds_sar6
# Out:
# array([936.12137338, 936.12137338, 936.12137338, 936.12137338,
#        936.12137338, 936.12137338, 936.12137338, 936.12137338,
#        936.12137338, 936.12137338, 936.12137338, 936.12137338])

# %%
df_preds['sarima6_auto'] = preds_sar6
df_preds['sarima6_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    936.121373
# 2020-02-29    936.121373
# Freq: M, Name: sarima6_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['invok_dollars'], label='Train')
plt.plot(test['invok_dollars'], label='Test')
plt.plot(df_preds['sarima6_auto'], label='SARIMA_6_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 6 Model for Chantix Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima6_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 6 Model: 524.8567489229813
# RMSE for SARIMA with Seasonality of 6 Model: 555.9632990889726

# %% [markdown]
# Try a SARIMA Model with m = 12

# %%
model_s12 = pmd.auto_arima(train['invok_dollars'], m=12, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.25 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=503.741, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=503.038, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=500.595, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=501.863, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=498.616, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=500.597, Time=0.07 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=502.517, Time=0.18 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=500.217, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=501.098, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=502.398, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=497.609, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,0)[12]             : AIC=499.560, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[12]             : AIC=499.556, Time=0.04 sec
#  ARIMA(0,1,1)(1,0,1)[12]             : AIC=inf, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[12]             : AIC=499.440, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,0)[12]             : AIC=499.459, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[12]             : AIC=499.440, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[12]             : AIC=501.338, Time=0.06 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[12]
# Total fit time: 1.162 seconds

# %%
model_s12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   36
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -246.805
# Date:                Tue, 15 Mar 2022   AIC                            497.609
# Time:                        19:52:09   BIC                            500.720
# Sample:                             0   HQIC                           498.683
#                                  - 36
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.4951      0.106     -4.661      0.000      -0.703      -0.287
# sigma2      7.744e+04   1.27e+04      6.095      0.000    5.25e+04    1.02e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                11.74
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.76   Skew:                             1.14
# Prob(H) (two-sided):                  0.03   Kurtosis:                         4.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
preds_sar12 = model_s12.predict(test.shape[0])
preds_sar12
# Out:
# array([936.12137338, 936.12137338, 936.12137338, 936.12137338,
#        936.12137338, 936.12137338, 936.12137338, 936.12137338,
#        936.12137338, 936.12137338, 936.12137338, 936.12137338])

# %%
df_preds['sarima12_auto'] = preds_sar12
df_preds['sarima12_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    936.121373
# 2020-02-29    936.121373
# Freq: M, Name: sarima12_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['invok_dollars'], label='Train')
plt.plot(test['invok_dollars'], label='Test')
plt.plot(df_preds['sarima12_auto'], label='SARIMA_12_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 12 Model for Chantix Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima12_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 12 Model: 524.8567489229813
# RMSE for SARIMA with Seasonality of 12 Model: 555.9632990889726

# %% [markdown]
# Try a SARIMA Model with m = 18

# %%
model_s18 = pmd.auto_arima(train['invok_dollars'], m=18, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[18] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(0,1,0)(0,0,0)[18] intercept   : AIC=503.741, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[18] intercept   : AIC=503.063, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,1)[18] intercept   : AIC=500.191, Time=0.17 sec
#  ARIMA(0,1,0)(0,0,0)[18]             : AIC=501.863, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[18] intercept   : AIC=498.616, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,0)[18] intercept   : AIC=500.188, Time=0.16 sec
#  ARIMA(0,1,1)(1,0,1)[18] intercept   : AIC=502.194, Time=0.20 sec
#  ARIMA(1,1,1)(0,0,0)[18] intercept   : AIC=inf, Time=0.05 sec
#  ARIMA(0,1,2)(0,0,0)[18] intercept   : AIC=500.217, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[18] intercept   : AIC=501.098, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[18] intercept   : AIC=502.398, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,0)[18]             : AIC=497.609, Time=0.02 sec
#  ARIMA(0,1,1)(1,0,0)[18]             : AIC=499.129, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,1)[18]             : AIC=499.132, Time=0.08 sec
#  ARIMA(0,1,1)(1,0,1)[18]             : AIC=inf, Time=0.18 sec
#  ARIMA(1,1,1)(0,0,0)[18]             : AIC=499.440, Time=0.03 sec
#  ARIMA(0,1,2)(0,0,0)[18]             : AIC=499.459, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[18]             : AIC=499.440, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[18]             : AIC=501.338, Time=0.06 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[18]
# Total fit time: 1.893 seconds

# %%
model_s18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   36
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -246.805
# Date:                Tue, 15 Mar 2022   AIC                            497.609
# Time:                        19:52:11   BIC                            500.720
# Sample:                             0   HQIC                           498.683
#                                  - 36
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.4951      0.106     -4.661      0.000      -0.703      -0.287
# sigma2      7.744e+04   1.27e+04      6.095      0.000    5.25e+04    1.02e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                11.74
# Prob(Q):                              0.97   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.76   Skew:                             1.14
# Prob(H) (two-sided):                  0.03   Kurtosis:                         4.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
preds_sar18 = model_s18.predict(test.shape[0])
preds_sar18
# Out:
# array([936.12137338, 936.12137338, 936.12137338, 936.12137338,
#        936.12137338, 936.12137338, 936.12137338, 936.12137338,
#        936.12137338, 936.12137338, 936.12137338, 936.12137338])

# %%
df_preds['sarima18_auto'] = preds_sar18
df_preds['sarima18_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    936.121373
# 2020-02-29    936.121373
# Freq: M, Name: sarima18_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['invok_dollars'], label='Train')
plt.plot(test['invok_dollars'], label='Test')
plt.plot(df_preds['sarima18_auto'], label='SARIMA_18_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 18 Model for Chantix Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 18 Model: 524.8567489229813
# RMSE for SARIMA with Seasonality of 18 Model: 555.9632990889726

# %%
print("Summary of Metrics for Monthly Chantix CMS Payments")
print("_________________________________________________")
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['simple_mean'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_4'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_6'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_12'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['seasonal_18'], squared=False))
print("_________________________________________________")
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['ses'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m12'], squared=False))
print("_________________________________________________")
# Out:
# Summary of Metrics for Monthly Chantix CMS Payments
# _________________________________________________
# MAE for Simple Mean Baseline Model: 355.37249999999995
# RMSE for Simple Mean Baseline Model: 374.9468312863394
# _________________________________________________
# MAE for Seasonal Baseline 4 Shift Model: 390.26500000000004
# RMSE for Seasonal Baseline 4 Shift Model: 438.9094957201693
# _________________________________________________
# MAE for Seasonal Baseline 6 Shift Model: 467.2933333333333
# RMSE for Seasonal Baseline 6 Shift Model: 514.9071487818621
# _________________________________________________
# MAE for Seasonal Baseline 12 Shift Model: 509.585
# RMSE for Seasonal Baseline 12 Shift Model: 576.6662924372581
# _________________________________________________
# MAE for Seasonal Baseline 18 Shift Model: 345.88166666666666
# RMSE for Seasonal Baseline 18 Shift Model: 383.8411832385889
# _________________________________________________
# MAE for Simple Exponential Smoothing Model: 525.7131457771462
# RMSE for Simple Exponential Smoothing Model: 557.0232422933949
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 4 Model: 910.385995047317
# RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model: 1005.9122280495674
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 6 Model: 1020.9044495536219
# RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model: 1124.226447361893
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 12 Model: 1672.5537393636587
# RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model: 1773.1565847400611
# _________________________________________________

# %%
print("Continued Summary of Metrics for Monthly Chantix CMS Payments")
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_m18'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a12'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['hw_a18'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima4_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima6_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima12_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['invok_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['invok_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# Continued Summary of Metrics for Monthly Chantix CMS Payments
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 145.29564200482955
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 229.98877792550033
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 670.4250920873711
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 722.1309748375982
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 780.5912701828323
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 844.9990293364119
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 816.4045821215763
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 884.0088688412732
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 18 Model: 274.675576030541
# RMSE for Holt-Winters Additive with Seasonality of 18 Model: 309.18879530733255
# _________________________________________________
# MAE for SARIMA with Seasonality of 4 Model: 524.8567489229813
# RMSE for SARIMA with Seasonality of 4 Model: 555.9632990889726
# _________________________________________________
# MAE for SARIMA with Seasonality of 6 Model: 524.8567489229813
# RMSE for SARIMA with Seasonality of 6 Model: 555.9632990889726
# _________________________________________________
# MAE for SARIMA with Seasonality of 12 Model: 524.8567489229813
# RMSE for SARIMA with Seasonality of 12 Model: 555.9632990889726
# _________________________________________________
# MAE for SARIMA with Seasonality of 18 Model: 524.8567489229813
# RMSE for SARIMA with Seasonality of 18 Model: 555.9632990889726

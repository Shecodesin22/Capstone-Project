# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cinci_1320 = pd.read_csv('./data/cinci1320.csv', index_col='Date_of_Payment', parse_dates=True).sort_index()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,18,19,47,48,49,50,51,52,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_1320.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     148974               RODNEY
# 2013-08-01                      58931                 PAUL
# 2013-08-01                     812462               ALFRED
# 2013-08-01                     108863                 MARK
# 2013-08-01                     195441           MANOJKUMAR
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                        NaN              VIVIAN
# 2013-08-01                     JOSEPH            FAVORITO
# 2013-08-01                      JAMES            SUGAWARA
# 2013-08-01                          A            MANEGOLD
# 2013-08-01                          S               SINGH
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2013-08-01                                       8000 5 MILE RD
# 2013-08-01                                       7575 5 MILE RD
# 2013-08-01                                     8477 FOXCROFT DR
# 2013-08-01                                     2450 KIPLING AVE
# 2013-08-01                                  10600 MONTGOMERY RD
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2013-08-01                                                  240
# 2013-08-01                                                  NaN
# 2013-08-01                                                  NaN
# 2013-08-01                                            SUITE 104
# 2013-08-01                                            SUITE 200
#
#                 Recipient_City  ... xarelto victoza humira levemir invokana  \
# Date_of_Payment                 ...
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
#
#                 farxiga entresto chantix myrbetriq toujeo
# Date_of_Payment
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
#
# [5 rows x 89 columns]

# %%
cinci_1320['Change_Type'].value_counts()
# Out:
# UNCHANGED    364686
# CHANGED         726
# ADD               1
# Name: Change_Type, dtype: int64

# %%
cinci_1320['humira'].value_counts()
# Out:
# 0    359188
# 1      6225
# Name: humira, dtype: int64

# %%
humira = cinci_1320[(cinci_1320['humira']==1) & (cinci_1320['Number_of_Payments_Included_in_Total_Amount']==1)].copy()

# %%
humira.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     126284             JENNIFER
# 2013-08-01                     228696              MICHAEL
# 2013-08-01                     522396               JORDAN
# 2013-08-01                     254592               ALEXEI
# 2013-08-01                     255498                LOUIS
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                       LYNN             HUGGINS
# 2013-08-01                        NaN          HENRICKSON
# 2013-08-01                      TYLER               JONES
# 2013-08-01                          A                GROM
# 2013-08-01                        NaN          FLASPOHLER
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2013-08-01                                      3333 BURNET AVE
# 2013-08-01                                      3333 BURNET AVE
# 2013-08-01                                      3333 BURNET AVE
# 2013-08-01                                      3333 BURNET AVE
# 2013-08-01                                     2355 NORWOOD AVE
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2013-08-01                                               BLDG E
# 2013-08-01                                                  NaN
# 2013-08-01                                                  NaN
# 2013-08-01                                                  NaN
# 2013-08-01                                                APT 1
#
#                 Recipient_City  ... xarelto victoza humira levemir invokana  \
# Date_of_Payment                 ...
# 2013-08-01          CINCINNATI  ...       0       0      1       0        0
# 2013-08-01          CINCINNATI  ...       0       0      1       0        0
# 2013-08-01          CINCINNATI  ...       0       0      1       0        0
# 2013-08-01          CINCINNATI  ...       0       0      1       0        0
# 2013-08-01          CINCINNATI  ...       0       0      1       0        0
#
#                 farxiga entresto chantix myrbetriq toujeo
# Date_of_Payment
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
#
# [5 rows x 89 columns]

# %%
humira['humira'].value_counts()
# Out:
# 1    6225
# Name: humira, dtype: int64

# %%
humira['Change_Type'].value_counts()
# Out:
# UNCHANGED    6225
# Name: Change_Type, dtype: int64

# %%
humira['humi_dollars'] = [k if ((i ==1) & (j ==1)) else 0 for i, j, k in zip(humira['humira'], humira['Number_of_Payments_Included_in_Total_Amount'], humira['Total_Amount_of_Payment_USDollars'])]

#Ben Peck helped me with this during office hours.  I was oh-so-close but not quite there!

# %%
humira['humi_dollars'].sum()
# Out:
# 1022517.3

# %%
humira.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     126284             JENNIFER
# 2013-08-01                     228696              MICHAEL
# 2013-08-01                     522396               JORDAN
# 2013-08-01                     254592               ALEXEI
# 2013-08-01                     255498                LOUIS
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                       LYNN             HUGGINS
# 2013-08-01                        NaN          HENRICKSON
# 2013-08-01                      TYLER               JONES
# 2013-08-01                          A                GROM
# 2013-08-01                        NaN          FLASPOHLER
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2013-08-01                                      3333 BURNET AVE
# 2013-08-01                                      3333 BURNET AVE
# 2013-08-01                                      3333 BURNET AVE
# 2013-08-01                                      3333 BURNET AVE
# 2013-08-01                                     2355 NORWOOD AVE
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2013-08-01                                               BLDG E
# 2013-08-01                                                  NaN
# 2013-08-01                                                  NaN
# 2013-08-01                                                  NaN
# 2013-08-01                                                APT 1
#
#                 Recipient_City  ... victoza humira levemir invokana farxiga  \
# Date_of_Payment                 ...
# 2013-08-01          CINCINNATI  ...       0      1       0        0       0
# 2013-08-01          CINCINNATI  ...       0      1       0        0       0
# 2013-08-01          CINCINNATI  ...       0      1       0        0       0
# 2013-08-01          CINCINNATI  ...       0      1       0        0       0
# 2013-08-01          CINCINNATI  ...       0      1       0        0       0
#
#                 entresto chantix myrbetriq toujeo humi_dollars
# Date_of_Payment
# 2013-08-01             0       0         0      0        23.64
# 2013-08-01             0       0         0      0        23.63
# 2013-08-01             0       0         0      0        23.63
# 2013-08-01             0       0         0      0        23.63
# 2013-08-01             0       0         0      0        11.49
#
# [5 rows x 90 columns]

# %%
humira['Physician_Profile_ID'].value_counts()
# Out:
# 205125    703
# 113709    284
# 76196     214
# 26710     209
# 245630    151
#          ...
# 806286      1
# 465998      1
# 543540      1
# 392482      1
# 209635      1
# Name: Physician_Profile_ID, Length: 250, dtype: int64

# %% [markdown]
# Appy Benford's Law to data of physician with most reimbursements for humira

# %%
benny_humi = humira[humira['Physician_Profile_ID']== 435991].copy()

# %%
benny_humi.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2015-09-24        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2015-09-24                     435991                CYRIL
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2015-09-24                          K              MELVIN
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2015-09-24                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2015-09-24                                      3131 HARVEY AVE
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2015-09-24                                             STE. 104
#
#                 Recipient_City  ... victoza humira levemir invokana farxiga  \
# Date_of_Payment                 ...
# 2015-09-24          CINCINNATI  ...       0      1       0        0       0
#
#                 entresto chantix myrbetriq toujeo humi_dollars
# Date_of_Payment
# 2015-09-24             0       0         0      0        86.36
#
# [1 rows x 90 columns]

# %% [markdown]
# Set up columns for Benford's Law Graph

# %% [markdown]
# Learned about this in Noah's lesson during week 12 and code is based on what he shared.

# %%
digits = list(range(1,10))
benford = [np.log10(1 + (1/d)) for d in digits]
benford
# Out:
# [0.3010299956639812,
#  0.17609125905568124,
#  0.12493873660829993,
#  0.09691001300805642,
#  0.07918124604762482,
#  0.06694678963061322,
#  0.05799194697768673,
#  0.05115252244738129,
#  0.04575749056067514]

# %%
benny_humi['prep_dollars'] = [amt if amt > 1 else amt*10 for amt in benny_humi['humi_dollars']]

# %%
benny_humi['FIRST_DIGIT'] = [int(str(amt)[0]) for amt in benny_humi['prep_dollars']]

# %%
benny_humi.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2015-09-24        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2015-09-24                     435991                CYRIL
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2015-09-24                          K              MELVIN
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2015-09-24                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2015-09-24                                      3131 HARVEY AVE
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2015-09-24                                             STE. 104
#
#                 Recipient_City  ... levemir invokana farxiga entresto chantix  \
# Date_of_Payment                 ...
# 2015-09-24          CINCINNATI  ...       0        0       0        0       0
#
#                 myrbetriq toujeo humi_dollars prep_dollars FIRST_DIGIT
# Date_of_Payment
# 2015-09-24              0      0        86.36        86.36           8
#
# [1 rows x 92 columns]

# %%
percentages = benny_humi['FIRST_DIGIT'].value_counts(normalize = True).sort_index()

# %%
plt.bar(digits, benford)

plt.plot(percentages, color = 'orange', marker = 'o')
plt.xticks(digits);

# %%
drop_cols = ['Change_Type','Covered_Recipient_Type',
'Physician_First_Name',
'Physician_Middle_Name',
'Physician_Last_Name',
'Physician_Name_Suffix',
'Recipient_Primary_Business_Street_Address_Line1',
'Recipient_Primary_Business_Street_Address_Line2',
'Recipient_City',
'Recipient_State',
'Recipient_Zip_Code',
'Recipient_Country',
'Physician_Primary_Type',
'Physician_Specialty',
'Physician_License_State_code1',
'Physician_License_State_code2',
'Physician_License_State_code3',
'Physician_License_State_code4',
'Physician_License_State_code5',
'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
'Form_of_Payment_or_Transfer_of_Value',
'City_of_Travel',
'State_of_Travel',
'Country_of_Travel',
'Physician_Ownership_Indicator',
'Third_Party_Payment_Recipient_Indicator',
'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
'Charity_Indicator',
'Third_Party_Equals_Covered_Recipient_Indicator',
'Contextual_Information',
'Delay_in_Publication_Indicator',
'Dispute_Status_for_Publication',
'Related_Product_Indicator',
'Covered_or_Noncovered_Indicator_1',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Product_Category_or_Therapeutic_Area_1',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Associated_Drug_or_Biological_NDC_1',
'Covered_or_Noncovered_Indicator_2',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Product_Category_or_Therapeutic_Area_2',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Associated_Drug_or_Biological_NDC_2',
'Covered_or_Noncovered_Indicator_3',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Product_Category_or_Therapeutic_Area_3',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Associated_Drug_or_Biological_NDC_3',
'Covered_or_Noncovered_Indicator_4',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Product_Category_or_Therapeutic_Area_4',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Associated_Drug_or_Biological_NDC_4',
'Covered_or_Noncovered_Indicator_5',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Product_Category_or_Therapeutic_Area_5',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Associated_Drug_or_Biological_NDC_5', 
'Physician_Profile_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
'Total_Amount_of_Payment_USDollars','Number_of_Payments_Included_in_Total_Amount', 
'Nature_of_Payment_or_Transfer_of_Value', 'Record_ID', 
'Payment_Publication_Date', 'Program_Year',
'NDC_of_Associated_Covered_Drug_or_Biological1',
'NDC_of_Associated_Covered_Drug_or_Biological2',
'NDC_of_Associated_Covered_Drug_or_Biological3',
'NDC_of_Associated_Covered_Drug_or_Biological4',
'NDC_of_Associated_Covered_Drug_or_Biological5',
'Name_of_Associated_Covered_Device_or_Medical_Supply1',
'Name_of_Associated_Covered_Device_or_Medical_Supply2',
'Name_of_Associated_Covered_Device_or_Medical_Supply3',
'Name_of_Associated_Covered_Device_or_Medical_Supply4',
'Name_of_Associated_Covered_Device_or_Medical_Supply5',
'xarelto', 'farxiga', 'victoza', 'invokana', 'levemir',
'entresto', 'chantix', 'myrbetriq', 'toujeo']

# %%
humira.drop(columns = drop_cols, inplace = True)

# %%
humira.head()
# Out:
#                  humira  humi_dollars
# Date_of_Payment
# 2013-08-01            1         23.64
# 2013-08-01            1         23.63
# 2013-08-01            1         23.63
# 2013-08-01            1         23.63
# 2013-08-01            1         11.49

# %% [markdown]
# Was reminded of the importance of checking data for outliers by this article, and modeled my filtering code below on this article:
# https://www.analyticsvidhya.com/blog/2021/08/holt-winters-method-for-time-series-analysis/

# %%
sns.boxplot(x = humira['humi_dollars']);

# %%
humira['z_score'] = [ ((i - humira['humi_dollars'].mean())/humira['humi_dollars'].std()) for i in humira['humi_dollars']]

# %%
humira.shape
# Out:
# (6225, 3)

# %%
humirab = humira[(np.abs(humira['z_score']) < 3)].copy()

# %%
humirab.shape
# Out:
# (6021, 3)

# %%
humira_daily = humirab.resample('d').sum()

# %%
humira_daily.head()
# Out:
#                  humira  humi_dollars   z_score
# Date_of_Payment
# 2013-08-01            7        152.67 -1.498164
# 2013-08-02            0          0.00  0.000000
# 2013-08-03            0          0.00  0.000000
# 2013-08-04            1        118.75 -0.068376
# 2013-08-05            0          0.00  0.000000

# %%
humira_daily.sort_index()
# Out:
#                  humira  humi_dollars   z_score
# Date_of_Payment
# 2013-08-01            7        152.67 -1.498164
# 2013-08-02            0          0.00  0.000000
# 2013-08-03            0          0.00  0.000000
# 2013-08-04            1        118.75 -0.068376
# 2013-08-05            0          0.00  0.000000
# ...                 ...           ...       ...
# 2020-12-19            0          0.00  0.000000
# 2020-12-20            0          0.00  0.000000
# 2020-12-21            1       1425.00  1.894196
# 2020-12-22            0          0.00  0.000000
# 2020-12-23            3         16.78 -0.715164
#
# [2702 rows x 3 columns]

# %% [markdown]
# Look at some plots

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf

# %%
plot_acf(humira_daily['humi_dollars'], alpha=None, lags=24);

# %%
plot_pacf(humira_daily['humi_dollars'], alpha=None, lags=24);
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# Adding 1 to the weekly sales for each observation so that Holt_winters will work.

# %%
humira_daily['humi_dollars'] = [i+1 for i in humira_daily['humi_dollars']]

# %% [markdown]
# Set up Train and Test Sets using 2013 - 2020 Data

# %%
train = humira_daily.loc[:'2019-12-31']
train
# Out:
#                  humira  humi_dollars   z_score
# Date_of_Payment
# 2013-08-01            7        153.67 -1.498164
# 2013-08-02            0          1.00  0.000000
# 2013-08-03            0          1.00  0.000000
# 2013-08-04            1        119.75 -0.068376
# 2013-08-05            0          1.00  0.000000
# ...                 ...           ...       ...
# 2019-12-27            0          1.00  0.000000
# 2019-12-28            0          1.00  0.000000
# 2019-12-29            0          1.00  0.000000
# 2019-12-30            0          1.00  0.000000
# 2019-12-31            0          1.00  0.000000
#
# [2344 rows x 3 columns]

# %%
train['humi_dollars'].max()
# Out:
# 5621.09

# %%
train.describe()
# Out:
#             humira  humi_dollars      z_score
# count  2344.000000   2344.000000  2344.000000
# mean      2.441553    141.615422    -0.391288
# std       3.333888    402.322837     0.795294
# min       0.000000      1.000000    -4.681366
# 25%       0.000000      1.000000    -0.689901
# 50%       1.000000     14.600000    -0.193019
# 75%       4.000000     60.890000     0.000000
# max      22.000000   5621.090000     4.106942

# %%
train.index.freq = 'D'

# %%
train.shape
# Out:
# (2344, 3)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2344 entries, 2013-08-01 to 2019-12-31
# Freq: D
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   humira        2344 non-null   int64
#  1   humi_dollars  2344 non-null   float64
#  2   z_score       2344 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 73.2 KB

# %%
train.index
# Out:
# DatetimeIndex(['2013-08-01', '2013-08-02', '2013-08-03', '2013-08-04',
#                '2013-08-05', '2013-08-06', '2013-08-07', '2013-08-08',
#                '2013-08-09', '2013-08-10',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', name='Date_of_Payment', length=2344, freq='D')

# %%
test = humira_daily.loc['2020-01-01':]
test
# Out:
#                  humira  humi_dollars   z_score
# Date_of_Payment
# 2020-01-01            0          1.00  0.000000
# 2020-01-02            0          1.00  0.000000
# 2020-01-03            0          1.00  0.000000
# 2020-01-04            0          1.00  0.000000
# 2020-01-05            0          1.00  0.000000
# ...                 ...           ...       ...
# 2020-12-19            0          1.00  0.000000
# 2020-12-20            0          1.00  0.000000
# 2020-12-21            1       1426.00  1.894196
# 2020-12-22            0          1.00  0.000000
# 2020-12-23            3         17.78 -0.715164
#
# [358 rows x 3 columns]

# %%
test.describe()
# Out:
#            humira  humi_dollars     z_score
# count  358.000000    358.000000  358.000000
# mean     0.832402     37.032989   -0.151292
# std      1.716573    176.542408    0.465437
# min      0.000000      1.000000   -2.498522
# 25%      0.000000      1.000000   -0.218369
# 50%      0.000000      1.000000    0.000000
# 75%      1.000000     17.952500    0.000000
# max     11.000000   1430.740000    1.894196

# %%
test.shape
# Out:
# (358, 3)

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')

plt.legend(loc='best')
plt.title("Daily Payments for Humira Drug");

# %% [markdown]
# Baseline - Simple Mean (Naive Model)

# %%
df_preds = test.copy(deep=True)
df_preds
# Out:
#                  humira  humi_dollars   z_score
# Date_of_Payment
# 2020-01-01            0          1.00  0.000000
# 2020-01-02            0          1.00  0.000000
# 2020-01-03            0          1.00  0.000000
# 2020-01-04            0          1.00  0.000000
# 2020-01-05            0          1.00  0.000000
# ...                 ...           ...       ...
# 2020-12-19            0          1.00  0.000000
# 2020-12-20            0          1.00  0.000000
# 2020-12-21            1       1426.00  1.894196
# 2020-12-22            0          1.00  0.000000
# 2020-12-23            3         17.78 -0.715164
#
# [358 rows x 3 columns]

# %%
df_preds['simple_mean'] = train['humi_dollars'].mean()
df_preds
# Out:
#                  humira  humi_dollars   z_score  simple_mean
# Date_of_Payment
# 2020-01-01            0          1.00  0.000000   141.615422
# 2020-01-02            0          1.00  0.000000   141.615422
# 2020-01-03            0          1.00  0.000000   141.615422
# 2020-01-04            0          1.00  0.000000   141.615422
# 2020-01-05            0          1.00  0.000000   141.615422
# ...                 ...           ...       ...          ...
# 2020-12-19            0          1.00  0.000000   141.615422
# 2020-12-20            0          1.00  0.000000   141.615422
# 2020-12-21            1       1426.00  1.894196   141.615422
# 2020-12-22            0          1.00  0.000000   141.615422
# 2020-12-23            3         17.78 -0.715164   141.615422
#
# [358 rows x 4 columns]

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['simple_mean'], label="Baseline (Mean)")

plt.legend(loc='best')
plt.title("Baseline (Mean) Forecast for Daily Humira Payments");

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['simple_mean'], squared=False))
# Out:
# MAE for Simple Mean Baseline Model: 147.59196772456
# RMSE for Simple Mean Baseline Model: 204.9820671694276

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 7

# %%
df_preds['seasonal_7'] = train['humi_dollars'].shift(7, freq='D') 
df_preds.head(2)
# Out:
#                  humira  humi_dollars  z_score  simple_mean  seasonal_7
# Date_of_Payment
# 2020-01-01            0           1.0      0.0   141.615422         1.0
# 2020-01-02            0           1.0      0.0   141.615422         1.0

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_7'], label='Seasonal 7')

plt.legend(loc='best')
plt.title("Seasonal 7 Forecast for Daily Humira Payments");

# %%
df_preds['seasonal_7'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 7 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_7']))
print("RMSE for Seasonal Baseline 7 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_7'], squared=False))
# Out:
# MAE for Seasonal Baseline 7 Shift Model: 37.01343575418994
# RMSE for Seasonal Baseline 7 Shift Model: 180.14235222790091

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 52

# %%
df_preds['seasonal_52'] = train['humi_dollars'].shift(52, freq='D') 
df_preds.head(2)
# Out:
#                  humira  humi_dollars  z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01            0           1.0      0.0   141.615422         1.0
# 2020-01-02            0           1.0      0.0   141.615422         1.0
#
#                  seasonal_52
# Date_of_Payment
# 2020-01-01              1.00
# 2020-01-02             42.82

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_52'], label='Seasonal 52')

plt.legend(loc='best')
plt.title("Seasonal 52 Forecast for Daily Humira Payments");

# %%
df_preds['seasonal_52'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 52 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_52']))
print("RMSE for Seasonal Baseline 52 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_52'], squared=False))
# Out:
# MAE for Seasonal Baseline 52 Shift Model: 38.130418994413404
# RMSE for Seasonal Baseline 52 Shift Model: 180.41469005596198

# %% [markdown]
# This is barely slightly better than the baseline model which had an MSE of 755.49.

# %% [markdown]
# Try a Seasonal Model with a shift of 364

# %%
df_preds['seasonal_364'] = train['humi_dollars'].shift(364, freq='D') 
df_preds.head(2)
# Out:
#                  humira  humi_dollars  z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01            0           1.0      0.0   141.615422         1.0
# 2020-01-02            0           1.0      0.0   141.615422         1.0
#
#                  seasonal_52  seasonal_364
# Date_of_Payment
# 2020-01-01              1.00           1.0
# 2020-01-02             42.82           1.0

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_364'], label='Seasonal')

plt.legend(loc='best')
plt.title("Seasonal 364 Forecast for Daily Humira Payments");

# %%
print("MAE for Seasonal Baseline 364 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_364']))
print("RMSE for Seasonal Baseline 364 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_364'], squared=False))
# Out:
# MAE for Seasonal Baseline 364 Shift Model: 107.52022346368715
# RMSE for Seasonal Baseline 364 Shift Model: 301.1746124480618

# %% [markdown]
# Simple Exponential Smoothing Model

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing

# %%
ses = SimpleExpSmoothing(train['humi_dollars']).fit(smoothing_level=.5)

# %%
ses.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ==============================================================================
# Dep. Variable:           humi_dollars   No. Observations:                 2344
# Model:             SimpleExpSmoothing   SSE                      478292610.078
# Optimized:                       True   AIC                          28662.023
# Trend:                           None   BIC                          28673.542
# Seasonal:                        None   AICC                         28662.040
# Seasonal Periods:                None   Date:                 Sun, 13 Mar 2022
# Box-Cox:                        False   Time:                         23:24:18
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.5000000                alpha                False
# initial_level              89.779918                  l.0                 True
# ------------------------------------------------------------------------------
# """

# %%
ses_forecast = ses.forecast(len(test))

# %%
df_preds['ses'] = ses_forecast

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['ses'], label='Simple Exponential Smoothing')

plt.legend(loc='best')
plt.title("Simple Exponential Smoothing for Humira Daily Payments");

# %%
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['ses'], squared=False))
# Out:
# MAE for Simple Exponential Smoothing Model: 36.04026093306699
# RMSE for Simple Exponential Smoothing Model: 179.93665263760676

# %% [markdown]
# This is horrible!  The MSE is nearly twice that of the baseline and seasonal models!  Will discard this model.

# %% [markdown]
# Holt-Winters Multiplicative Model with Seasonality of 52

# %%
hw_m52 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=52, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m52.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             humi_dollars   No. Observations:                 2344
# Model:             ExponentialSmoothing   SSE                      555685996.328
# Optimized:                         True   AIC                          29121.578
# Trend:                   Multiplicative   BIC                          29444.116
# Seasonal:                Multiplicative   AICC                         29124.573
# Seasonal Periods:                    52   Date:                 Sun, 13 Mar 2022
# Box-Cox:                          False   Time:                         23:24:19
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0050000                alpha                 True
# smoothing_trend                  0.0001                 beta                 True
# smoothing_seasonal            0.0355357                gamma                 True
# initial_level                 65.042897                  l.0                 True
# initial_trend                 0.9778656                  b.0                 True
# initial_seasons.0             1.2397252                  s.0                 True
# initial_seasons.1             0.0833779                  s.1                 True
# initial_seasons.2             0.2532999                  s.2                 True
# initial_seasons.3             0.2140759                  s.3                 True
# initial_seasons.4             0.0408063                  s.4                 True
# initial_seasons.5             1.0748090                  s.5                 True
# initial_seasons.6             0.2184073                  s.6                 True
# initial_seasons.7             1.3007793                  s.7                 True
# initial_seasons.8             0.2931167                  s.8                 True
# initial_seasons.9             1.1541531                  s.9                 True
# initial_seasons.10            0.1994097                 s.10                 True
# initial_seasons.11            0.0745990                 s.11                 True
# initial_seasons.12            0.0112803                 s.12                 True
# initial_seasons.13            0.1656654                 s.13                 True
# initial_seasons.14            3.2743692                 s.14                 True
# initial_seasons.15            0.5251804                 s.15                 True
# initial_seasons.16            0.2810095                 s.16                 True
# initial_seasons.17            2.8285532                 s.17                 True
# initial_seasons.18            0.0424418                 s.18                 True
# initial_seasons.19            0.2907646                 s.19                 True
# initial_seasons.20            0.2491683                 s.20                 True
# initial_seasons.21            0.1368250                 s.21                 True
# initial_seasons.22            0.2272307                 s.22                 True
# initial_seasons.23            0.2461098                 s.23                 True
# initial_seasons.24            0.9289441                 s.24                 True
# initial_seasons.25            2.3897775                 s.25                 True
# initial_seasons.26            0.2562144                 s.26                 True
# initial_seasons.27            0.9318296                 s.27                 True
# initial_seasons.28            0.0467817                 s.28                 True
# initial_seasons.29            0.1795475                 s.29                 True
# initial_seasons.30            0.4467133                 s.30                 True
# initial_seasons.31            0.1767495                 s.31                 True
# initial_seasons.32            0.9881738                 s.32                 True
# initial_seasons.33            0.5667719                 s.33                 True
# initial_seasons.34            12.347493                 s.34                 True
# initial_seasons.35            1.3936286                 s.35                 True
# initial_seasons.36            2.4919479                 s.36                 True
# initial_seasons.37            0.1839399                 s.37                 True
# initial_seasons.38            4.3942970                 s.38                 True
# initial_seasons.39            2.8633241                 s.39                 True
# initial_seasons.40            3.8188216                 s.40                 True
# initial_seasons.41            0.3219245                 s.41                 True
# initial_seasons.42            0.5481589                 s.42                 True
# initial_seasons.43            0.0135191                 s.43                 True
# initial_seasons.44            0.0682031                 s.44                 True
# initial_seasons.45            0.7490657                 s.45                 True
# initial_seasons.46            0.2758657                 s.46                 True
# initial_seasons.47            0.4741574                 s.47                 True
# initial_seasons.48            0.2775264                 s.48                 True
# initial_seasons.49            0.0171993                 s.49                 True
# initial_seasons.50            0.0164389                 s.50                 True
# initial_seasons.51            0.4078284                 s.51                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m52'] = hw_m52.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01            0           1.0      0.0   141.615422         1.0
# 2020-01-02            0           1.0      0.0   141.615422         1.0
#
#                  seasonal_52  seasonal_364       ses    hw_m52
# Date_of_Payment
# 2020-01-01              1.00           1.0  1.018596  2.943739
# 2020-01-02             42.82           1.0  1.018596  3.264384

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m52'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative with Seasonality of 52 for Humira Daily Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 52 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m52']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 52 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m52'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 52 Model: 36.76859765925056
# RMSE for Holt-Winters Multiplicative with Seasonality of 52 Model: 179.9893581584501

# %% [markdown]
# This is not as good as the baseline or the seasonal models!

# %%
hw_m364 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=364, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m364.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             humi_dollars   No. Observations:                 2344
# Model:             ExponentialSmoothing   SSE                      663208101.581
# Optimized:                         True   AIC                          30160.197
# Trend:                   Multiplicative   BIC                          32279.735
# Seasonal:                Multiplicative   AICC                         30299.346
# Seasonal Periods:                   364   Date:                 Sun, 13 Mar 2022
# Box-Cox:                          False   Time:                         23:24:20
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.0050000                alpha                 True
# smoothing_trend                   0.0001                 beta                 True
# smoothing_seasonal             0.0710714                gamma                 True
# initial_level                  131.91177                  l.0                 True
# initial_trend                  0.9985730                  b.0                 True
# initial_seasons.0              0.1415061                  s.0                 True
# initial_seasons.1              0.1426649                  s.1                 True
# initial_seasons.2              0.0549780                  s.2                 True
# initial_seasons.3              0.0063276                  s.3                 True
# initial_seasons.4              0.2081661                  s.4                 True
# initial_seasons.5              2.2370877                  s.5                 True
# initial_seasons.6              0.1408528                  s.6                 True
# initial_seasons.7              1.4156736                  s.7                 True
# initial_seasons.8              0.0529852                  s.8                 True
# initial_seasons.9              0.0459136                  s.9                 True
# initial_seasons.10             0.0064671                 s.10                 True
# initial_seasons.11             4.6944739                 s.11                 True
# initial_seasons.12             0.1069408                 s.12                 True
# initial_seasons.13             0.3740637                 s.13                 True
# initial_seasons.14             0.3465798                 s.14                 True
# initial_seasons.15             0.0933746                 s.15                 True
# initial_seasons.16             0.0064926                 s.16                 True
# initial_seasons.17             0.0064926                 s.17                 True
# initial_seasons.18             2.5103218                 s.18                 True
# initial_seasons.19             2.5090770                 s.19                 True
# initial_seasons.20             0.0837394                 s.20                 True
# initial_seasons.21             0.7871593                 s.21                 True
# initial_seasons.22             3.1657660                 s.22                 True
# initial_seasons.23             2.1208374                 s.23                 True
# initial_seasons.24             0.0064833                 s.24                 True
# initial_seasons.25             0.1913822                 s.25                 True
# initial_seasons.26             0.2190261                 s.26                 True
# initial_seasons.27             0.1549200                 s.27                 True
# initial_seasons.28             0.3434647                 s.28                 True
# initial_seasons.29             0.2032523                 s.29                 True
# initial_seasons.30             0.0065304                 s.30                 True
# initial_seasons.31             0.0065278                 s.31                 True
# initial_seasons.32             0.3487246                 s.32                 True
# initial_seasons.33             0.3823395                 s.33                 True
# initial_seasons.34             0.5669494                 s.34                 True
# initial_seasons.35             0.3704171                 s.35                 True
# initial_seasons.36             0.0866127                 s.36                 True
# initial_seasons.37             1.8132582                 s.37                 True
# initial_seasons.38             0.0065616                 s.38                 True
# initial_seasons.39             0.0065617                 s.39                 True
# initial_seasons.40             0.2211103                 s.40                 True
# initial_seasons.41             0.2763030                 s.41                 True
# initial_seasons.42             0.0615898                 s.42                 True
# initial_seasons.43             0.0431864                 s.43                 True
# initial_seasons.44             0.0064087                 s.44                 True
# initial_seasons.45             0.0064087                 s.45                 True
# initial_seasons.46             1.3739532                 s.46                 True
# initial_seasons.47             1.9828200                 s.47                 True
# initial_seasons.48             0.5043666                 s.48                 True
# initial_seasons.49             1.3078935                 s.49                 True
# initial_seasons.50             3.0481267                 s.50                 True
# initial_seasons.51             0.0063502                 s.51                 True
# initial_seasons.52             0.0063494                 s.52                 True
# initial_seasons.53             2.7455979                 s.53                 True
# initial_seasons.54             0.6043324                 s.54                 True
# initial_seasons.55             0.4702345                 s.55                 True
# initial_seasons.56             0.4884615                 s.56                 True
# initial_seasons.57             0.6742155                 s.57                 True
# initial_seasons.58             0.0064572                 s.58                 True
# initial_seasons.59             0.0064572                 s.59                 True
# initial_seasons.60             0.2026267                 s.60                 True
# initial_seasons.61             0.9166240                 s.61                 True
# initial_seasons.62             0.0707268                 s.62                 True
# initial_seasons.63             0.3687764                 s.63                 True
# initial_seasons.64             0.1768244                 s.64                 True
# initial_seasons.65             0.0064140                 s.65                 True
# initial_seasons.66             0.0064140                 s.66                 True
# initial_seasons.67             3.0075505                 s.67                 True
# initial_seasons.68             0.9412315                 s.68                 True
# initial_seasons.69             2.4341157                 s.69                 True
# initial_seasons.70             5.2013806                 s.70                 True
# initial_seasons.71             0.8626208                 s.71                 True
# initial_seasons.72             2.0824572                 s.72                 True
# initial_seasons.73             0.0062083                 s.73                 True
# initial_seasons.74             2.8253608                 s.74                 True
# initial_seasons.75             4.9792854                 s.75                 True
# initial_seasons.76             4.0904879                 s.76                 True
# initial_seasons.77             0.8211159                 s.77                 True
# initial_seasons.78             1.0128294                 s.78                 True
# initial_seasons.79             1.1877850                 s.79                 True
# initial_seasons.80             0.1059500                 s.80                 True
# initial_seasons.81             4.3473050                 s.81                 True
# initial_seasons.82             0.3710361                 s.82                 True
# initial_seasons.83             2.0075307                 s.83                 True
# initial_seasons.84             1.3571519                 s.84                 True
# initial_seasons.85             0.6539267                 s.85                 True
# initial_seasons.86             0.0063038                 s.86                 True
# initial_seasons.87             0.0063038                 s.87                 True
# initial_seasons.88             0.5281839                 s.88                 True
# initial_seasons.89             2.5322474                 s.89                 True
# initial_seasons.90             1.8189685                 s.90                 True
# initial_seasons.91             4.2662658                 s.91                 True
# initial_seasons.92             0.7305541                 s.92                 True
# initial_seasons.93             0.0062703                 s.93                 True
# initial_seasons.94             0.3430302                 s.94                 True
# initial_seasons.95             4.7077733                 s.95                 True
# initial_seasons.96             1.9147735                 s.96                 True
# initial_seasons.97             0.1228506                 s.97                 True
# initial_seasons.98             0.0355536                 s.98                 True
# initial_seasons.99             0.3088381                 s.99                 True
# initial_seasons.100            0.0063164                s.100                 True
# initial_seasons.101            0.0063270                s.101                 True
# initial_seasons.102            0.2325963                s.102                 True
# initial_seasons.103            0.1660988                s.103                 True
# initial_seasons.104            1.3901069                s.104                 True
# initial_seasons.105            0.7170939                s.105                 True
# initial_seasons.106            1.7807914                s.106                 True
# initial_seasons.107            0.0288225                s.107                 True
# initial_seasons.108            0.0840024                s.108                 True
# initial_seasons.109            2.8750653                s.109                 True
# initial_seasons.110            4.7788517                s.110                 True
# initial_seasons.111            0.4603459                s.111                 True
# initial_seasons.112            1.3922660                s.112                 True
# initial_seasons.113            2.9152598                s.113                 True
# initial_seasons.114            0.0063239                s.114                 True
# initial_seasons.115            0.0063247                s.115                 True
# initial_seasons.116            7.4034689                s.116                 True
# initial_seasons.117            0.3651736                s.117                 True
# initial_seasons.118            2.6733523                s.118                 True
# initial_seasons.119            0.0062985                s.119                 True
# initial_seasons.120            0.0062997                s.120                 True
# initial_seasons.121            0.0062999                s.121                 True
# initial_seasons.122            0.0062996                s.122                 True
# initial_seasons.123            0.0896357                s.123                 True
# initial_seasons.124            0.3549014                s.124                 True
# initial_seasons.125            5.0839124                s.125                 True
# initial_seasons.126            0.5208021                s.126                 True
# initial_seasons.127            0.1308398                s.127                 True
# initial_seasons.128            1.7569814                s.128                 True
# initial_seasons.129            0.0063469                s.129                 True
# initial_seasons.130            2.8991830                s.130                 True
# initial_seasons.131            0.2961342                s.131                 True
# initial_seasons.132            3.4161021                s.132                 True
# initial_seasons.133            1.7935171                s.133                 True
# initial_seasons.134            0.7583418                s.134                 True
# initial_seasons.135            0.0288506                s.135                 True
# initial_seasons.136            0.0063584                s.136                 True
# initial_seasons.137            0.6836614                s.137                 True
# initial_seasons.138            0.3190998                s.138                 True
# initial_seasons.139            0.2874249                s.139                 True
# initial_seasons.140            0.4502666                s.140                 True
# initial_seasons.141            0.9194976                s.141                 True
# initial_seasons.142            0.0063766                s.142                 True
# initial_seasons.143            0.0063775                s.143                 True
# initial_seasons.144            2.5866319                s.144                 True
# initial_seasons.145            0.2599160                s.145                 True
# initial_seasons.146            0.0265742                s.146                 True
# initial_seasons.147            0.1083460                s.147                 True
# initial_seasons.148            0.0064035                s.148                 True
# initial_seasons.149            0.0064146                s.149                 True
# initial_seasons.150            0.0064169                s.150                 True
# initial_seasons.151            0.0064211                s.151                 True
# initial_seasons.152            0.0064247                s.152                 True
# initial_seasons.153            0.1474397                s.153                 True
# initial_seasons.154            0.0064332                s.154                 True
# initial_seasons.155            0.0064296                s.155                 True
# initial_seasons.156            0.0064289                s.156                 True
# initial_seasons.157            0.0064289                s.157                 True
# initial_seasons.158            0.0224634                s.158                 True
# initial_seasons.159            0.1229674                s.159                 True
# initial_seasons.160            1.1245300                s.160                 True
# initial_seasons.161            0.2444412                s.161                 True
# initial_seasons.162            0.8291869                s.162                 True
# initial_seasons.163            2.0100952                s.163                 True
# initial_seasons.164            0.0064638                s.164                 True
# initial_seasons.165            0.9399770                s.165                 True
# initial_seasons.166            0.1284893                s.166                 True
# initial_seasons.167            0.7813073                s.167                 True
# initial_seasons.168            0.4409754                s.168                 True
# initial_seasons.169            0.4793755                s.169                 True
# initial_seasons.170            0.0064112                s.170                 True
# initial_seasons.171            0.0064112                s.171                 True
# initial_seasons.172            0.1397429                s.172                 True
# initial_seasons.173            0.4133344                s.173                 True
# initial_seasons.174            1.0826274                s.174                 True
# initial_seasons.175            7.6031005                s.175                 True
# initial_seasons.176            3.4559936                s.176                 True
# initial_seasons.177            0.1102611                s.177                 True
# initial_seasons.178            0.0064603                s.178                 True
# initial_seasons.179            2.8301850                s.179                 True
# initial_seasons.180            0.0971438                s.180                 True
# initial_seasons.181            0.8948373                s.181                 True
# initial_seasons.182            2.4816355                s.182                 True
# initial_seasons.183            1.6382764                s.183                 True
# initial_seasons.184            0.0062344                s.184                 True
# initial_seasons.185            0.0062364                s.185                 True
# initial_seasons.186            0.0608314                s.186                 True
# initial_seasons.187            0.3296920                s.187                 True
# initial_seasons.188            0.3676089                s.188                 True
# initial_seasons.189            0.6314528                s.189                 True
# initial_seasons.190            10.737098                s.190                 True
# initial_seasons.191            0.0062759                s.191                 True
# initial_seasons.192            0.0062766                s.192                 True
# initial_seasons.193            0.1266929                s.193                 True
# initial_seasons.194            0.3706161                s.194                 True
# initial_seasons.195            0.9034069                s.195                 True
# initial_seasons.196            3.7055356                s.196                 True
# initial_seasons.197            2.0626314                s.197                 True
# initial_seasons.198            0.0062629                s.198                 True
# initial_seasons.199            0.0062629                s.199                 True
# initial_seasons.200            0.0925588                s.200                 True
# initial_seasons.201            1.3957395                s.201                 True
# initial_seasons.202            0.8008636                s.202                 True
# initial_seasons.203            2.2174913                s.203                 True
# initial_seasons.204            0.5918199                s.204                 True
# initial_seasons.205            0.0062437                s.205                 True
# initial_seasons.206            2.4413224                s.206                 True
# initial_seasons.207            3.0946852                s.207                 True
# initial_seasons.208            2.2897077                s.208                 True
# initial_seasons.209            0.3033392                s.209                 True
# initial_seasons.210            3.3008321                s.210                 True
# initial_seasons.211            0.6932174                s.211                 True
# initial_seasons.212            0.6423273                s.212                 True
# initial_seasons.213            0.0062559                s.213                 True
# initial_seasons.214            0.1196922                s.214                 True
# initial_seasons.215            1.7864420                s.215                 True
# initial_seasons.216            2.4058753                s.216                 True
# initial_seasons.217            0.4551482                s.217                 True
# initial_seasons.218            0.3279528                s.218                 True
# initial_seasons.219            0.0062464                s.219                 True
# initial_seasons.220            0.2056989                s.220                 True
# initial_seasons.221            0.0692742                s.221                 True
# initial_seasons.222            0.2217238                s.222                 True
# initial_seasons.223            0.9049560                s.223                 True
# initial_seasons.224            0.2014495                s.224                 True
# initial_seasons.225            1.5682200                s.225                 True
# initial_seasons.226            0.0062379                s.226                 True
# initial_seasons.227            0.0062379                s.227                 True
# initial_seasons.228            0.1359969                s.228                 True
# initial_seasons.229            0.2938896                s.229                 True
# initial_seasons.230            0.0735142                s.230                 True
# initial_seasons.231            0.8132762                s.231                 True
# initial_seasons.232            1.3158953                s.232                 True
# initial_seasons.233            0.0062851                s.233                 True
# initial_seasons.234            0.2317943                s.234                 True
# initial_seasons.235            3.6058302                s.235                 True
# initial_seasons.236            0.6095729                s.236                 True
# initial_seasons.237            4.2542495                s.237                 True
# initial_seasons.238            4.3784081                s.238                 True
# initial_seasons.239            1.6431185                s.239                 True
# initial_seasons.240            0.0063171                s.240                 True
# initial_seasons.241            0.0063171                s.241                 True
# initial_seasons.242            0.1512792                s.242                 True
# initial_seasons.243            2.1666053                s.243                 True
# initial_seasons.244            0.4034665                s.244                 True
# initial_seasons.245            0.2676332                s.245                 True
# initial_seasons.246            2.6248486                s.246                 True
# initial_seasons.247            0.0063208                s.247                 True
# initial_seasons.248            0.0063208                s.248                 True
# initial_seasons.249            2.1838882                s.249                 True
# initial_seasons.250            1.3727174                s.250                 True
# initial_seasons.251            2.3550208                s.251                 True
# initial_seasons.252            0.7559758                s.252                 True
# initial_seasons.253            0.3585451                s.253                 True
# initial_seasons.254            0.0062704                s.254                 True
# initial_seasons.255            0.0062800                s.255                 True
# initial_seasons.256            3.3496361                s.256                 True
# initial_seasons.257            4.2956022                s.257                 True
# initial_seasons.258            0.7039098                s.258                 True
# initial_seasons.259            3.5689947                s.259                 True
# initial_seasons.260            4.6765309                s.260                 True
# initial_seasons.261            0.0063601                s.261                 True
# initial_seasons.262            0.0063729                s.262                 True
# initial_seasons.263            0.1313454                s.263                 True
# initial_seasons.264            0.2780535                s.264                 True
# initial_seasons.265            0.2551177                s.265                 True
# initial_seasons.266            0.8044820                s.266                 True
# initial_seasons.267            2.0251121                s.267                 True
# initial_seasons.268            0.0064379                s.268                 True
# initial_seasons.269            0.0064379                s.269                 True
# initial_seasons.270            0.2746462                s.270                 True
# initial_seasons.271            0.5362347                s.271                 True
# initial_seasons.272            2.4128350                s.272                 True
# initial_seasons.273            2.5944869                s.273                 True
# initial_seasons.274            0.7895060                s.274                 True
# initial_seasons.275            0.6385927                s.275                 True
# initial_seasons.276            0.3372191                s.276                 True
# initial_seasons.277            0.2190054                s.277                 True
# initial_seasons.278            0.6927917                s.278                 True
# initial_seasons.279            0.7217758                s.279                 True
# initial_seasons.280            0.6745217                s.280                 True
# initial_seasons.281            7.9819558                s.281                 True
# initial_seasons.282            1.4975400                s.282                 True
# initial_seasons.283            0.0064028                s.283                 True
# initial_seasons.284            3.3712259                s.284                 True
# initial_seasons.285            1.9693079                s.285                 True
# initial_seasons.286            0.4275020                s.286                 True
# initial_seasons.287            3.0492250                s.287                 True
# initial_seasons.288            2.5978673                s.288                 True
# initial_seasons.289            0.3000722                s.289                 True
# initial_seasons.290            0.0298777                s.290                 True
# initial_seasons.291            4.0064374                s.291                 True
# initial_seasons.292            0.0914582                s.292                 True
# initial_seasons.293            0.1296386                s.293                 True
# initial_seasons.294            2.3174660                s.294                 True
# initial_seasons.295            2.3677848                s.295                 True
# initial_seasons.296            0.2612508                s.296                 True
# initial_seasons.297            0.0063508                s.297                 True
# initial_seasons.298            0.1967589                s.298                 True
# initial_seasons.299            2.7099794                s.299                 True
# initial_seasons.300            0.3153272                s.300                 True
# initial_seasons.301            0.2824784                s.301                 True
# initial_seasons.302            0.2391497                s.302                 True
# initial_seasons.303            0.8655382                s.303                 True
# initial_seasons.304            0.0522834                s.304                 True
# initial_seasons.305            4.5593986                s.305                 True
# initial_seasons.306            2.3821561                s.306                 True
# initial_seasons.307            0.2853515                s.307                 True
# initial_seasons.308            0.0616114                s.308                 True
# initial_seasons.309            0.5524816                s.309                 True
# initial_seasons.310            1.4044886                s.310                 True
# initial_seasons.311            0.0063686                s.311                 True
# initial_seasons.312            1.9069583                s.312                 True
# initial_seasons.313            0.5430798                s.313                 True
# initial_seasons.314            0.3530612                s.314                 True
# initial_seasons.315            1.8109778                s.315                 True
# initial_seasons.316            0.1940571                s.316                 True
# initial_seasons.317            0.0064899                s.317                 True
# initial_seasons.318            0.0064966                s.318                 True
# initial_seasons.319            0.4440859                s.319                 True
# initial_seasons.320            1.3194825                s.320                 True
# initial_seasons.321            0.1785489                s.321                 True
# initial_seasons.322            0.1398432                s.322                 True
# initial_seasons.323            3.2720536                s.323                 True
# initial_seasons.324            1.0147233                s.324                 True
# initial_seasons.325            0.0065755                s.325                 True
# initial_seasons.326            0.0289291                s.326                 True
# initial_seasons.327            0.0910448                s.327                 True
# initial_seasons.328            1.4732426                s.328                 True
# initial_seasons.329            2.2746780                s.329                 True
# initial_seasons.330            3.1930651                s.330                 True
# initial_seasons.331            0.5537488                s.331                 True
# initial_seasons.332            0.2503030                s.332                 True
# initial_seasons.333            1.0727898                s.333                 True
# initial_seasons.334            0.1183637                s.334                 True
# initial_seasons.335            1.5022727                s.335                 True
# initial_seasons.336            0.3097436                s.336                 True
# initial_seasons.337            0.0979194                s.337                 True
# initial_seasons.338            0.0065942                s.338                 True
# initial_seasons.339            0.0065956                s.339                 True
# initial_seasons.340            0.5960583                s.340                 True
# initial_seasons.341            0.1106876                s.341                 True
# initial_seasons.342            3.1205747                s.342                 True
# initial_seasons.343            0.2202410                s.343                 True
# initial_seasons.344            0.1881157                s.344                 True
# initial_seasons.345            0.0065558                s.345                 True
# initial_seasons.346            0.0065383                s.346                 True
# initial_seasons.347            0.0792059                s.347                 True
# initial_seasons.348            0.2342698                s.348                 True
# initial_seasons.349            1.5566904                s.349                 True
# initial_seasons.350            0.3246863                s.350                 True
# initial_seasons.351            0.4854591                s.351                 True
# initial_seasons.352            0.0065231                s.352                 True
# initial_seasons.353            0.0065231                s.353                 True
# initial_seasons.354            1.0054996                s.354                 True
# initial_seasons.355            0.3955684                s.355                 True
# initial_seasons.356            0.4305012                s.356                 True
# initial_seasons.357            2.2155743                s.357                 True
# initial_seasons.358            4.8894272                s.358                 True
# initial_seasons.359            0.0063885                s.359                 True
# initial_seasons.360            0.0063875                s.360                 True
# initial_seasons.361            0.0656037                s.361                 True
# initial_seasons.362            0.3740318                s.362                 True
# initial_seasons.363            0.2330828                s.363                 True
# ----------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m364'] = hw_m364.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01            0           1.0      0.0   141.615422         1.0
# 2020-01-02            0           1.0      0.0   141.615422         1.0
#
#                  seasonal_52  seasonal_364       ses    hw_m52     hw_m364
# Date_of_Payment
# 2020-01-01              1.00           1.0  1.018596  2.943739  462.076257
# 2020-01-02             42.82           1.0  1.018596  3.264384  108.907786

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m364'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative with Seasonality of 364 for Humira Daily Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 364 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m364']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 364 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m364'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 364 Model: 345.6782088930877
# RMSE for Holt-Winters Multiplicative with Seasonality of 364 Model: 586.5118974441523

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 52.

# %%
hw_a52 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=52, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a52.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             humi_dollars   No. Observations:                 2344
# Model:             ExponentialSmoothing   SSE                      413310144.797
# Optimized:                         True   AIC                          28427.742
# Trend:                         Additive   BIC                          28750.280
# Seasonal:                      Additive   AICC                         28430.737
# Seasonal Periods:                    52   Date:                 Sun, 13 Mar 2022
# Box-Cox:                          False   Time:                         23:24:21
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0403571                alpha                 True
# smoothing_trend               0.0080714                 beta                 True
# smoothing_seasonal            0.1028189                gamma                 True
# initial_level                 65.042897                  l.0                 True
# initial_trend                -1.4396876                  b.0                 True
# initial_seasons.0            -53.678771                  s.0                 True
# initial_seasons.1            -108.66795                  s.1                 True
# initial_seasons.2            -94.494516                  s.2                 True
# initial_seasons.3            -94.628218                  s.3                 True
# initial_seasons.4            -118.67492                  s.4                 True
# initial_seasons.5            -10.250453                  s.5                 True
# initial_seasons.6            -94.987353                  s.6                 True
# initial_seasons.7             68.191902                  s.7                 True
# initial_seasons.8            -78.542473                  s.8                 True
# initial_seasons.9             78.628681                  s.9                 True
# initial_seasons.10           -92.597184                 s.10                 True
# initial_seasons.11           -112.40858                 s.11                 True
# initial_seasons.12           -124.27553                 s.12                 True
# initial_seasons.13           -105.67404                 s.13                 True
# initial_seasons.14            387.00690                 s.14                 True
# initial_seasons.15           -62.431992                 s.15                 True
# initial_seasons.16           -104.80288                 s.16                 True
# initial_seasons.17            71.682623                 s.17                 True
# initial_seasons.18           -122.08620                 s.18                 True
# initial_seasons.19           -103.53747                 s.19                 True
# initial_seasons.20           -104.79492                 s.20                 True
# initial_seasons.21           -119.60658                 s.21                 True
# initial_seasons.22           -101.70815                 s.22                 True
# initial_seasons.23           -108.25526                 s.23                 True
# initial_seasons.24           -53.566968                 s.24                 True
# initial_seasons.25            89.771710                 s.25                 True
# initial_seasons.26           -93.943747                 s.26                 True
# initial_seasons.27           -26.393386                 s.27                 True
# initial_seasons.28           -119.73098                 s.28                 True
# initial_seasons.29           -116.39466                 s.29                 True
# initial_seasons.30           -70.321992                 s.30                 True
# initial_seasons.31           -97.154155                 s.31                 True
# initial_seasons.32            14.227455                 s.32                 True
# initial_seasons.33           -43.095429                 s.33                 True
# initial_seasons.34            1797.3463                 s.34                 True
# initial_seasons.35           -60.410718                 s.35                 True
# initial_seasons.36            233.96587                 s.36                 True
# initial_seasons.37           -104.34125                 s.37                 True
# initial_seasons.38            351.77758                 s.38                 True
# initial_seasons.39            196.22705                 s.39                 True
# initial_seasons.40            446.01909                 s.40                 True
# initial_seasons.41           -86.646103                 s.41                 True
# initial_seasons.42           -103.44824                 s.42                 True
# initial_seasons.43           -121.74615                 s.43                 True
# initial_seasons.44           -117.69012                 s.44                 True
# initial_seasons.45            4.1669984                 s.45                 True
# initial_seasons.46           -84.267425                 s.46                 True
# initial_seasons.47           -107.07408                 s.47                 True
# initial_seasons.48           -107.24740                 s.48                 True
# initial_seasons.49           -120.66702                 s.49                 True
# initial_seasons.50           -120.74661                 s.50                 True
# initial_seasons.51           -68.022280                 s.51                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a52'] = hw_a52.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01            0           1.0      0.0   141.615422         1.0
# 2020-01-02            0           1.0      0.0   141.615422         1.0
#
#                  seasonal_52  seasonal_364       ses    hw_m52     hw_m364  \
# Date_of_Payment
# 2020-01-01              1.00           1.0  1.018596  2.943739  462.076257
# 2020-01-02             42.82           1.0  1.018596  3.264384  108.907786
#
#                     hw_a52
# Date_of_Payment
# 2020-01-01      -69.164674
# 2020-01-02      -70.184887

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a52'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 52 for Daily Humira Payments");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 52 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a52']))
print("RMSE for Holt-Winters Additive with Seasonality of 52 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a52'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 52 Model: 121.67246536261307
# RMSE for Holt-Winters Additive with Seasonality of 52 Model: 225.51426782909203

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 7.

# %%
hw_a7 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=7, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             humi_dollars   No. Observations:                 2344
# Model:             ExponentialSmoothing   SSE                      373636346.698
# Optimized:                         True   AIC                          28101.197
# Trend:                         Additive   BIC                          28164.552
# Seasonal:                      Additive   AICC                         28101.353
# Seasonal Periods:                     7   Date:                 Sun, 13 Mar 2022
# Box-Cox:                          False   Time:                         23:24:22
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0403571                alpha                 True
# smoothing_trend               0.0080714                 beta                 True
# smoothing_seasonal            0.0342730                gamma                 True
# initial_level                 68.363619                  l.0                 True
# initial_trend                 2.8147706                  b.0                 True
# initial_seasons.0             81.565163                  s.0                 True
# initial_seasons.1             119.49409                  s.1                 True
# initial_seasons.2            -50.645908                  s.2                 True
# initial_seasons.3            -54.195265                  s.3                 True
# initial_seasons.4            -53.173051                  s.4                 True
# initial_seasons.5             11.595878                  s.5                 True
# initial_seasons.6            -54.640908                  s.6                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a7'] = hw_a7.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01            0           1.0      0.0   141.615422         1.0
# 2020-01-02            0           1.0      0.0   141.615422         1.0
#
#                  seasonal_52  seasonal_364       ses    hw_m52     hw_m364  \
# Date_of_Payment
# 2020-01-01              1.00           1.0  1.018596  2.943739  462.076257
# 2020-01-02             42.82           1.0  1.018596  3.264384  108.907786
#
#                     hw_a52      hw_a7
# Date_of_Payment
# 2020-01-01      -69.164674  40.805585
# 2020-01-02      -70.184887   7.738203

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a7'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 7 for Daily Payments for Humira");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 7 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a7']))
print("RMSE for Holt-Winters Additive with Seasonality of 7 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a7'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 7 Model: 116.12974109572367
# RMSE for Holt-Winters Additive with Seasonality of 7 Model: 217.5885413599756

# %%
hw_a364 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=364, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a364.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             humi_dollars   No. Observations:                 2344
# Model:             ExponentialSmoothing   SSE                      331688035.348
# Optimized:                         True   AIC                          28536.054
# Trend:                         Additive   BIC                          30655.592
# Seasonal:                      Additive   AICC                         28675.202
# Seasonal Periods:                   364   Date:                 Sun, 13 Mar 2022
# Box-Cox:                          False   Time:                         23:24:23
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.0050000                alpha                 True
# smoothing_trend                0.0025000                 beta                 True
# smoothing_seasonal                0.0001                gamma                 True
# initial_level                  131.91177                  l.0                 True
# initial_trend                 -0.1882396                  b.0                 True
# initial_seasons.0             -141.26934                  s.0                 True
# initial_seasons.1             -140.92995                  s.1                 True
# initial_seasons.2             -158.66850                  s.2                 True
# initial_seasons.3             -165.76600                  s.3                 True
# initial_seasons.4             -136.45404                  s.4                 True
# initial_seasons.5              331.08438                  s.5                 True
# initial_seasons.6             -147.79907                  s.6                 True
# initial_seasons.7              25.624364                  s.7                 True
# initial_seasons.8             -157.67041                  s.8                 True
# initial_seasons.9             -156.64350                  s.9                 True
# initial_seasons.10            -161.84350                 s.10                 True
# initial_seasons.11             650.88650                 s.11                 True
# initial_seasons.12            -147.18734                 s.12                 True
# initial_seasons.13            -106.28282                 s.13                 True
# initial_seasons.14            -111.51103                 s.14                 True
# initial_seasons.15            -144.50165                 s.15                 True
# initial_seasons.16            -160.65069                 s.16                 True
# initial_seasons.17            -160.65069                 s.17                 True
# initial_seasons.18             238.11557                 s.18                 True
# initial_seasons.19             166.41072                 s.19                 True
# initial_seasons.20            -144.87114                 s.20                 True
# initial_seasons.21            -49.026848                 s.21                 True
# initial_seasons.22             304.31638                 s.22                 True
# initial_seasons.23             305.53207                 s.23                 True
# initial_seasons.24            -160.70459                 s.24                 True
# initial_seasons.25            -126.97993                 s.25                 True
# initial_seasons.26            -128.79821                 s.26                 True
# initial_seasons.27            -133.56761                 s.27                 True
# initial_seasons.28            -101.92000                 s.28                 True
# initial_seasons.29            -133.29184                 s.29                 True
# initial_seasons.30            -160.60359                 s.30                 True
# initial_seasons.31            -160.60359                 s.31                 True
# initial_seasons.32            -117.99365                 s.32                 True
# initial_seasons.33            -92.771141                 s.33                 True
# initial_seasons.34            -88.799894                 s.34                 True
# initial_seasons.35            -97.672910                 s.35                 True
# initial_seasons.36            -148.02177                 s.36                 True
# initial_seasons.37             144.45856                 s.37                 True
# initial_seasons.38            -160.80995                 s.38                 True
# initial_seasons.39            -160.82420                 s.39                 True
# initial_seasons.40            -127.07363                 s.40                 True
# initial_seasons.41            -117.35211                 s.41                 True
# initial_seasons.42            -151.53871                 s.42                 True
# initial_seasons.43            -157.01129                 s.43                 True
# initial_seasons.44            -162.57956                 s.44                 True
# initial_seasons.45            -162.57956                 s.45                 True
# initial_seasons.46             118.76345                 s.46                 True
# initial_seasons.47             126.11746                 s.47                 True
# initial_seasons.48            -55.185382                 s.48                 True
# initial_seasons.49             106.65765                 s.49                 True
# initial_seasons.50             279.02828                 s.50                 True
# initial_seasons.51            -163.24796                 s.51                 True
# initial_seasons.52            -163.24796                 s.52                 True
# initial_seasons.53             408.33878                 s.53                 True
# initial_seasons.54            -64.874276                 s.54                 True
# initial_seasons.55            -83.932429                 s.55                 True
# initial_seasons.56            -76.702501                 s.56                 True
# initial_seasons.57            -34.504637                 s.57                 True
# initial_seasons.58            -163.24506                 s.58                 True
# initial_seasons.59            -163.24506                 s.59                 True
# initial_seasons.60            -130.14086                 s.60                 True
# initial_seasons.61            -13.814609                 s.61                 True
# initial_seasons.62            -153.50584                 s.62                 True
# initial_seasons.63            -102.57118                 s.63                 True
# initial_seasons.64            -142.27022                 s.64                 True
# initial_seasons.65            -163.20221                 s.65                 True
# initial_seasons.66            -163.20221                 s.66                 True
# initial_seasons.67             378.82017                 s.67                 True
# initial_seasons.68             5.9855245                 s.68                 True
# initial_seasons.69             290.13831                 s.69                 True
# initial_seasons.70             658.13580                 s.70                 True
# initial_seasons.71            -2.7650181                 s.71                 True
# initial_seasons.72             176.66900                 s.72                 True
# initial_seasons.73            -166.00350                 s.73                 True
# initial_seasons.74             379.23105                 s.74                 True
# initial_seasons.75             797.18565                 s.75                 True
# initial_seasons.76             327.83450                 s.76                 True
# initial_seasons.77            -33.773438                 s.77                 True
# initial_seasons.78             13.030195                 s.78                 True
# initial_seasons.79             69.395569                 s.79                 True
# initial_seasons.80            -151.30443                 s.80                 True
# initial_seasons.81             690.22518                 s.81                 True
# initial_seasons.82            -102.39113                 s.82                 True
# initial_seasons.83             157.60837                 s.83                 True
# initial_seasons.84             12.623285                 s.84                 True
# initial_seasons.85            -81.968033                 s.85                 True
# initial_seasons.86            -164.89384                 s.86                 True
# initial_seasons.87            -164.89384                 s.87                 True
# initial_seasons.88            -84.925210                 s.88                 True
# initial_seasons.89             324.65407                 s.89                 True
# initial_seasons.90             55.722159                 s.90                 True
# initial_seasons.91             335.00188                 s.91                 True
# initial_seasons.92            -35.616567                 s.92                 True
# initial_seasons.93            -165.89163                 s.93                 True
# initial_seasons.94            -126.86265                 s.94                 True
# initial_seasons.95             557.20848                 s.95                 True
# initial_seasons.96             220.53856                 s.96                 True
# initial_seasons.97            -145.96873                 s.97                 True
# initial_seasons.98            -160.38367                 s.98                 True
# initial_seasons.99            -113.97659                 s.99                 True
# initial_seasons.100           -163.48430                s.100                 True
# initial_seasons.101           -163.48947                s.101                 True
# initial_seasons.102           -122.31019                s.102                 True
# initial_seasons.103           -140.75992                s.103                 True
# initial_seasons.104            84.920868                s.104                 True
# initial_seasons.105           -40.966059                s.105                 True
# initial_seasons.106            165.70722                s.106                 True
# initial_seasons.107           -158.83278                s.107                 True
# initial_seasons.108           -148.39528                s.108                 True
# initial_seasons.109            376.08741                s.109                 True
# initial_seasons.110            501.86620                s.110                 True
# initial_seasons.111           -84.849716                s.111                 True
# initial_seasons.112            50.411513                s.112                 True
# initial_seasons.113            285.69542                s.113                 True
# initial_seasons.114           -162.72142                s.114                 True
# initial_seasons.115           -162.72142                s.115                 True
# initial_seasons.116            1085.1797                s.116                 True
# initial_seasons.117           -107.14108                s.117                 True
# initial_seasons.118            330.21076                s.118                 True
# initial_seasons.119           -163.47122                s.119                 True
# initial_seasons.120           -163.47705                s.120                 True
# initial_seasons.121           -163.47705                s.121                 True
# initial_seasons.122           -163.47705                s.122                 True
# initial_seasons.123           -150.01949                s.123                 True
# initial_seasons.124           -97.799081                s.124                 True
# initial_seasons.125            556.47896                s.125                 True
# initial_seasons.126           -79.101694                s.126                 True
# initial_seasons.127           -139.13518                s.127                 True
# initial_seasons.128            169.80717                s.128                 True
# initial_seasons.129           -162.19481                s.129                 True
# initial_seasons.130            365.43255                s.130                 True
# initial_seasons.131           -111.01541                s.131                 True
# initial_seasons.132            399.77949                s.132                 True
# initial_seasons.133            140.37775                s.133                 True
# initial_seasons.134           -53.243991                s.134                 True
# initial_seasons.135           -159.11929                s.135                 True
# initial_seasons.136           -162.38679                s.136                 True
# initial_seasons.137           -68.131491                s.137                 True
# initial_seasons.138           -116.34958                s.138                 True
# initial_seasons.139           -122.61320                s.139                 True
# initial_seasons.140           -96.912147                s.140                 True
# initial_seasons.141           -38.618342                s.141                 True
# initial_seasons.142           -161.64081                s.142                 True
# initial_seasons.143           -161.64081                s.143                 True
# initial_seasons.144            214.92620                s.144                 True
# initial_seasons.145           -124.90249                s.145                 True
# initial_seasons.146           -158.67840                s.146                 True
# initial_seasons.147           -148.72068                s.147                 True
# initial_seasons.148           -161.57480                s.148                 True
# initial_seasons.149           -161.57683                s.149                 True
# initial_seasons.150           -161.57683                s.150                 True
# initial_seasons.151           -161.57141                s.151                 True
# initial_seasons.152           -161.57249                s.152                 True
# initial_seasons.153           -136.99649                s.153                 True
# initial_seasons.154           -161.63038                s.154                 True
# initial_seasons.155           -161.69621                s.155                 True
# initial_seasons.156           -161.71065                s.156                 True
# initial_seasons.157           -161.71065                s.157                 True
# initial_seasons.158           -158.26489                s.158                 True
# initial_seasons.159           -143.33822                s.159                 True
# initial_seasons.160           -14.382333                s.160                 True
# initial_seasons.161           -111.38700                s.161                 True
# initial_seasons.162            0.8929249                s.162                 True
# initial_seasons.163            267.64500                s.163                 True
# initial_seasons.164           -161.53250                s.164                 True
# initial_seasons.165           -38.566337                s.165                 True
# initial_seasons.166           -142.11071                s.166                 True
# initial_seasons.167           -47.063631                s.167                 True
# initial_seasons.168           -93.476897                s.168                 True
# initial_seasons.169           -83.573514                s.169                 True
# initial_seasons.170           -162.46425                s.170                 True
# initial_seasons.171           -162.46425                s.171                 True
# initial_seasons.172           -142.40073                s.172                 True
# initial_seasons.173           -107.45187                s.173                 True
# initial_seasons.174            4.9391577                s.174                 True
# initial_seasons.175            1179.7373                s.175                 True
# initial_seasons.176            387.78374                s.176                 True
# initial_seasons.177           -149.23223                s.177                 True
# initial_seasons.178           -161.51723                s.178                 True
# initial_seasons.179            400.67803                s.179                 True
# initial_seasons.180           -148.66536                s.180                 True
# initial_seasons.181           -35.084359                s.181                 True
# initial_seasons.182            337.56134                s.182                 True
# initial_seasons.183            171.12666                s.183                 True
# initial_seasons.184           -165.05567                s.184                 True
# initial_seasons.185           -165.02222                s.185                 True
# initial_seasons.186           -156.08338                s.186                 True
# initial_seasons.187           -118.03067                s.187                 True
# initial_seasons.188           -112.56318                s.188                 True
# initial_seasons.189           -80.672800                s.189                 True
# initial_seasons.190            1245.9562                s.190                 True
# initial_seasons.191           -164.77305                s.191                 True
# initial_seasons.192           -164.76365                s.192                 True
# initial_seasons.193           -145.20314                s.193                 True
# initial_seasons.194           -109.22971                s.194                 True
# initial_seasons.195           -31.291941                s.195                 True
# initial_seasons.196            395.42066                s.196                 True
# initial_seasons.197            264.45755                s.197                 True
# initial_seasons.198           -164.35330                s.198                 True
# initial_seasons.199           -164.35330                s.199                 True
# initial_seasons.200           -150.83699                s.200                 True
# initial_seasons.201            39.799724                s.201                 True
# initial_seasons.202           -15.372377                s.202                 True
# initial_seasons.203            153.46663                s.203                 True
# initial_seasons.204           -59.369493                s.204                 True
# initial_seasons.205           -164.73830                s.205                 True
# initial_seasons.206            173.82646                s.206                 True
# initial_seasons.207            282.61126                s.207                 True
# initial_seasons.208            158.52378                s.208                 True
# initial_seasons.209           -122.59865                s.209                 True
# initial_seasons.210            441.75715                s.210                 True
# initial_seasons.211           -22.628408                s.211                 True
# initial_seasons.212           -25.186306                s.212                 True
# initial_seasons.213           -164.72175                s.213                 True
# initial_seasons.214           -146.92888                s.214                 True
# initial_seasons.215            130.78618                s.215                 True
# initial_seasons.216            206.61215                s.216                 True
# initial_seasons.217           -93.482151                s.217                 True
# initial_seasons.218           -112.72289                s.218                 True
# initial_seasons.219           -164.69556                s.219                 True
# initial_seasons.220           -136.82335                s.220                 True
# initial_seasons.221           -154.92244                s.221                 True
# initial_seasons.222           -131.60296                s.222                 True
# initial_seasons.223            6.4185774                s.223                 True
# initial_seasons.224           -131.64065                s.224                 True
# initial_seasons.225            57.694360                s.225                 True
# initial_seasons.226           -164.66564                s.226                 True
# initial_seasons.227           -164.66564                s.227                 True
# initial_seasons.228           -145.31213                s.228                 True
# initial_seasons.229           -122.23887                s.229                 True
# initial_seasons.230           -155.33147                s.230                 True
# initial_seasons.231            0.5166611                s.231                 True
# initial_seasons.232            109.90908                s.232                 True
# initial_seasons.233           -164.82398                s.233                 True
# initial_seasons.234           -114.35827                s.234                 True
# initial_seasons.235            478.13042                s.235                 True
# initial_seasons.236           -58.471670                s.236                 True
# initial_seasons.237            401.26919                s.237                 True
# initial_seasons.238            449.04762                s.238                 True
# initial_seasons.239            57.022084                s.239                 True
# initial_seasons.240           -164.77095                s.240                 True
# initial_seasons.241           -164.77095                s.241                 True
# initial_seasons.242           -143.79095                s.242                 True
# initial_seasons.243            280.92405                s.243                 True
# initial_seasons.244           -106.21095                s.244                 True
# initial_seasons.245           -125.05095                s.245                 True
# initial_seasons.246            203.49287                s.246                 True
# initial_seasons.247           -164.80831                s.247                 True
# initial_seasons.248           -164.80831                s.248                 True
# initial_seasons.249            321.87151                s.249                 True
# initial_seasons.250            16.371877                s.250                 True
# initial_seasons.251            356.18947                s.251                 True
# initial_seasons.252           -10.053390                s.252                 True
# initial_seasons.253           -116.04247                s.253                 True
# initial_seasons.254           -165.51663                s.254                 True
# initial_seasons.255           -165.51663                s.255                 True
# initial_seasons.256            415.42696                s.256                 True
# initial_seasons.257            558.03084                s.257                 True
# initial_seasons.258           -31.673892                s.258                 True
# initial_seasons.259            318.55222                s.259                 True
# initial_seasons.260            492.49165                s.260                 True
# initial_seasons.261           -166.35617                s.261                 True
# initial_seasons.262           -166.33426                s.262                 True
# initial_seasons.263           -147.88370                s.263                 True
# initial_seasons.264           -115.43029                s.264                 True
# initial_seasons.265           -127.69164                s.265                 True
# initial_seasons.266            12.155820                s.266                 True
# initial_seasons.267            344.68780                s.267                 True
# initial_seasons.268           -166.81490                s.268                 True
# initial_seasons.269           -166.81490                s.269                 True
# initial_seasons.270           -124.54905                s.270                 True
# initial_seasons.271           -62.076079                s.271                 True
# initial_seasons.272            424.75069                s.272                 True
# initial_seasons.273            204.24811                s.273                 True
# initial_seasons.274           -60.647659                s.274                 True
# initial_seasons.275           -83.523717                s.275                 True
# initial_seasons.276           -118.71974                s.276                 True
# initial_seasons.277           -137.58371                s.277                 True
# initial_seasons.278           -67.139149                s.278                 True
# initial_seasons.279           -70.220701                s.279                 True
# initial_seasons.280           -57.993799                s.280                 True
# initial_seasons.281            1019.8827                s.281                 True
# initial_seasons.282            43.506524                s.282                 True
# initial_seasons.283           -167.24765                s.283                 True
# initial_seasons.284            265.26485                s.284                 True
# initial_seasons.285            320.07555                s.285                 True
# initial_seasons.286           -105.45918                s.286                 True
# initial_seasons.287            286.37958                s.287                 True
# initial_seasons.288            168.22939                s.288                 True
# initial_seasons.289           -130.66449                s.289                 True
# initial_seasons.290           -161.30649                s.290                 True
# initial_seasons.291            470.30741                s.291                 True
# initial_seasons.292           -152.88383                s.292                 True
# initial_seasons.293           -148.84080                s.293                 True
# initial_seasons.294            145.04691                s.294                 True
# initial_seasons.295            144.86765                s.295                 True
# initial_seasons.296           -133.26060                s.296                 True
# initial_seasons.297           -167.13003                s.297                 True
# initial_seasons.298           -141.71305                s.298                 True
# initial_seasons.299            204.97078                s.299                 True
# initial_seasons.300           -120.50047                s.300                 True
# initial_seasons.301           -124.44450                s.301                 True
# initial_seasons.302           -135.63543                s.302                 True
# initial_seasons.303            44.324566                s.303                 True
# initial_seasons.304           -160.08043                s.304                 True
# initial_seasons.305            689.51707                s.305                 True
# initial_seasons.306            143.30494                s.306                 True
# initial_seasons.307           -113.67599                s.307                 True
# initial_seasons.308           -157.11467                s.308                 True
# initial_seasons.309           -45.803442                s.309                 True
# initial_seasons.310            172.42764                s.310                 True
# initial_seasons.311           -167.03986                s.311                 True
# initial_seasons.312            73.221946                s.312                 True
# initial_seasons.313           -96.614788                s.313                 True
# initial_seasons.314           -117.83327                s.314                 True
# initial_seasons.315            46.490040                s.315                 True
# initial_seasons.316           -141.33553                s.316                 True
# initial_seasons.317           -167.25819                s.317                 True
# initial_seasons.318           -167.09146                s.318                 True
# initial_seasons.319           -98.964197                s.319                 True
# initial_seasons.320            139.64305                s.320                 True
# initial_seasons.321           -140.02792                s.321                 True
# initial_seasons.322           -148.22800                s.322                 True
# initial_seasons.323            368.54078                s.323                 True
# initial_seasons.324            98.020305                s.324                 True
# initial_seasons.325           -165.12749                s.325                 True
# initial_seasons.326           -161.61637                s.326                 True
# initial_seasons.327           -153.43279                s.327                 True
# initial_seasons.328            103.60966                s.328                 True
# initial_seasons.329            314.20583                s.329                 True
# initial_seasons.330            582.95012                s.330                 True
# initial_seasons.331           -96.746766                s.331                 True
# initial_seasons.332           -134.39177                s.332                 True
# initial_seasons.333           -12.391766                s.333                 True
# initial_seasons.334           -137.84177                s.334                 True
# initial_seasons.335            222.24573                s.335                 True
# initial_seasons.336           -123.53927                s.336                 True
# initial_seasons.337           -152.78476                s.337                 True
# initial_seasons.338           -164.55183                s.338                 True
# initial_seasons.339           -164.52091                s.339                 True
# initial_seasons.340           -58.661581                s.340                 True
# initial_seasons.341           -146.69602                s.341                 True
# initial_seasons.342            252.12909                s.342                 True
# initial_seasons.343           -125.76417                s.343                 True
# initial_seasons.344           -140.07951                s.344                 True
# initial_seasons.345           -164.48271                s.345                 True
# initial_seasons.346           -164.48271                s.346                 True
# initial_seasons.347           -152.61047                s.347                 True
# initial_seasons.348           -131.64276                s.348                 True
# initial_seasons.349            40.266750                s.349                 True
# initial_seasons.350           -115.11076                s.350                 True
# initial_seasons.351           -98.575063                s.351                 True
# initial_seasons.352           -164.70283                s.352                 True
# initial_seasons.353           -164.70283                s.353                 True
# initial_seasons.354            88.636922                s.354                 True
# initial_seasons.355           -109.88837                s.355                 True
# initial_seasons.356           -104.23637                s.356                 True
# initial_seasons.357            128.83508                s.357                 True
# initial_seasons.358            571.57769                s.358                 True
# initial_seasons.359           -165.66598                s.359                 True
# initial_seasons.360           -165.68285                s.360                 True
# initial_seasons.361           -156.04499                s.361                 True
# initial_seasons.362           -110.80250                s.362                 True
# initial_seasons.363           -116.09883                s.363                 True
# ----------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a364'] = hw_a364.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01            0           1.0      0.0   141.615422         1.0
# 2020-01-02            0           1.0      0.0   141.615422         1.0
#
#                  seasonal_52  seasonal_364       ses    hw_m52     hw_m364  \
# Date_of_Payment
# 2020-01-01              1.00           1.0  1.018596  2.943739  462.076257
# 2020-01-02             42.82           1.0  1.018596  3.264384  108.907786
#
#                     hw_a52      hw_a7    hw_a364
# Date_of_Payment
# 2020-01-01      -69.164674  40.805585  57.731819
# 2020-01-02      -70.184887   7.738203 -39.300098

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a364'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 364 for Daily Payments for Humira");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 364 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a364']))
print("RMSE for Holt-Winters Additive with Seasonality of 364 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a364'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 364 Model: 179.69606320847285
# RMSE for Holt-Winters Additive with Seasonality of 364 Model: 289.46512161637247

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 7.

# %%
hw_m7 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=7, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             humi_dollars   No. Observations:                 2344
# Model:             ExponentialSmoothing   SSE                      532509664.410
# Optimized:                         True   AIC                          28931.718
# Trend:                   Multiplicative   BIC                          28995.074
# Seasonal:                Multiplicative   AICC                         28931.874
# Seasonal Periods:                     7   Date:                 Sun, 13 Mar 2022
# Box-Cox:                          False   Time:                         23:24:25
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0403571                alpha                 True
# smoothing_trend               0.0080714                 beta                 True
# smoothing_seasonal               0.0001                gamma                 True
# initial_level                 68.363619                  l.0                 True
# initial_trend                 1.0411735                  b.0                 True
# initial_seasons.0             1.5092534                  s.0                 True
# initial_seasons.1             2.1930474                  s.1                 True
# initial_seasons.2             0.4562909                  s.2                 True
# initial_seasons.3             0.3235273                  s.3                 True
# initial_seasons.4             0.3244648                  s.4                 True
# initial_seasons.5             1.2508796                  s.5                 True
# initial_seasons.6             0.9425367                  s.6                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m7'] = hw_m7.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01            0           1.0      0.0   141.615422         1.0
# 2020-01-02            0           1.0      0.0   141.615422         1.0
#
#                  seasonal_52  seasonal_364       ses    hw_m52     hw_m364  \
# Date_of_Payment
# 2020-01-01              1.00           1.0  1.018596  2.943739  462.076257
# 2020-01-02             42.82           1.0  1.018596  3.264384  108.907786
#
#                     hw_a52      hw_a7    hw_a364      hw_m7
# Date_of_Payment
# 2020-01-01      -69.164674  40.805585  57.731819  20.860724
# 2020-01-02      -70.184887   7.738203 -39.300098  32.887754

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m7'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 7 Model for Humira Daily Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 7 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m7']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 7 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m7'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 7 Model: 38.57549145042523
# RMSE for Holt-Winters Multiplicative with Seasonality of 7 Model: 179.54433259798463

# %% [markdown]
# Beats seasonal 52 and baseline mean models, but prediction curve just looks all wrong!

# %% [markdown]
# Try a SARIMA Model

# %%
from pmdarima.utils import tsdisplay

# %%
traina = train['humi_dollars']

# %%
tsdisplay(traina)
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\pmdarima\utils\visualization.py:220: FutureWarning: the 'unbiased'' keyword is deprecated, use 'adjusted' instead
#   res = tsaplots.plot_acf(

# %%
import pmdarima as pmd
model_s7 = pmd.auto_arima(train['humi_dollars'], m=7, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=4.46 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=36184.880, Time=0.04 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=35606.624, Time=0.24 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=inf, Time=1.27 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=36182.880, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=35606.677, Time=0.08 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=35604.918, Time=0.57 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=4.58 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=2.20 sec
#  ARIMA(0,1,0)(2,0,0)[7] intercept   : AIC=36186.249, Time=0.32 sec
#  ARIMA(2,1,0)(2,0,0)[7] intercept   : AIC=35350.449, Time=1.70 sec
#  ARIMA(2,1,0)(1,0,0)[7] intercept   : AIC=35352.757, Time=0.36 sec
#  ARIMA(2,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=15.45 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=3.38 sec
#  ARIMA(3,1,0)(2,0,0)[7] intercept   : AIC=35190.527, Time=2.63 sec
#  ARIMA(3,1,0)(1,0,0)[7] intercept   : AIC=35191.261, Time=0.55 sec
#  ARIMA(3,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=15.81 sec
#  ARIMA(3,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=3.94 sec
#  ARIMA(4,1,0)(2,0,0)[7] intercept   : AIC=35102.163, Time=4.00 sec
#  ARIMA(4,1,0)(1,0,0)[7] intercept   : AIC=35103.756, Time=0.59 sec
#  ARIMA(4,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=17.10 sec
#  ARIMA(4,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=3.91 sec
#  ARIMA(5,1,0)(2,0,0)[7] intercept   : AIC=34966.622, Time=3.11 sec
#  ARIMA(5,1,0)(1,0,0)[7] intercept   : AIC=34967.272, Time=0.86 sec
#  ARIMA(5,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=20.93 sec
#  ARIMA(5,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=5.86 sec
#  ARIMA(5,1,1)(2,0,0)[7] intercept   : AIC=inf, Time=18.59 sec
#  ARIMA(4,1,1)(2,0,0)[7] intercept   : AIC=inf, Time=24.38 sec
#  ARIMA(5,1,0)(2,0,0)[7]             : AIC=34964.622, Time=0.75 sec
#  ARIMA(5,1,0)(1,0,0)[7]             : AIC=34965.272, Time=0.41 sec
#  ARIMA(5,1,0)(2,0,1)[7]             : AIC=inf, Time=10.31 sec
#  ARIMA(5,1,0)(1,0,1)[7]             : AIC=inf, Time=4.32 sec
#  ARIMA(4,1,0)(2,0,0)[7]             : AIC=35100.163, Time=0.61 sec
#  ARIMA(5,1,1)(2,0,0)[7]             : AIC=inf, Time=18.48 sec
#  ARIMA(4,1,1)(2,0,0)[7]             : AIC=inf, Time=10.79 sec
#
# Best model:  ARIMA(5,1,0)(2,0,0)[7]
# Total fit time: 202.611 seconds

# %%
model_s7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                 2344
# Model:             SARIMAX(5, 1, 0)x(2, 0, 0, 7)   Log Likelihood              -17474.311
# Date:                           Sun, 13 Mar 2022   AIC                          34964.622
# Time:                                   23:27:49   BIC                          35010.696
# Sample:                                        0   HQIC                         34981.404
#                                           - 2344
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.8012      0.012    -64.940      0.000      -0.825      -0.777
# ar.L2         -0.6708      0.017    -39.375      0.000      -0.704      -0.637
# ar.L3         -0.5330      0.019    -28.713      0.000      -0.569      -0.497
# ar.L4         -0.3745      0.017    -21.568      0.000      -0.409      -0.340
# ar.L5         -0.2388      0.013    -18.443      0.000      -0.264      -0.213
# ar.S.L7        0.0211      0.017      1.240      0.215      -0.012       0.055
# ar.S.L14       0.0336      0.020      1.687      0.092      -0.005       0.073
# sigma2      1.766e+05   1415.879    124.707      0.000    1.74e+05    1.79e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.55   Jarque-Bera (JB):             67168.30
# Prob(Q):                              0.21   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.30   Skew:                             3.57
# Prob(H) (two-sided):                  0.00   Kurtosis:                        28.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
preds_sar7 = model_s7.predict(test.shape[0])
preds_sar7
# Out:
# array([0.08243452, 0.43518832, 3.31501616, 0.75379412, 0.6975719 ,
#        0.66177355, 0.52687473, 0.59539189, 0.66646797, 0.71614281,
#        0.64051087, 0.62943191, 0.61216343, 0.62963074, 0.61101196,
#        0.61973525, 0.71183423, 0.62244328, 0.61911783, 0.6218757 ,
#        0.61921121, 0.61966042, 0.62093633, 0.62444027, 0.62015205,
#        0.62054984, 0.62015253, 0.62029477, 0.61943037, 0.61979377,
#        0.6230566 , 0.62010534, 0.61998658, 0.6199798 , 0.61985432,
#        0.61987521, 0.61995212, 0.62016024, 0.61994241, 0.61993422,
#        0.61991656, 0.61992652, 0.61990368, 0.61991967, 0.62003014,
#        0.61992275, 0.61991869, 0.61992014, 0.61991715, 0.61991731,
#        0.61991931, 0.61992809, 0.61991872, 0.61991882, 0.61991839,
#        0.61991855, 0.61991759, 0.6199181 , 0.61992209, 0.61991837,
#        0.61991824, 0.61991824, 0.61991811, 0.61991809, 0.61991819,
#        0.61991859, 0.61991819, 0.61991818, 0.61991816, 0.61991816,
#        0.61991814, 0.61991816, 0.6199183 , 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991815, 0.61991816, 0.61991817,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816, 0.61991816, 0.61991816,
#        0.61991816, 0.61991816, 0.61991816])

# %%
df_preds['sarima7_auto'] = preds_sar7
df_preds['sarima7_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-01    0.082435
# 2020-01-02    0.435188
# Freq: D, Name: sarima7_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['humi_dollars'], label='Train')
plt.plot(test['humi_dollars'], label='Test')
plt.plot(df_preds['sarima7_auto'], label='SARIMA_7_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 7 Model for Humira Daily Payments");

# %%
print("MAE for SARIMA with Seasonality of 7 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['sarima7_auto']))
print("RMSE for SARIMA with Seasonality of 7 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['sarima7_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 7 Model: 36.419357683873734
# RMSE for SARIMA with Seasonality of 7 Model: 180.01699114519198

# %% [markdown]
# Try a SARIMA Model with m = 52 -

# %%
#model_s52 = pmd.auto_arima(train['humi_dollars'], m=52, trace=True)

# %%
#model_s52.summary()

# %%
#preds_sar52 = model_s52.predict(test.shape[0])
#preds_sar52

# %%
#df_preds['sarima52_auto'] = preds_sar52
#df_preds['sarima52_auto'].head(2)

# %%
#plt.figure(figsize=(16,8))
#plt.plot(train['humi_dollars'], label='Train')
#plt.plot(test['humi_dollars'], label='Test')
#plt.plot(df_preds['sarima52_auto'], label='SARIMA_52_auto')
#plt.legend(loc='best')
#plt.title("SARIMA Seasonality of 7 Model for Humira Daily Payments");

# %%
#print("MAE for Holt-Winters Additive with Seasonality of 52 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['sarima52_auto']))
#print("RMSE for Holt-Winters Additive with Seasonality of 52 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['sarima52_auto'], squared=False))

# %%
print("Summary of Metrics for Daily Humira CMS Payments")
print("_________________________________________________")
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['simple_mean'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 7 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_7']))
print("RMSE for Seasonal Baseline 7 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_7'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 52 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_52']))
print("RMSE for Seasonal Baseline 52 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_52'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 364 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_364']))
print("RMSE for Seasonal Baseline 364 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_364'], squared=False))
print("_________________________________________________")
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['ses'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 7 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m7']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 7 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m7'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 52 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m52']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 52 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m52'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 364 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m364']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 364 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m364'], squared=False))
print("_________________________________________________")
# Out:
# Summary of Metrics for Daily Humira CMS Payments
# _________________________________________________
# MAE for Simple Mean Baseline Model: 147.59196772456
# RMSE for Simple Mean Baseline Model: 204.9820671694276
# _________________________________________________
# MAE for Seasonal Baseline 7 Shift Model: 37.01343575418994
# RMSE for Seasonal Baseline 7 Shift Model: 180.14235222790091
# _________________________________________________
# MAE for Seasonal Baseline 52 Shift Model: 38.130418994413404
# RMSE for Seasonal Baseline 52 Shift Model: 180.41469005596198
# _________________________________________________
# MAE for Seasonal Baseline 364 Shift Model: 107.52022346368715
# RMSE for Seasonal Baseline 364 Shift Model: 301.1746124480618
# _________________________________________________
# MAE for Simple Exponential Smoothing Model: 36.04026093306699
# RMSE for Simple Exponential Smoothing Model: 179.93665263760676
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 7 Model: 38.57549145042523
# RMSE for Holt-Winters Multiplicative with Seasonality of 7 Model: 179.54433259798463
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 52 Model: 36.76859765925056
# RMSE for Holt-Winters Multiplicative with Seasonality of 52 Model: 179.9893581584501
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 364 Model: 345.6782088930877
# RMSE for Holt-Winters Multiplicative with Seasonality of 364 Model: 586.5118974441523
# _________________________________________________

# %%
print("Continued Summary of Metrics for Daily Humira CMS Payments")
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 7 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a7']))
print("RMSE for Holt-Winters Additive with Seasonality of 7 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a7'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 52 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a52']))
print("RMSE for Holt-Winters Additive with Seasonality of 52 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a52'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 364 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a364']))
print("RMSE for Holt-Winters Additive with Seasonality of 364 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a364'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 7 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['sarima7_auto']))
print("RMSE for SARIMA with Seasonality of 7 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['sarima7_auto'], squared=False))
print("_________________________________________________")
#print("MAE for SARIMA with Seasonality of 52 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['sarima52_auto']))
#print("RMSE for SARIMA with Seasonality of 52 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['sarima52_auto'], squared=False))
# Out:
# Continued Summary of Metrics for Daily Humira CMS Payments
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 7 Model: 116.12974109572367
# RMSE for Holt-Winters Additive with Seasonality of 7 Model: 217.5885413599756
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 52 Model: 121.67246536261307
# RMSE for Holt-Winters Additive with Seasonality of 52 Model: 225.51426782909203
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 364 Model: 179.69606320847285
# RMSE for Holt-Winters Additive with Seasonality of 364 Model: 289.46512161637247
# _________________________________________________
# MAE for SARIMA with Seasonality of 7 Model: 36.419357683873734
# RMSE for SARIMA with Seasonality of 7 Model: 180.01699114519198
# _________________________________________________

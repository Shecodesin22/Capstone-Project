# %%
import pandas as pd
import seaborn as sns
import numpy as np
pd.set_option('display.max_rows', 300, 'display.max_columns', 300)

# %% [markdown]
# #Found this code to fix a data type Warning
# #https://www.roelpeters.be/solved-dtypewarning-columns-have-mixed-types-specify-dtype-option-on-import-or-set-low-memory-in-pandas/

# %%
def convert_dtype(x):
    if not x:
        return ''
    try:
        return str(x)   
    except:        
        return ''

# %%
#Read in core data file - this is pulled from the general payments file for 2013 and is Ohio only
ohio2013 = pd.read_csv('./data/ohiodr2013.csv',converters={
'Change_Type':convert_dtype,'Covered_Recipient_Type':convert_dtype,
'Teaching_Hospital_Name':convert_dtype,
'Physician_First_Name':convert_dtype,
'Physician_Middle_Name':convert_dtype,
'Physician_Last_Name':convert_dtype,
'Physician_Name_Suffix':convert_dtype,
'Recipient_Primary_Business_Street_Address_Line1':convert_dtype,
'Recipient_Primary_Business_Street_Address_Line2':convert_dtype,
'Recipient_City':convert_dtype,
'Recipient_State':convert_dtype,
'Recipient_Zip_Code':convert_dtype,
'Recipient_Country':convert_dtype,
'Recipient_Province':convert_dtype,
'Recipient_Postal_Code':convert_dtype,
'Physician_Primary_Type':convert_dtype,
'Physician_Specialty':convert_dtype,
'Physician_License_State_code1':convert_dtype,
'Physician_License_State_code2':convert_dtype,
'Physician_License_State_code3':convert_dtype,
'Physician_License_State_code4':convert_dtype,
'Physician_License_State_code5':convert_dtype,
'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name':convert_dtype,
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name':convert_dtype,
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State':convert_dtype,
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country':convert_dtype,
'Form_of_Payment_or_Transfer_of_Value':convert_dtype,
'City_of_Travel':convert_dtype,
'State_of_Travel':convert_dtype,
'Country_of_Travel':convert_dtype,
'Physician_Ownership_Indicator':convert_dtype,
'Third_Party_Payment_Recipient_Indicator':convert_dtype,
'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value':convert_dtype,
'Charity_Indicator':convert_dtype,
'Third_Party_Equals_Covered_Recipient_Indicator':convert_dtype,
'Contextual_Information':convert_dtype,
'Delay_in_Publication_Indicator':convert_dtype,
'Dispute_Status_for_Publication':convert_dtype,
'Product_Indicator':convert_dtype,    
'Name_of_Associated_Covered_Drug_or_Biological1':convert_dtype,
'Name_of_Associated_Covered_Drug_or_Biological2':convert_dtype,
'Name_of_Associated_Covered_Drug_or_Biological3':convert_dtype,
'Name_of_Associated_Covered_Drug_or_Biological4':convert_dtype,
'Name_of_Associated_Covered_Drug_or_Biological5':convert_dtype,
'NDC_of_Associated_Covered_Drug_or_Biological1':convert_dtype,
'NDC_of_Associated_Covered_Drug_or_Biological2':convert_dtype,
'NDC_of_Associated_Covered_Drug_or_Biological3':convert_dtype,
'NDC_of_Associated_Covered_Drug_or_Biological4':convert_dtype,
'NDC_of_Associated_Covered_Drug_or_Biological5':convert_dtype,
'Name_of_Associated_Covered_Device_or_Medical_Supply1':convert_dtype,
'Name_of_Associated_Covered_Device_or_Medical_Supply2':convert_dtype,
'Name_of_Associated_Covered_Device_or_Medical_Supply3':convert_dtype,
'Name_of_Associated_Covered_Device_or_Medical_Supply4':convert_dtype,
'Name_of_Associated_Covered_Device_or_Medical_Supply5':convert_dtype      
 })
ohio2013.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                    NaN
# 1   UNCHANGED  Covered Recipient Physician                    NaN
#
#    Teaching_Hospital_ID Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                   NaN                                       8454.0
# 1                   NaN                                     202929.0
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0                 SEAN                     P            CALLAHAN
# 1                 SEAN                     C             CANNONE
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                                                         615 FULTON ST
# 1                                                 2550 CLEVELAND AVE NW
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                                   PORT CLINTON
# 1                                                         CANTON
#
#   Recipient_State Recipient_Zip_Code Recipient_Country Recipient_Province  \
# 0              OH              43452     United States
# 1              OH              44709     United States
#
#   Recipient_Postal_Code Physician_Primary_Type  \
# 0                               Medical Doctor
# 1                         Doctor of Osteopathy
#
#                                  Physician_Specialty  \
# 0  Allopathic & Osteopathic Physicians|Family Med...
# 1  Allopathic & Osteopathic Physicians|Family Med...
#
#   Physician_License_State_code1 Physician_License_State_code2  \
# 0                            OH
# 1                            OH
#
#   Physician_License_State_code3 Physician_License_State_code4  \
# 0
# 1
#
#   Physician_License_State_code5  \
# 0
# 1
#
#   Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name  \
# 0                          Forest Laboratories, Inc.
# 1                          Forest Laboratories, Inc.
#
#    Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID  \
# 0                                       100000005529
# 1                                       100000005529
#
#   Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name  \
# 0                       FOREST PHARMACEUTICALS, INC.
# 1                       FOREST PHARMACEUTICALS, INC.
#
#   Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State  \
# 0                                                 NJ
# 1                                                 NJ
#
#   Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country  \
# 0                                      United States
# 1                                      United States
#
#    Total_Amount_of_Payment_USDollars Date_of_Payment  \
# 0                               5.85      08/27/2013
# 1                              19.69      12/11/2013
#
#    Number_of_Payments_Included_in_Total_Amount  \
# 0                                            2
# 1                                            2
#
#   Form_of_Payment_or_Transfer_of_Value Nature_of_Payment_or_Transfer_of_Value  \
# 0           In-kind items and services                      Food and Beverage
# 1           In-kind items and services                      Food and Beverage
#
#   City_of_Travel State_of_Travel Country_of_Travel  \
# 0
# 1
#
#   Physician_Ownership_Indicator Third_Party_Payment_Recipient_Indicator  \
# 0                            No                  No Third Party Payment
# 1                            No                                  Entity
#
#   Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value  \
# 0
# 1                           CONSORTIUM CONCEPTS, LLC
#
#   Charity_Indicator Third_Party_Equals_Covered_Recipient_Indicator  \
# 0                No
# 1                No                                             No
#
#   Contextual_Information Delay_in_Publication_Indicator  Record_ID  \
# 0                                                    No  100273318
# 1                                                    No  100274296
#
#   Dispute_Status_for_Publication Product_Indicator  \
# 0                             No           Covered
# 1                             No           Covered
#
#   Name_of_Associated_Covered_Drug_or_Biological1  \
# 0                                        VIIBRYD
# 1                                     NAMENDA XR
#
#   Name_of_Associated_Covered_Drug_or_Biological2  \
# 0
# 1
#
#   Name_of_Associated_Covered_Drug_or_Biological3  \
# 0
# 1
#
#   Name_of_Associated_Covered_Drug_or_Biological4  \
# 0
# 1
#
#   Name_of_Associated_Covered_Drug_or_Biological5  \
# 0
# 1
#
#   NDC_of_Associated_Covered_Drug_or_Biological1  \
# 0                                   456114030.0
# 1                                   456342833.0
#
#   NDC_of_Associated_Covered_Drug_or_Biological2  \
# 0
# 1
#
#   NDC_of_Associated_Covered_Drug_or_Biological3  \
# 0
# 1
#
#   NDC_of_Associated_Covered_Drug_or_Biological4  \
# 0
# 1
#
#   NDC_of_Associated_Covered_Drug_or_Biological5  \
# 0
# 1
#
#   Name_of_Associated_Covered_Device_or_Medical_Supply1  \
# 0
# 1
#
#   Name_of_Associated_Covered_Device_or_Medical_Supply2  \
# 0
# 1
#
#   Name_of_Associated_Covered_Device_or_Medical_Supply3  \
# 0
# 1
#
#   Name_of_Associated_Covered_Device_or_Medical_Supply4  \
# 0
# 1
#
#   Name_of_Associated_Covered_Device_or_Medical_Supply5  Program_Year  \
# 0                                                               2013
# 1                                                               2013
#
#   Payment_Publication_Date
# 0               01/22/2021
# 1               01/22/2021

# %%
ohio2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180060 entries, 0 to 180059
# Data columns (total 65 columns):
#  #   Column                                                             Non-Null Count   Dtype
# ---  ------                                                             --------------   -----
#  0   Change_Type                                                        180060 non-null  object
#  1   Covered_Recipient_Type                                             180060 non-null  object
#  2   Teaching_Hospital_CCN                                              0 non-null       float64
#  3   Teaching_Hospital_ID                                               0 non-null       float64
#  4   Teaching_Hospital_Name                                             180060 non-null  object
#  5   Physician_Profile_ID                                               180060 non-null  float64
#  6   Physician_First_Name                                               180060 non-null  object
#  7   Physician_Middle_Name                                              180060 non-null  object
#  8   Physician_Last_Name                                                180060 non-null  object
#  9   Physician_Name_Suffix                                              180060 non-null  object
#  10  Recipient_Primary_Business_Street_Address_Line1                    180060 non-null  object
#  11  Recipient_Primary_Business_Street_Address_Line2                    180060 non-null  object
#  12  Recipient_City                                                     180060 non-null  object
#  13  Recipient_State                                                    180060 non-null  object
#  14  Recipient_Zip_Code                                                 180060 non-null  object
#  15  Recipient_Country                                                  180060 non-null  object
#  16  Recipient_Province                                                 180060 non-null  object
#  17  Recipient_Postal_Code                                              180060 non-null  object
#  18  Physician_Primary_Type                                             180060 non-null  object
#  19  Physician_Specialty                                                180060 non-null  object
#  20  Physician_License_State_code1                                      180060 non-null  object
#  21  Physician_License_State_code2                                      180060 non-null  object
#  22  Physician_License_State_code3                                      180060 non-null  object
#  23  Physician_License_State_code4                                      180060 non-null  object
#  24  Physician_License_State_code5                                      180060 non-null  object
#  25  Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name          180060 non-null  object
#  26  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID        180060 non-null  int64
#  27  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name      180060 non-null  object
#  28  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State     180060 non-null  object
#  29  Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country   180060 non-null  object
#  30  Total_Amount_of_Payment_USDollars                                  180060 non-null  float64
#  31  Date_of_Payment                                                    180060 non-null  object
#  32  Number_of_Payments_Included_in_Total_Amount                        180060 non-null  int64
#  33  Form_of_Payment_or_Transfer_of_Value                               180060 non-null  object
#  34  Nature_of_Payment_or_Transfer_of_Value                             180060 non-null  object
#  35  City_of_Travel                                                     180060 non-null  object
#  36  State_of_Travel                                                    180060 non-null  object
#  37  Country_of_Travel                                                  180060 non-null  object
#  38  Physician_Ownership_Indicator                                      180060 non-null  object
#  39  Third_Party_Payment_Recipient_Indicator                            180060 non-null  object
#  40  Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value  180060 non-null  object
#  41  Charity_Indicator                                                  180060 non-null  object
#  42  Third_Party_Equals_Covered_Recipient_Indicator                     180060 non-null  object
#  43  Contextual_Information                                             180060 non-null  object
#  44  Delay_in_Publication_Indicator                                     180060 non-null  object
#  45  Record_ID                                                          180060 non-null  int64
#  46  Dispute_Status_for_Publication                                     180060 non-null  object
#  47  Product_Indicator                                                  180060 non-null  object
#  48  Name_of_Associated_Covered_Drug_or_Biological1                     180060 non-null  object
#  49  Name_of_Associated_Covered_Drug_or_Biological2                     180060 non-null  object
#  50  Name_of_Associated_Covered_Drug_or_Biological3                     180060 non-null  object
#  51  Name_of_Associated_Covered_Drug_or_Biological4                     180060 non-null  object
#  52  Name_of_Associated_Covered_Drug_or_Biological5                     180060 non-null  object
#  53  NDC_of_Associated_Covered_Drug_or_Biological1                      180060 non-null  object
#  54  NDC_of_Associated_Covered_Drug_or_Biological2                      180060 non-null  object
#  55  NDC_of_Associated_Covered_Drug_or_Biological3                      180060 non-null  object
#  56  NDC_of_Associated_Covered_Drug_or_Biological4                      180060 non-null  object
#  57  NDC_of_Associated_Covered_Drug_or_Biological5                      180060 non-null  object
#  58  Name_of_Associated_Covered_Device_or_Medical_Supply1               180060 non-null  object
#  59  Name_of_Associated_Covered_Device_or_Medical_Supply2               180060 non-null  object
#  60  Name_of_Associated_Covered_Device_or_Medical_Supply3               180060 non-null  object
#  61  Name_of_Associated_Covered_Device_or_Medical_Supply4               180060 non-null  object
#  62  Name_of_Associated_Covered_Device_or_Medical_Supply5               180060 non-null  object
#  63  Program_Year                                                       180060 non-null  int64
#  64  Payment_Publication_Date                                           180060 non-null  object
# dtypes: float64(4), int64(4), object(57)
# memory usage: 89.3+ MB

# %%
cinci2013 = ohio2013[((ohio2013['Recipient_City']=='Cincinnati') | (ohio2013['Recipient_City']=='CINCINNATI'))].copy()

# %%
cinci2013['Recipient_City'].value_counts()
# Out:
# CINCINNATI    16471
# Cincinnati     4352
# Name: Recipient_City, dtype: int64

# %%
cinci2013['Covered_Recipient_Type'].value_counts()
# Out:
# Covered Recipient Physician    20823
# Name: Covered_Recipient_Type, dtype: int64

# %%
cinci_dr2013 = cinci2013[cinci2013['Covered_Recipient_Type']=='Covered Recipient Physician'].copy()

# %%
cinci_dr2013['Covered_Recipient_Type'].value_counts()
# Out:
# Covered Recipient Physician    20823
# Name: Covered_Recipient_Type, dtype: int64

# %%
cinci_dr2013['Physician_Ownership_Indicator'].value_counts()
# Out:
# No     20612
# Yes      211
# Name: Physician_Ownership_Indicator, dtype: int64

# %%
cinci_dr2013.rename(columns = {'Product_Indicator':'Related_Product_Indicator',
'Name_of_Associated_Covered_Drug_or_Biological1':'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Name_of_Associated_Covered_Drug_or_Biological2':'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Name_of_Associated_Covered_Drug_or_Biological3':'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Name_of_Associated_Covered_Drug_or_Biological4':'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Name_of_Associated_Covered_Drug_or_Biological5':'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'NDC_OF_Associated_Covered_Drug_or_Biological1':'Associated_Drug_or_Biological_NDC_1',                         
'NDC_OF_Associated_Covered_Drug_or_Biological2':'Associated_Drug_or_Biological_NDC_2',                         
'NDC_OF_Associated_Covered_Drug_or_Biological3':'Associated_Drug_or_Biological_NDC_3',                         
'NDC_OF_Associated_Covered_Drug_or_Biological4':'Associated_Drug_or_Biological_NDC_4',                         
'NDC_OF_Associated_Covered_Drug_or_Biological5':'Associated_Drug_or_Biological_NDC_5',}, inplace=True)

# %%
cinci_dr2013['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].value_counts()
# Out:
#             6159
# Victoza      520
# Invokana     474
# Xarelto      434
# Levemir      385
#             ...
# Blincyto       1
# Cosentyx       1
# Saizen         1
# Hylenex        1
# Vagifem        1
# Name: Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1, Length: 502, dtype: int64

# %%
cinci_dr2013['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2'].value_counts()
# Out:
#                                  17504
# Xarelto                            317
# DALIRESP                           211
# Victoza                            184
# TRADJENTA                          178
# AXIRON                             163
# Oseni                              144
# Invokana                           134
# HUMALOG                            126
# INTUNIV                            115
# LINZESS 290 mcg                    109
# LANTUS                              97
# CIALIS                              96
# NovoLog Mix 70 30                   93
# PRADAXA                             84
# PENTASA                             68
# OXYCONTIN                           67
# AVONEX                              64
# Colcrys                             63
# LIPOFEN                             61
# COMBIVENT RESPIMAT                  60
# JENTADUETO                          54
# BUTRANS                             48
# NovoLog                             40
# RAYOS-2mg Prednisone                37
# VENTAVIS ILOPROST                   31
# Simponi                             30
# Skyla                               27
# Zegerid                             26
# Prolia                              24
# VESIcare                            19
# Risperdal Consta                    18
# Remicade                            17
# MYOBLOC                             15
# ZETIA                               15
# HOSPITAL                            15
# BEPREVE                             14
# Edarbyclor                          13
# Cataract Equipment                  13
# CRESTOR                             12
# Cycloset                            12
# JANUMET                             11
# FLUZONE INTRADERMAL                 11
# Stelara                             11
# VIIBRYD                             11
# XGEVA                               10
# Sensipar                            10
# Desonate                            10
# Evicel                               9
# Travatan Z                           9
# SPIRIVA                              9
# LOTEMAX GEL                          9
# TIROSINT                             9
# DIFICID                              8
# MENACTRA                             8
# Pomalyst                             8
# INTERMEZZO                           8
# Actemra                              8
# PENTACEL                             7
# Invega Sustenna                      7
# Tarceva                              7
# Invega                               7
# AmBisome                             7
# EVISTA                               6
# Vectibix                             6
# SYMBICORT                            6
# LIPTRUZET                            6
# HIV                                  6
# LACRISERT                            6
# ZOSTAVAX                             6
# NON BRAND                            5
# PYLERA                               5
# Moxeza                               5
# BESIVANCE                            5
# ALREX                                5
# EXFORGE                              5
# Ilevro                               5
# Doxil                                4
# VICTRELIS                            4
# Alinia for Oral Suspension           4
# FLUZONE HIGH DOSE                    4
# JANUMET Diabetes                     4
# SIGNIFOR                             4
# BRILINTA                             4
# JANUMET XR                           3
# NASONEX                              3
# VYTORIN                              3
# Simbrinza                            3
# Istodax                              3
# ZEMURON                              3
# RAYOS-1mg Prednisone                 3
# TEKTURNA                             3
# Systane                              3
# ZENPEP                               3
# Revlimid                             3
# EPOGEN                               3
# LE - Mini MaxLock Extreme            3
# DYSPORT                              2
# PROLENSA                             2
# Procrit                              2
# XERESE                               2
# CARAC CREAM                          2
# GANIRELIX                            2
# LE - Cannulated Intra Fix Sys        2
# ELIGARD                              2
# NEUPOGEN                             2
# Duovisc                              2
# SEROQUEL XR                          2
# N A                                  2
# Imbruvica                            2
# LEVITRA                              2
# AMYVID                               2
# INNOPRAN XL                          2
# Migranal                             2
# STRATTERA                            2
# V512                                 1
# NO PRODUCT DISCUSSED                 1
# SYLATRON                             1
# Vidaza                               1
# INTRON A                             1
# ZALTRAP                              1
# RECTIV                               1
# PNEUMOVAX 23                         1
# Stivarga                             1
# Luxor                                1
# Patanase                             1
# SERETIDE                             1
# Amniograft                           1
# ENTEREG                              1
# APRISO                               1
# NEXPLANON                            1
# SKLICE DETAIL                        1
# Select-OB DHA Caplets                1
# Vitafol-OB DHA Caplet                1
# LE - MaxLock Extreme                 1
# EpiPen                               1
# Bromfed DM Pint bottle               1
# DATSCAN IOFLUPANE                    1
# Viscoat                              1
# Zelboraf                             1
# TASIGNA                              1
# EXELON PATCH                         1
# ONGLYZA                              1
# Omeclamox                            1
# ADACEL                               1
# TARCEVA                              1
# Name: Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2, dtype: int64

# %%
cinci_dr2013['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3'].value_counts()
# Out:
#                                  20041
# Kazano                             144
# STRATTERA                          119
# INTERMEZZO                          90
# COMBIVENT RESPIMAT                  52
# RAYOS-5mg Prednisone                37
# VELETRI EPOPROSTENOL                27
# TRADJENTA                           23
# Victoza                             18
# GANIRELIX                           15
# PEDIATRICS                          15
# ADACEL                              15
# FLUZONE HIGH DOSE                   15
# ZYLET                               14
# Invega                              14
# ALREX                               13
# Simbrinza                           12
# Remicade                            11
# ZEMURON                              9
# Zegerid                              9
# ONGLYZA                              9
# AXIRON                               8
# JENTADUETO                           8
# Risperdal                            7
# XGEVA                                6
# Procrit                              6
# OXYCONTIN                            6
# PROLENSA                             5
# Stelara                              5
# ZENPEP                               5
# ARESTIN                              4
# PNEUMOVAX 23                         4
# Pataday                              4
# PYLERA                               3
# AUVIQ                                3
# RAYOS-2mg Prednisone                 3
# Sensipar                             3
# ZOLINZA                              3
# ZETIA                                2
# LE - MaxTorque Cann Screw Sys        2
# Istodax                              2
# ZYCLARA                              2
# Viscoat                              2
# LOTEMAX GEL                          2
# SUPRENZA                             2
# Doxil                                2
# LE - MaxLock Extreme                 2
# FLUZONE                              2
# NovoLog Mix 70 30                    1
# NASONEX                              1
# BESIVANCE                            1
# NUVARING                             1
# Duovisc                              1
# ADVAIR                               1
# SKLICE                               1
# BUTRANS                              1
# OMNISCAN GADODIAMIDE                 1
# ENTEREG                              1
# LOVAZA                               1
# Silenor                              1
# CRESTOR                              1
# SYMBICORT                            1
# CANASA                               1
# LE - Mini MaxLock Extreme            1
# LE - RFS Pin                         1
# AVODART                              1
# Name: Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3, dtype: int64

# %%
cinci_dr2013['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4'].value_counts()
# Out:
#                                         20760
# NovoLog Mix 70 30                          17
# ADACEL                                     12
# FLUZONE                                    10
# LE - MaxTorque Cann Screw Sys               3
# RAYOS-5mg Prednisone                        3
# SKLICE DETAIL                               3
# CANASA                                      3
# LE - RFS Screw                              1
# LE - Mini MaxTorque Sys                     1
# Zitripro                                    1
# LE - Mini MaxLock Extreme                   1
# IMMUNIZATION SOLUTIO                        1
# Doxil                                       1
# MYOVIEW TECHNETIUM TC99M TETROFOSMIN        1
# AUVIQ                                       1
# MK-0822                                     1
# GANIRELIX                                   1
# JANUMET XR                                  1
# ZENPEP                                      1
# Name: Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4, dtype: int64

# %%
cinci_dr2013['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5'].value_counts()
# Out:
#                            20793
# FLUZONE                        8
# FLUZONE QIV                    8
# SKLICE                         6
# AUVIQ                          3
# LE - Mini MaxTorque Sys        2
# Vituz                          1
# VISIPAQUE IODIXANOL            1
# MK-4305                        1
# Name: Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5, dtype: int64

# %%
drop_cols = ['Name_of_Associated_Covered_Device_or_Medical_Supply1', 'Name_of_Associated_Covered_Device_or_Medical_Supply2', 'Name_of_Associated_Covered_Device_or_Medical_Supply3',
             'Name_of_Associated_Covered_Device_or_Medical_Supply4','Name_of_Associated_Covered_Device_or_Medical_Supply5']

# %%
cinci_dr2013.drop(columns=drop_cols, inplace = True)

# %%
cinci_dr2013.to_csv('./data/cincidr2013.csv', index=False)  #Gene told me about index=False to prevent getting an Unnamed:0 column in my csv/dataset (when I read it back in)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cinci_1320 = pd.read_csv('./data/cinci1320.csv', index_col='Date_of_Payment', parse_dates=True).sort_index()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,18,19,47,48,49,50,51,52,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_1320.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     148974               RODNEY
# 2013-08-01                      58931                 PAUL
# 2013-08-01                     812462               ALFRED
# 2013-08-01                     108863                 MARK
# 2013-08-01                     195441           MANOJKUMAR
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                        NaN              VIVIAN
# 2013-08-01                     JOSEPH            FAVORITO
# ...

# %%
cinci_1320['Change_Type'].value_counts()
# Out:
# UNCHANGED    364686
# CHANGED         726
# ADD               1
# Name: Change_Type, dtype: int64

# %%
cinci_1320['xarelto'].value_counts()
# Out:
# 0    353682
# 1     11731
# Name: xarelto, dtype: int64

# %%
xarelto = cinci_1320[(cinci_1320['xarelto']==1) & (cinci_1320['Number_of_Payments_Included_in_Total_Amount']==1)].copy()

# %%
xarelto.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     236354               JOSEPH
# 2013-08-01                     160571                PETER
# 2013-08-01                     288614              DOUGLAS
# 2013-08-01                     296032              GREGORY
# 2013-08-01                    1113857               JEREMY
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                    RICHARD           DAGENBACH
# 2013-08-01                         A.           SCHEIDLER
# ...

# %%
xarelto['xarelto'].value_counts()
# Out:
# 1    11731
# Name: xarelto, dtype: int64

# %%
xarelto['Change_Type'].value_counts()
# Out:
# UNCHANGED    11731
# Name: Change_Type, dtype: int64

# %%
xarelto['xare_dollars'] = [k if ((i ==1) & (j ==1)) else 0 for i, j, k in zip(xarelto['xarelto'], xarelto['Number_of_Payments_Included_in_Total_Amount'], xarelto['Total_Amount_of_Payment_USDollars'])]

#Ben Peck helped me with this during office hours.  I was oh-so-close but not quite there!

# %%
xarelto['xare_dollars'].sum()
# Out:
# 1747345.12

# %%
xarelto.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     236354               JOSEPH
# 2013-08-01                     160571                PETER
# 2013-08-01                     288614              DOUGLAS
# 2013-08-01                     296032              GREGORY
# 2013-08-01                    1113857               JEREMY
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                    RICHARD           DAGENBACH
# 2013-08-01                         A.           SCHEIDLER
# ...

# %%
drop_cols = ['Change_Type','Covered_Recipient_Type',
'Physician_First_Name',
'Physician_Middle_Name',
'Physician_Last_Name',
'Physician_Name_Suffix',
'Recipient_Primary_Business_Street_Address_Line1',
'Recipient_Primary_Business_Street_Address_Line2',
'Recipient_City',
'Recipient_State',
'Recipient_Zip_Code',
'Recipient_Country',
'Physician_Primary_Type',
'Physician_Specialty',
'Physician_License_State_code1',
'Physician_License_State_code2',
'Physician_License_State_code3',
'Physician_License_State_code4',
'Physician_License_State_code5',
'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
'Form_of_Payment_or_Transfer_of_Value',
'City_of_Travel',
'State_of_Travel',
'Country_of_Travel',
'Physician_Ownership_Indicator',
'Third_Party_Payment_Recipient_Indicator',
'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
'Charity_Indicator',
'Third_Party_Equals_Covered_Recipient_Indicator',
'Contextual_Information',
'Delay_in_Publication_Indicator',
'Dispute_Status_for_Publication',
'Related_Product_Indicator',
'Covered_or_Noncovered_Indicator_1',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Product_Category_or_Therapeutic_Area_1',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Associated_Drug_or_Biological_NDC_1',
'Covered_or_Noncovered_Indicator_2',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Product_Category_or_Therapeutic_Area_2',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Associated_Drug_or_Biological_NDC_2',
'Covered_or_Noncovered_Indicator_3',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Product_Category_or_Therapeutic_Area_3',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Associated_Drug_or_Biological_NDC_3',
'Covered_or_Noncovered_Indicator_4',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Product_Category_or_Therapeutic_Area_4',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Associated_Drug_or_Biological_NDC_4',
'Covered_or_Noncovered_Indicator_5',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Product_Category_or_Therapeutic_Area_5',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Associated_Drug_or_Biological_NDC_5', 
'Physician_Profile_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
'Total_Amount_of_Payment_USDollars','Number_of_Payments_Included_in_Total_Amount', 
'Nature_of_Payment_or_Transfer_of_Value', 'Record_ID', 
'Payment_Publication_Date', 'Program_Year',
'NDC_of_Associated_Covered_Drug_or_Biological1',
'NDC_of_Associated_Covered_Drug_or_Biological2',
'NDC_of_Associated_Covered_Drug_or_Biological3',
'NDC_of_Associated_Covered_Drug_or_Biological4',
'NDC_of_Associated_Covered_Drug_or_Biological5',
'Name_of_Associated_Covered_Device_or_Medical_Supply1',
'Name_of_Associated_Covered_Device_or_Medical_Supply2',
'Name_of_Associated_Covered_Device_or_Medical_Supply3',
'Name_of_Associated_Covered_Device_or_Medical_Supply4',
'Name_of_Associated_Covered_Device_or_Medical_Supply5',
'invokana', 'farxiga', 'victoza', 'humira', 'levemir',
'entresto', 'chantix', 'myrbetriq', 'toujeo']

# %%
xarelto.drop(columns = drop_cols, inplace = True)

# %%
xarelto.head()
# Out:
#                  xarelto  xare_dollars
# Date_of_Payment
# 2013-08-01             1         11.97
# 2013-08-01             1          8.89
# 2013-08-01             1         14.54
# 2013-08-01             1         13.63
# 2013-08-01             1         11.97

# %% [markdown]
# Was reminded of the importance of checking data for outliers by this article, and modeled my filtering code below on this article:
# https://www.analyticsvidhya.com/blog/2021/08/holt-winters-method-for-time-series-analysis/

# %%
sns.boxplot(x = xarelto['xare_dollars']);

# %%
xarelto['z_score'] = [ ((i - xarelto['xare_dollars'].mean())/xarelto['xare_dollars'].std()) for i in xarelto['xare_dollars']]

# %%
xarelto.shape
# Out:
# (11731, 3)

# %% [markdown]
# Add chart to see data before dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(xarelto.index, xarelto['xare_dollars'], label='Before Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Xarelto Drug - Before Outliers Dropped");

# %%
xareltob = xarelto[(np.abs(xarelto['z_score']) < 3)].copy()

# %%
xareltob.shape
# Out:
# (11323, 3)

# %% [markdown]
# Add chart to see data after dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(xareltob.index, xareltob['xare_dollars'], label='After Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Xarelto Drug - After Outliers Dropped");

# %% [markdown]
# Drop Z-score before aggregating

# %%
xareltob.drop(columns='z_score', inplace=True)

# %%
xarelto_monthly = xareltob.resample('m').sum()

# %%
xarelto_monthly.head()
# Out:
#                  xarelto  xare_dollars
# Date_of_Payment
# 2013-08-31            74       3489.82
# 2013-09-30            74       2105.47
# 2013-10-31            88       6174.00
# 2013-11-30           101       9742.12
# 2013-12-31            88       4107.66

# %%
xarelto_monthly.sort_index()
# Out:
#                  xarelto  xare_dollars
# Date_of_Payment
# 2013-08-31            74       3489.82
# 2013-09-30            74       2105.47
# 2013-10-31            88       6174.00
# 2013-11-30           101       9742.12
# 2013-12-31            88       4107.66
# ...                  ...           ...
# 2020-08-31            41       1548.63
# 2020-09-30            51        706.55
# 2020-10-31            52        758.70
# 2020-11-30            40       2060.09
# 2020-12-31            56       2566.49
#
# [89 rows x 2 columns]

# %% [markdown]
# Look at some plots

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf

# %%
plot_acf(xarelto_monthly['xare_dollars'], alpha=None, lags=24);

# %%
plot_pacf(xarelto_monthly['xare_dollars'], alpha=None, lags=24);
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# Adding 1 to the weekly sales for each observation so that Holt_winters will work.

# %%
xarelto_monthly['xare_dollars'] = [i+1 for i in xarelto_monthly['xare_dollars']]

# %% [markdown]
# Set up Train and Test Sets using 2013 - 2020 Data

# %%
train = xarelto_monthly.loc[:'2019-12-31']
train
# Out:
#                  xarelto  xare_dollars
# Date_of_Payment
# 2013-08-31            74       3490.82
# 2013-09-30            74       2106.47
# 2013-10-31            88       6175.00
# 2013-11-30           101       9743.12
# 2013-12-31            88       4108.66
# ...                  ...           ...
# 2019-08-31           158       4388.64
# 2019-09-30           118       2339.39
# 2019-10-31           119       4965.63
# 2019-11-30           101       2459.95
# 2019-12-31           145       4410.85
#
# [77 rows x 2 columns]

# %%
train['xare_dollars'].max()
# Out:
# 18436.43

# %%
train.describe()
# Out:
#           xarelto  xare_dollars
# count   77.000000     77.000000
# mean   139.389610   5413.115325
# std     38.781492   3596.101014
# min     71.000000    733.180000
# 25%    113.000000   2785.350000
# 50%    139.000000   4528.500000
# 75%    158.000000   6175.000000
# max    274.000000  18436.430000

# %%
train.index.freq = 'M'

# %%
train.shape
# Out:
# (77, 2)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 77 entries, 2013-08-31 to 2019-12-31
# Freq: M
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   xarelto       77 non-null     int64
#  1   xare_dollars  77 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.8 KB

# %%
train.index
# Out:
# DatetimeIndex(['2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30',
#                '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31',
#                '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31',
#                '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30',
#                '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31',
#                '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31',
#                '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30',
#                '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31',
#                '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31',
#                '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30',
#                '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31',
#                '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31',
#                '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30',
# ...

# %%
test = xarelto_monthly.loc['2020-01-01':]
test
# Out:
#                  xarelto  xare_dollars
# Date_of_Payment
# 2020-01-31           113       1709.76
# 2020-02-29            84       2035.72
# 2020-03-31            49       1635.74
# 2020-04-30            18        511.58
# 2020-05-31            24        359.04
# 2020-06-30            32        433.36
# 2020-07-31            30       1481.66
# 2020-08-31            41       1549.63
# 2020-09-30            51        707.55
# 2020-10-31            52        759.70
# 2020-11-30            40       2061.09
# 2020-12-31            56       2567.49

# %%
test.describe()
# Out:
#           xarelto  xare_dollars
# count   12.000000     12.000000
# mean    49.166667   1317.693333
# std     26.566669    738.564582
# min     18.000000    359.040000
# 25%     31.500000    658.557500
# 50%     45.000000   1515.645000
# 75%     53.000000   1791.250000
# max    113.000000   2567.490000

# %%
test.shape
# Out:
# (12, 2)

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')

plt.legend(loc='best')
plt.title("Monthly Payments for Xarelto Drug");

# %% [markdown]
# Baseline - Simple Mean (Naive Model)

# %%
df_preds = test.copy(deep=True)
df_preds
# Out:
#                  xarelto  xare_dollars
# Date_of_Payment
# 2020-01-31           113       1709.76
# 2020-02-29            84       2035.72
# 2020-03-31            49       1635.74
# 2020-04-30            18        511.58
# 2020-05-31            24        359.04
# 2020-06-30            32        433.36
# 2020-07-31            30       1481.66
# 2020-08-31            41       1549.63
# 2020-09-30            51        707.55
# 2020-10-31            52        759.70
# 2020-11-30            40       2061.09
# 2020-12-31            56       2567.49

# %%
df_preds['simple_mean'] = train['xare_dollars'].mean()
df_preds
# Out:
#                  xarelto  xare_dollars  simple_mean
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325
# 2020-02-29            84       2035.72  5413.115325
# 2020-03-31            49       1635.74  5413.115325
# 2020-04-30            18        511.58  5413.115325
# 2020-05-31            24        359.04  5413.115325
# 2020-06-30            32        433.36  5413.115325
# 2020-07-31            30       1481.66  5413.115325
# 2020-08-31            41       1549.63  5413.115325
# 2020-09-30            51        707.55  5413.115325
# 2020-10-31            52        759.70  5413.115325
# 2020-11-30            40       2061.09  5413.115325
# 2020-12-31            56       2567.49  5413.115325

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['simple_mean'], label="Baseline (Mean)")

plt.legend(loc='best')
plt.title("Baseline (Mean) Forecast for Monthly Xarelto Payments");

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['simple_mean'], squared=False))
# Out:
# MAE for Simple Mean Baseline Model: 4095.421991341993
# RMSE for Simple Mean Baseline Model: 4156.020026237823

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 4

# %%
df_preds['seasonal_4'] = train['xare_dollars'].shift(4, freq='M') 
df_preds.head(2)
# Out:
#                  xarelto  xare_dollars  simple_mean  seasonal_4
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325     2339.39
# 2020-02-29            84       2035.72  5413.115325     4965.63

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_4'], label='Seasonal 4')

plt.legend(loc='best')
plt.title("Seasonal 4 Forecast for Monthly Xarelto Payments");

# %%
df_preds['seasonal_4'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['seasonal_4'], squared=False))
# Out:
# MAE for Seasonal Baseline 4 Shift Model: 1516.8783333333333
# RMSE for Seasonal Baseline 4 Shift Model: 1864.0386996697966

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 6

# %%
df_preds['seasonal_6'] = train['xare_dollars'].shift(6, freq='M') 
df_preds.head(2)
# Out:
#                  xarelto  xare_dollars  simple_mean  seasonal_4  seasonal_6
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325     2339.39     6029.20
# 2020-02-29            84       2035.72  5413.115325     4965.63     4388.64

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_6'], label='Seasonal 6')

plt.legend(loc='best')
plt.title("Seasonal 6 Forecast for Monthly Xarelto Payments");

# %%
df_preds['seasonal_6'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['seasonal_6'], squared=False))
# Out:
# MAE for Seasonal Baseline 6 Shift Model: 2252.965
# RMSE for Seasonal Baseline 6 Shift Model: 2602.503060619398

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 12

# %%
df_preds['seasonal_12'] = train['xare_dollars'].shift(12, freq='M') 
df_preds.head(2)
# Out:
#                  xarelto  xare_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325     2339.39     6029.20
# 2020-02-29            84       2035.72  5413.115325     4965.63     4388.64
#
#                  seasonal_12
# Date_of_Payment
# 2020-01-31           1537.38
# 2020-02-29           1941.17

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_12'], label='Seasonal 12')

plt.legend(loc='best')
plt.title("Seasonal 12 Forecast for Monthly Xarelto Payments");

# %%
df_preds['seasonal_12'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['seasonal_12'], squared=False))
# Out:
# MAE for Seasonal Baseline 12 Shift Model: 2941.31
# RMSE for Seasonal Baseline 12 Shift Model: 3656.8862307866057

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 18

# %%
df_preds['seasonal_18'] = train['xare_dollars'].shift(18, freq='M') 
df_preds.head(2)
# Out:
#                  xarelto  xare_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325     2339.39     6029.20
# 2020-02-29            84       2035.72  5413.115325     4965.63     4388.64
#
#                  seasonal_12  seasonal_18
# Date_of_Payment
# 2020-01-31           1537.38      1994.90
# 2020-02-29           1941.17      1597.16

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_18'], label='Seasonal 18')

plt.legend(loc='best')
plt.title("Seasonal 18 Forecast for Monthly Xarelto Payments");

# %%
df_preds['seasonal_18'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['seasonal_18'], squared=False))
# Out:
# MAE for Seasonal Baseline 18 Shift Model: 2921.1041666666665
# RMSE for Seasonal Baseline 18 Shift Model: 3562.854243078855

# %% [markdown]
# Simple Exponential Smoothing Model

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing

# %%
ses = SimpleExpSmoothing(train['xare_dollars']).fit(smoothing_level=.5)

# %%
ses.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ...
# Dep. Variable:           xare_dollars   No. Observations:                   77
# Model:             SimpleExpSmoothing   SSE                     1126987134.623
# Optimized:                       True   AIC                           1274.424
# Trend:                           None   BIC                           1279.111
# Seasonal:                        None   AICC                          1274.979
# Seasonal Periods:                None   Date:                 Tue, 15 Mar 2022
# Box-Cox:                        False   Time:                         18:48:43
# Box-Cox Coeff.:                  None
# ...
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.5000000                alpha                False
# ...

# %%
ses_forecast = ses.forecast(len(test))

# %%
df_preds['ses'] = ses_forecast

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['ses'], label='Simple Exponential Smoothing')

plt.legend(loc='best')
plt.title("Simple Exponential Smoothing for Xarelto Monthly Payments");

# %%
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['ses'], squared=False))
# Out:
# MAE for Simple Exponential Smoothing Model: 2589.5255358438194
# RMSE for Simple Exponential Smoothing Model: 2684.3367285252125

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 4.

# %%
hw_a4 = ExponentialSmoothing(
    train['xare_dollars'],
    seasonal_periods=4, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             xare_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                     1200504929.393
# Optimized:                         True   AIC                           1291.290
# Trend:                         Additive   BIC                           1310.040
# Seasonal:                      Additive   AICC                          1294.623
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:48:43
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1817857                alpha                 True
# ...

# %%
df_preds['hw_a4'] = hw_a4.forecast(len(test))
df_preds.head(2)
# Out:
#                  xarelto  xare_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325     2339.39     6029.20
# 2020-02-29            84       2035.72  5413.115325     4965.63     4388.64
#
#                  seasonal_12  seasonal_18          ses        hw_a4
# Date_of_Payment
# 2020-01-31           1537.38      1994.90  3907.218869  3824.557887
# 2020-02-29           1941.17      1597.16  3907.218869  3316.720407

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a4'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 4 for Monthly Payments for Xarelto");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_a4'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 2265.465536710269
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 2382.0740358518788

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 6.

# %%
hw_a6 = ExponentialSmoothing(
    train['xare_dollars'],
    seasonal_periods=6, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             xare_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      993218875.774
# Optimized:                         True   AIC                           1280.695
# Trend:                         Additive   BIC                           1304.133
# Seasonal:                      Additive   AICC                          1285.570
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:48:44
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2167700                alpha                 True
# ...

# %%
df_preds['hw_a6'] = hw_a6.forecast(len(test))
df_preds.head(2)
# Out:
#                  xarelto  xare_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325     2339.39     6029.20
# 2020-02-29            84       2035.72  5413.115325     4965.63     4388.64
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1537.38      1994.90  3907.218869  3824.557887
# 2020-02-29           1941.17      1597.16  3907.218869  3316.720407
#
#                        hw_a6
# Date_of_Payment
# 2020-01-31       3006.196224
# 2020-02-29       1910.720891

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a6'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 6 for Monthly Payments for Xarelto");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_a6'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 2155.040942321174
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 2709.4376688741827

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 12.

# %%
hw_a12 = ExponentialSmoothing(
    train['xare_dollars'],
    seasonal_periods=12, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             xare_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      837520014.858
# Optimized:                         True   AIC                           1279.566
# Trend:                         Additive   BIC                           1317.066
# Seasonal:                      Additive   AICC                          1291.359
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:48:44
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1464286                alpha                 True
# ...

# %%
df_preds['hw_a12'] = hw_a12.forecast(len(test))
df_preds.head(2)
# Out:
#                  xarelto  xare_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325     2339.39     6029.20
# 2020-02-29            84       2035.72  5413.115325     4965.63     4388.64
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1537.38      1994.90  3907.218869  3824.557887
# 2020-02-29           1941.17      1597.16  3907.218869  3316.720407
#
#                        hw_a6       hw_a12
# Date_of_Payment
# 2020-01-31       3006.196224   848.197852
# 2020-02-29       1910.720891  1880.798127

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a12'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 12 for Monthly Payments for Xarelto");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_a12'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 1852.8090903182567
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 2663.7370300325324

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 18.

# %%
hw_a18 = ExponentialSmoothing(
    train['xare_dollars'],
    seasonal_periods=18, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             xare_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      792180875.807
# Optimized:                         True   AIC                           1287.280
# Trend:                         Additive   BIC                           1338.844
# Seasonal:                      Additive   AICC                          1310.357
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:48:45
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1464286                alpha                 True
# ...

# %%
df_preds['hw_a18'] = hw_a18.forecast(len(test))
df_preds.head(2)
# Out:
#                  xarelto  xare_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325     2339.39     6029.20
# 2020-02-29            84       2035.72  5413.115325     4965.63     4388.64
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1537.38      1994.90  3907.218869  3824.557887
# 2020-02-29           1941.17      1597.16  3907.218869  3316.720407
#
#                        hw_a6       hw_a12       hw_a18
# Date_of_Payment
# 2020-01-31       3006.196224   848.197852  2906.326483
# 2020-02-29       1910.720891  1880.798127  4467.138648

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a18'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 18 for Monthly Payments for Xarelto");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_a18'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 18 Model: 3439.0667270568997
# RMSE for Holt-Winters Additive with Seasonality of 18 Model: 4173.433802696119

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 4.

# %%
hw_m4 = ExponentialSmoothing(
    train['xare_dollars'],
    seasonal_periods=4, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             xare_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                     1154901131.612
# Optimized:                         True   AIC                           1288.308
# Trend:                   Multiplicative   BIC                           1307.058
# Seasonal:                Multiplicative   AICC                          1291.641
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:48:45
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1110714                alpha                 True
# ...

# %%
df_preds['hw_m4'] = hw_m4.forecast(len(test))
df_preds.head(2)
# Out:
#                  xarelto  xare_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325     2339.39     6029.20
# 2020-02-29            84       2035.72  5413.115325     4965.63     4388.64
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1537.38      1994.90  3907.218869  3824.557887
# 2020-02-29           1941.17      1597.16  3907.218869  3316.720407
#
#                        hw_a6       hw_a12       hw_a18        hw_m4
# Date_of_Payment
# 2020-01-31       3006.196224   848.197852  2906.326483  3871.674554
# 2020-02-29       1910.720891  1880.798127  4467.138648  3453.935455

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m4'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 4 Model for Xarelto Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_m4'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 4 Model: 2271.284785090302
# RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model: 2392.6920226677803

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 6.

# %%
hw_m6 = ExponentialSmoothing(
    train['xare_dollars'],
    seasonal_periods=6, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             xare_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      998584070.765
# Optimized:                         True   AIC                           1281.109
# Trend:                   Multiplicative   BIC                           1304.547
# Seasonal:                Multiplicative   AICC                          1285.984
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:48:46
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1817857                alpha                 True
# ...

# %%
df_preds['hw_m6'] = hw_m6.forecast(len(test))
df_preds.head(2)
# Out:
#                  xarelto  xare_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325     2339.39     6029.20
# 2020-02-29            84       2035.72  5413.115325     4965.63     4388.64
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1537.38      1994.90  3907.218869  3824.557887
# 2020-02-29           1941.17      1597.16  3907.218869  3316.720407
#
#                        hw_a6       hw_a12       hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31       3006.196224   848.197852  2906.326483  3871.674554
# 2020-02-29       1910.720891  1880.798127  4467.138648  3453.935455
#
#                        hw_m6
# Date_of_Payment
# 2020-01-31       2912.352870
# 2020-02-29       2114.583826

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m6'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 6 Model for Xarelto Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_m6'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 6 Model: 1421.510230025927
# RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model: 1769.8942144109246

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 12.

# %%
hw_m12 = ExponentialSmoothing(
    train['xare_dollars'],
    seasonal_periods=12, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             xare_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      787791530.574
# Optimized:                         True   AIC                           1274.852
# Trend:                   Multiplicative   BIC                           1312.353
# Seasonal:                Multiplicative   AICC                          1286.645
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:48:46
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1817857                alpha                 True
# ...

# %%
df_preds['hw_m12'] = hw_m12.forecast(len(test))
df_preds.head(2)
# Out:
#                  xarelto  xare_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325     2339.39     6029.20
# 2020-02-29            84       2035.72  5413.115325     4965.63     4388.64
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1537.38      1994.90  3907.218869  3824.557887
# 2020-02-29           1941.17      1597.16  3907.218869  3316.720407
#
#                        hw_a6       hw_a12       hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31       3006.196224   848.197852  2906.326483  3871.674554
# 2020-02-29       1910.720891  1880.798127  4467.138648  3453.935455
#
#                        hw_m6       hw_m12
# Date_of_Payment
# 2020-01-31       2912.352870  2361.244657
# 2020-02-29       2114.583826  2990.742134

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m12'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 12 Model for Xarelto Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_m12'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 12 Model: 2189.640169562092
# RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model: 2618.9987552297775

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 18.

# %%
hw_m18 = ExponentialSmoothing(
    train['xare_dollars'],
    seasonal_periods=18, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             xare_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      848593661.191
# Optimized:                         True   AIC                           1292.577
# Trend:                   Multiplicative   BIC                           1344.141
# Seasonal:                Multiplicative   AICC                          1315.654
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         18:48:47
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1110714                alpha                 True
# ...

# %%
df_preds['hw_m18'] = hw_m18.forecast(len(test))
df_preds.head(2)
# Out:
#                  xarelto  xare_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           113       1709.76  5413.115325     2339.39     6029.20
# 2020-02-29            84       2035.72  5413.115325     4965.63     4388.64
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31           1537.38      1994.90  3907.218869  3824.557887
# 2020-02-29           1941.17      1597.16  3907.218869  3316.720407
#
#                        hw_a6       hw_a12       hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31       3006.196224   848.197852  2906.326483  3871.674554
# 2020-02-29       1910.720891  1880.798127  4467.138648  3453.935455
#
#                        hw_m6       hw_m12       hw_m18
# Date_of_Payment
# 2020-01-31       2912.352870  2361.244657  3463.116300
# 2020-02-29       2114.583826  2990.742134  4832.412231

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['xare_dollars'], label='Train')
plt.plot(test.index, test['xare_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m18'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 18 Model for Xarelto Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_m18'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 3654.3563662574015
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 4381.069017547752

# %% [markdown]
# Try a SARIMA Model

# %%
from pmdarima.utils import tsdisplay

# %%
traina = train['xare_dollars']

# %%
tsdisplay(traina)
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\pmdarima\utils\visualization.py:220: FutureWarning: the 'unbiased'' keyword is deprecated, use 'adjusted' instead
#   res = tsaplots.plot_acf(

# %% [markdown]
# SARIMA Model with Seasonality of 4

# %%
import pmdarima as pmd
model_s4 = pmd.auto_arima(train['xare_dollars'], m=4, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[4] intercept   : AIC=1485.388, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[4] intercept   : AIC=1482.401, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[4] intercept   : AIC=1480.834, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,1)[4] intercept   : AIC=1481.692, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[4]             : AIC=1572.232, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[4] intercept   : AIC=1479.054, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,1)[4] intercept   : AIC=1480.737, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,1)[4] intercept   : AIC=1482.737, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[4] intercept   : AIC=1481.057, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,0)[4] intercept   : AIC=1481.150, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[4] intercept   : AIC=1479.878, Time=0.01 sec
#  ARIMA(2,0,1)(0,0,0)[4] intercept   : AIC=1482.814, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[4]             : AIC=1504.436, Time=0.01 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[4] intercept
# ...

# %%
model_s4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   77
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                -736.527
# Date:                Tue, 15 Mar 2022   AIC                           1479.054
# Time:                        18:48:48   BIC                           1486.085
# Sample:                             0   HQIC                          1481.866
#                                  - 77
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   4025.7205    832.356      4.837      0.000    2394.332    5657.109
# ar.L1          0.2556      0.099      2.589      0.010       0.062       0.449
# sigma2      1.201e+07      0.158   7.62e+07      0.000     1.2e+07     1.2e+07
# ...

# %%
preds_sar4 = model_s4.predict(test.shape[0])
preds_sar4
# Out:
# array([5153.02185734, 5342.70216071, 5391.17963548, 5403.56924851,
#        5406.73571938, 5407.54498902, 5407.75181781, 5407.80467801,
#        5407.81818773, 5407.82164048, 5407.82252291, 5407.82274844])

# %%
df_preds['sarima4_auto'] = preds_sar4
df_preds['sarima4_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    5153.021857
# 2020-02-29    5342.702161
# Freq: M, Name: sarima4_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['xare_dollars'], label='Train')
plt.plot(test['xare_dollars'], label='Test')
plt.plot(df_preds['sarima4_auto'], label='SARIMA_4_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 4 Model for Xarelto Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['sarima4_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 4 Model: 4061.6062671501427
# RMSE for SARIMA with Seasonality of 4 Model: 4126.27950463045

# %% [markdown]
# SARIMA Model with Seasonality of 6

# %%
model_s6 = pmd.auto_arima(train['xare_dollars'], m=6, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[6] intercept   : AIC=1482.337, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[6] intercept   : AIC=1482.401, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[6] intercept   : AIC=1480.483, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,1)[6] intercept   : AIC=1481.265, Time=0.02 sec
#  ARIMA(0,0,0)(0,0,0)[6]             : AIC=1572.232, Time=0.00 sec
#  ARIMA(1,0,0)(0,0,0)[6] intercept   : AIC=1479.054, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,1)[6] intercept   : AIC=1480.551, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,1)[6] intercept   : AIC=1482.447, Time=0.08 sec
#  ARIMA(2,0,0)(0,0,0)[6] intercept   : AIC=1481.057, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[6] intercept   : AIC=1481.150, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[6] intercept   : AIC=1479.878, Time=0.01 sec
#  ARIMA(2,0,1)(0,0,0)[6] intercept   : AIC=1482.814, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[6]             : AIC=1504.436, Time=0.01 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[6] intercept
# ...

# %%
model_s6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   77
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                -736.527
# Date:                Tue, 15 Mar 2022   AIC                           1479.054
# Time:                        18:48:49   BIC                           1486.085
# Sample:                             0   HQIC                          1481.866
#                                  - 77
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   4025.7205    832.356      4.837      0.000    2394.332    5657.109
# ar.L1          0.2556      0.099      2.589      0.010       0.062       0.449
# sigma2      1.201e+07      0.158   7.62e+07      0.000     1.2e+07     1.2e+07
# ...

# %%
preds_sar6 = model_s6.predict(test.shape[0])
preds_sar6
# Out:
# array([5153.02185734, 5342.70216071, 5391.17963548, 5403.56924851,
#        5406.73571938, 5407.54498902, 5407.75181781, 5407.80467801,
#        5407.81818773, 5407.82164048, 5407.82252291, 5407.82274844])

# %%
df_preds['sarima6_auto'] = preds_sar6
df_preds['sarima6_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    5153.021857
# 2020-02-29    5342.702161
# Freq: M, Name: sarima6_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['xare_dollars'], label='Train')
plt.plot(test['xare_dollars'], label='Test')
plt.plot(df_preds['sarima6_auto'], label='SARIMA_6_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 6 Model for Xarelto Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['sarima6_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 6 Model: 4061.6062671501427
# RMSE for SARIMA with Seasonality of 6 Model: 4126.27950463045

# %% [markdown]
# Try a SARIMA Model with m = 12

# %%
model_s12 = pmd.auto_arima(train['xare_dollars'], m=12, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=1482.369, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=1482.401, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=1479.616, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=1479.271, Time=0.03 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=1572.232, Time=0.00 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=1479.878, Time=0.01 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=1481.263, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=1481.139, Time=0.10 sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : AIC=1480.680, Time=0.03 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=1483.092, Time=0.16 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : AIC=1482.217, Time=0.02 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=1480.517, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,1)[12] intercept   : AIC=1479.063, Time=0.04 sec
# ...

# %%
model_s12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                                    y   No. Observations:                   77
# Model:             SARIMAX(0, 0, 2)x(0, 0, [1], 12)   Log Likelihood                -734.531
# Date:                              Tue, 15 Mar 2022   AIC                           1479.063
# Time:                                      18:48:51   BIC                           1490.782
# Sample:                                           0   HQIC                          1483.750
#                                                - 77
# Covariance Type:                                opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   5116.7455    964.402      5.306      0.000    3226.553    7006.938
# ...

# %%
preds_sar12 = model_s12.predict(test.shape[0])
preds_sar12
# Out:
# array([3926.4392857 , 4665.86706515, 4904.7059152 , 5137.90291705,
#        5485.12548255, 5292.74952417, 5409.70648157, 5080.83008865,
#        4499.61520969, 5148.7775213 , 4582.58441823, 4983.58132887])

# %%
df_preds['sarima12_auto'] = preds_sar12
df_preds['sarima12_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    3926.439286
# 2020-02-29    4665.867065
# Freq: M, Name: sarima12_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['xare_dollars'], label='Train')
plt.plot(test['xare_dollars'], label='Test')
plt.plot(df_preds['sarima12_auto'], label='SARIMA_12_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 12 Model for Xarelto Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['sarima12_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 12 Model: 3608.797103176096
# RMSE for SARIMA with Seasonality of 12 Model: 3736.6303462036753

# %% [markdown]
# Try a SARIMA Model with m = 18

# %%
model_s18 = pmd.auto_arima(train['xare_dollars'], m=18, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[18] intercept   : AIC=1482.152, Time=0.66 sec
#  ARIMA(0,0,0)(0,0,0)[18] intercept   : AIC=1482.401, Time=0.01 sec
#  ARIMA(1,0,0)(1,0,0)[18] intercept   : AIC=1480.921, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,1)[18] intercept   : AIC=1481.705, Time=0.07 sec
#  ARIMA(0,0,0)(0,0,0)[18]             : AIC=1572.232, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[18] intercept   : AIC=1479.054, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,1)[18] intercept   : AIC=1480.833, Time=0.07 sec
#  ARIMA(1,0,0)(1,0,1)[18] intercept   : AIC=1482.829, Time=0.13 sec
#  ARIMA(2,0,0)(0,0,0)[18] intercept   : AIC=1481.057, Time=0.01 sec
#  ARIMA(1,0,1)(0,0,0)[18] intercept   : AIC=1481.150, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[18] intercept   : AIC=1479.878, Time=0.01 sec
#  ARIMA(2,0,1)(0,0,0)[18] intercept   : AIC=1482.814, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[18]             : AIC=1504.436, Time=0.01 sec
#
# Best model:  ARIMA(1,0,0)(0,0,0)[18] intercept
# ...

# %%
model_s18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   77
# Model:               SARIMAX(1, 0, 0)   Log Likelihood                -736.527
# Date:                Tue, 15 Mar 2022   AIC                           1479.054
# Time:                        18:48:53   BIC                           1486.085
# Sample:                             0   HQIC                          1481.866
#                                  - 77
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   4025.7205    832.356      4.837      0.000    2394.332    5657.109
# ar.L1          0.2556      0.099      2.589      0.010       0.062       0.449
# sigma2      1.201e+07      0.158   7.62e+07      0.000     1.2e+07     1.2e+07
# ...

# %%
preds_sar18 = model_s18.predict(test.shape[0])
preds_sar18
# Out:
# array([5153.02185734, 5342.70216071, 5391.17963548, 5403.56924851,
#        5406.73571938, 5407.54498902, 5407.75181781, 5407.80467801,
#        5407.81818773, 5407.82164048, 5407.82252291, 5407.82274844])

# %%
df_preds['sarima18_auto'] = preds_sar18
df_preds['sarima18_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    5153.021857
# 2020-02-29    5342.702161
# Freq: M, Name: sarima18_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['xare_dollars'], label='Train')
plt.plot(test['xare_dollars'], label='Test')
plt.plot(df_preds['sarima18_auto'], label='SARIMA_18_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 18 Model for Xarelto Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 18 Model: 4061.6062671501427
# RMSE for SARIMA with Seasonality of 18 Model: 4126.27950463045

# %%
print("Summary of Metrics for Monthly Xarelto CMS Payments")
print("_________________________________________________")
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['simple_mean'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['seasonal_4'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['seasonal_6'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['seasonal_12'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['seasonal_18'], squared=False))
print("_________________________________________________")
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['ses'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_m4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_m6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_m12'], squared=False))
print("_________________________________________________")
# Out:
# Summary of Metrics for Monthly Xarelto CMS Payments
# _________________________________________________
# MAE for Simple Mean Baseline Model: 4095.421991341993
# RMSE for Simple Mean Baseline Model: 4156.020026237823
# _________________________________________________
# MAE for Seasonal Baseline 4 Shift Model: 1516.8783333333333
# RMSE for Seasonal Baseline 4 Shift Model: 1864.0386996697966
# _________________________________________________
# MAE for Seasonal Baseline 6 Shift Model: 2252.965
# RMSE for Seasonal Baseline 6 Shift Model: 2602.503060619398
# _________________________________________________
# MAE for Seasonal Baseline 12 Shift Model: 2941.31
# RMSE for Seasonal Baseline 12 Shift Model: 3656.8862307866057
# _________________________________________________
# MAE for Seasonal Baseline 18 Shift Model: 2921.1041666666665
# RMSE for Seasonal Baseline 18 Shift Model: 3562.854243078855
# _________________________________________________
# ...

# %%
print("Continued Summary of Metrics for Monthly Xarelto CMS Payments")
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_m18'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_a4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_a6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_a12'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['hw_a18'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['sarima4_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['sarima6_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['sarima12_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['xare_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['xare_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# Continued Summary of Metrics for Monthly Xarelto CMS Payments
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 3654.3563662574015
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 4381.069017547752
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 2265.465536710269
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 2382.0740358518788
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 2155.040942321174
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 2709.4376688741827
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 1852.8090903182567
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 2663.7370300325324
# _________________________________________________
# ...

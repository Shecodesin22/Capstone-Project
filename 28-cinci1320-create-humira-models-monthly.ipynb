# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cinci_1320 = pd.read_csv('./data/cinci1320.csv', index_col='Date_of_Payment', parse_dates=True).sort_index()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,18,19,47,48,49,50,51,52,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_1320.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     148974               RODNEY
# 2013-08-01                      58931                 PAUL
# 2013-08-01                     812462               ALFRED
# 2013-08-01                     108863                 MARK
# 2013-08-01                     195441           MANOJKUMAR
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                        NaN              VIVIAN
# 2013-08-01                     JOSEPH            FAVORITO
# ...

# %%
cinci_1320['Change_Type'].value_counts()
# Out:
# UNCHANGED    364686
# CHANGED         726
# ADD               1
# Name: Change_Type, dtype: int64

# %%
cinci_1320['humira'].value_counts()
# Out:
# 0    359188
# 1      6225
# Name: humira, dtype: int64

# %%
humira = cinci_1320[(cinci_1320['humira']==1) & (cinci_1320['Number_of_Payments_Included_in_Total_Amount']==1)].copy()

# %%
humira.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     126284             JENNIFER
# 2013-08-01                     228696              MICHAEL
# 2013-08-01                     522396               JORDAN
# 2013-08-01                     254592               ALEXEI
# 2013-08-01                     255498                LOUIS
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                       LYNN             HUGGINS
# 2013-08-01                        NaN          HENRICKSON
# ...

# %%
humira['humira'].value_counts()
# Out:
# 1    6225
# Name: humira, dtype: int64

# %%
humira['Change_Type'].value_counts()
# Out:
# UNCHANGED    6225
# Name: Change_Type, dtype: int64

# %%
humira['humi_dollars'] = [k if ((i ==1) & (j ==1)) else 0 for i, j, k in zip(humira['humira'], humira['Number_of_Payments_Included_in_Total_Amount'], humira['Total_Amount_of_Payment_USDollars'])]

#Ben Peck helped me with this during office hours.  I was oh-so-close but not quite there!

# %%
humira['humi_dollars'].sum()
# Out:
# 1022517.3

# %%
humira.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     126284             JENNIFER
# 2013-08-01                     228696              MICHAEL
# 2013-08-01                     522396               JORDAN
# 2013-08-01                     254592               ALEXEI
# 2013-08-01                     255498                LOUIS
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                       LYNN             HUGGINS
# 2013-08-01                        NaN          HENRICKSON
# ...

# %%
drop_cols = ['Change_Type','Covered_Recipient_Type',
'Physician_First_Name',
'Physician_Middle_Name',
'Physician_Last_Name',
'Physician_Name_Suffix',
'Recipient_Primary_Business_Street_Address_Line1',
'Recipient_Primary_Business_Street_Address_Line2',
'Recipient_City',
'Recipient_State',
'Recipient_Zip_Code',
'Recipient_Country',
'Physician_Primary_Type',
'Physician_Specialty',
'Physician_License_State_code1',
'Physician_License_State_code2',
'Physician_License_State_code3',
'Physician_License_State_code4',
'Physician_License_State_code5',
'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
'Form_of_Payment_or_Transfer_of_Value',
'City_of_Travel',
'State_of_Travel',
'Country_of_Travel',
'Physician_Ownership_Indicator',
'Third_Party_Payment_Recipient_Indicator',
'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
'Charity_Indicator',
'Third_Party_Equals_Covered_Recipient_Indicator',
'Contextual_Information',
'Delay_in_Publication_Indicator',
'Dispute_Status_for_Publication',
'Related_Product_Indicator',
'Covered_or_Noncovered_Indicator_1',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Product_Category_or_Therapeutic_Area_1',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Associated_Drug_or_Biological_NDC_1',
'Covered_or_Noncovered_Indicator_2',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Product_Category_or_Therapeutic_Area_2',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Associated_Drug_or_Biological_NDC_2',
'Covered_or_Noncovered_Indicator_3',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Product_Category_or_Therapeutic_Area_3',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Associated_Drug_or_Biological_NDC_3',
'Covered_or_Noncovered_Indicator_4',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Product_Category_or_Therapeutic_Area_4',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Associated_Drug_or_Biological_NDC_4',
'Covered_or_Noncovered_Indicator_5',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Product_Category_or_Therapeutic_Area_5',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Associated_Drug_or_Biological_NDC_5', 
'Physician_Profile_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
'Total_Amount_of_Payment_USDollars','Number_of_Payments_Included_in_Total_Amount', 
'Nature_of_Payment_or_Transfer_of_Value', 'Record_ID', 
'Payment_Publication_Date', 'Program_Year',
'NDC_of_Associated_Covered_Drug_or_Biological1',
'NDC_of_Associated_Covered_Drug_or_Biological2',
'NDC_of_Associated_Covered_Drug_or_Biological3',
'NDC_of_Associated_Covered_Drug_or_Biological4',
'NDC_of_Associated_Covered_Drug_or_Biological5',
'Name_of_Associated_Covered_Device_or_Medical_Supply1',
'Name_of_Associated_Covered_Device_or_Medical_Supply2',
'Name_of_Associated_Covered_Device_or_Medical_Supply3',
'Name_of_Associated_Covered_Device_or_Medical_Supply4',
'Name_of_Associated_Covered_Device_or_Medical_Supply5',
'xarelto', 'farxiga', 'victoza', 'invokana', 'levemir',
'entresto', 'chantix', 'myrbetriq', 'toujeo']

# %%
humira.drop(columns = drop_cols, inplace = True)

# %%
humira.head()
# Out:
#                  humira  humi_dollars
# Date_of_Payment
# 2013-08-01            1         23.64
# 2013-08-01            1         23.63
# 2013-08-01            1         23.63
# 2013-08-01            1         23.63
# 2013-08-01            1         11.49

# %% [markdown]
# Was reminded of the importance of checking data for outliers by this article, and modeled my filtering code below on this article:
# https://www.analyticsvidhya.com/blog/2021/08/holt-winters-method-for-time-series-analysis/

# %%
sns.boxplot(x = humira['humi_dollars']);

# %%
humira['z_score'] = [ ((i - humira['humi_dollars'].mean())/humira['humi_dollars'].std()) for i in humira['humi_dollars']]

# %%
humira.shape
# Out:
# (6225, 3)

# %% [markdown]
# Add chart to see data before dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(humira.index, humira['humi_dollars'], label='Before Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Humira Drug - Before Outliers Dropped");

# %%
humirab = humira[(np.abs(humira['z_score']) < 3)].copy()

# %%
humirab.shape
# Out:
# (6021, 3)

# %% [markdown]
# Add chart to see data after dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(humirab.index, humirab['humi_dollars'], label='After Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Humira Drug - After Outliers Dropped");

# %% [markdown]
# Drop Z-score before aggregating

# %%
humirab.drop(columns='z_score', inplace=True)

# %%
humira_monthly = humirab.resample('m').sum()

# %%
humira_monthly.head()
# Out:
#                  humira  humi_dollars
# Date_of_Payment
# 2013-08-31           49       2532.69
# 2013-09-30           31        782.84
# 2013-10-31           48       4319.05
# 2013-11-30           54       4321.67
# 2013-12-31           56       5231.32

# %%
humira_monthly.sort_index()
# Out:
#                  humira  humi_dollars
# Date_of_Payment
# 2013-08-31           49       2532.69
# 2013-09-30           31        782.84
# 2013-10-31           48       4319.05
# 2013-11-30           54       4321.67
# 2013-12-31           56       5231.32
# ...                 ...           ...
# 2020-08-31           33        615.31
# 2020-09-30           23        393.76
# 2020-10-31           25       3108.62
# 2020-11-30           44       4363.23
# 2020-12-31           19       1656.99
#
# [89 rows x 2 columns]

# %% [markdown]
# Look at some plots

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf

# %%
plot_acf(humira_monthly['humi_dollars'], alpha=None, lags=24);

# %%
plot_pacf(humira_monthly['humi_dollars'], alpha=None, lags=24);
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# Adding 1 to the weekly sales for each observation so that Holt_winters will work.

# %%
humira_monthly['humi_dollars'] = [i+1 for i in humira_monthly['humi_dollars']]

# %% [markdown]
# Set up Train and Test Sets using 2013 - 2020 Data

# %%
train = humira_monthly.loc[:'2019-12-31']
train
# Out:
#                  humira  humi_dollars
# Date_of_Payment
# 2013-08-31           49       2533.69
# 2013-09-30           31        783.84
# 2013-10-31           48       4320.05
# 2013-11-30           54       4322.67
# 2013-12-31           56       5232.32
# ...                 ...           ...
# 2019-08-31           94       2720.10
# 2019-09-30           46       2863.27
# 2019-10-31           57        899.63
# 2019-11-30           37        809.55
# 2019-12-31           38        466.19
#
# [77 rows x 2 columns]

# %%
train['humi_dollars'].max()
# Out:
# 15312.56

# %%
train.describe()
# Out:
#            humira  humi_dollars
# count   77.000000     77.000000
# mean    74.324675   4281.552597
# std     21.573889   3032.476380
# min     31.000000    466.190000
# 25%     56.000000   2103.700000
# 50%     75.000000   3758.990000
# 75%     88.000000   5806.140000
# max    132.000000  15312.560000

# %%
train.index.freq = 'M'

# %%
train.shape
# Out:
# (77, 2)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 77 entries, 2013-08-31 to 2019-12-31
# Freq: M
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   humira        77 non-null     int64
#  1   humi_dollars  77 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.8 KB

# %%
train.index
# Out:
# DatetimeIndex(['2013-08-31', '2013-09-30', '2013-10-31', '2013-11-30',
#                '2013-12-31', '2014-01-31', '2014-02-28', '2014-03-31',
#                '2014-04-30', '2014-05-31', '2014-06-30', '2014-07-31',
#                '2014-08-31', '2014-09-30', '2014-10-31', '2014-11-30',
#                '2014-12-31', '2015-01-31', '2015-02-28', '2015-03-31',
#                '2015-04-30', '2015-05-31', '2015-06-30', '2015-07-31',
#                '2015-08-31', '2015-09-30', '2015-10-31', '2015-11-30',
#                '2015-12-31', '2016-01-31', '2016-02-29', '2016-03-31',
#                '2016-04-30', '2016-05-31', '2016-06-30', '2016-07-31',
#                '2016-08-31', '2016-09-30', '2016-10-31', '2016-11-30',
#                '2016-12-31', '2017-01-31', '2017-02-28', '2017-03-31',
#                '2017-04-30', '2017-05-31', '2017-06-30', '2017-07-31',
#                '2017-08-31', '2017-09-30', '2017-10-31', '2017-11-30',
# ...

# %%
test = humira_monthly.loc['2020-01-01':]
test
# Out:
#                  humira  humi_dollars
# Date_of_Payment
# 2020-01-31           33        581.60
# 2020-02-29           53        661.20
# 2020-03-31           22        229.02
# 2020-04-30            6        739.61
# 2020-05-31            6        113.66
# 2020-06-30           17        184.67
# 2020-07-31           17        259.14
# 2020-08-31           33        616.31
# 2020-09-30           23        394.76
# 2020-10-31           25       3109.62
# 2020-11-30           44       4364.23
# 2020-12-31           19       1657.99

# %%
test.describe()
# Out:
#           humira  humi_dollars
# count  12.000000     12.000000
# mean   24.833333   1075.984167
# std    14.050774   1334.746605
# min     6.000000    113.660000
# 25%    17.000000    251.610000
# 50%    22.500000    598.955000
# 75%    33.000000    969.205000
# max    53.000000   4364.230000

# %%
test.shape
# Out:
# (12, 2)

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')

plt.legend(loc='best')
plt.title("Monthly Payments for Humira Drug");

# %% [markdown]
# Baseline - Simple Mean (Naive Model)

# %%
df_preds = test.copy(deep=True)
df_preds
# Out:
#                  humira  humi_dollars
# Date_of_Payment
# 2020-01-31           33        581.60
# 2020-02-29           53        661.20
# 2020-03-31           22        229.02
# 2020-04-30            6        739.61
# 2020-05-31            6        113.66
# 2020-06-30           17        184.67
# 2020-07-31           17        259.14
# 2020-08-31           33        616.31
# 2020-09-30           23        394.76
# 2020-10-31           25       3109.62
# 2020-11-30           44       4364.23
# 2020-12-31           19       1657.99

# %%
df_preds['simple_mean'] = train['humi_dollars'].mean()
df_preds
# Out:
#                  humira  humi_dollars  simple_mean
# Date_of_Payment
# 2020-01-31           33        581.60  4281.552597
# 2020-02-29           53        661.20  4281.552597
# 2020-03-31           22        229.02  4281.552597
# 2020-04-30            6        739.61  4281.552597
# 2020-05-31            6        113.66  4281.552597
# 2020-06-30           17        184.67  4281.552597
# 2020-07-31           17        259.14  4281.552597
# 2020-08-31           33        616.31  4281.552597
# 2020-09-30           23        394.76  4281.552597
# 2020-10-31           25       3109.62  4281.552597
# 2020-11-30           44       4364.23  4281.552597
# 2020-12-31           19       1657.99  4281.552597

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['simple_mean'], label="Baseline (Mean)")

plt.legend(loc='best')
plt.title("Baseline (Mean) Forecast for Monthly Humira Payments");

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['simple_mean'], squared=False))
# Out:
# MAE for Simple Mean Baseline Model: 3219.347997835497
# RMSE for Simple Mean Baseline Model: 3450.9064154009043

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 4

# %%
df_preds['seasonal_4'] = train['humi_dollars'].shift(4, freq='M') 
df_preds.head(2)
# Out:
#                  humira  humi_dollars  simple_mean  seasonal_4
# Date_of_Payment
# 2020-01-31           33         581.6  4281.552597     2863.27
# 2020-02-29           53         661.2  4281.552597      899.63

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_4'], label='Seasonal 4')

plt.legend(loc='best')
plt.title("Seasonal 4 Forecast for Monthly Humira Payments");

# %%
df_preds['seasonal_4'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_4'], squared=False))
# Out:
# MAE for Seasonal Baseline 4 Shift Model: 1172.8691666666666
# RMSE for Seasonal Baseline 4 Shift Model: 1774.5811695134337

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 6

# %%
df_preds['seasonal_6'] = train['humi_dollars'].shift(6, freq='M') 
df_preds.head(2)
# Out:
#                  humira  humi_dollars  simple_mean  seasonal_4  seasonal_6
# Date_of_Payment
# 2020-01-31           33         581.6  4281.552597     2863.27     1202.17
# 2020-02-29           53         661.2  4281.552597      899.63     2720.10

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_6'], label='Seasonal 6')

plt.legend(loc='best')
plt.title("Seasonal 6 Forecast for Monthly Humira Payments");

# %%
df_preds['seasonal_6'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_6'], squared=False))
# Out:
# MAE for Seasonal Baseline 6 Shift Model: 1404.4333333333334
# RMSE for Seasonal Baseline 6 Shift Model: 1919.6477561217662

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 12

# %%
df_preds['seasonal_12'] = train['humi_dollars'].shift(12, freq='M') 
df_preds.head(2)
# Out:
#                  humira  humi_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           33         581.6  4281.552597     2863.27     1202.17
# 2020-02-29           53         661.2  4281.552597      899.63     2720.10
#
#                  seasonal_12
# Date_of_Payment
# 2020-01-31            713.78
# 2020-02-29           3854.05

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_12'], label='Seasonal 12')

plt.legend(loc='best')
plt.title("Seasonal 12 Forecast for Monthly Humira Payments");

# %%
df_preds['seasonal_12'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_12'], squared=False))
# Out:
# MAE for Seasonal Baseline 12 Shift Model: 2583.29
# RMSE for Seasonal Baseline 12 Shift Model: 3038.1782451879503

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 18

# %%
df_preds['seasonal_18'] = train['humi_dollars'].shift(18, freq='M') 
df_preds.head(2)
# Out:
#                  humira  humi_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           33         581.6  4281.552597     2863.27     1202.17
# 2020-02-29           53         661.2  4281.552597      899.63     2720.10
#
#                  seasonal_12  seasonal_18
# Date_of_Payment
# 2020-01-31            713.78      2068.82
# 2020-02-29           3854.05      2426.13

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_18'], label='Seasonal 18')

plt.legend(loc='best')
plt.title("Seasonal 18 Forecast for Monthly Humira Payments");

# %%
df_preds['seasonal_18'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_18'], squared=False))
# Out:
# MAE for Seasonal Baseline 18 Shift Model: 2797.7208333333333
# RMSE for Seasonal Baseline 18 Shift Model: 3443.6979092575757

# %% [markdown]
# Simple Exponential Smoothing Model

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing

# %%
ses = SimpleExpSmoothing(train['humi_dollars']).fit(smoothing_level=.5)

# %%
ses.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ...
# Dep. Variable:           humi_dollars   No. Observations:                   77
# Model:             SimpleExpSmoothing   SSE                      817244373.039
# Optimized:                       True   AIC                           1249.679
# Trend:                           None   BIC                           1254.366
# Seasonal:                        None   AICC                          1250.234
# Seasonal Periods:                None   Date:                 Tue, 15 Mar 2022
# Box-Cox:                        False   Time:                         19:03:38
# Box-Cox Coeff.:                  None
# ...
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.5000000                alpha                False
# ...

# %%
ses_forecast = ses.forecast(len(test))

# %%
df_preds['ses'] = ses_forecast

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['ses'], label='Simple Exponential Smoothing')

plt.legend(loc='best')
plt.title("Simple Exponential Smoothing for Humira Monthly Payments");

# %%
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['ses'], squared=False))
# Out:
# MAE for Simple Exponential Smoothing Model: 895.244743805718
# RMSE for Simple Exponential Smoothing Model: 1290.1871158287763

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 4.

# %%
hw_a4 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=4, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             humi_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      722485479.360
# Optimized:                         True   AIC                           1252.189
# Trend:                         Additive   BIC                           1270.939
# Seasonal:                      Additive   AICC                          1255.522
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:03:39
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1110714                alpha                 True
# ...

# %%
df_preds['hw_a4'] = hw_a4.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           33         581.6  4281.552597     2863.27     1202.17
# 2020-02-29           53         661.2  4281.552597      899.63     2720.10
#
#                  seasonal_12  seasonal_18         ses        hw_a4
# Date_of_Payment
# 2020-01-31            713.78      2068.82  898.511154  1878.176216
# 2020-02-29           3854.05      2426.13  898.511154  2936.403906

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a4'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 4 for Monthly Payments for Humira");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a4'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 1419.0289975648857
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 1626.4227213174925

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 6.

# %%
hw_a6 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=6, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             humi_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      637158748.597
# Optimized:                         True   AIC                           1246.512
# Trend:                         Additive   BIC                           1269.950
# Seasonal:                      Additive   AICC                          1251.387
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:03:39
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1119604                alpha                 True
# ...

# %%
df_preds['hw_a6'] = hw_a6.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           33         581.6  4281.552597     2863.27     1202.17
# 2020-02-29           53         661.2  4281.552597      899.63     2720.10
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            713.78      2068.82  898.511154  1878.176216
# 2020-02-29           3854.05      2426.13  898.511154  2936.403906
#
#                        hw_a6
# Date_of_Payment
# 2020-01-31        790.349031
# 2020-02-29       1580.536782

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a6'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 6 for Monthly Payments for Humira");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a6'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 1061.4771517185857
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 1452.4085495367503

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 12.

# %%
hw_a12 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=12, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             humi_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      574730955.521
# Optimized:                         True   AIC                           1250.572
# Trend:                         Additive   BIC                           1288.073
# Seasonal:                      Additive   AICC                          1262.365
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:03:40
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1464286                alpha                 True
# ...

# %%
df_preds['hw_a12'] = hw_a12.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           33         581.6  4281.552597     2863.27     1202.17
# 2020-02-29           53         661.2  4281.552597      899.63     2720.10
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            713.78      2068.82  898.511154  1878.176216
# 2020-02-29           3854.05      2426.13  898.511154  2936.403906
#
#                        hw_a6       hw_a12
# Date_of_Payment
# 2020-01-31        790.349031  2070.948038
# 2020-02-29       1580.536782  2487.361196

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a12'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 12 for Monthly Payments for Humira");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a12'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 1581.250008955819
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 1720.2274652576289

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 18.

# %%
hw_a18 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=18, 
    trend='add',
    seasonal='add'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_a18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             humi_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      548807951.187
# Optimized:                         True   AIC                           1259.018
# Trend:                         Additive   BIC                           1310.582
# Seasonal:                      Additive   AICC                          1282.095
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:03:40
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1464286                alpha                 True
# ...

# %%
df_preds['hw_a18'] = hw_a18.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           33         581.6  4281.552597     2863.27     1202.17
# 2020-02-29           53         661.2  4281.552597      899.63     2720.10
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            713.78      2068.82  898.511154  1878.176216
# 2020-02-29           3854.05      2426.13  898.511154  2936.403906
#
#                        hw_a6       hw_a12       hw_a18
# Date_of_Payment
# 2020-01-31        790.349031  2070.948038     6.278828
# 2020-02-29       1580.536782  2487.361196  1924.897556

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a18'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 18 for Monthly Payments for Humira");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a18'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 18 Model: 2117.5042684801006
# RMSE for Holt-Winters Additive with Seasonality of 18 Model: 2523.9640961623095

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 4.

# %%
hw_m4 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=4, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             humi_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      755101129.340
# Optimized:                         True   AIC                           1255.589
# Trend:                   Multiplicative   BIC                           1274.339
# Seasonal:                Multiplicative   AICC                          1258.922
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:03:41
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1817857                alpha                 True
# ...

# %%
df_preds['hw_m4'] = hw_m4.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           33         581.6  4281.552597     2863.27     1202.17
# 2020-02-29           53         661.2  4281.552597      899.63     2720.10
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            713.78      2068.82  898.511154  1878.176216
# 2020-02-29           3854.05      2426.13  898.511154  2936.403906
#
#                        hw_a6       hw_a12       hw_a18        hw_m4
# Date_of_Payment
# 2020-01-31        790.349031  2070.948038     6.278828  1944.876278
# 2020-02-29       1580.536782  2487.361196  1924.897556  2476.648464

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m4'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 4 Model for Humira Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m4'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 4 Model: 1422.2605967539978
# RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model: 1557.7891977003412

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 6.

# %%
hw_m6 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=6, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             humi_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      656474646.885
# Optimized:                         True   AIC                           1248.811
# Trend:                   Multiplicative   BIC                           1272.249
# Seasonal:                Multiplicative   AICC                          1253.686
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:03:41
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1817857                alpha                 True
# ...

# %%
df_preds['hw_m6'] = hw_m6.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           33         581.6  4281.552597     2863.27     1202.17
# 2020-02-29           53         661.2  4281.552597      899.63     2720.10
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            713.78      2068.82  898.511154  1878.176216
# 2020-02-29           3854.05      2426.13  898.511154  2936.403906
#
#                        hw_a6       hw_a12       hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31        790.349031  2070.948038     6.278828  1944.876278
# 2020-02-29       1580.536782  2487.361196  1924.897556  2476.648464
#
#                        hw_m6
# Date_of_Payment
# 2020-01-31       1835.401498
# 2020-02-29       2623.464272

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m6'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 6 Model for Humira Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m6'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 6 Model: 1717.9618656395905
# RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model: 1886.9684948352806

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 12.

# %%
hw_m12 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=12, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             humi_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      656279125.219
# Optimized:                         True   AIC                           1260.788
# Trend:                   Multiplicative   BIC                           1298.289
# Seasonal:                Multiplicative   AICC                          1272.582
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:03:42
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1817857                alpha                 True
# ...

# %%
df_preds['hw_m12'] = hw_m12.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           33         581.6  4281.552597     2863.27     1202.17
# 2020-02-29           53         661.2  4281.552597      899.63     2720.10
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            713.78      2068.82  898.511154  1878.176216
# 2020-02-29           3854.05      2426.13  898.511154  2936.403906
#
#                        hw_a6       hw_a12       hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31        790.349031  2070.948038     6.278828  1944.876278
# 2020-02-29       1580.536782  2487.361196  1924.897556  2476.648464
#
#                        hw_m6       hw_m12
# Date_of_Payment
# 2020-01-31       1835.401498  2144.345724
# 2020-02-29       2623.464272  2639.307452

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m12'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 12 Model for Humira Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m12'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 12 Model: 1387.4204267611722
# RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model: 1551.9246223352104

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 18.

# %%
hw_m18 = ExponentialSmoothing(
    train['humi_dollars'],
    seasonal_periods=18, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             humi_dollars   No. Observations:                   77
# Model:             ExponentialSmoothing   SSE                      635531288.598
# Optimized:                         True   AIC                           1270.315
# Trend:                   Multiplicative   BIC                           1321.879
# Seasonal:                Multiplicative   AICC                          1293.392
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:03:43
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1110714                alpha                 True
# ...

# %%
df_preds['hw_m18'] = hw_m18.forecast(len(test))
df_preds.head(2)
# Out:
#                  humira  humi_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31           33         581.6  4281.552597     2863.27     1202.17
# 2020-02-29           53         661.2  4281.552597      899.63     2720.10
#
#                  seasonal_12  seasonal_18         ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            713.78      2068.82  898.511154  1878.176216
# 2020-02-29           3854.05      2426.13  898.511154  2936.403906
#
#                        hw_a6       hw_a12       hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31        790.349031  2070.948038     6.278828  1944.876278
# 2020-02-29       1580.536782  2487.361196  1924.897556  2476.648464
#
#                        hw_m6       hw_m12       hw_m18
# Date_of_Payment
# 2020-01-31       1835.401498  2144.345724  2461.015370
# 2020-02-29       2623.464272  2639.307452  4017.472429

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['humi_dollars'], label='Train')
plt.plot(test.index, test['humi_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m18'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 18 Model for Humira Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m18'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 2306.8301908606627
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 2885.981629894456

# %% [markdown]
# Try a SARIMA Model

# %%
from pmdarima.utils import tsdisplay

# %%
traina = train['humi_dollars']

# %%
tsdisplay(traina)
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\pmdarima\utils\visualization.py:220: FutureWarning: the 'unbiased'' keyword is deprecated, use 'adjusted' instead
#   res = tsaplots.plot_acf(

# %% [markdown]
# SARIMA Model with Seasonality of 4

# %%
import pmdarima as pmd
model_s4 = pmd.auto_arima(train['humi_dollars'], m=4, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[4] intercept   : AIC=1445.999, Time=0.26 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=1483.152, Time=0.00 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=1454.000, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=1441.011, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=1481.162, Time=0.00 sec
#  ARIMA(0,1,1)(0,0,0)[4] intercept   : AIC=1439.599, Time=0.06 sec
#  ARIMA(0,1,1)(1,0,0)[4] intercept   : AIC=1439.517, Time=0.11 sec
#  ARIMA(0,1,1)(2,0,0)[4] intercept   : AIC=1441.378, Time=0.14 sec
#  ARIMA(0,1,1)(1,0,1)[4] intercept   : AIC=1441.292, Time=0.16 sec
#  ARIMA(0,1,1)(2,0,1)[4] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,1,0)(1,0,0)[4] intercept   : AIC=1482.873, Time=0.01 sec
#  ARIMA(1,1,1)(1,0,0)[4] intercept   : AIC=1441.743, Time=0.08 sec
#  ARIMA(0,1,2)(1,0,0)[4] intercept   : AIC=1440.910, Time=0.09 sec
#  ARIMA(1,1,2)(1,0,0)[4] intercept   : AIC=1442.161, Time=0.15 sec
# ...

# %%
model_s4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                                 y   No. Observations:                   77
# Model:             SARIMAX(0, 1, 1)x(0, 0, 1, 4)   Log Likelihood                -715.725
# Date:                           Tue, 15 Mar 2022   AIC                           1437.450
# Time:                                   19:03:46   BIC                           1444.442
# Sample:                                        0   HQIC                          1440.245
#                                             - 77
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8249      0.073    -11.246      0.000      -0.969      -0.681
# ma.S.L4       -0.1943      0.115     -1.694      0.090      -0.419       0.030
# ...

# %%
preds_sar4 = model_s4.predict(test.shape[0])
preds_sar4
# Out:
# array([2175.48620978, 2443.07454409, 2610.06375925, 2651.85822781,
#        2307.2833586 , 2307.2833586 , 2307.2833586 , 2307.2833586 ,
#        2307.2833586 , 2307.2833586 , 2307.2833586 , 2307.2833586 ])

# %%
df_preds['sarima4_auto'] = preds_sar4
df_preds['sarima4_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    2175.486210
# 2020-02-29    2443.074544
# Freq: M, Name: sarima4_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['humi_dollars'], label='Train')
plt.plot(test['humi_dollars'], label='Test')
plt.plot(df_preds['sarima4_auto'], label='SARIMA_4_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 4 Model for Humira Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['sarima4_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 4 Model: 1762.1255146123146
# RMSE for SARIMA with Seasonality of 4 Model: 1834.1089314633314

# %% [markdown]
# SARIMA Model with Seasonality of 6

# %%
model_s6 = pmd.auto_arima(train['humi_dollars'], m=6, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[6] intercept   : AIC=1446.382, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[6] intercept   : AIC=1483.152, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[6] intercept   : AIC=1455.076, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[6] intercept   : AIC=1438.797, Time=0.16 sec
#  ARIMA(0,1,0)(0,0,0)[6]             : AIC=1481.162, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[6] intercept   : AIC=1439.599, Time=0.06 sec
#  ARIMA(0,1,1)(1,0,1)[6] intercept   : AIC=1442.407, Time=0.09 sec
#  ARIMA(0,1,1)(0,0,2)[6] intercept   : AIC=1440.704, Time=0.23 sec
#  ARIMA(0,1,1)(1,0,0)[6] intercept   : AIC=1439.152, Time=0.12 sec
#  ARIMA(0,1,1)(1,0,2)[6] intercept   : AIC=inf, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,1)[6] intercept   : AIC=1484.180, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,1)[6] intercept   : AIC=1440.359, Time=0.17 sec
#  ARIMA(0,1,2)(0,0,1)[6] intercept   : AIC=1440.731, Time=0.10 sec
#  ARIMA(1,1,0)(0,0,1)[6] intercept   : AIC=1455.185, Time=0.03 sec
# ...

# %%
model_s6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                                 y   No. Observations:                   77
# Model:             SARIMAX(0, 1, 1)x(0, 0, 1, 6)   Log Likelihood                -715.477
# Date:                           Tue, 15 Mar 2022   AIC                           1436.954
# Time:                                   19:03:49   BIC                           1443.946
# Sample:                                        0   HQIC                          1439.748
#                                             - 77
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8830      0.057    -15.582      0.000      -0.994      -0.772
# ma.S.L6        0.2046      0.098      2.088      0.037       0.013       0.397
# ...

# %%
preds_sar6 = model_s6.predict(test.shape[0])
preds_sar6
# Out:
# array([2082.18272339, 2267.77429032, 2194.48625159, 2012.37004811,
#        1919.29132765, 1738.40721419, 2232.38646661, 2232.38646661,
#        2232.38646661, 2232.38646661, 2232.38646661, 2232.38646661])

# %%
df_preds['sarima6_auto'] = preds_sar6
df_preds['sarima6_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    2082.182723
# 2020-02-29    2267.774290
# Freq: M, Name: sarima6_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['humi_dollars'], label='Train')
plt.plot(test['humi_dollars'], label='Test')
plt.plot(df_preds['sarima6_auto'], label='SARIMA_6_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 6 Model for Humira Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['sarima6_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 6 Model: 1559.5978990381527
# RMSE for SARIMA with Seasonality of 6 Model: 1620.614894283641

# %% [markdown]
# Try a SARIMA Model with m = 12

# %%
model_s12 = pmd.auto_arima(train['humi_dollars'], m=12, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=1449.066, Time=0.42 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1483.152, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1458.875, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1441.440, Time=0.18 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1481.162, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=1439.599, Time=0.06 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=1441.385, Time=0.17 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=1443.964, Time=0.30 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=1441.291, Time=0.09 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=1441.445, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1456.898, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=1443.532, Time=0.13 sec
#  ARIMA(0,1,1)(0,0,0)[12]             : AIC=1437.742, Time=0.03 sec
# ...

# %%
model_s12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   77
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -716.871
# Date:                Tue, 15 Mar 2022   AIC                           1437.742
# Time:                        19:03:51   BIC                           1442.404
# Sample:                             0   HQIC                          1439.605
#                                  - 77
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8650      0.064    -13.441      0.000      -0.991      -0.739
# sigma2      9.016e+06   1.34e+06      6.739      0.000    6.39e+06    1.16e+07
# ...
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):                10.27
# ...

# %%
preds_sar12 = model_s12.predict(test.shape[0])
preds_sar12
# Out:
# array([2345.69163181, 2345.69163181, 2345.69163181, 2345.69163181,
#        2345.69163181, 2345.69163181, 2345.69163181, 2345.69163181,
#        2345.69163181, 2345.69163181, 2345.69163181, 2345.69163181])

# %%
df_preds['sarima12_auto'] = preds_sar12
df_preds['sarima12_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    2345.691632
# 2020-02-29    2345.691632
# Freq: M, Name: sarima12_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['humi_dollars'], label='Train')
plt.plot(test['humi_dollars'], label='Test')
plt.plot(df_preds['sarima12_auto'], label='SARIMA_12_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 12 Model for Humira Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['sarima12_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 12 Model: 1733.4519212075286
# RMSE for SARIMA with Seasonality of 12 Model: 1801.455847576703

# %% [markdown]
# Try a SARIMA Model with m = 18

# %%
model_s18 = pmd.auto_arima(train['humi_dollars'], m=18, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[18] intercept   : AIC=inf, Time=1.18 sec
#  ARIMA(0,1,0)(0,0,0)[18] intercept   : AIC=1483.152, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[18] intercept   : AIC=1458.893, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,1)[18] intercept   : AIC=1441.587, Time=0.42 sec
#  ARIMA(0,1,0)(0,0,0)[18]             : AIC=1481.162, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[18] intercept   : AIC=1439.599, Time=0.06 sec
#  ARIMA(0,1,1)(1,0,0)[18] intercept   : AIC=1442.853, Time=0.29 sec
#  ARIMA(0,1,1)(1,0,1)[18] intercept   : AIC=inf, Time=0.71 sec
#  ARIMA(1,1,1)(0,0,0)[18] intercept   : AIC=1441.291, Time=0.09 sec
#  ARIMA(0,1,2)(0,0,0)[18] intercept   : AIC=1441.445, Time=0.05 sec
#  ARIMA(1,1,0)(0,0,0)[18] intercept   : AIC=1456.898, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[18] intercept   : AIC=1443.532, Time=0.14 sec
#  ARIMA(0,1,1)(0,0,0)[18]             : AIC=1437.742, Time=0.03 sec
# ...

# %%
model_s18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   77
# Model:               SARIMAX(0, 1, 1)   Log Likelihood                -716.871
# Date:                Tue, 15 Mar 2022   AIC                           1437.742
# Time:                        19:03:56   BIC                           1442.404
# Sample:                             0   HQIC                          1439.605
#                                  - 77
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.8650      0.064    -13.441      0.000      -0.991      -0.739
# sigma2      9.016e+06   1.34e+06      6.739      0.000    6.39e+06    1.16e+07
# ...
# Ljung-Box (L1) (Q):                   0.21   Jarque-Bera (JB):                10.27
# ...

# %%
preds_sar18 = model_s18.predict(test.shape[0])
preds_sar18
# Out:
# array([2345.69163181, 2345.69163181, 2345.69163181, 2345.69163181,
#        2345.69163181, 2345.69163181, 2345.69163181, 2345.69163181,
#        2345.69163181, 2345.69163181, 2345.69163181, 2345.69163181])

# %%
df_preds['sarima18_auto'] = preds_sar18
df_preds['sarima18_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    2345.691632
# 2020-02-29    2345.691632
# Freq: M, Name: sarima18_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['humi_dollars'], label='Train')
plt.plot(test['humi_dollars'], label='Test')
plt.plot(df_preds['sarima18_auto'], label='SARIMA_18_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 18 Model for Humira Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 18 Model: 1733.4519212075286
# RMSE for SARIMA with Seasonality of 18 Model: 1801.455847576703

# %%
print("Summary of Metrics for Monthly Humira CMS Payments")
print("_________________________________________________")
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['simple_mean'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_4'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_6'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_12'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['seasonal_18'], squared=False))
print("_________________________________________________")
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['ses'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m12'], squared=False))
print("_________________________________________________")
# Out:
# Summary of Metrics for Monthly Humira CMS Payments
# _________________________________________________
# MAE for Simple Mean Baseline Model: 3219.347997835497
# RMSE for Simple Mean Baseline Model: 3450.9064154009043
# _________________________________________________
# MAE for Seasonal Baseline 4 Shift Model: 1172.8691666666666
# RMSE for Seasonal Baseline 4 Shift Model: 1774.5811695134337
# _________________________________________________
# MAE for Seasonal Baseline 6 Shift Model: 1404.4333333333334
# RMSE for Seasonal Baseline 6 Shift Model: 1919.6477561217662
# _________________________________________________
# MAE for Seasonal Baseline 12 Shift Model: 2583.29
# RMSE for Seasonal Baseline 12 Shift Model: 3038.1782451879503
# _________________________________________________
# MAE for Seasonal Baseline 18 Shift Model: 2797.7208333333333
# RMSE for Seasonal Baseline 18 Shift Model: 3443.6979092575757
# _________________________________________________
# ...

# %%
print("Continued Summary of Metrics for Monthly Humira CMS Payments")
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_m18'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a12'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['hw_a18'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['sarima4_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['sarima6_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['sarima12_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['humi_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['humi_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# Continued Summary of Metrics for Monthly Humira CMS Payments
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 2306.8301908606627
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 2885.981629894456
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 1419.0289975648857
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 1626.4227213174925
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 1061.4771517185857
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 1452.4085495367503
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 1581.250008955819
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 1720.2274652576289
# _________________________________________________
# ...

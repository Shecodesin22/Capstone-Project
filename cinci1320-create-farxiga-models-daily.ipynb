# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cinci_1320 = pd.read_csv('./data/cinci1320.csv', index_col='Date_of_Payment', parse_dates=True).sort_index()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,18,19,47,48,49,50,51,52,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_1320.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     148974               RODNEY
# 2013-08-01                      58931                 PAUL
# 2013-08-01                     812462               ALFRED
# 2013-08-01                     108863                 MARK
# 2013-08-01                     195441           MANOJKUMAR
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                        NaN              VIVIAN
# 2013-08-01                     JOSEPH            FAVORITO
# 2013-08-01                      JAMES            SUGAWARA
# 2013-08-01                          A            MANEGOLD
# 2013-08-01                          S               SINGH
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2013-08-01                                       8000 5 MILE RD
# 2013-08-01                                       7575 5 MILE RD
# 2013-08-01                                     8477 FOXCROFT DR
# 2013-08-01                                     2450 KIPLING AVE
# 2013-08-01                                  10600 MONTGOMERY RD
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2013-08-01                                                  240
# 2013-08-01                                                  NaN
# 2013-08-01                                                  NaN
# 2013-08-01                                            SUITE 104
# 2013-08-01                                            SUITE 200
#
#                 Recipient_City  ... xarelto victoza humira levemir invokana  \
# Date_of_Payment                 ...
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
#
#                 farxiga entresto chantix myrbetriq toujeo
# Date_of_Payment
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
#
# [5 rows x 89 columns]

# %%
cinci_1320['Change_Type'].value_counts()
# Out:
# UNCHANGED    364686
# CHANGED         726
# ADD               1
# Name: Change_Type, dtype: int64

# %%
cinci_1320['farxiga'].value_counts()
# Out:
# 0    361702
# 1      3711
# Name: farxiga, dtype: int64

# %%
farxiga = cinci_1320[(cinci_1320['farxiga']==1) & (cinci_1320['Number_of_Payments_Included_in_Total_Amount']==1)].copy()

# %%
farxiga.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2014-02-07        UNCHANGED  Covered Recipient Physician
# 2014-02-07        UNCHANGED  Covered Recipient Physician
# 2014-02-10        UNCHANGED  Covered Recipient Physician
# 2014-02-10        UNCHANGED  Covered Recipient Physician
# 2014-02-10        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2014-02-07                     261294                Peter
# 2014-02-07                     116125                 Ming
# 2014-02-10                     204210                 Rosa
# 2014-02-10                     688851                Vikas
# 2014-02-10                      11601                James
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2014-02-07                          K                Wong
# 2014-02-07                          E            Ashworth
# 2014-02-10                          M              Robles
# 2014-02-10                        NaN             Kashyap
# 2014-02-10                          I          Fidelholtz
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2014-02-07                        NaN
# 2014-02-07                        NaN
# 2014-02-10                        NaN
# 2014-02-10                        NaN
# 2014-02-10                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2014-02-07                                       8000 5 Mile Rd
# 2014-02-07                                    8000 Five Mile Rd
# 2014-02-10                                  10495 Montgomery Rd
# 2014-02-10                                        494 Neeb Road
# 2014-02-10                                    6103 Hamilton Ave
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2014-02-07                                             Ste. 250
# 2014-02-07                                            Suite 250
# 2014-02-10                                             Suite 15
# 2014-02-10                                                  NaN
# 2014-02-10                                                  NaN
#
#                 Recipient_City  ... xarelto victoza humira levemir invokana  \
# Date_of_Payment                 ...
# 2014-02-07          Cincinnati  ...       0       0      0       0        0
# 2014-02-07          Cincinnati  ...       0       0      0       0        0
# 2014-02-10          Cincinnati  ...       0       0      0       0        0
# 2014-02-10          Cincinnati  ...       0       0      0       0        0
# 2014-02-10          Cincinnati  ...       0       0      0       0        0
#
#                 farxiga entresto chantix myrbetriq toujeo
# Date_of_Payment
# 2014-02-07            1        0       0         0      0
# 2014-02-07            1        0       0         0      0
# 2014-02-10            1        0       0         0      0
# 2014-02-10            1        0       0         0      0
# 2014-02-10            1        0       0         0      0
#
# [5 rows x 89 columns]

# %%
farxiga['farxiga'].value_counts()
# Out:
# 1    3453
# Name: farxiga, dtype: int64

# %%
farxiga['Change_Type'].value_counts()
# Out:
# UNCHANGED    3453
# Name: Change_Type, dtype: int64

# %%
farxiga['farx_dollars'] = [k if ((i ==1) & (j ==1)) else 0 for i, j, k in zip(farxiga['farxiga'], farxiga['Number_of_Payments_Included_in_Total_Amount'], farxiga['Total_Amount_of_Payment_USDollars'])]

#Ben Peck helped me with this during office hours.  I was oh-so-close but not quite there!

# %%
farxiga['farx_dollars'].sum()
# Out:
# 179826.00999999998

# %%
farxiga.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2014-02-07        UNCHANGED  Covered Recipient Physician
# 2014-02-07        UNCHANGED  Covered Recipient Physician
# 2014-02-10        UNCHANGED  Covered Recipient Physician
# 2014-02-10        UNCHANGED  Covered Recipient Physician
# 2014-02-10        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2014-02-07                     261294                Peter
# 2014-02-07                     116125                 Ming
# 2014-02-10                     204210                 Rosa
# 2014-02-10                     688851                Vikas
# 2014-02-10                      11601                James
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2014-02-07                          K                Wong
# 2014-02-07                          E            Ashworth
# 2014-02-10                          M              Robles
# 2014-02-10                        NaN             Kashyap
# 2014-02-10                          I          Fidelholtz
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2014-02-07                        NaN
# 2014-02-07                        NaN
# 2014-02-10                        NaN
# 2014-02-10                        NaN
# 2014-02-10                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2014-02-07                                       8000 5 Mile Rd
# 2014-02-07                                    8000 Five Mile Rd
# 2014-02-10                                  10495 Montgomery Rd
# 2014-02-10                                        494 Neeb Road
# 2014-02-10                                    6103 Hamilton Ave
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2014-02-07                                             Ste. 250
# 2014-02-07                                            Suite 250
# 2014-02-10                                             Suite 15
# 2014-02-10                                                  NaN
# 2014-02-10                                                  NaN
#
#                 Recipient_City  ... victoza humira levemir invokana farxiga  \
# Date_of_Payment                 ...
# 2014-02-07          Cincinnati  ...       0      0       0        0       1
# 2014-02-07          Cincinnati  ...       0      0       0        0       1
# 2014-02-10          Cincinnati  ...       0      0       0        0       1
# 2014-02-10          Cincinnati  ...       0      0       0        0       1
# 2014-02-10          Cincinnati  ...       0      0       0        0       1
#
#                 entresto chantix myrbetriq toujeo farx_dollars
# Date_of_Payment
# 2014-02-07             0       0         0      0        10.40
# 2014-02-07             0       0         0      0        10.40
# 2014-02-10             0       0         0      0        15.11
# 2014-02-10             0       0         0      0        12.00
# 2014-02-10             0       0         0      0        12.23
#
# [5 rows x 90 columns]

# %%
farxiga['Physician_Profile_ID'].value_counts()
# Out:
# 351960     143
# 204210      73
# 498994      65
# 340304      56
# 554128      54
#           ...
# 276839       1
# 261976       1
# 224913       1
# 1231343      1
# 4219859      1
# Name: Physician_Profile_ID, Length: 442, dtype: int64

# %% [markdown]
# Appy Benford's Law to data of physician with most reimbursements for farxiga

# %%
benny_farx = farxiga[farxiga['Physician_Profile_ID']== 435991].copy()

# %%
benny_farx.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2014-06-24        UNCHANGED  Covered Recipient Physician
# 2014-11-21        UNCHANGED  Covered Recipient Physician
# 2014-12-19        UNCHANGED  Covered Recipient Physician
# 2015-01-06        UNCHANGED  Covered Recipient Physician
# 2015-01-28        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2014-06-24                     435991                   C.
# 2014-11-21                     435991                   C.
# 2014-12-19                     435991                   C.
# 2015-01-06                     435991                   C.
# 2015-01-28                     435991                   C.
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2014-06-24                      Keith              Melvin
# 2014-11-21                      Keith              Melvin
# 2014-12-19                      Keith              Melvin
# 2015-01-06                      Keith              Melvin
# 2015-01-28                      Keith              Melvin
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2014-06-24                        NaN
# 2014-11-21                        NaN
# 2014-12-19                        NaN
# 2015-01-06                        NaN
# 2015-01-28                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2014-06-24                                      3131 Harvey Ave
# 2014-11-21                                      3131 Harvey Ave
# 2014-12-19                                      3131 Harvey Ave
# 2015-01-06                                      3131 Harvey Ave
# 2015-01-28                                      3131 Harvey Ave
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2014-06-24                                             Ste. 104
# 2014-11-21                                             Ste. 104
# 2014-12-19                                             Ste. 104
# 2015-01-06                                              Ste 104
# 2015-01-28                                              Ste 104
#
#                 Recipient_City  ... victoza humira levemir invokana farxiga  \
# Date_of_Payment                 ...
# 2014-06-24          Cincinnati  ...       0      0       0        0       1
# 2014-11-21          Cincinnati  ...       0      0       0        0       1
# 2014-12-19          Cincinnati  ...       0      0       0        0       1
# 2015-01-06          Cincinnati  ...       0      0       0        0       1
# 2015-01-28          Cincinnati  ...       0      0       0        0       1
#
#                 entresto chantix myrbetriq toujeo farx_dollars
# Date_of_Payment
# 2014-06-24             0       0         0      0        11.52
# 2014-11-21             0       0         0      0        10.39
# 2014-12-19             0       0         0      0        10.15
# 2015-01-06             0       0         0      0        13.74
# 2015-01-28             0       0         0      0        15.30
#
# [5 rows x 90 columns]

# %% [markdown]
# Set up columns for Benford's Law Graph

# %% [markdown]
# Learned about this in Noah's lesson during week 12 and code is based on what he shared.

# %%
digits = list(range(1,10))
benford = [np.log10(1 + (1/d)) for d in digits]
benford
# Out:
# [0.3010299956639812,
#  0.17609125905568124,
#  0.12493873660829993,
#  0.09691001300805642,
#  0.07918124604762482,
#  0.06694678963061322,
#  0.05799194697768673,
#  0.05115252244738129,
#  0.04575749056067514]

# %%
benny_farx['prep_dollars'] = [amt if amt > 1 else amt*10 for amt in benny_farx['farx_dollars']]

# %%
benny_farx['FIRST_DIGIT'] = [int(str(amt)[0]) for amt in benny_farx['prep_dollars']]

# %%
benny_farx.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2014-06-24        UNCHANGED  Covered Recipient Physician
# 2014-11-21        UNCHANGED  Covered Recipient Physician
# 2014-12-19        UNCHANGED  Covered Recipient Physician
# 2015-01-06        UNCHANGED  Covered Recipient Physician
# 2015-01-28        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2014-06-24                     435991                   C.
# 2014-11-21                     435991                   C.
# 2014-12-19                     435991                   C.
# 2015-01-06                     435991                   C.
# 2015-01-28                     435991                   C.
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2014-06-24                      Keith              Melvin
# 2014-11-21                      Keith              Melvin
# 2014-12-19                      Keith              Melvin
# 2015-01-06                      Keith              Melvin
# 2015-01-28                      Keith              Melvin
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2014-06-24                        NaN
# 2014-11-21                        NaN
# 2014-12-19                        NaN
# 2015-01-06                        NaN
# 2015-01-28                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2014-06-24                                      3131 Harvey Ave
# 2014-11-21                                      3131 Harvey Ave
# 2014-12-19                                      3131 Harvey Ave
# 2015-01-06                                      3131 Harvey Ave
# 2015-01-28                                      3131 Harvey Ave
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2014-06-24                                             Ste. 104
# 2014-11-21                                             Ste. 104
# 2014-12-19                                             Ste. 104
# 2015-01-06                                              Ste 104
# 2015-01-28                                              Ste 104
#
#                 Recipient_City  ... levemir invokana farxiga entresto chantix  \
# Date_of_Payment                 ...
# 2014-06-24          Cincinnati  ...       0        0       1        0       0
# 2014-11-21          Cincinnati  ...       0        0       1        0       0
# 2014-12-19          Cincinnati  ...       0        0       1        0       0
# 2015-01-06          Cincinnati  ...       0        0       1        0       0
# 2015-01-28          Cincinnati  ...       0        0       1        0       0
#
#                 myrbetriq toujeo farx_dollars prep_dollars FIRST_DIGIT
# Date_of_Payment
# 2014-06-24              0      0        11.52        11.52           1
# 2014-11-21              0      0        10.39        10.39           1
# 2014-12-19              0      0        10.15        10.15           1
# 2015-01-06              0      0        13.74        13.74           1
# 2015-01-28              0      0        15.30        15.30           1
#
# [5 rows x 92 columns]

# %%
percentages = benny_farx['FIRST_DIGIT'].value_counts(normalize = True).sort_index()

# %%
plt.bar(digits, benford)

plt.plot(percentages, color = 'orange', marker = 'o')
plt.xticks(digits);

# %%
drop_cols = ['Change_Type','Covered_Recipient_Type',
'Physician_First_Name',
'Physician_Middle_Name',
'Physician_Last_Name',
'Physician_Name_Suffix',
'Recipient_Primary_Business_Street_Address_Line1',
'Recipient_Primary_Business_Street_Address_Line2',
'Recipient_City',
'Recipient_State',
'Recipient_Zip_Code',
'Recipient_Country',
'Physician_Primary_Type',
'Physician_Specialty',
'Physician_License_State_code1',
'Physician_License_State_code2',
'Physician_License_State_code3',
'Physician_License_State_code4',
'Physician_License_State_code5',
'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
'Form_of_Payment_or_Transfer_of_Value',
'City_of_Travel',
'State_of_Travel',
'Country_of_Travel',
'Physician_Ownership_Indicator',
'Third_Party_Payment_Recipient_Indicator',
'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
'Charity_Indicator',
'Third_Party_Equals_Covered_Recipient_Indicator',
'Contextual_Information',
'Delay_in_Publication_Indicator',
'Dispute_Status_for_Publication',
'Related_Product_Indicator',
'Covered_or_Noncovered_Indicator_1',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Product_Category_or_Therapeutic_Area_1',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Associated_Drug_or_Biological_NDC_1',
'Covered_or_Noncovered_Indicator_2',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Product_Category_or_Therapeutic_Area_2',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Associated_Drug_or_Biological_NDC_2',
'Covered_or_Noncovered_Indicator_3',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Product_Category_or_Therapeutic_Area_3',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Associated_Drug_or_Biological_NDC_3',
'Covered_or_Noncovered_Indicator_4',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Product_Category_or_Therapeutic_Area_4',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Associated_Drug_or_Biological_NDC_4',
'Covered_or_Noncovered_Indicator_5',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Product_Category_or_Therapeutic_Area_5',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Associated_Drug_or_Biological_NDC_5', 
'Physician_Profile_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
'Total_Amount_of_Payment_USDollars','Number_of_Payments_Included_in_Total_Amount', 
'Nature_of_Payment_or_Transfer_of_Value', 'Record_ID', 
'Payment_Publication_Date', 'Program_Year',
'NDC_of_Associated_Covered_Drug_or_Biological1',
'NDC_of_Associated_Covered_Drug_or_Biological2',
'NDC_of_Associated_Covered_Drug_or_Biological3',
'NDC_of_Associated_Covered_Drug_or_Biological4',
'NDC_of_Associated_Covered_Drug_or_Biological5',
'Name_of_Associated_Covered_Device_or_Medical_Supply1',
'Name_of_Associated_Covered_Device_or_Medical_Supply2',
'Name_of_Associated_Covered_Device_or_Medical_Supply3',
'Name_of_Associated_Covered_Device_or_Medical_Supply4',
'Name_of_Associated_Covered_Device_or_Medical_Supply5',
'xarelto', 'invokana', 'victoza', 'humira', 'levemir',
'entresto', 'chantix', 'myrbetriq', 'toujeo']

# %%
farxiga.drop(columns = drop_cols, inplace = True)

# %%
farxiga.head()
# Out:
#                  farxiga  farx_dollars
# Date_of_Payment
# 2014-02-07             1         10.40
# 2014-02-07             1         10.40
# 2014-02-10             1         15.11
# 2014-02-10             1         12.00
# 2014-02-10             1         12.23

# %% [markdown]
# Was reminded of the importance of checking data for outliers by this article, and modeled my filtering code below on this article:
# https://www.analyticsvidhya.com/blog/2021/08/holt-winters-method-for-time-series-analysis/

# %%
sns.boxplot(x = farxiga['farx_dollars']);

# %%
farxiga['z_score'] = [ ((i - farxiga['farx_dollars'].mean())/farxiga['farx_dollars'].std()) for i in farxiga['farx_dollars']]

# %%
farxiga.shape
# Out:
# (3453, 3)

# %%
farxigab = farxiga[(np.abs(farxiga['z_score']) < 3)].copy()

# %%
farxigab.shape
# Out:
# (3403, 3)

# %%
farxiga_daily = farxigab.resample('d').sum()

# %%
farxiga_daily.head()
# Out:
#                  farxiga  farx_dollars   z_score
# Date_of_Payment
# 2014-02-07             2         20.80 -0.294390
# 2014-02-08             0          0.00  0.000000
# 2014-02-09             0          0.00  0.000000
# 2014-02-10             5         63.86 -0.694089
# 2014-02-11             4         50.08 -0.558832

# %%
farxiga_daily.sort_index()
# Out:
#                  farxiga  farx_dollars   z_score
# Date_of_Payment
# 2014-02-07             2         20.80 -0.294390
# 2014-02-08             0          0.00  0.000000
# 2014-02-09             0          0.00  0.000000
# 2014-02-10             5         63.86 -0.694089
# 2014-02-11             4         50.08 -0.558832
# ...                  ...           ...       ...
# 2020-12-11             1         13.57 -0.136000
# 2020-12-12             0          0.00  0.000000
# 2020-12-13             0          0.00  0.000000
# 2020-12-14             0          0.00  0.000000
# 2020-12-15             1         11.76 -0.142392
#
# [2504 rows x 3 columns]

# %% [markdown]
# Look at some plots

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf

# %%
plot_acf(farxiga_daily['farx_dollars'], alpha=None, lags=24);

# %%
plot_pacf(farxiga_daily['farx_dollars'], alpha=None, lags=24);
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# Adding 1 to the weekly sales for each observation so that Holt_winters will work.

# %%
farxiga_daily['farx_dollars'] = [i+1 for i in farxiga_daily['farx_dollars']]

# %% [markdown]
# Set up Train and Test Sets using 2013 - 2020 Data

# %%
train = farxiga_daily.loc[:'2019-12-31']
train
# Out:
#                  farxiga  farx_dollars   z_score
# Date_of_Payment
# 2014-02-07             2         21.80 -0.294390
# 2014-02-08             0          1.00  0.000000
# 2014-02-09             0          1.00  0.000000
# 2014-02-10             5         64.86 -0.694089
# 2014-02-11             4         51.08 -0.558832
# ...                  ...           ...       ...
# 2019-12-27             0          1.00  0.000000
# 2019-12-28             0          1.00  0.000000
# 2019-12-29             0          1.00  0.000000
# 2019-12-30             0          1.00  0.000000
# 2019-12-31             0          1.00  0.000000
#
# [2154 rows x 3 columns]

# %%
train['farx_dollars'].max()
# Out:
# 2101.0

# %%
train.describe()
# Out:
#            farxiga  farx_dollars      z_score
# count  2154.000000   2154.000000  2154.000000
# mean      1.364903     25.519415    -0.164444
# std       2.098502     74.943954     0.298255
# min       0.000000      1.000000    -2.000416
# 25%       0.000000      1.000000    -0.281905
# 50%       0.000000      1.000000     0.000000
# 75%       2.000000     28.555000     0.000000
# max      24.000000   2101.000000     3.002385

# %%
train.index.freq = 'D'

# %%
train.shape
# Out:
# (2154, 3)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2154 entries, 2014-02-07 to 2019-12-31
# Freq: D
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   farxiga       2154 non-null   int64
#  1   farx_dollars  2154 non-null   float64
#  2   z_score       2154 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 67.3 KB

# %%
train.index
# Out:
# DatetimeIndex(['2014-02-07', '2014-02-08', '2014-02-09', '2014-02-10',
#                '2014-02-11', '2014-02-12', '2014-02-13', '2014-02-14',
#                '2014-02-15', '2014-02-16',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', name='Date_of_Payment', length=2154, freq='D')

# %%
test = farxiga_daily.loc['2020-01-01':]
test
# Out:
#                  farxiga  farx_dollars   z_score
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000
# 2020-01-02             3         37.09 -0.424315
# 2020-01-03             1         13.46 -0.139920
# 2020-01-04             0          1.00  0.000000
# 2020-01-05             0          1.00  0.000000
# ...                  ...           ...       ...
# 2020-12-11             1         14.57 -0.136000
# 2020-12-12             0          1.00  0.000000
# 2020-12-13             0          1.00  0.000000
# 2020-12-14             0          1.00  0.000000
# 2020-12-15             1         12.76 -0.142392
#
# [350 rows x 3 columns]

# %%
test.describe()
# Out:
#           farxiga  farx_dollars     z_score
# count  350.000000    350.000000  350.000000
# mean     1.322857     52.942429   -0.059861
# std      2.119981    271.166758    0.859715
# min      0.000000      1.000000   -1.291593
# 25%      0.000000      1.000000   -0.261192
# 50%      0.000000      1.000000    0.000000
# 75%      2.000000     28.537500    0.000000
# max     12.000000   4351.000000   14.075443

# %%
test.shape
# Out:
# (350, 3)

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')

plt.legend(loc='best')
plt.title("Daily Payments for Farxiga Drug");

# %% [markdown]
# Baseline - Simple Mean (Naive Model)

# %%
df_preds = test.copy(deep=True)
df_preds
# Out:
#                  farxiga  farx_dollars   z_score
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000
# 2020-01-02             3         37.09 -0.424315
# 2020-01-03             1         13.46 -0.139920
# 2020-01-04             0          1.00  0.000000
# 2020-01-05             0          1.00  0.000000
# ...                  ...           ...       ...
# 2020-12-11             1         14.57 -0.136000
# 2020-12-12             0          1.00  0.000000
# 2020-12-13             0          1.00  0.000000
# 2020-12-14             0          1.00  0.000000
# 2020-12-15             1         12.76 -0.142392
#
# [350 rows x 3 columns]

# %%
df_preds['simple_mean'] = train['farx_dollars'].mean()
df_preds
# Out:
#                  farxiga  farx_dollars   z_score  simple_mean
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    25.519415
# 2020-01-02             3         37.09 -0.424315    25.519415
# 2020-01-03             1         13.46 -0.139920    25.519415
# 2020-01-04             0          1.00  0.000000    25.519415
# 2020-01-05             0          1.00  0.000000    25.519415
# ...                  ...           ...       ...          ...
# 2020-12-11             1         14.57 -0.136000    25.519415
# 2020-12-12             0          1.00  0.000000    25.519415
# 2020-12-13             0          1.00  0.000000    25.519415
# 2020-12-14             0          1.00  0.000000    25.519415
# 2020-12-15             1         12.76 -0.142392    25.519415
#
# [350 rows x 4 columns]

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['simple_mean'], label="Baseline (Mean)")

plt.legend(loc='best')
plt.title("Baseline (Mean) Forecast for Daily Farxiga Payments");

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['simple_mean'], squared=False))
# Out:
# MAE for Simple Mean Baseline Model: 58.22890736171906
# RMSE for Simple Mean Baseline Model: 272.16418262145794

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 7

# %%
df_preds['seasonal_7'] = train['farx_dollars'].shift(7, freq='D') 
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars   z_score  simple_mean  seasonal_7
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    25.519415         1.0
# 2020-01-02             3         37.09 -0.424315    25.519415         1.0

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_7'], label='Seasonal 7')

plt.legend(loc='best')
plt.title("Seasonal 7 Forecast for Daily Farxiga Payments");

# %%
df_preds['seasonal_7'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 7 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_7']))
print("RMSE for Seasonal Baseline 7 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_7'], squared=False))
# Out:
# MAE for Seasonal Baseline 7 Shift Model: 52.92242857142857
# RMSE for Seasonal Baseline 7 Shift Model: 275.90495051168824

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 52

# %%
df_preds['seasonal_52'] = train['farx_dollars'].shift(52, freq='D') 
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    25.519415         1.0
# 2020-01-02             3         37.09 -0.424315    25.519415         1.0
#
#                  seasonal_52
# Date_of_Payment
# 2020-01-01               1.0
# 2020-01-02              67.9

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_52'], label='Seasonal 52')

plt.legend(loc='best')
plt.title("Seasonal 52 Forecast for Daily Farxiga Payments");

# %%
df_preds['seasonal_52'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 52 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_52']))
print("RMSE for Seasonal Baseline 52 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_52'], squared=False))
# Out:
# MAE for Seasonal Baseline 52 Shift Model: 55.57262857142857
# RMSE for Seasonal Baseline 52 Shift Model: 277.07381012595596

# %% [markdown]
# This is barely slightly better than the baseline model which had an MSE of 755.49.

# %% [markdown]
# Try a Seasonal Model with a shift of 364

# %%
df_preds['seasonal_364'] = train['farx_dollars'].shift(364, freq='D') 
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    25.519415         1.0
# 2020-01-02             3         37.09 -0.424315    25.519415         1.0
#
#                  seasonal_52  seasonal_364
# Date_of_Payment
# 2020-01-01               1.0           1.0
# 2020-01-02              67.9          37.5

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_364'], label='Seasonal')

plt.legend(loc='best')
plt.title("Seasonal 364 Forecast for Daily Farxiga Payments");

# %%
print("MAE for Seasonal Baseline 364 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_364']))
print("RMSE for Seasonal Baseline 364 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_364'], squared=False))
# Out:
# MAE for Seasonal Baseline 364 Shift Model: 65.27051428571428
# RMSE for Seasonal Baseline 364 Shift Model: 290.98548460410484

# %% [markdown]
# Simple Exponential Smoothing Model

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing

# %%
ses = SimpleExpSmoothing(train['farx_dollars']).fit(smoothing_level=.5)

# %%
ses.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ==============================================================================
# Dep. Variable:           farx_dollars   No. Observations:                 2154
# Model:             SimpleExpSmoothing   SSE                       15548497.494
# Optimized:                       True   AIC                          19140.982
# Trend:                           None   BIC                          19152.332
# Seasonal:                        None   AICC                         19141.001
# Seasonal Periods:                None   Date:                 Mon, 14 Mar 2022
# Box-Cox:                        False   Time:                         00:05:54
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.5000000                alpha                False
# initial_level              18.177853                  l.0                 True
# ------------------------------------------------------------------------------
# """

# %%
ses_forecast = ses.forecast(len(test))

# %%
df_preds['ses'] = ses_forecast

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['ses'], label='Simple Exponential Smoothing')

plt.legend(loc='best')
plt.title("Simple Exponential Smoothing for Farxiga Daily Payments");

# %%
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['ses'], squared=False))
# Out:
# MAE for Simple Exponential Smoothing Model: 51.949470453985434
# RMSE for Simple Exponential Smoothing Model: 275.70711797672016

# %% [markdown]
# This is horrible!  The MSE is nearly twice that of the baseline and seasonal models!  Will discard this model.

# %% [markdown]
# Holt-Winters Multiplicative Model with Seasonality of 52

# %%
hw_m52 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=52, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m52.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             farx_dollars   No. Observations:                 2154
# Model:             ExponentialSmoothing   SSE                       14165491.690
# Optimized:                         True   AIC                          19048.326
# Trend:                   Multiplicative   BIC                          19366.130
# Seasonal:                Multiplicative   AICC                         19051.592
# Seasonal Periods:                    52   Date:                 Mon, 14 Mar 2022
# Box-Cox:                          False   Time:                         00:05:56
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0403571                alpha                 True
# smoothing_trend                  0.0001                 beta                 True
# smoothing_seasonal            0.1028189                gamma                 True
# initial_level                 43.120981                  l.0                 True
# initial_trend                 1.0047591                  b.0                 True
# initial_seasons.0             0.5186546                  s.0                 True
# initial_seasons.1             2.5858477                  s.1                 True
# initial_seasons.2             0.6133323                  s.2                 True
# initial_seasons.3             0.3147786                  s.3                 True
# initial_seasons.4             0.2925651                  s.4                 True
# initial_seasons.5             2.1113578                  s.5                 True
# initial_seasons.6             0.1125043                  s.6                 True
# initial_seasons.7             1.2358246                  s.7                 True
# initial_seasons.8             0.7458915                  s.8                 True
# initial_seasons.9             0.5827932                  s.9                 True
# initial_seasons.10            0.1492333                 s.10                 True
# initial_seasons.11            0.6504544                 s.11                 True
# initial_seasons.12            0.5904707                 s.12                 True
# initial_seasons.13            0.3463963                 s.13                 True
# initial_seasons.14            0.6386644                 s.14                 True
# initial_seasons.15            1.9681125                 s.15                 True
# initial_seasons.16            0.2034361                 s.16                 True
# initial_seasons.17            0.4164272                 s.17                 True
# initial_seasons.18            0.9838509                 s.18                 True
# initial_seasons.19            0.3216027                 s.19                 True
# initial_seasons.20            0.6790678                 s.20                 True
# initial_seasons.21            4.4723449                 s.21                 True
# initial_seasons.22            0.3159530                 s.22                 True
# initial_seasons.23            0.3625933                 s.23                 True
# initial_seasons.24            1.7186561                 s.24                 True
# initial_seasons.25            0.3367577                 s.25                 True
# initial_seasons.26            0.8622830                 s.26                 True
# initial_seasons.27            0.7619854                 s.27                 True
# initial_seasons.28            1.4218823                 s.28                 True
# initial_seasons.29            1.3152140                 s.29                 True
# initial_seasons.30            0.7731795                 s.30                 True
# initial_seasons.31            0.5990309                 s.31                 True
# initial_seasons.32            1.1423235                 s.32                 True
# initial_seasons.33            1.9989362                 s.33                 True
# initial_seasons.34            0.9165051                 s.34                 True
# initial_seasons.35            0.9955243                 s.35                 True
# initial_seasons.36            1.6846596                 s.36                 True
# initial_seasons.37            0.4131164                 s.37                 True
# initial_seasons.38            1.3273907                 s.38                 True
# initial_seasons.39            0.1211217                 s.39                 True
# initial_seasons.40            3.6718751                 s.40                 True
# initial_seasons.41            0.8502717                 s.41                 True
# initial_seasons.42            0.7127547                 s.42                 True
# initial_seasons.43            0.1286451                 s.43                 True
# initial_seasons.44            0.2635793                 s.44                 True
# initial_seasons.45            0.2380121                 s.45                 True
# initial_seasons.46            4.8271026                 s.46                 True
# initial_seasons.47            0.3345416                 s.47                 True
# initial_seasons.48            0.2759498                 s.48                 True
# initial_seasons.49            0.4481699                 s.49                 True
# initial_seasons.50            2.5392406                 s.50                 True
# initial_seasons.51            0.1091339                 s.51                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m52'] = hw_m52.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    25.519415         1.0
# 2020-01-02             3         37.09 -0.424315    25.519415         1.0
#
#                  seasonal_52  seasonal_364       ses     hw_m52
# Date_of_Payment
# 2020-01-01               1.0           1.0  1.047397  49.570501
# 2020-01-02              67.9          37.5  1.047397  28.882171

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m52'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative with Seasonality of 52 for Farxiga Daily Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 52 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m52']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 52 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m52'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 52 Model: 154.50017377939284
# RMSE for Holt-Winters Multiplicative with Seasonality of 52 Model: 319.29872183976687

# %% [markdown]
# This is not as good as the baseline or the seasonal models!

# %%
hw_m364 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=364, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m364.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             farx_dollars   No. Observations:                 2154
# Model:             ExponentialSmoothing   SSE                       15443535.717
# Optimized:                         True   AIC                          19858.392
# Trend:                   Multiplicative   BIC                          21946.822
# Seasonal:                Multiplicative   AICC                         20012.368
# Seasonal Periods:                   364   Date:                 Mon, 14 Mar 2022
# Box-Cox:                          False   Time:                         00:05:58
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.0050249                alpha                 True
# smoothing_trend                0.0001006                 beta                 True
# smoothing_seasonal             0.0001249                gamma                 True
# initial_level                  17.106366                  l.0                 True
# initial_trend                  0.9995489                  b.0                 True
# initial_seasons.0              0.9118156                  s.0                 True
# initial_seasons.1              0.3536257                  s.1                 True
# initial_seasons.2              0.0658051                  s.2                 True
# initial_seasons.3              1.1993958                  s.3                 True
# initial_seasons.4              0.8085786                  s.4                 True
# initial_seasons.5              2.1045137                  s.5                 True
# initial_seasons.6              1.3409972                  s.6                 True
# initial_seasons.7              0.6088902                  s.7                 True
# initial_seasons.8              0.2355498                  s.8                 True
# initial_seasons.9              0.0654129                  s.9                 True
# initial_seasons.10             0.8172998                 s.10                 True
# initial_seasons.11             2.8431819                 s.11                 True
# initial_seasons.12             4.0654864                 s.12                 True
# initial_seasons.13             1.0857973                 s.13                 True
# initial_seasons.14             1.0427822                 s.14                 True
# initial_seasons.15             0.0639418                 s.15                 True
# initial_seasons.16             0.0640405                 s.16                 True
# initial_seasons.17             1.8236730                 s.17                 True
# initial_seasons.18             7.6390101                 s.18                 True
# initial_seasons.19             9.6137339                 s.19                 True
# initial_seasons.20             2.0108780                 s.20                 True
# initial_seasons.21             2.6015697                 s.21                 True
# initial_seasons.22             0.0659781                 s.22                 True
# initial_seasons.23             0.0660931                 s.23                 True
# initial_seasons.24             1.5237388                 s.24                 True
# initial_seasons.25             1.6707597                 s.25                 True
# initial_seasons.26             2.7617197                 s.26                 True
# initial_seasons.27             2.2583934                 s.27                 True
# initial_seasons.28             3.1437505                 s.28                 True
# initial_seasons.29             0.0677692                 s.29                 True
# initial_seasons.30             0.0678882                 s.30                 True
# initial_seasons.31             2.3305241                 s.31                 True
# initial_seasons.32             1.1505993                 s.32                 True
# initial_seasons.33             1.3119738                 s.33                 True
# initial_seasons.34             3.2787017                 s.34                 True
# initial_seasons.35             1.5671054                 s.35                 True
# initial_seasons.36             0.0631841                 s.36                 True
# initial_seasons.37             0.0632803                 s.37                 True
# initial_seasons.38             1.1042580                 s.38                 True
# initial_seasons.39             2.7682560                 s.39                 True
# initial_seasons.40             2.3176770                 s.40                 True
# initial_seasons.41             2.3910317                 s.41                 True
# initial_seasons.42             4.4033596                 s.42                 True
# initial_seasons.43             0.0669892                 s.43                 True
# initial_seasons.44             0.0671107                 s.44                 True
# initial_seasons.45             1.9737619                 s.45                 True
# initial_seasons.46             3.4507222                 s.46                 True
# initial_seasons.47             0.4326407                 s.47                 True
# initial_seasons.48             7.9865141                 s.48                 True
# initial_seasons.49             1.0801749                 s.49                 True
# initial_seasons.50             0.2520697                 s.50                 True
# initial_seasons.51             0.0719183                 s.51                 True
# initial_seasons.52             0.7877973                 s.52                 True
# initial_seasons.53             2.6673410                 s.53                 True
# initial_seasons.54             1.0626120                 s.54                 True
# initial_seasons.55             1.5727137                 s.55                 True
# initial_seasons.56             1.0287243                 s.56                 True
# initial_seasons.57             0.0688067                 s.57                 True
# initial_seasons.58             0.0689434                 s.58                 True
# initial_seasons.59             0.7922824                 s.59                 True
# initial_seasons.60             1.3773273                 s.60                 True
# initial_seasons.61             0.5378164                 s.61                 True
# initial_seasons.62             0.1608877                 s.62                 True
# initial_seasons.63             0.9635314                 s.63                 True
# initial_seasons.64             0.3206616                 s.64                 True
# initial_seasons.65             0.0696865                 s.65                 True
# initial_seasons.66             0.6356815                 s.66                 True
# initial_seasons.67             0.3318623                 s.67                 True
# initial_seasons.68             0.7537133                 s.68                 True
# initial_seasons.69             2.2670510                 s.69                 True
# initial_seasons.70             1.7254973                 s.70                 True
# initial_seasons.71             0.4094323                 s.71                 True
# initial_seasons.72             0.0706275                 s.72                 True
# initial_seasons.73             0.4221676                 s.73                 True
# initial_seasons.74             3.8888987                 s.74                 True
# initial_seasons.75             1.1564448                 s.75                 True
# initial_seasons.76             1.1724084                 s.76                 True
# initial_seasons.77             0.6793252                 s.77                 True
# initial_seasons.78             0.0701981                 s.78                 True
# initial_seasons.79             0.0703502                 s.79                 True
# initial_seasons.80             0.5962379                 s.80                 True
# initial_seasons.81             0.9688539                 s.81                 True
# initial_seasons.82             1.2657455                 s.82                 True
# initial_seasons.83             0.6071664                 s.83                 True
# initial_seasons.84             0.9581463                 s.84                 True
# initial_seasons.85             0.0707160                 s.85                 True
# initial_seasons.86             0.0708740                 s.86                 True
# initial_seasons.87             0.7823318                 s.87                 True
# initial_seasons.88             0.7229209                 s.88                 True
# initial_seasons.89             1.2206664                 s.89                 True
# initial_seasons.90             1.2537916                 s.90                 True
# initial_seasons.91             0.4046209                 s.91                 True
# initial_seasons.92             0.0714295                 s.92                 True
# initial_seasons.93             0.0715956                 s.93                 True
# initial_seasons.94             0.5224326                 s.94                 True
# initial_seasons.95             1.4222482                 s.95                 True
# initial_seasons.96             2.7672826                 s.96                 True
# initial_seasons.97             1.0106040                 s.97                 True
# initial_seasons.98             0.6974391                 s.98                 True
# initial_seasons.99             0.0713002                 s.99                 True
# initial_seasons.100            0.0714635                s.100                 True
# initial_seasons.101            1.7846912                s.101                 True
# initial_seasons.102            3.6454578                s.102                 True
# initial_seasons.103            1.7559659                s.103                 True
# initial_seasons.104            1.5363269                s.104                 True
# initial_seasons.105            1.2124004                s.105                 True
# initial_seasons.106            1.5044503                s.106                 True
# initial_seasons.107            0.0712695                s.107                 True
# initial_seasons.108            1.0566367                s.108                 True
# initial_seasons.109            1.6990366                s.109                 True
# initial_seasons.110            0.4009761                s.110                 True
# initial_seasons.111            1.6420699                s.111                 True
# initial_seasons.112            1.1587343                s.112                 True
# initial_seasons.113            0.0699550                s.113                 True
# initial_seasons.114            0.0701156                s.114                 True
# initial_seasons.115            0.0702726                s.115                 True
# initial_seasons.116            4.9844565                s.116                 True
# initial_seasons.117            0.7146036                s.117                 True
# initial_seasons.118            0.8591269                s.118                 True
# initial_seasons.119            0.8732780                s.119                 True
# initial_seasons.120            5.8812483                s.120                 True
# initial_seasons.121            0.0716094                s.121                 True
# initial_seasons.122            0.6343746                s.122                 True
# initial_seasons.123            0.8307474                s.123                 True
# initial_seasons.124            0.6074286                s.124                 True
# initial_seasons.125            1.3745483                s.125                 True
# initial_seasons.126            0.9822221                s.126                 True
# initial_seasons.127            0.2646587                s.127                 True
# initial_seasons.128            0.0720925                s.128                 True
# initial_seasons.129            0.5103208                s.129                 True
# initial_seasons.130            3.2095966                s.130                 True
# initial_seasons.131            0.9212204                s.131                 True
# initial_seasons.132            1.7672989                s.132                 True
# initial_seasons.133            0.6487441                s.133                 True
# initial_seasons.134            0.5848310                s.134                 True
# initial_seasons.135            0.0713946                s.135                 True
# initial_seasons.136            1.8326484                s.136                 True
# initial_seasons.137            0.9135410                s.137                 True
# initial_seasons.138            1.6337572                s.138                 True
# initial_seasons.139            0.7051738                s.139                 True
# initial_seasons.140            0.9846174                s.140                 True
# initial_seasons.141            0.0709189                s.141                 True
# initial_seasons.142            0.0710880                s.142                 True
# initial_seasons.143            0.8141359                s.143                 True
# initial_seasons.144            1.2272669                s.144                 True
# initial_seasons.145            1.8669319                s.145                 True
# initial_seasons.146            0.9817987                s.146                 True
# initial_seasons.147            2.4960222                s.147                 True
# initial_seasons.148            0.0714994                s.148                 True
# initial_seasons.149            0.0716753                s.149                 True
# initial_seasons.150            1.0897425                s.150                 True
# initial_seasons.151            0.5311324                s.151                 True
# initial_seasons.152            0.5886024                s.152                 True
# initial_seasons.153            0.4411029                s.153                 True
# initial_seasons.154            0.2286844                s.154                 True
# initial_seasons.155            0.0726735                s.155                 True
# initial_seasons.156            0.0728527                s.156                 True
# initial_seasons.157            0.6198274                s.157                 True
# initial_seasons.158            5.0609665                s.158                 True
# initial_seasons.159            1.5468375                s.159                 True
# initial_seasons.160            1.0738383                s.160                 True
# initial_seasons.161            0.8922105                s.161                 True
# initial_seasons.162            2.5780633                s.162                 True
# initial_seasons.163            0.0739922                s.163                 True
# initial_seasons.164            1.5789024                s.164                 True
# initial_seasons.165            5.2000599                s.165                 True
# initial_seasons.166            1.5007667                s.166                 True
# initial_seasons.167            0.9046822                s.167                 True
# initial_seasons.168            0.5630672                s.168                 True
# initial_seasons.169            0.0768784                s.169                 True
# initial_seasons.170            0.0770773                s.170                 True
# initial_seasons.171            0.7784926                s.171                 True
# initial_seasons.172            1.0367356                s.172                 True
# initial_seasons.173            0.7770092                s.173                 True
# initial_seasons.174            1.5200182                s.174                 True
# initial_seasons.175            0.6255400                s.175                 True
# initial_seasons.176            0.0780917                s.176                 True
# initial_seasons.177            0.0783079                s.177                 True
# initial_seasons.178            0.8224848                s.178                 True
# initial_seasons.179            1.2420956                s.179                 True
# initial_seasons.180            8.4502715                s.180                 True
# initial_seasons.181            1.9584708                s.181                 True
# initial_seasons.182            0.6271226                s.182                 True
# initial_seasons.183            0.1698751                s.183                 True
# initial_seasons.184            0.0750014                s.184                 True
# initial_seasons.185            0.7114210                s.185                 True
# initial_seasons.186            0.8227304                s.186                 True
# initial_seasons.187            1.9292592                s.187                 True
# initial_seasons.188            1.1108607                s.188                 True
# initial_seasons.189            0.2041830                s.189                 True
# initial_seasons.190            0.0755959                s.190                 True
# initial_seasons.191            0.0757504                s.191                 True
# initial_seasons.192            0.2602431                s.192                 True
# initial_seasons.193            0.5121099                s.193                 True
# initial_seasons.194            1.9381707                s.194                 True
# initial_seasons.195            1.3920927                s.195                 True
# initial_seasons.196            1.4034293                s.196                 True
# initial_seasons.197            0.0759342                s.197                 True
# initial_seasons.198            0.0760890                s.198                 True
# initial_seasons.199            0.9055576                s.199                 True
# initial_seasons.200            1.5040494                s.200                 True
# initial_seasons.201            2.1621691                s.201                 True
# initial_seasons.202            2.9421679                s.202                 True
# initial_seasons.203            1.5526536                s.203                 True
# initial_seasons.204            0.3095493                s.204                 True
# initial_seasons.205            0.0759174                s.205                 True
# initial_seasons.206            0.3130820                s.206                 True
# initial_seasons.207            0.9411702                s.207                 True
# initial_seasons.208            1.2167678                s.208                 True
# initial_seasons.209            1.1212665                s.209                 True
# initial_seasons.210            0.2884397                s.210                 True
# initial_seasons.211            4.1742223                s.211                 True
# initial_seasons.212            0.0762757                s.212                 True
# initial_seasons.213            0.4423052                s.213                 True
# initial_seasons.214            0.4226888                s.214                 True
# initial_seasons.215            1.3614586                s.215                 True
# initial_seasons.216            1.5770896                s.216                 True
# initial_seasons.217            0.0763147                s.217                 True
# initial_seasons.218            0.1203600                s.218                 True
# initial_seasons.219            0.0766637                s.219                 True
# initial_seasons.220            0.6171378                s.220                 True
# initial_seasons.221            1.0776408                s.221                 True
# initial_seasons.222            1.1739438                s.222                 True
# initial_seasons.223            1.7292603                s.223                 True
# initial_seasons.224            0.9727399                s.224                 True
# initial_seasons.225            0.1161410                s.225                 True
# initial_seasons.226            0.0764263                s.226                 True
# initial_seasons.227            0.5440600                s.227                 True
# initial_seasons.228            3.1204686                s.228                 True
# initial_seasons.229            2.0075859                s.229                 True
# initial_seasons.230            0.8476313                s.230                 True
# initial_seasons.231            1.1194778                s.231                 True
# initial_seasons.232            0.0767950                s.232                 True
# initial_seasons.233            0.0769434                s.233                 True
# initial_seasons.234            1.3008839                s.234                 True
# initial_seasons.235            2.1151762                s.235                 True
# initial_seasons.236            6.2832957                s.236                 True
# initial_seasons.237            0.9498067                s.237                 True
# initial_seasons.238            0.4930819                s.238                 True
# initial_seasons.239            0.9426169                s.239                 True
# initial_seasons.240            0.0656771                s.240                 True
# initial_seasons.241            0.9735573                s.241                 True
# initial_seasons.242            2.3200363                s.242                 True
# initial_seasons.243            0.9357778                s.243                 True
# initial_seasons.244            0.8394471                s.244                 True
# initial_seasons.245            0.8213940                s.245                 True
# initial_seasons.246            0.0657361                s.246                 True
# initial_seasons.247            0.0658156                s.247                 True
# initial_seasons.248            0.6431385                s.248                 True
# initial_seasons.249            0.7808874                s.249                 True
# initial_seasons.250            0.8034933                s.250                 True
# initial_seasons.251            1.6646188                s.251                 True
# initial_seasons.252            0.6567787                s.252                 True
# initial_seasons.253            0.4598599                s.253                 True
# initial_seasons.254            0.0657111                s.254                 True
# initial_seasons.255            1.2713532                s.255                 True
# initial_seasons.256            0.6760784                s.256                 True
# initial_seasons.257            0.9330543                s.257                 True
# initial_seasons.258            1.7544375                s.258                 True
# initial_seasons.259            1.7840725                s.259                 True
# initial_seasons.260            0.0654472                s.260                 True
# initial_seasons.261            0.0655188                s.261                 True
# initial_seasons.262            0.9784869                s.262                 True
# initial_seasons.263            1.8187689                s.263                 True
# initial_seasons.264            2.0360930                s.264                 True
# initial_seasons.265            1.4825402                s.265                 True
# initial_seasons.266            14.638423                s.266                 True
# initial_seasons.267            0.0652778                s.267                 True
# initial_seasons.268            0.0653372                s.268                 True
# initial_seasons.269            3.3936424                s.269                 True
# initial_seasons.270            0.9819469                s.270                 True
# initial_seasons.271            1.0245194                s.271                 True
# initial_seasons.272            1.7346550                s.272                 True
# initial_seasons.273            0.7039137                s.273                 True
# initial_seasons.274            5.4489142                s.274                 True
# initial_seasons.275            0.0664532                s.275                 True
# initial_seasons.276            0.5344104                s.276                 True
# initial_seasons.277            1.1806061                s.277                 True
# initial_seasons.278            3.2506777                s.278                 True
# initial_seasons.279            4.4553266                s.279                 True
# initial_seasons.280            0.8500791                s.280                 True
# initial_seasons.281            0.0624396                s.281                 True
# initial_seasons.282            0.0624975                s.282                 True
# initial_seasons.283            1.2807818                s.283                 True
# initial_seasons.284            1.9614885                s.284                 True
# initial_seasons.285            2.2183628                s.285                 True
# initial_seasons.286            2.0093101                s.286                 True
# initial_seasons.287            1.4736646                s.287                 True
# initial_seasons.288            1.3647094                s.288                 True
# initial_seasons.289            0.0649512                s.289                 True
# initial_seasons.290            0.8113526                s.290                 True
# initial_seasons.291            1.0359371                s.291                 True
# initial_seasons.292            0.6550919                s.292                 True
# initial_seasons.293            2.0627844                s.293                 True
# initial_seasons.294            6.3852019                s.294                 True
# initial_seasons.295            0.0650268                s.295                 True
# initial_seasons.296            0.0650947                s.296                 True
# initial_seasons.297            0.9077287                s.297                 True
# initial_seasons.298            1.4471492                s.298                 True
# initial_seasons.299            0.4860816                s.299                 True
# initial_seasons.300            2.0291554                s.300                 True
# initial_seasons.301            43.169172                s.301                 True
# initial_seasons.302            0.0653710                s.302                 True
# initial_seasons.303            0.0654417                s.303                 True
# initial_seasons.304            1.6550451                s.304                 True
# initial_seasons.305            2.8751889                s.305                 True
# initial_seasons.306            2.1113780                s.306                 True
# initial_seasons.307            1.8775347                s.307                 True
# initial_seasons.308            1.0582455                s.308                 True
# initial_seasons.309            3.0723126                s.309                 True
# initial_seasons.310            0.0652683                s.310                 True
# initial_seasons.311            0.8119401                s.311                 True
# initial_seasons.312            1.2048720                s.312                 True
# initial_seasons.313            0.6988346                s.313                 True
# initial_seasons.314            1.4054727                s.314                 True
# initial_seasons.315            1.9996446                s.315                 True
# initial_seasons.316            1.3152138                s.316                 True
# initial_seasons.317            0.0679904                s.317                 True
# initial_seasons.318            0.5487825                s.318                 True
# initial_seasons.319            0.9515752                s.319                 True
# initial_seasons.320            0.3938621                s.320                 True
# initial_seasons.321            2.0646841                s.321                 True
# initial_seasons.322            1.3510909                s.322                 True
# initial_seasons.323            0.0687876                s.323                 True
# initial_seasons.324            0.0688683                s.324                 True
# initial_seasons.325            1.4523291                s.325                 True
# initial_seasons.326            0.0696374                s.326                 True
# initial_seasons.327            0.0697410                s.327                 True
# initial_seasons.328            0.2986333                s.328                 True
# initial_seasons.329            0.7100928                s.329                 True
# initial_seasons.330            0.0701238                s.330                 True
# initial_seasons.331            0.0702159                s.331                 True
# initial_seasons.332            0.5949743                s.332                 True
# initial_seasons.333            2.3347381                s.333                 True
# initial_seasons.334            1.6291106                s.334                 True
# initial_seasons.335            0.7356974                s.335                 True
# initial_seasons.336            0.7312760                s.336                 True
# initial_seasons.337            0.0720293                s.337                 True
# initial_seasons.338            0.0721440                s.338                 True
# initial_seasons.339            1.4901085                s.339                 True
# initial_seasons.340            2.2573138                s.340                 True
# initial_seasons.341            1.3475541                s.341                 True
# initial_seasons.342            24.762163                s.342                 True
# initial_seasons.343            1.1920130                s.343                 True
# initial_seasons.344            8.7291696                s.344                 True
# initial_seasons.345            0.0732963                s.345                 True
# initial_seasons.346            0.0733722                s.346                 True
# initial_seasons.347            2.2379141                s.347                 True
# initial_seasons.348            0.5177260                s.348                 True
# initial_seasons.349            1.2153463                s.349                 True
# initial_seasons.350            2.0437076                s.350                 True
# initial_seasons.351            0.0739550                s.351                 True
# initial_seasons.352            0.0740980                s.352                 True
# initial_seasons.353            3.3894614                s.353                 True
# initial_seasons.354            1.5764052                s.354                 True
# initial_seasons.355            5.6280020                s.355                 True
# initial_seasons.356            3.7367413                s.356                 True
# initial_seasons.357            0.6840070                s.357                 True
# initial_seasons.358            0.0739678                s.358                 True
# initial_seasons.359            0.0741140                s.359                 True
# initial_seasons.360            2.1603448                s.360                 True
# initial_seasons.361            1.8203462                s.361                 True
# initial_seasons.362            0.9872990                s.362                 True
# initial_seasons.363            0.8659810                s.363                 True
# ----------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m364'] = hw_m364.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    25.519415         1.0
# 2020-01-02             3         37.09 -0.424315    25.519415         1.0
#
#                  seasonal_52  seasonal_364       ses     hw_m52    hw_m364
# Date_of_Payment
# 2020-01-01               1.0           1.0  1.047397  49.570501  40.916972
# 2020-01-02              67.9          37.5  1.047397  28.882171  18.473810

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m364'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative with Seasonality of 364 for Farxiga Daily Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 364 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m364']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 364 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m364'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 364 Model: 64.2557730033896
# RMSE for Holt-Winters Multiplicative with Seasonality of 364 Model: 279.46045908745026

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 52.

# %%
hw_a52 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=52, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a52.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             farx_dollars   No. Observations:                 2154
# Model:             ExponentialSmoothing   SSE                       12347733.852
# Optimized:                         True   AIC                          18752.503
# Trend:                         Additive   BIC                          19070.308
# Seasonal:                      Additive   AICC                         18755.770
# Seasonal Periods:                    52   Date:                 Mon, 14 Mar 2022
# Box-Cox:                          False   Time:                         00:05:59
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0403654                alpha                 True
# smoothing_trend               0.0001006                 beta                 True
# smoothing_seasonal            0.0343836                gamma                 True
# initial_level                 43.049453                  l.0                 True
# initial_trend                 0.0147379                  b.0                 True
# initial_seasons.0            -7.9540001                  s.0                 True
# initial_seasons.1             64.578148                  s.1                 True
# initial_seasons.2            -0.0157275                  s.2                 True
# initial_seasons.3            -9.6432264                  s.3                 True
# initial_seasons.4            -10.446970                  s.4                 True
# initial_seasons.5             6.5366855                  s.5                 True
# initial_seasons.6            -15.955797                  s.6                 True
# initial_seasons.7             9.7830103                  s.7                 True
# initial_seasons.8             0.9072074                  s.8                 True
# initial_seasons.9            -2.0683226                  s.9                 True
# initial_seasons.10           -14.981951                 s.10                 True
# initial_seasons.11           -1.4303406                 s.11                 True
# initial_seasons.12           -4.6271335                 s.12                 True
# initial_seasons.13           -10.425873                 s.13                 True
# initial_seasons.14           -2.5069495                 s.14                 True
# initial_seasons.15            4.3196978                 s.15                 True
# initial_seasons.16           -12.750835                 s.16                 True
# initial_seasons.17           -8.5224563                 s.17                 True
# initial_seasons.18            4.7066032                 s.18                 True
# initial_seasons.19           -9.7128608                 s.19                 True
# initial_seasons.20           -1.0965566                 s.20                 True
# initial_seasons.21            24.953259                 s.21                 True
# initial_seasons.22           -9.2005740                 s.22                 True
# initial_seasons.23           -8.6038785                 s.23                 True
# initial_seasons.24            0.9388434                 s.24                 True
# initial_seasons.25           -9.4220901                 s.25                 True
# initial_seasons.26           -2.9637855                 s.26                 True
# initial_seasons.27           -5.9131486                 s.27                 True
# initial_seasons.28            8.4683480                 s.28                 True
# initial_seasons.29            0.6639682                 s.29                 True
# initial_seasons.30           -9.1059878                 s.30                 True
# initial_seasons.31           -4.9616983                 s.31                 True
# initial_seasons.32           -0.3890467                 s.32                 True
# initial_seasons.33            44.339677                 s.33                 True
# initial_seasons.34           -3.9624782                 s.34                 True
# initial_seasons.35            5.0880087                 s.35                 True
# initial_seasons.36            2.6710834                 s.36                 True
# initial_seasons.37           -13.823240                 s.37                 True
# initial_seasons.38            20.233628                 s.38                 True
# initial_seasons.39           -18.888576                 s.39                 True
# initial_seasons.40            66.304437                 s.40                 True
# initial_seasons.41           -2.2528111                 s.41                 True
# initial_seasons.42           -10.028195                 s.42                 True
# initial_seasons.43           -18.124497                 s.43                 True
# initial_seasons.44           -15.359928                 s.44                 True
# initial_seasons.45           -13.532396                 s.45                 True
# initial_seasons.46            7.3887077                 s.46                 True
# initial_seasons.47           -9.6031809                 s.47                 True
# initial_seasons.48           -11.234415                 s.48                 True
# initial_seasons.49           -9.8865519                 s.49                 True
# initial_seasons.50            34.506442                 s.50                 True
# initial_seasons.51           -17.062974                 s.51                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a52'] = hw_a52.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    25.519415         1.0
# 2020-01-02             3         37.09 -0.424315    25.519415         1.0
#
#                  seasonal_52  seasonal_364       ses     hw_m52    hw_m364  \
# Date_of_Payment
# 2020-01-01               1.0           1.0  1.047397  49.570501  40.916972
# 2020-01-02              67.9          37.5  1.047397  28.882171  18.473810
#
#                     hw_a52
# Date_of_Payment
# 2020-01-01       34.308036
# 2020-01-02       25.988053

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a52'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 52 for Daily Farxiga Payments");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 52 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a52']))
print("RMSE for Holt-Winters Additive with Seasonality of 52 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a52'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 52 Model: 66.08914572813603
# RMSE for Holt-Winters Additive with Seasonality of 52 Model: 271.4123935894528

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 7.

# %%
hw_a7 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=7, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             farx_dollars   No. Observations:                 2154
# Model:             ExponentialSmoothing   SSE                       11612795.099
# Optimized:                         True   AIC                          18530.323
# Trend:                         Additive   BIC                          18592.749
# Seasonal:                      Additive   AICC                         18530.493
# Seasonal Periods:                     7   Date:                 Mon, 14 Mar 2022
# Box-Cox:                          False   Time:                         00:06:00
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0403714                alpha                 True
# smoothing_trend               0.0080742                 beta                 True
# smoothing_seasonal            0.0342862                gamma                 True
# initial_level                 31.080712                  l.0                 True
# initial_trend                -0.1521123                  b.0                 True
# initial_seasons.0            -10.736716                  s.0                 True
# initial_seasons.1            -31.657275                  s.1                 True
# initial_seasons.2            -41.695470                  s.2                 True
# initial_seasons.3             12.974380                  s.3                 True
# initial_seasons.4             17.923521                  s.4                 True
# initial_seasons.5             39.385820                  s.5                 True
# initial_seasons.6             13.809216                  s.6                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a7'] = hw_a7.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    25.519415         1.0
# 2020-01-02             3         37.09 -0.424315    25.519415         1.0
#
#                  seasonal_52  seasonal_364       ses     hw_m52    hw_m364  \
# Date_of_Payment
# 2020-01-01               1.0           1.0  1.047397  49.570501  40.916972
# 2020-01-02              67.9          37.5  1.047397  28.882171  18.473810
#
#                     hw_a52      hw_a7
# Date_of_Payment
# 2020-01-01       34.308036  45.072222
# 2020-01-02       25.988053  59.917949

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a7'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 7 for Daily Payments for Farxiga");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 7 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a7']))
print("RMSE for Holt-Winters Additive with Seasonality of 7 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a7'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 7 Model: 60.44060001732508
# RMSE for Holt-Winters Additive with Seasonality of 7 Model: 270.534608516935

# %%
hw_a364 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=364, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a364.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             farx_dollars   No. Observations:                 2154
# Model:             ExponentialSmoothing   SSE                       10760882.087
# Optimized:                         True   AIC                          19080.210
# Trend:                         Additive   BIC                          21168.640
# Seasonal:                      Additive   AICC                         19234.186
# Seasonal Periods:                   364   Date:                 Mon, 14 Mar 2022
# Box-Cox:                          False   Time:                         00:06:02
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.0403729                alpha                 True
# smoothing_trend                0.0001010                 beta                 True
# smoothing_seasonal             0.0001241                gamma                 True
# initial_level                  17.228471                  l.0                 True
# initial_trend                 -0.0663602                  b.0                 True
# initial_seasons.0             -8.0960023                  s.0                 True
# initial_seasons.1             -14.853335                  s.1                 True
# initial_seasons.2             -21.973230                  s.2                 True
# initial_seasons.3              6.5947239                  s.3                 True
# initial_seasons.4             -12.015396                  s.4                 True
# initial_seasons.5              7.0496065                  s.5                 True
# initial_seasons.6             -1.0846815                  s.6                 True
# initial_seasons.7             -13.721659                  s.7                 True
# initial_seasons.8             -15.716011                  s.8                 True
# initial_seasons.9             -22.106649                  s.9                 True
# initial_seasons.10            -6.3643554                 s.10                 True
# initial_seasons.11             36.449822                 s.11                 True
# initial_seasons.12             84.959626                 s.12                 True
# initial_seasons.13            -0.5106764                 s.13                 True
# initial_seasons.14            -8.3241871                 s.14                 True
# initial_seasons.15            -22.152782                 s.15                 True
# initial_seasons.16            -22.152776                 s.16                 True
# initial_seasons.17             11.637336                 s.17                 True
# initial_seasons.18             139.68202                 s.18                 True
# initial_seasons.19             197.26642                 s.19                 True
# initial_seasons.20             12.193020                 s.20                 True
# initial_seasons.21             10.265626                 s.21                 True
# initial_seasons.22            -22.181197                 s.22                 True
# initial_seasons.23            -22.181716                 s.23                 True
# initial_seasons.24             18.488207                 s.24                 True
# initial_seasons.25             8.8243637                 s.25                 True
# initial_seasons.26             37.804821                 s.26                 True
# initial_seasons.27             21.670103                 s.27                 True
# initial_seasons.28             22.003483                 s.28                 True
# initial_seasons.29            -22.268716                 s.29                 True
# initial_seasons.30            -22.274773                 s.30                 True
# initial_seasons.31             6.6163287                 s.31                 True
# initial_seasons.32            -0.2730305                 s.32                 True
# initial_seasons.33            -4.9248871                 s.33                 True
# initial_seasons.34             36.617896                 s.34                 True
# initial_seasons.35            -19.693169                 s.35                 True
# initial_seasons.36            -22.355539                 s.36                 True
# initial_seasons.37            -22.355565                 s.37                 True
# initial_seasons.38            -10.871391                 s.38                 True
# initial_seasons.39             13.894262                 s.39                 True
# initial_seasons.40             2.9315616                 s.40                 True
# initial_seasons.41             13.831507                 s.41                 True
# initial_seasons.42             40.341245                 s.42                 True
# initial_seasons.43            -22.428735                 s.43                 True
# initial_seasons.44            -22.428525                 s.44                 True
# initial_seasons.45             13.251857                 s.45                 True
# initial_seasons.46             31.978172                 s.46                 True
# initial_seasons.47            -10.701296                 s.47                 True
# initial_seasons.48             164.29575                 s.48                 True
# initial_seasons.49            -8.3670619                 s.49                 True
# initial_seasons.50            -17.852693                 s.50                 True
# initial_seasons.51            -22.476361                 s.51                 True
# initial_seasons.52            -5.5494922                 s.52                 True
# initial_seasons.53             28.659630                 s.53                 True
# initial_seasons.54            -8.9403984                 s.54                 True
# initial_seasons.55            -4.2590225                 s.55                 True
# initial_seasons.56            -5.4512060                 s.56                 True
# initial_seasons.57            -22.601890                 s.57                 True
# initial_seasons.58            -22.601566                 s.58                 True
# initial_seasons.59            -6.5332380                 s.59                 True
# initial_seasons.60             3.6552493                 s.60                 True
# initial_seasons.61            -10.740988                 s.61                 True
# initial_seasons.62            -19.417168                 s.62                 True
# initial_seasons.63            -13.400555                 s.63                 True
# initial_seasons.64            -19.821883                 s.64                 True
# initial_seasons.65            -22.739831                 s.65                 True
# initial_seasons.66            -7.4678006                 s.66                 True
# initial_seasons.67            -14.842798                 s.67                 True
# initial_seasons.68            -3.7320381                 s.68                 True
# initial_seasons.69             40.241431                 s.69                 True
# initial_seasons.70            -2.5838048                 s.70                 True
# initial_seasons.71            -13.242359                 s.71                 True
# initial_seasons.72            -22.768208                 s.72                 True
# initial_seasons.73            -19.854377                 s.73                 True
# initial_seasons.74             85.309684                 s.74                 True
# initial_seasons.75             2.8141879                 s.75                 True
# initial_seasons.76             0.4690973                 s.76                 True
# initial_seasons.77            -5.6448323                 s.77                 True
# initial_seasons.78            -23.052916                 s.78                 True
# initial_seasons.79            -23.052930                 s.79                 True
# initial_seasons.80            -11.127746                 s.80                 True
# initial_seasons.81            -2.1637572                 s.81                 True
# initial_seasons.82            -0.6587359                 s.82                 True
# initial_seasons.83            -8.1883590                 s.83                 True
# initial_seasons.84            -17.064491                 s.84                 True
# initial_seasons.85            -23.115843                 s.85                 True
# initial_seasons.86            -23.115856                 s.86                 True
# initial_seasons.87            -14.343311                 s.87                 True
# initial_seasons.88            -3.2265065                 s.88                 True
# initial_seasons.89            -4.0249705                 s.89                 True
# initial_seasons.90             10.481557                 s.90                 True
# initial_seasons.91            -13.162301                 s.91                 True
# initial_seasons.92            -23.218807                 s.92                 True
# initial_seasons.93            -23.218588                 s.93                 True
# initial_seasons.94            -7.7766441                 s.94                 True
# initial_seasons.95             11.715766                 s.95                 True
# initial_seasons.96             55.419620                 s.96                 True
# initial_seasons.97             3.4031801                 s.97                 True
# initial_seasons.98            -4.9369877                 s.98                 True
# initial_seasons.99            -23.290384                 s.99                 True
# initial_seasons.100           -23.290470                s.100                 True
# initial_seasons.101            23.948345                s.101                 True
# initial_seasons.102           -16.935189                s.102                 True
# initial_seasons.103            29.258427                s.103                 True
# initial_seasons.104            9.1806437                s.104                 True
# initial_seasons.105            8.3523610                s.105                 True
# initial_seasons.106            10.096641                s.106                 True
# initial_seasons.107           -23.349477                s.107                 True
# initial_seasons.108            6.2784747                s.108                 True
# initial_seasons.109            25.108714                s.109                 True
# initial_seasons.110           -13.224096                s.110                 True
# initial_seasons.111            22.007988                s.111                 True
# initial_seasons.112            10.537548                s.112                 True
# initial_seasons.113           -23.413738                s.113                 True
# initial_seasons.114           -23.413649                s.114                 True
# initial_seasons.115           -23.441327                s.115                 True
# initial_seasons.116            89.576917                s.116                 True
# initial_seasons.117           -4.2512521                s.117                 True
# initial_seasons.118           -0.2892641                s.118                 True
# initial_seasons.119           -0.9042628                s.119                 True
# initial_seasons.120           -23.587132                s.120                 True
# initial_seasons.121           -23.604749                s.121                 True
# initial_seasons.122           -9.3958693                s.122                 True
# initial_seasons.123           -5.0257402                s.123                 True
# initial_seasons.124           -13.764517                s.124                 True
# initial_seasons.125           -11.562076                s.125                 True
# initial_seasons.126            3.1864921                s.126                 True
# initial_seasons.127           -21.083124                s.127                 True
# initial_seasons.128           -23.783908                s.128                 True
# initial_seasons.129           -18.896359                s.129                 True
# initial_seasons.130            70.253813                s.130                 True
# initial_seasons.131            3.1965496                s.131                 True
# initial_seasons.132            27.871366                s.132                 True
# initial_seasons.133           -18.620543                s.133                 True
# initial_seasons.134           -18.218031                s.134                 True
# initial_seasons.135           -23.766391                s.135                 True
# initial_seasons.136            24.031942                s.136                 True
# initial_seasons.137            1.8037959                s.137                 True
# initial_seasons.138            22.970523                s.138                 True
# initial_seasons.139           -5.2692895                s.139                 True
# initial_seasons.140           -3.5640490                s.140                 True
# initial_seasons.141           -23.804240                s.141                 True
# initial_seasons.142           -23.804040                s.142                 True
# initial_seasons.143           -3.3462083                s.143                 True
# initial_seasons.144            12.811719                s.144                 True
# initial_seasons.145            21.337021                s.145                 True
# initial_seasons.146            2.2481713                s.146                 True
# initial_seasons.147            35.470942                s.147                 True
# initial_seasons.148           -23.742885                s.148                 True
# initial_seasons.149           -23.742651                s.149                 True
# initial_seasons.150           -20.234867                s.150                 True
# initial_seasons.151           -17.750091                s.151                 True
# initial_seasons.152           -8.4384044                s.152                 True
# initial_seasons.153           -13.811606                s.153                 True
# initial_seasons.154           -20.121776                s.154                 True
# initial_seasons.155           -23.686295                s.155                 True
# initial_seasons.156           -23.685766                s.156                 True
# initial_seasons.157           -8.3521956                s.157                 True
# initial_seasons.158            112.33113                s.158                 True
# initial_seasons.159            14.195186                s.159                 True
# initial_seasons.160            8.3428215                s.160                 True
# initial_seasons.161            2.4962067                s.161                 True
# initial_seasons.162           -23.637424                s.162                 True
# initial_seasons.163           -23.652902                s.163                 True
# initial_seasons.164            7.5019265                s.164                 True
# initial_seasons.165            96.870272                s.165                 True
# initial_seasons.166            20.614368                s.166                 True
# initial_seasons.167            0.6075487                s.167                 True
# initial_seasons.168           -17.192001                s.168                 True
# initial_seasons.169           -23.677534                s.169                 True
# initial_seasons.170           -23.677449                s.170                 True
# initial_seasons.171           -3.1720846                s.171                 True
# initial_seasons.172            6.9705574                s.172                 True
# initial_seasons.173           -2.9369930                s.173                 True
# initial_seasons.174            19.887027                s.174                 True
# initial_seasons.175           -17.950859                s.175                 True
# initial_seasons.176           -23.649898                s.176                 True
# initial_seasons.177           -23.649764                s.177                 True
# initial_seasons.178           -11.285792                s.178                 True
# initial_seasons.179            7.8088314                s.179                 True
# initial_seasons.180            247.23125                s.180                 True
# initial_seasons.181            34.655773                s.181                 True
# initial_seasons.182           -13.560489                s.182                 True
# initial_seasons.183           -18.567949                s.183                 True
# initial_seasons.184           -21.788466                s.184                 True
# initial_seasons.185           -9.4925820                s.185                 True
# initial_seasons.186           -5.0754126                s.186                 True
# initial_seasons.187            19.919299                s.187                 True
# initial_seasons.188            10.320619                s.188                 True
# initial_seasons.189           -17.961286                s.189                 True
# initial_seasons.190           -21.693769                s.190                 True
# initial_seasons.191           -21.689344                s.191                 True
# initial_seasons.192           -15.539828                s.192                 True
# initial_seasons.193           -7.5231002                s.193                 True
# initial_seasons.194            39.407726                s.194                 True
# initial_seasons.195            16.377502                s.195                 True
# initial_seasons.196            16.080116                s.196                 True
# initial_seasons.197           -21.521294                s.197                 True
# initial_seasons.198           -21.521715                s.198                 True
# initial_seasons.199            1.6583197                s.199                 True
# initial_seasons.200            26.040671                s.200                 True
# initial_seasons.201            44.148164                s.201                 True
# initial_seasons.202            48.919379                s.202                 True
# initial_seasons.203            23.681292                s.203                 True
# initial_seasons.204           -14.342299                s.204                 True
# initial_seasons.205           -21.976970                s.205                 True
# initial_seasons.206           -13.698651                s.206                 True
# initial_seasons.207            4.5444194                s.207                 True
# initial_seasons.208            16.287798                s.208                 True
# initial_seasons.209            0.1247931                s.209                 True
# initial_seasons.210           -15.028311                s.210                 True
# initial_seasons.211           -21.955753                s.211                 True
# initial_seasons.212           -21.967951                s.212                 True
# initial_seasons.213           -15.891555                s.213                 True
# initial_seasons.214           -10.334795                s.214                 True
# initial_seasons.215            3.3374953                s.215                 True
# initial_seasons.216            22.394904                s.216                 True
# initial_seasons.217           -21.765462                s.217                 True
# initial_seasons.218           -21.741167                s.218                 True
# initial_seasons.219           -21.751022                s.219                 True
# initial_seasons.220           -4.0743506                s.220                 True
# initial_seasons.221           -4.1343602                s.221                 True
# initial_seasons.222            12.588084                s.222                 True
# initial_seasons.223            30.066345                s.223                 True
# initial_seasons.224            8.1280045                s.224                 True
# initial_seasons.225           -21.472850                s.225                 True
# initial_seasons.226           -21.483708                s.226                 True
# initial_seasons.227           -6.1917098                s.227                 True
# initial_seasons.228            63.130112                s.228                 True
# initial_seasons.229            14.980430                s.229                 True
# initial_seasons.230            3.3456496                s.230                 True
# initial_seasons.231           -0.2480574                s.231                 True
# initial_seasons.232           -21.703603                s.232                 True
# initial_seasons.233           -21.710782                s.233                 True
# initial_seasons.234            12.989975                s.234                 True
# initial_seasons.235            43.147676                s.235                 True
# initial_seasons.236            145.05925                s.236                 True
# initial_seasons.237           -6.6956046                s.237                 True
# initial_seasons.238           -7.9592981                s.238                 True
# initial_seasons.239           -21.464954                s.239                 True
# initial_seasons.240           -21.474043                s.240                 True
# initial_seasons.241           -1.8017691                s.241                 True
# initial_seasons.242           -18.956766                s.242                 True
# initial_seasons.243           -8.5265019                s.243                 True
# initial_seasons.244           -6.4354761                s.244                 True
# initial_seasons.245           -13.847308                s.245                 True
# initial_seasons.246           -21.411496                s.246                 True
# initial_seasons.247           -21.412144                s.247                 True
# initial_seasons.248           -4.1730983                s.248                 True
# initial_seasons.249           -0.6343405                s.249                 True
# initial_seasons.250            1.3728575                s.250                 True
# initial_seasons.251            8.4936506                s.251                 True
# initial_seasons.252           -13.201628                s.252                 True
# initial_seasons.253           -9.5491323                s.253                 True
# initial_seasons.254           -21.394822                s.254                 True
# initial_seasons.255            3.7580198                s.255                 True
# initial_seasons.256           -10.336261                s.256                 True
# initial_seasons.257           -4.3926450                s.257                 True
# initial_seasons.258           -7.5450732                s.258                 True
# initial_seasons.259            4.2584193                s.259                 True
# initial_seasons.260           -21.408854                s.260                 True
# initial_seasons.261           -21.410025                s.261                 True
# initial_seasons.262           -6.5683035                s.262                 True
# initial_seasons.263            12.147441                s.263                 True
# initial_seasons.264            9.9867318                s.264                 True
# initial_seasons.265            16.756666                s.265                 True
# initial_seasons.266           -12.171742                s.266                 True
# initial_seasons.267           -21.389771                s.267                 True
# initial_seasons.268           -21.388872                s.268                 True
# initial_seasons.269            73.802489                s.269                 True
# initial_seasons.270           -1.9935097                s.270                 True
# initial_seasons.271           -2.4526593                s.271                 True
# initial_seasons.272            0.4603775                s.272                 True
# initial_seasons.273           -7.2889714                s.273                 True
# initial_seasons.274           -21.351669                s.274                 True
# initial_seasons.275           -21.392923                s.275                 True
# initial_seasons.276           -12.490295                s.276                 True
# initial_seasons.277            0.5878103                s.277                 True
# initial_seasons.278            84.255657                s.278                 True
# initial_seasons.279            1.7448772                s.279                 True
# initial_seasons.280           -14.564629                s.280                 True
# initial_seasons.281           -21.368890                s.281                 True
# initial_seasons.282           -21.367759                s.282                 True
# initial_seasons.283           -0.1784894                s.283                 True
# initial_seasons.284            21.688884                s.284                 True
# initial_seasons.285            23.593160                s.285                 True
# initial_seasons.286            14.766872                s.286                 True
# initial_seasons.287            6.0657272                s.287                 True
# initial_seasons.288           -21.304083                s.288                 True
# initial_seasons.289           -21.361100                s.289                 True
# initial_seasons.290           -2.6761684                s.290                 True
# initial_seasons.291            6.3292385                s.291                 True
# initial_seasons.292           -16.010286                s.292                 True
# initial_seasons.293           -21.279679                s.293                 True
# initial_seasons.294           -21.205547                s.294                 True
# initial_seasons.295           -21.243388                s.295                 True
# initial_seasons.296           -21.243073                s.296                 True
# initial_seasons.297           -1.9336693                s.297                 True
# initial_seasons.298            11.301801                s.298                 True
# initial_seasons.299           -7.0883606                s.299                 True
# initial_seasons.300            47.738553                s.300                 True
# initial_seasons.301           -21.413116                s.301                 True
# initial_seasons.302           -21.491950                s.302                 True
# initial_seasons.303           -21.492056                s.303                 True
# initial_seasons.304            12.339593                s.304                 True
# initial_seasons.305           -0.9897091                s.305                 True
# initial_seasons.306            3.5673786                s.306                 True
# initial_seasons.307            22.602345                s.307                 True
# initial_seasons.308            8.3874942                s.308                 True
# initial_seasons.309           -21.401938                s.309                 True
# initial_seasons.310           -21.435550                s.310                 True
# initial_seasons.311           -15.780837                s.311                 True
# initial_seasons.312           -13.009188                s.312                 True
# initial_seasons.313           -2.0323242                s.313                 True
# initial_seasons.314            9.7630696                s.314                 True
# initial_seasons.315            1.8955142                s.315                 True
# initial_seasons.316           -7.4971865                s.316                 True
# initial_seasons.317           -21.351353                s.317                 True
# initial_seasons.318           -18.001349                s.318                 True
# initial_seasons.319           -1.3449189                s.319                 True
# initial_seasons.320           -12.923877                s.320                 True
# initial_seasons.321           -17.714865                s.321                 True
# initial_seasons.322           -21.307775                s.322                 True
# initial_seasons.323           -21.303472                s.323                 True
# initial_seasons.324           -21.302735                s.324                 True
# initial_seasons.325           -6.7059071                s.325                 True
# initial_seasons.326           -21.312966                s.326                 True
# initial_seasons.327           -21.304701                s.327                 True
# initial_seasons.328           -18.030598                s.328                 True
# initial_seasons.329           -14.605225                s.329                 True
# initial_seasons.330           -21.445267                s.330                 True
# initial_seasons.331           -21.445015                s.331                 True
# initial_seasons.332           -15.868065                s.332                 True
# initial_seasons.333            13.090292                s.333                 True
# initial_seasons.334            7.3663301                s.334                 True
# initial_seasons.335           -9.4184234                s.335                 True
# initial_seasons.336            0.4488889                s.336                 True
# initial_seasons.337           -21.462704                s.337                 True
# initial_seasons.338           -21.462697                s.338                 True
# initial_seasons.339           -3.6285986                s.339                 True
# initial_seasons.340            14.518606                s.340                 True
# initial_seasons.341           -2.7530778                s.341                 True
# initial_seasons.342           -21.513452                s.342                 True
# initial_seasons.343           -9.9082110                s.343                 True
# initial_seasons.344           -21.532925                s.344                 True
# initial_seasons.345           -21.543658                s.345                 True
# initial_seasons.346           -21.548631                s.346                 True
# initial_seasons.347            10.547162                s.347                 True
# initial_seasons.348           -10.430421                s.348                 True
# initial_seasons.349           -1.4525354                s.349                 True
# initial_seasons.350            5.1109380                s.350                 True
# initial_seasons.351           -21.865577                s.351                 True
# initial_seasons.352           -21.865531                s.352                 True
# initial_seasons.353            38.536710                s.353                 True
# initial_seasons.354            5.9954080                s.354                 True
# initial_seasons.355            131.95345                s.355                 True
# initial_seasons.356            51.298637                s.356                 True
# initial_seasons.357           -12.459275                s.357                 True
# initial_seasons.358           -21.905130                s.358                 True
# initial_seasons.359           -21.905291                s.359                 True
# initial_seasons.360            11.589881                s.360                 True
# initial_seasons.361            5.9510303                s.361                 True
# initial_seasons.362           -6.3442676                s.362                 True
# initial_seasons.363           -6.9104017                s.363                 True
# ----------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a364'] = hw_a364.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    25.519415         1.0
# 2020-01-02             3         37.09 -0.424315    25.519415         1.0
#
#                  seasonal_52  seasonal_364       ses     hw_m52    hw_m364  \
# Date_of_Payment
# 2020-01-01               1.0           1.0  1.047397  49.570501  40.916972
# 2020-01-02              67.9          37.5  1.047397  28.882171  18.473810
#
#                     hw_a52      hw_a7    hw_a364
# Date_of_Payment
# 2020-01-01       34.308036  45.072222  53.619642
# 2020-01-02       25.988053  59.917949  36.791062

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a364'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 364 for Daily Payments for Farxiga");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 364 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a364']))
print("RMSE for Holt-Winters Additive with Seasonality of 364 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a364'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 364 Model: 63.40587121520131
# RMSE for Holt-Winters Additive with Seasonality of 364 Model: 270.43353982927914

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 7.

# %%
hw_m7 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=7, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             farx_dollars   No. Observations:                 2154
# Model:             ExponentialSmoothing   SSE                       13495145.418
# Optimized:                         True   AIC                          18853.902
# Trend:                   Multiplicative   BIC                          18916.328
# Seasonal:                Multiplicative   AICC                         18854.072
# Seasonal Periods:                     7   Date:                 Mon, 14 Mar 2022
# Box-Cox:                          False   Time:                         00:06:04
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0403571                alpha                 True
# smoothing_trend               0.0080714                 beta                 True
# smoothing_seasonal               0.0001                gamma                 True
# initial_level                 31.077238                  l.0                 True
# initial_trend                 1.0404048                  b.0                 True
# initial_seasons.0             0.7095580                  s.0                 True
# initial_seasons.1             0.1252060                  s.1                 True
# initial_seasons.2             0.0242826                  s.2                 True
# initial_seasons.3             1.3014628                  s.3                 True
# initial_seasons.4             1.6266764                  s.4                 True
# initial_seasons.5             1.8934150                  s.5                 True
# initial_seasons.6             1.3193993                  s.6                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m7'] = hw_m7.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    25.519415         1.0
# 2020-01-02             3         37.09 -0.424315    25.519415         1.0
#
#                  seasonal_52  seasonal_364       ses     hw_m52    hw_m364  \
# Date_of_Payment
# 2020-01-01               1.0           1.0  1.047397  49.570501  40.916972
# 2020-01-02              67.9          37.5  1.047397  28.882171  18.473810
#
#                     hw_a52      hw_a7    hw_a364       hw_m7
# Date_of_Payment
# 2020-01-01       34.308036  45.072222  53.619642  225.249318
# 2020-01-02       25.988053  59.917949  36.791062  160.383114

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m7'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 7 Model for Farxiga Daily Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 7 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m7']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 7 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m7'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 7 Model: 4245.507767632649
# RMSE for Holt-Winters Multiplicative with Seasonality of 7 Model: 8372.590611201862

# %% [markdown]
# Beats seasonal 52 and baseline mean models, but prediction curve just looks all wrong!

# %% [markdown]
# Try a SARIMA Model

# %%
from pmdarima.utils import tsdisplay

# %%
traina = train['farx_dollars']

# %%
tsdisplay(traina)
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\pmdarima\utils\visualization.py:220: FutureWarning: the 'unbiased'' keyword is deprecated, use 'adjusted' instead
#   res = tsaplots.plot_acf(

# %%
import pmdarima as pmd
model_s7 = pmd.auto_arima(train['farx_dollars'], m=7, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=1.82 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=26030.432, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=25511.589, Time=0.26 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=inf, Time=0.86 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=26028.432, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[7] intercept   : AIC=25515.592, Time=0.09 sec
#  ARIMA(1,1,0)(2,0,0)[7] intercept   : AIC=25512.061, Time=0.56 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=1.84 sec
#  ARIMA(1,1,0)(0,0,1)[7] intercept   : AIC=25511.873, Time=0.33 sec
#  ARIMA(1,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=3.85 sec
#  ARIMA(0,1,0)(1,0,0)[7] intercept   : AIC=26032.243, Time=0.11 sec
#  ARIMA(2,1,0)(1,0,0)[7] intercept   : AIC=25299.125, Time=0.37 sec
#  ARIMA(2,1,0)(0,0,0)[7] intercept   : AIC=25306.897, Time=0.12 sec
#  ARIMA(2,1,0)(2,0,0)[7] intercept   : AIC=25295.374, Time=4.46 sec
#  ARIMA(2,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=14.80 sec
#  ARIMA(2,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=2.58 sec
#  ARIMA(3,1,0)(2,0,0)[7] intercept   : AIC=25173.058, Time=5.16 sec
#  ARIMA(3,1,0)(1,0,0)[7] intercept   : AIC=25178.859, Time=1.30 sec
#  ARIMA(3,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=16.07 sec
#  ARIMA(3,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=3.39 sec
#  ARIMA(4,1,0)(2,0,0)[7] intercept   : AIC=25080.394, Time=7.32 sec
#  ARIMA(4,1,0)(1,0,0)[7] intercept   : AIC=25085.396, Time=1.20 sec
#  ARIMA(4,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=18.92 sec
#  ARIMA(4,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=3.09 sec
#  ARIMA(5,1,0)(2,0,0)[7] intercept   : AIC=24992.426, Time=4.04 sec
#  ARIMA(5,1,0)(1,0,0)[7] intercept   : AIC=24993.519, Time=0.63 sec
#  ARIMA(5,1,0)(2,0,1)[7] intercept   : AIC=inf, Time=19.37 sec
#  ARIMA(5,1,0)(1,0,1)[7] intercept   : AIC=inf, Time=5.30 sec
#  ARIMA(5,1,1)(2,0,0)[7] intercept   : AIC=24672.646, Time=18.82 sec
#  ARIMA(5,1,1)(1,0,0)[7] intercept   : AIC=24672.347, Time=4.52 sec
#  ARIMA(5,1,1)(0,0,0)[7] intercept   : AIC=24671.937, Time=2.01 sec
#  ARIMA(5,1,1)(0,0,1)[7] intercept   : AIC=24672.435, Time=3.64 sec
#  ARIMA(5,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=5.77 sec
#  ARIMA(4,1,1)(0,0,0)[7] intercept   : AIC=24671.574, Time=1.73 sec
#  ARIMA(4,1,1)(1,0,0)[7] intercept   : AIC=24671.532, Time=3.88 sec
#  ARIMA(4,1,1)(2,0,0)[7] intercept   : AIC=inf, Time=16.61 sec
#  ARIMA(4,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=4.35 sec
#  ARIMA(4,1,1)(0,0,1)[7] intercept   : AIC=24671.651, Time=4.19 sec
#  ARIMA(4,1,1)(2,0,1)[7] intercept   : AIC=inf, Time=33.94 sec
#  ARIMA(3,1,1)(1,0,0)[7] intercept   : AIC=inf, Time=2.27 sec
#  ARIMA(4,1,2)(1,0,0)[7] intercept   : AIC=24677.327, Time=2.40 sec
#  ARIMA(3,1,2)(1,0,0)[7] intercept   : AIC=24678.889, Time=2.87 sec
#  ARIMA(5,1,2)(1,0,0)[7] intercept   : AIC=24672.915, Time=5.78 sec
#  ARIMA(4,1,1)(1,0,0)[7]             : AIC=24669.625, Time=2.01 sec
#  ARIMA(4,1,1)(0,0,0)[7]             : AIC=24669.642, Time=1.11 sec
#  ARIMA(4,1,1)(2,0,0)[7]             : AIC=24669.644, Time=11.22 sec
#  ARIMA(4,1,1)(1,0,1)[7]             : AIC=inf, Time=3.62 sec
#  ARIMA(4,1,1)(0,0,1)[7]             : AIC=24669.742, Time=1.91 sec
#  ARIMA(4,1,1)(2,0,1)[7]             : AIC=inf, Time=16.89 sec
#  ARIMA(3,1,1)(1,0,0)[7]             : AIC=24671.809, Time=2.31 sec
#  ARIMA(4,1,0)(1,0,0)[7]             : AIC=25083.396, Time=0.58 sec
#  ARIMA(5,1,1)(1,0,0)[7]             : AIC=24670.420, Time=2.00 sec
#  ARIMA(4,1,2)(1,0,0)[7]             : AIC=24675.454, Time=1.54 sec
#  ARIMA(3,1,0)(1,0,0)[7]             : AIC=25176.859, Time=0.52 sec
#  ARIMA(3,1,2)(1,0,0)[7]             : AIC=24677.063, Time=1.37 sec
#  ARIMA(5,1,0)(1,0,0)[7]             : AIC=24991.519, Time=0.28 sec
#  ARIMA(5,1,2)(1,0,0)[7]             : AIC=24670.997, Time=2.61 sec
#
# Best model:  ARIMA(4,1,1)(1,0,0)[7]
# Total fit time: 278.725 seconds

# %%
model_s7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                 2154
# Model:             SARIMAX(4, 1, 1)x(1, 0, [], 7)   Log Likelihood              -12327.812
# Date:                            Mon, 14 Mar 2022   AIC                          24669.625
# Time:                                    00:10:45   BIC                          24709.347
# Sample:                                         0   HQIC                         24684.156
#                                            - 2154
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0410      0.015      2.654      0.008       0.011       0.071
# ar.L2         -0.0262      0.052     -0.502      0.616      -0.129       0.076
# ar.L3         -0.0412      0.019     -2.116      0.034      -0.079      -0.003
# ar.L4         -0.0456      0.030     -1.507      0.132      -0.105       0.014
# ma.L1         -0.9826      0.004   -276.759      0.000      -0.990      -0.976
# ar.S.L7        0.0322      0.024      1.330      0.184      -0.015       0.080
# sigma2      5498.7370     16.125    341.006      0.000    5467.133    5530.341
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):           9150966.12
# Prob(Q):                              0.95   Prob(JB):                         0.00
# Heteroskedasticity (H):              13.65   Skew:                            14.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                       321.14
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
preds_sar7 = model_s7.predict(test.shape[0])
preds_sar7
# Out:
# array([51.70443597, 53.7901216 , 52.54930758, 50.32615038, 47.86898214,
#        47.78263849, 47.99176799, 49.83911846, 50.02522137, 49.97982749,
#        49.88651051, 49.79194621, 49.78390221, 49.79196955, 49.85331068,
#        49.86026573, 49.85897992, 49.8558197 , 49.85263939, 49.85232775,
#        49.85258729, 49.85457767, 49.8548106 , 49.85477157, 49.85466906,
#        49.8545655 , 49.85455493, 49.85456322, 49.85462744, 49.85463502,
#        49.85463379, 49.85463048, 49.85462714, 49.85462679, 49.85462706,
#        49.85462913, 49.85462937, 49.85462934, 49.85462923, 49.85462912,
#        49.85462911, 49.85462912, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462918, 49.85462918, 49.85462918, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919,
#        49.85462919, 49.85462919, 49.85462919, 49.85462919, 49.85462919])

# %%
df_preds['sarima7_auto'] = preds_sar7
df_preds['sarima7_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-01    51.704436
# 2020-01-02    53.790122
# Freq: D, Name: sarima7_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['farx_dollars'], label='Train')
plt.plot(test['farx_dollars'], label='Test')
plt.plot(df_preds['sarima7_auto'], label='SARIMA_7_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 7 Model for Farxiga Daily Payments");

# %%
print("MAE for SARIMA with Seasonality of 7 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['sarima7_auto']))
print("RMSE for SARIMA with Seasonality of 7 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['sarima7_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 7 Model: 72.77810828082741
# RMSE for SARIMA with Seasonality of 7 Model: 270.79801988238984

# %% [markdown]
# Try a SARIMA Model with m = 52 - Ran out of memory after 11m 58.4s!

# %%
#model_s52 = pmd.auto_arima(train['farx_dollars'], m=52, trace=True)

# %%
#model_s52.summary()

# %%
#preds_sar52 = model_s52.predict(test.shape[0])
#preds_sar52

# %%
#df_preds['sarima52_auto'] = preds_sar52
#df_preds['sarima52_auto'].head(2)

# %%
#plt.figure(figsize=(16,8))
#plt.plot(train['farx_dollars'], label='Train')
#plt.plot(test['farx_dollars'], label='Test')
#plt.plot(df_preds['sarima52_auto'], label='SARIMA_52_auto')
#plt.legend(loc='best')
#plt.title("SARIMA Seasonality of 7 Model for Farxiga Daily Payments");

# %%
#print("MAE for Holt-Winters Additive with Seasonality of 52 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['sarima52_auto']))
#print("RMSE for Holt-Winters Additive with Seasonality of 52 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['sarima52_auto'], squared=False))

# %%
print("Summary of Metrics for Daily Farxiga CMS Payments")
print("_________________________________________________")
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['simple_mean'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 7 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_7']))
print("RMSE for Seasonal Baseline 7 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_7'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 52 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_52']))
print("RMSE for Seasonal Baseline 52 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_52'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 364 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_364']))
print("RMSE for Seasonal Baseline 364 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_364'], squared=False))
print("_________________________________________________")
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['ses'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 7 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m7']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 7 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m7'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 52 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m52']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 52 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m52'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 364 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m364']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 364 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m364'], squared=False))
print("_________________________________________________")
# Out:
# Summary of Metrics for Daily Farxiga CMS Payments
# _________________________________________________
# MAE for Simple Mean Baseline Model: 58.22890736171906
# RMSE for Simple Mean Baseline Model: 272.16418262145794
# _________________________________________________
# MAE for Seasonal Baseline 7 Shift Model: 52.92242857142857
# RMSE for Seasonal Baseline 7 Shift Model: 275.90495051168824
# _________________________________________________
# MAE for Seasonal Baseline 52 Shift Model: 55.57262857142857
# RMSE for Seasonal Baseline 52 Shift Model: 277.07381012595596
# _________________________________________________
# MAE for Seasonal Baseline 364 Shift Model: 65.27051428571428
# RMSE for Seasonal Baseline 364 Shift Model: 290.98548460410484
# _________________________________________________
# MAE for Simple Exponential Smoothing Model: 51.949470453985434
# RMSE for Simple Exponential Smoothing Model: 275.70711797672016
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 7 Model: 4245.507767632649
# RMSE for Holt-Winters Multiplicative with Seasonality of 7 Model: 8372.590611201862
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 52 Model: 154.50017377939284
# RMSE for Holt-Winters Multiplicative with Seasonality of 52 Model: 319.29872183976687
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 364 Model: 64.2557730033896
# RMSE for Holt-Winters Multiplicative with Seasonality of 364 Model: 279.46045908745026
# _________________________________________________

# %%
print("Continued Summary of Metrics for Daily Farxiga CMS Payments")
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 7 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a7']))
print("RMSE for Holt-Winters Additive with Seasonality of 7 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a7'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 52 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a52']))
print("RMSE for Holt-Winters Additive with Seasonality of 52 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a52'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 364 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a364']))
print("RMSE for Holt-Winters Additive with Seasonality of 364 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a364'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 7 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['sarima7_auto']))
print("RMSE for SARIMA with Seasonality of 7 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['sarima7_auto'], squared=False))
print("_________________________________________________")
#print("MAE for SARIMA with Seasonality of 52 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['sarima52_auto']))
#print("RMSE for SARIMA with Seasonality of 52 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['sarima52_auto'], squared=False))
# Out:
# Continued Summary of Metrics for Daily Farxiga CMS Payments
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 7 Model: 60.44060001732508
# RMSE for Holt-Winters Additive with Seasonality of 7 Model: 270.534608516935
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 52 Model: 66.08914572813603
# RMSE for Holt-Winters Additive with Seasonality of 52 Model: 271.4123935894528
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 364 Model: 63.40587121520131
# RMSE for Holt-Winters Additive with Seasonality of 364 Model: 270.43353982927914
# _________________________________________________
# MAE for SARIMA with Seasonality of 7 Model: 72.77810828082741
# RMSE for SARIMA with Seasonality of 7 Model: 270.79801988238984
# _________________________________________________

# %%
import pandas as pd
import seaborn as sns
import numpy as np
pd.set_option('display.max_rows', None, 'display.max_columns', 500)

# %%
#Import 2013 Cincinnati data

# %%
cinci_2013 = pd.read_csv('./data/cincidr2013.csv')
# Out:
# C:\Users\sarah\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3340: DtypeWarning: Columns (57) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_2013c = cinci_2013.convert_dtypes()

# %%
cinci_2013c['Date_of_Payment'] = pd.to_datetime(cinci_2013c['Date_of_Payment'])
cinci_2013c['Payment_Publication_Date'] = pd.to_datetime(cinci_2013c['Payment_Publication_Date'])

# %%
cinci_2013c.dtypes
# Out:
# Change_Type                                                                  string
# Covered_Recipient_Type                                                       string
# Teaching_Hospital_CCN                                                         Int64
# Teaching_Hospital_ID                                                          Int64
# Teaching_Hospital_Name                                                        Int64
# Physician_Profile_ID                                                          Int64
# Physician_First_Name                                                         string
# Physician_Middle_Name                                                        string
# Physician_Last_Name                                                          string
# Physician_Name_Suffix                                                        string
# Recipient_Primary_Business_Street_Address_Line1                              string
# ...

# %%
cinci_2013c.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                   <NA>
# 1   UNCHANGED  Covered Recipient Physician                   <NA>
#
#    Teaching_Hospital_ID  Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                  <NA>                    <NA>                109571
# 1                  <NA>                    <NA>                109571
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0               EDWARD                     Y               CHANG
# 1               EDWARD                     Y               CHANG
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                  <NA>                              4803 MONTGOMERY RD
# 1                  <NA>                              4803 MONTGOMERY RD
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                         STE 120     CINCINNATI
# ...

# %%
#Import 2014 Cincinnati data

# %%
cinci_2014 = pd.read_csv('./data/cincidr2014.csv')
# Out:
# C:\Users\sarah\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3340: DtypeWarning: Columns (23,24,54,55,56,57,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_2014c = cinci_2014.convert_dtypes()

# %%
cinci_2014c['Date_of_Payment'] = pd.to_datetime(cinci_2014c['Date_of_Payment'])
cinci_2014c['Payment_Publication_Date'] = pd.to_datetime(cinci_2014c['Payment_Publication_Date'])

# %%
cinci_2014c.dtypes
# Out:
# Change_Type                                                                  string
# Covered_Recipient_Type                                                       string
# Teaching_Hospital_CCN                                                         Int64
# Teaching_Hospital_ID                                                          Int64
# Teaching_Hospital_Name                                                        Int64
# Physician_Profile_ID                                                          Int64
# Physician_First_Name                                                         string
# Physician_Middle_Name                                                        string
# Physician_Last_Name                                                          string
# Physician_Name_Suffix                                                        string
# Recipient_Primary_Business_Street_Address_Line1                              string
# ...

# %%
cinci_2014c.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                   <NA>
# 1   UNCHANGED  Covered Recipient Physician                   <NA>
#
#    Teaching_Hospital_ID  Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                  <NA>                    <NA>                219676
# 1                  <NA>                    <NA>                280591
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0               andrew                  <NA>               hearn
# 1              TIMOTHY                  <NA>             BRENNAN
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                  <NA>                          3300 MERCY HEALTH BLVD
# 1                  <NA>                               2841 BOUDINOT AVE
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                      SUITE 2010     CINCINNATI
# ...

# %%
#Import 2015 Cincinnati data

# %%
cinci_2015 = pd.read_csv('./data/cincidr2015.csv')
# Out:
# C:\Users\sarah\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3340: DtypeWarning: Columns (23,24,52,57) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_2015c = cinci_2015.convert_dtypes()

# %%
cinci_2015c['Date_of_Payment'] = pd.to_datetime(cinci_2015c['Date_of_Payment'])
cinci_2015c['Payment_Publication_Date'] = pd.to_datetime(cinci_2015c['Payment_Publication_Date'])

# %%
cinci_2015c.dtypes
# Out:
# Change_Type                                                                  string
# Covered_Recipient_Type                                                       string
# Teaching_Hospital_CCN                                                         Int64
# Teaching_Hospital_ID                                                          Int64
# Teaching_Hospital_Name                                                        Int64
# Physician_Profile_ID                                                          Int64
# Physician_First_Name                                                         string
# Physician_Middle_Name                                                        string
# Physician_Last_Name                                                          string
# Physician_Name_Suffix                                                        string
# Recipient_Primary_Business_Street_Address_Line1                              string
# ...

# %%
cinci_2015c.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                   <NA>
# 1   UNCHANGED  Covered Recipient Physician                   <NA>
#
#    Teaching_Hospital_ID  Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                  <NA>                    <NA>                123386
# 1                  <NA>                    <NA>                356953
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0              CHARLES               MCCRORY               PERME
# 1               DIANNE                  <NA>                RUNK
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                  <NA>                                   7500 STATE RD
# 1                  <NA>                                4850 RED BANK RD
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                            <NA>     CINCINNATI
# ...

# %%
cinci_1315 = pd.concat([cinci_2013c,cinci_2014c, cinci_2015c], ignore_index=True)

# %%
cinci_1315.head(2)
# Out:
#   Change_Type       Covered_Recipient_Type  Teaching_Hospital_CCN  \
# 0   UNCHANGED  Covered Recipient Physician                   <NA>
# 1   UNCHANGED  Covered Recipient Physician                   <NA>
#
#    Teaching_Hospital_ID  Teaching_Hospital_Name  Physician_Profile_ID  \
# 0                  <NA>                    <NA>                109571
# 1                  <NA>                    <NA>                109571
#
#   Physician_First_Name Physician_Middle_Name Physician_Last_Name  \
# 0               EDWARD                     Y               CHANG
# 1               EDWARD                     Y               CHANG
#
#   Physician_Name_Suffix Recipient_Primary_Business_Street_Address_Line1  \
# 0                  <NA>                              4803 MONTGOMERY RD
# 1                  <NA>                              4803 MONTGOMERY RD
#
#   Recipient_Primary_Business_Street_Address_Line2 Recipient_City  \
# 0                                         STE 120     CINCINNATI
# ...

# %%
drop_col = ['Teaching_Hospital_CCN', 'Teaching_Hospital_ID', 'Teaching_Hospital_Name', 'Recipient_Province', 'Recipient_Postal_Code']

# %%
cinci_1315.drop(columns=drop_col, inplace = True)

# %%
cinci_1315.shape
# Out:
# (128810, 60)

# %%
cinci_1315['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'] = cinci_1315['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].fillna('Blank')

# %%
cinci_1315['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'] = cinci_1315['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].str.lower()

# %%
cinci_1315['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].value_counts()
# Out:
# blank                                                                    31881
# levemir                                                                   5040
# xarelto                                                                   4540
# invokana                                                                  3095
# victoza                                                                   2862
# humira                                                                    2058
# brintellix                                                                1437
# myrbetriq                                                                 1406
# symbicort                                                                 1261
# humalog                                                                   1253
# linzess                                                                   1130
# tanzeum                                                                   1120
# ...

# %%
cinci_1315['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1'].isna().sum()
# Out:
# 0

# %%
#cinci_1820['XARELTO'] = [1 if i == 'XARELTO' else 0 for i in cinci_1820['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1']]

# %%
#cinci_1820['XARELTO'].value_counts()

# %%
cinci_1315.to_csv('./data/cinci1315.csv', index=False)  #Gene told me about index=False to prevent getting an Unnamed:0 column in my csv/dataset (when I read it back in)

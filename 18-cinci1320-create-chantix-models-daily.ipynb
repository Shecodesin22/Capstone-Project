# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cinci_1320 = pd.read_csv('./data/cinci1320.csv', index_col='Date_of_Payment', parse_dates=True).sort_index()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,18,19,47,48,49,50,51,52,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_1320.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     148974               RODNEY
# 2013-08-01                      58931                 PAUL
# 2013-08-01                     812462               ALFRED
# 2013-08-01                     108863                 MARK
# 2013-08-01                     195441           MANOJKUMAR
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                        NaN              VIVIAN
# 2013-08-01                     JOSEPH            FAVORITO
# 2013-08-01                      JAMES            SUGAWARA
# 2013-08-01                          A            MANEGOLD
# 2013-08-01                          S               SINGH
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
# 2013-08-01                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2013-08-01                                       8000 5 MILE RD
# 2013-08-01                                       7575 5 MILE RD
# 2013-08-01                                     8477 FOXCROFT DR
# 2013-08-01                                     2450 KIPLING AVE
# 2013-08-01                                  10600 MONTGOMERY RD
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2013-08-01                                                  240
# 2013-08-01                                                  NaN
# 2013-08-01                                                  NaN
# 2013-08-01                                            SUITE 104
# 2013-08-01                                            SUITE 200
#
#                 Recipient_City  ... xarelto victoza humira levemir invokana  \
# Date_of_Payment                 ...
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
# 2013-08-01          CINCINNATI  ...       0       0      0       0        0
#
#                 farxiga entresto chantix myrbetriq toujeo
# Date_of_Payment
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
# 2013-08-01            0        0       0         0      0
#
# [5 rows x 89 columns]

# %%
cinci_1320['Change_Type'].value_counts()
# Out:
# UNCHANGED    364686
# CHANGED         726
# ADD               1
# Name: Change_Type, dtype: int64

# %%
cinci_1320['chantix'].value_counts()
# Out:
# 0    361962
# 1      3451
# Name: chantix, dtype: int64

# %%
chantix = cinci_1320[(cinci_1320['chantix']==1) & (cinci_1320['Number_of_Payments_Included_in_Total_Amount']==1)].copy()

# %%
chantix.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2017-01-05        UNCHANGED  Covered Recipient Physician
# 2017-01-05        UNCHANGED  Covered Recipient Physician
# 2017-01-18        UNCHANGED  Covered Recipient Physician
# 2017-01-23        UNCHANGED  Covered Recipient Physician
# 2017-01-23        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2017-01-05                     276239               AMADOR
# 2017-01-05                     276239               AMADOR
# 2017-01-18                     226669                 JOHN
# 2017-01-23                     150863                 JOYA
# 2017-01-23                     498994              STEPHEN
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2017-01-05                     SANTOS          DELAMERCED
# 2017-01-05                     SANTOS          DELAMERCED
# 2017-01-18                          M           GALLAGHER
# 2017-01-23                          K               SYKES
# 2017-01-23                      EDWIN              WILSON
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2017-01-05                        NaN
# 2017-01-05                        NaN
# 2017-01-18                        NaN
# 2017-01-23                        NaN
# 2017-01-23                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2017-01-05                                 5885 HARRISON AVENUE
# 2017-01-05                                 5885 HARRISON AVENUE
# 2017-01-18                               3301 MERCY HEALTH BLVD
# 2017-01-23                                      11550 WINTON RD
# 2017-01-23                                     1230 W KEMPER RD
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2017-01-05                                                  NaN
# 2017-01-05                                                  NaN
# 2017-01-18                                            SUITE 450
# 2017-01-23                                                  NaN
# 2017-01-23                                1230 WEST KEMPER ROAD
#
#                 Recipient_City  ... xarelto victoza humira levemir invokana  \
# Date_of_Payment                 ...
# 2017-01-05          CINCINNATI  ...       0       0      0       0        0
# 2017-01-05          CINCINNATI  ...       0       0      0       0        0
# 2017-01-18          CINCINNATI  ...       0       0      0       0        0
# 2017-01-23          CINCINNATI  ...       0       0      0       0        0
# 2017-01-23          CINCINNATI  ...       0       0      0       0        0
#
#                 farxiga entresto chantix myrbetriq toujeo
# Date_of_Payment
# 2017-01-05            0        0       1         0      0
# 2017-01-05            0        0       1         0      0
# 2017-01-18            0        0       1         0      0
# 2017-01-23            0        0       1         0      0
# 2017-01-23            0        0       1         0      0
#
# [5 rows x 89 columns]

# %%
chantix['chantix'].value_counts()
# Out:
# 1    3451
# Name: chantix, dtype: int64

# %%
chantix['Change_Type'].value_counts()
# Out:
# UNCHANGED    3451
# Name: Change_Type, dtype: int64

# %%
chantix['chan_dollars'] = [k if ((i ==1) & (j ==1)) else 0 for i, j, k in zip(chantix['chantix'], chantix['Number_of_Payments_Included_in_Total_Amount'], chantix['Total_Amount_of_Payment_USDollars'])]

#Ben Peck helped me with this during office hours.  I was oh-so-close but not quite there!

# %%
chantix['chan_dollars'].sum()
# Out:
# 32087.03

# %%
chantix.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2017-01-05        UNCHANGED  Covered Recipient Physician
# 2017-01-05        UNCHANGED  Covered Recipient Physician
# 2017-01-18        UNCHANGED  Covered Recipient Physician
# 2017-01-23        UNCHANGED  Covered Recipient Physician
# 2017-01-23        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2017-01-05                     276239               AMADOR
# 2017-01-05                     276239               AMADOR
# 2017-01-18                     226669                 JOHN
# 2017-01-23                     150863                 JOYA
# 2017-01-23                     498994              STEPHEN
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2017-01-05                     SANTOS          DELAMERCED
# 2017-01-05                     SANTOS          DELAMERCED
# 2017-01-18                          M           GALLAGHER
# 2017-01-23                          K               SYKES
# 2017-01-23                      EDWIN              WILSON
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2017-01-05                        NaN
# 2017-01-05                        NaN
# 2017-01-18                        NaN
# 2017-01-23                        NaN
# 2017-01-23                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2017-01-05                                 5885 HARRISON AVENUE
# 2017-01-05                                 5885 HARRISON AVENUE
# 2017-01-18                               3301 MERCY HEALTH BLVD
# 2017-01-23                                      11550 WINTON RD
# 2017-01-23                                     1230 W KEMPER RD
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2017-01-05                                                  NaN
# 2017-01-05                                                  NaN
# 2017-01-18                                            SUITE 450
# 2017-01-23                                                  NaN
# 2017-01-23                                1230 WEST KEMPER ROAD
#
#                 Recipient_City  ... victoza humira levemir invokana farxiga  \
# Date_of_Payment                 ...
# 2017-01-05          CINCINNATI  ...       0      0       0        0       0
# 2017-01-05          CINCINNATI  ...       0      0       0        0       0
# 2017-01-18          CINCINNATI  ...       0      0       0        0       0
# 2017-01-23          CINCINNATI  ...       0      0       0        0       0
# 2017-01-23          CINCINNATI  ...       0      0       0        0       0
#
#                 entresto chantix myrbetriq toujeo chan_dollars
# Date_of_Payment
# 2017-01-05             0       1         0      0        10.00
# 2017-01-05             0       1         0      0         0.31
# 2017-01-18             0       1         0      0        12.69
# 2017-01-23             0       1         0      0         2.50
# 2017-01-23             0       1         0      0         2.50
#
# [5 rows x 90 columns]

# %%
chantix['Physician_Profile_ID'].value_counts()
# Out:
# 284570    69
# 46042     66
# 654380    59
# 498994    58
# 184524    57
#           ..
# 457627     1
# 74887      1
# 116273     1
# 65393      1
# 220141     1
# Name: Physician_Profile_ID, Length: 359, dtype: int64

# %% [markdown]
# Appy Benford's Law to data of physician with most reimbursements for chantix

# %%
benny_chan = chantix[chantix['Physician_Profile_ID']== 435991].copy()

# %%
benny_chan.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2018-02-19        UNCHANGED  Covered Recipient Physician
# 2018-03-21        UNCHANGED  Covered Recipient Physician
# 2018-05-16        UNCHANGED  Covered Recipient Physician
# 2018-05-17        UNCHANGED  Covered Recipient Physician
# 2018-06-27        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2018-02-19                     435991                CYRIL
# 2018-03-21                     435991                CYRIL
# 2018-05-16                     435991                CYRIL
# 2018-05-17                     435991                CYRIL
# 2018-06-27                     435991                CYRIL
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2018-02-19                          K              MELVIN
# 2018-03-21                          K              MELVIN
# 2018-05-16                          K              MELVIN
# 2018-05-17                          K              MELVIN
# 2018-06-27                          K              MELVIN
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2018-02-19                        NaN
# 2018-03-21                        NaN
# 2018-05-16                        NaN
# 2018-05-17                        NaN
# 2018-06-27                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2018-02-19                                        2135 DANA AVE
# 2018-03-21                                        2135 DANA AVE
# 2018-05-16                                        2135 DANA AVE
# 2018-05-17                                        2135 DANA AVE
# 2018-06-27                                        2135 DANA AVE
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2018-02-19                                                  NaN
# 2018-03-21                                                  NaN
# 2018-05-16                                                  NaN
# 2018-05-17                                                  NaN
# 2018-06-27                                                  NaN
#
#                 Recipient_City  ... victoza humira levemir invokana farxiga  \
# Date_of_Payment                 ...
# 2018-02-19          CINCINNATI  ...       0      0       0        0       0
# 2018-03-21          CINCINNATI  ...       0      0       0        0       0
# 2018-05-16          CINCINNATI  ...       0      0       0        0       0
# 2018-05-17          CINCINNATI  ...       0      0       0        0       0
# 2018-06-27          CINCINNATI  ...       0      0       0        0       0
#
#                 entresto chantix myrbetriq toujeo chan_dollars
# Date_of_Payment
# 2018-02-19             0       1         0      0        11.34
# 2018-03-21             0       1         0      0        11.99
# 2018-05-16             0       1         0      0        12.93
# 2018-05-17             0       1         0      0         0.29
# 2018-06-27             0       1         0      0         2.50
#
# [5 rows x 90 columns]

# %% [markdown]
# Set up columns for Benford's Law Graph

# %% [markdown]
# Learned about this in Noah's lesson during week 12 and code is based on what he shared.

# %%
digits = list(range(1,10))
benford = [np.log10(1 + (1/d)) for d in digits]
benford
# Out:
# [0.3010299956639812,
#  0.17609125905568124,
#  0.12493873660829993,
#  0.09691001300805642,
#  0.07918124604762482,
#  0.06694678963061322,
#  0.05799194697768673,
#  0.05115252244738129,
#  0.04575749056067514]

# %%
benny_chan['prep_dollars'] = [amt if amt > 1 else amt*10 for amt in benny_chan['chan_dollars']]

# %%
benny_chan['FIRST_DIGIT'] = [int(str(amt)[0]) for amt in benny_chan['prep_dollars']]

# %%
benny_chan.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2018-02-19        UNCHANGED  Covered Recipient Physician
# 2018-03-21        UNCHANGED  Covered Recipient Physician
# 2018-05-16        UNCHANGED  Covered Recipient Physician
# 2018-05-17        UNCHANGED  Covered Recipient Physician
# 2018-06-27        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2018-02-19                     435991                CYRIL
# 2018-03-21                     435991                CYRIL
# 2018-05-16                     435991                CYRIL
# 2018-05-17                     435991                CYRIL
# 2018-06-27                     435991                CYRIL
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2018-02-19                          K              MELVIN
# 2018-03-21                          K              MELVIN
# 2018-05-16                          K              MELVIN
# 2018-05-17                          K              MELVIN
# 2018-06-27                          K              MELVIN
#
#                 Physician_Name_Suffix  \
# Date_of_Payment
# 2018-02-19                        NaN
# 2018-03-21                        NaN
# 2018-05-16                        NaN
# 2018-05-17                        NaN
# 2018-06-27                        NaN
#
#                 Recipient_Primary_Business_Street_Address_Line1  \
# Date_of_Payment
# 2018-02-19                                        2135 DANA AVE
# 2018-03-21                                        2135 DANA AVE
# 2018-05-16                                        2135 DANA AVE
# 2018-05-17                                        2135 DANA AVE
# 2018-06-27                                        2135 DANA AVE
#
#                 Recipient_Primary_Business_Street_Address_Line2  \
# Date_of_Payment
# 2018-02-19                                                  NaN
# 2018-03-21                                                  NaN
# 2018-05-16                                                  NaN
# 2018-05-17                                                  NaN
# 2018-06-27                                                  NaN
#
#                 Recipient_City  ... levemir invokana farxiga entresto chantix  \
# Date_of_Payment                 ...
# 2018-02-19          CINCINNATI  ...       0        0       0        0       1
# 2018-03-21          CINCINNATI  ...       0        0       0        0       1
# 2018-05-16          CINCINNATI  ...       0        0       0        0       1
# 2018-05-17          CINCINNATI  ...       0        0       0        0       1
# 2018-06-27          CINCINNATI  ...       0        0       0        0       1
#
#                 myrbetriq toujeo chan_dollars prep_dollars FIRST_DIGIT
# Date_of_Payment
# 2018-02-19              0      0        11.34        11.34           1
# 2018-03-21              0      0        11.99        11.99           1
# 2018-05-16              0      0        12.93        12.93           1
# 2018-05-17              0      0         0.29         2.90           2
# 2018-06-27              0      0         2.50         2.50           2
#
# [5 rows x 92 columns]

# %%
percentages = benny_chan['FIRST_DIGIT'].value_counts(normalize = True).sort_index()

# %%
plt.bar(digits, benford)

plt.plot(percentages, color = 'orange', marker = 'o')
plt.xticks(digits);

# %%
drop_cols = ['Change_Type','Covered_Recipient_Type',
'Physician_First_Name',
'Physician_Middle_Name',
'Physician_Last_Name',
'Physician_Name_Suffix',
'Recipient_Primary_Business_Street_Address_Line1',
'Recipient_Primary_Business_Street_Address_Line2',
'Recipient_City',
'Recipient_State',
'Recipient_Zip_Code',
'Recipient_Country',
'Physician_Primary_Type',
'Physician_Specialty',
'Physician_License_State_code1',
'Physician_License_State_code2',
'Physician_License_State_code3',
'Physician_License_State_code4',
'Physician_License_State_code5',
'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
'Form_of_Payment_or_Transfer_of_Value',
'City_of_Travel',
'State_of_Travel',
'Country_of_Travel',
'Physician_Ownership_Indicator',
'Third_Party_Payment_Recipient_Indicator',
'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
'Charity_Indicator',
'Third_Party_Equals_Covered_Recipient_Indicator',
'Contextual_Information',
'Delay_in_Publication_Indicator',
'Dispute_Status_for_Publication',
'Related_Product_Indicator',
'Covered_or_Noncovered_Indicator_1',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Product_Category_or_Therapeutic_Area_1',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Associated_Drug_or_Biological_NDC_1',
'Covered_or_Noncovered_Indicator_2',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Product_Category_or_Therapeutic_Area_2',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Associated_Drug_or_Biological_NDC_2',
'Covered_or_Noncovered_Indicator_3',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Product_Category_or_Therapeutic_Area_3',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Associated_Drug_or_Biological_NDC_3',
'Covered_or_Noncovered_Indicator_4',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Product_Category_or_Therapeutic_Area_4',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Associated_Drug_or_Biological_NDC_4',
'Covered_or_Noncovered_Indicator_5',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Product_Category_or_Therapeutic_Area_5',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Associated_Drug_or_Biological_NDC_5', 
'Physician_Profile_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
'Total_Amount_of_Payment_USDollars','Number_of_Payments_Included_in_Total_Amount', 
'Nature_of_Payment_or_Transfer_of_Value', 'Record_ID', 
'Payment_Publication_Date', 'Program_Year',
'NDC_of_Associated_Covered_Drug_or_Biological1',
'NDC_of_Associated_Covered_Drug_or_Biological2',
'NDC_of_Associated_Covered_Drug_or_Biological3',
'NDC_of_Associated_Covered_Drug_or_Biological4',
'NDC_of_Associated_Covered_Drug_or_Biological5',
'Name_of_Associated_Covered_Device_or_Medical_Supply1',
'Name_of_Associated_Covered_Device_or_Medical_Supply2',
'Name_of_Associated_Covered_Device_or_Medical_Supply3',
'Name_of_Associated_Covered_Device_or_Medical_Supply4',
'Name_of_Associated_Covered_Device_or_Medical_Supply5',
'xarelto', 'farxiga', 'victoza', 'humira', 'levemir',
'entresto', 'invokana', 'myrbetriq', 'toujeo']

# %%
chantix.drop(columns = drop_cols, inplace = True)

# %%
chantix.head()
# Out:
#                  chantix  chan_dollars
# Date_of_Payment
# 2017-01-05             1         10.00
# 2017-01-05             1          0.31
# 2017-01-18             1         12.69
# 2017-01-23             1          2.50
# 2017-01-23             1          2.50

# %% [markdown]
# Was reminded of the importance of checking data for outliers by this article, and modeled my filtering code below on this article:
# https://www.analyticsvidhya.com/blog/2021/08/holt-winters-method-for-time-series-analysis/

# %%
sns.boxplot(x = chantix['chan_dollars']);

# %%
chantix['z_score'] = [ ((i - chantix['chan_dollars'].mean())/chantix['chan_dollars'].std()) for i in chantix['chan_dollars']]

# %%
chantix.shape
# Out:
# (3451, 3)

# %%
chantixb = chantix[(np.abs(chantix['z_score']) < 3)].copy()

# %%
chantixb.shape
# Out:
# (3435, 3)

# %%
chantix_daily = chantixb.resample('d').sum()

# %%
chantix_daily.head()
# Out:
#                  chantix  chan_dollars   z_score
# Date_of_Payment
# 2017-01-05             2         10.31 -0.917153
# 2017-01-06             0          0.00  0.000000
# 2017-01-07             0          0.00  0.000000
# 2017-01-08             0          0.00  0.000000
# 2017-01-09             0          0.00  0.000000

# %%
chantix_daily.sort_index()
# Out:
#                  chantix  chan_dollars   z_score
# Date_of_Payment
# 2017-01-05             2         10.31 -0.917153
# 2017-01-06             0          0.00  0.000000
# 2017-01-07             0          0.00  0.000000
# 2017-01-08             0          0.00  0.000000
# 2017-01-09             0          0.00  0.000000
# ...                  ...           ...       ...
# 2020-12-26             0          0.00  0.000000
# 2020-12-27             0          0.00  0.000000
# 2020-12-28             0          0.00  0.000000
# 2020-12-29             0          0.00  0.000000
# 2020-12-30             1         16.34  0.779490
#
# [1456 rows x 3 columns]

# %% [markdown]
# Look at some plots

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf

# %%
plot_acf(chantix_daily['chan_dollars'], alpha=None, lags=24);

# %%
plot_pacf(chantix_daily['chan_dollars'], alpha=None, lags=24);
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# Adding 1 to the weekly sales for each observation so that Holt_winters will work.

# %%
chantix_daily['chan_dollars'] = [i+1 for i in chantix_daily['chan_dollars']]

# %% [markdown]
# Set up Train and Test Sets using 2013 - 2020 Data

# %%
train = chantix_daily.loc[:'2019-12-31']
train
# Out:
#                  chantix  chan_dollars   z_score
# Date_of_Payment
# 2017-01-05             2         11.31 -0.917153
# 2017-01-06             0          1.00  0.000000
# 2017-01-07             0          1.00  0.000000
# 2017-01-08             0          1.00  0.000000
# 2017-01-09             0          1.00  0.000000
# ...                  ...           ...       ...
# 2019-12-27             0          1.00  0.000000
# 2019-12-28             0          1.00  0.000000
# 2019-12-29             0          1.00  0.000000
# 2019-12-30             0          1.00  0.000000
# 2019-12-31             0          1.00  0.000000
#
# [1091 rows x 3 columns]

# %%
train['chan_dollars'].max()
# Out:
# 253.89000000000001

# %%
train.describe()
# Out:
#            chantix  chan_dollars      z_score
# count  1091.000000   1091.000000  1091.000000
# mean      2.718607     23.467663    -0.311000
# std       3.753727     31.752199     1.492582
# min       0.000000      1.000000    -8.841673
# 25%       0.000000      1.000000    -0.411300
# 50%       1.000000      7.250000     0.000000
# 75%       4.000000     37.955000     0.000000
# max      23.000000    253.890000     8.437894

# %%
train.index.freq = 'D'

# %%
train.shape
# Out:
# (1091, 3)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1091 entries, 2017-01-05 to 2019-12-31
# Freq: D
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   chantix       1091 non-null   int64
#  1   chan_dollars  1091 non-null   float64
#  2   z_score       1091 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 34.1 KB

# %%
train.index
# Out:
# DatetimeIndex(['2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-14',
#                ...
#                '2019-12-22', '2019-12-23', '2019-12-24', '2019-12-25',
#                '2019-12-26', '2019-12-27', '2019-12-28', '2019-12-29',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', name='Date_of_Payment', length=1091, freq='D')

# %%
test = chantix_daily.loc['2020-01-01':]
test
# Out:
#                  chantix  chan_dollars   z_score
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000
# 2020-01-02             4         40.29  0.232275
# 2020-01-03             1         12.26  0.217185
# 2020-01-04             0          1.00  0.000000
# 2020-01-05             0          1.00  0.000000
# ...                  ...           ...       ...
# 2020-12-26             0          1.00  0.000000
# 2020-12-27             0          1.00  0.000000
# 2020-12-28             0          1.00  0.000000
# 2020-12-29             0          1.00  0.000000
# 2020-12-30             1         17.34  0.779490
#
# [365 rows x 3 columns]

# %%
test.describe()
# Out:
#           chantix  chan_dollars     z_score
# count  365.000000    365.000000  365.000000
# mean     1.284932     16.668740    0.411942
# std      2.259514     26.395225    0.955873
# min      0.000000      1.000000   -4.551684
# 25%      0.000000      1.000000    0.000000
# 50%      0.000000      1.000000    0.000000
# 75%      2.000000     24.310000    0.591317
# max     14.000000    129.960000    4.855384

# %%
test.shape
# Out:
# (365, 3)

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['chan_dollars'], label='Train')
plt.plot(test.index, test['chan_dollars'], label='Test')

plt.legend(loc='best')
plt.title("Daily Payments for Chantix Drug");

# %% [markdown]
# Baseline - Simple Mean (Naive Model)

# %%
df_preds = test.copy(deep=True)
df_preds
# Out:
#                  chantix  chan_dollars   z_score
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000
# 2020-01-02             4         40.29  0.232275
# 2020-01-03             1         12.26  0.217185
# 2020-01-04             0          1.00  0.000000
# 2020-01-05             0          1.00  0.000000
# ...                  ...           ...       ...
# 2020-12-26             0          1.00  0.000000
# 2020-12-27             0          1.00  0.000000
# 2020-12-28             0          1.00  0.000000
# 2020-12-29             0          1.00  0.000000
# 2020-12-30             1         17.34  0.779490
#
# [365 rows x 3 columns]

# %%
df_preds['simple_mean'] = train['chan_dollars'].mean()
df_preds
# Out:
#                  chantix  chan_dollars   z_score  simple_mean
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    23.467663
# 2020-01-02             4         40.29  0.232275    23.467663
# 2020-01-03             1         12.26  0.217185    23.467663
# 2020-01-04             0          1.00  0.000000    23.467663
# 2020-01-05             0          1.00  0.000000    23.467663
# ...                  ...           ...       ...          ...
# 2020-12-26             0          1.00  0.000000    23.467663
# 2020-12-27             0          1.00  0.000000    23.467663
# 2020-12-28             0          1.00  0.000000    23.467663
# 2020-12-29             0          1.00  0.000000    23.467663
# 2020-12-30             1         17.34  0.779490    23.467663
#
# [365 rows x 4 columns]

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['chan_dollars'], label='Train')
plt.plot(test.index, test['chan_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['simple_mean'], label="Baseline (Mean)")

plt.legend(loc='best')
plt.title("Baseline (Mean) Forecast for Daily Chantix Payments");

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['simple_mean'], squared=False))
# Out:
# MAE for Simple Mean Baseline Model: 22.556548824127677
# RMSE for Simple Mean Baseline Model: 27.221764975567535

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 7

# %%
df_preds['seasonal_7'] = train['chan_dollars'].shift(7, freq='D') 
df_preds.head(2)
# Out:
#                  chantix  chan_dollars   z_score  simple_mean  seasonal_7
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    23.467663         1.0
# 2020-01-02             4         40.29  0.232275    23.467663         1.0

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['chan_dollars'], label='Train')
plt.plot(test.index, test['chan_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_7'], label='Seasonal 7')

plt.legend(loc='best')
plt.title("Seasonal 7 Forecast for Daily Chantix Payments");

# %%
df_preds['seasonal_7'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 7 Shift Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['seasonal_7']))
print("RMSE for Seasonal Baseline 7 Shift Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['seasonal_7'], squared=False))
# Out:
# MAE for Seasonal Baseline 7 Shift Model: 16.649561643835618
# RMSE for Seasonal Baseline 7 Shift Model: 31.17463479369964

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 52

# %%
df_preds['seasonal_52'] = train['chan_dollars'].shift(52, freq='D') 
df_preds.head(2)
# Out:
#                  chantix  chan_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    23.467663         1.0
# 2020-01-02             4         40.29  0.232275    23.467663         1.0
#
#                  seasonal_52
# Date_of_Payment
# 2020-01-01              1.00
# 2020-01-02             38.53

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['chan_dollars'], label='Train')
plt.plot(test.index, test['chan_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_52'], label='Seasonal 52')

plt.legend(loc='best')
plt.title("Seasonal 52 Forecast for Daily Chantix Payments");

# %%
df_preds['seasonal_52'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 52 Shift Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['seasonal_52']))
print("RMSE for Seasonal Baseline 52 Shift Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['seasonal_52'], squared=False))
# Out:
# MAE for Seasonal Baseline 52 Shift Model: 17.96202739726027
# RMSE for Seasonal Baseline 52 Shift Model: 34.508197676049605

# %% [markdown]
# This is barely slightly better than the baseline model which had an MSE of 755.49.

# %% [markdown]
# Try a Seasonal Model with a shift of 364

# %%
df_preds['seasonal_364'] = train['chan_dollars'].shift(364, freq='D') 
df_preds.head(2)
# Out:
#                  chantix  chan_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    23.467663         1.0
# 2020-01-02             4         40.29  0.232275    23.467663         1.0
#
#                  seasonal_52  seasonal_364
# Date_of_Payment
# 2020-01-01              1.00         28.50
# 2020-01-02             38.53         45.81

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['chan_dollars'], label='Train')
plt.plot(test.index, test['chan_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_364'], label='Seasonal')

plt.legend(loc='best')
plt.title("Seasonal 364 Forecast for Daily Chantix Payments");

# %%
df_preds['seasonal_364'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 364 Shift Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['seasonal_364']))
print("RMSE for Seasonal Baseline 364 Shift Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['seasonal_364'], squared=False))
# Out:
# MAE for Seasonal Baseline 364 Shift Model: 27.78345205479452
# RMSE for Seasonal Baseline 364 Shift Model: 42.209450860178315

# %% [markdown]
# Simple Exponential Smoothing Model

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing

# %%
ses = SimpleExpSmoothing(train['chan_dollars']).fit(smoothing_level=.5)

# %%
ses.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ==============================================================================
# Dep. Variable:           chan_dollars   No. Observations:                 1091
# Model:             SimpleExpSmoothing   SSE                        1239432.514
# Optimized:                       True   AIC                           7679.528
# Trend:                           None   BIC                           7689.517
# Seasonal:                        None   AICC                          7679.565
# Seasonal Periods:                None   Date:                 Mon, 14 Mar 2022
# Box-Cox:                        False   Time:                         00:27:11
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.5000000                alpha                False
# initial_level              6.1552931                  l.0                 True
# ------------------------------------------------------------------------------
# """

# %%
ses_forecast = ses.forecast(len(test))

# %%
df_preds['ses'] = ses_forecast

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['chan_dollars'], label='Train')
plt.plot(test.index, test['chan_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['ses'], label='Simple Exponential Smoothing')

plt.legend(loc='best')
plt.title("Simple Exponential Smoothing for Chantix Daily Payments");

# %%
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['ses'], squared=False))
# Out:
# MAE for Simple Exponential Smoothing Model: 15.676596990133909
# RMSE for Simple Exponential Smoothing Model: 30.645916970009907

# %% [markdown]
# Holt-Winters Multiplicative Model with Seasonality of 52

# %%
hw_m52 = ExponentialSmoothing(
    train['chan_dollars'],
    seasonal_periods=52, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err

# %%
hw_m52.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             chan_dollars   No. Observations:                 1091
# Model:             ExponentialSmoothing   SSE                        1557025.321
# Optimized:                         True   AIC                           8036.411
# Trend:                   Multiplicative   BIC                           8316.122
# Seasonal:                Multiplicative   AICC                          8043.042
# Seasonal Periods:                    52   Date:                 Mon, 14 Mar 2022
# Box-Cox:                          False   Time:                         00:27:12
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0757143                alpha                 True
# smoothing_trend                  0.0001                 beta                 True
# smoothing_seasonal            0.1711640                gamma                 True
# initial_level                 8.7493718                  l.0                 True
# initial_trend                 1.0087639                  b.0                 True
# initial_seasons.0             0.1661396                  s.0                 True
# initial_seasons.1             1.6302011                  s.1                 True
# initial_seasons.2             0.1866932                  s.2                 True
# initial_seasons.3             3.3366334                  s.3                 True
# initial_seasons.4             0.1408964                  s.4                 True
# initial_seasons.5             1.5153217                  s.5                 True
# initial_seasons.6             1.7552619                  s.6                 True
# initial_seasons.7             0.5543221                  s.7                 True
# initial_seasons.8             0.8485526                  s.8                 True
# initial_seasons.9             1.3885103                  s.9                 True
# initial_seasons.10            0.1505551                 s.10                 True
# initial_seasons.11            2.5916255                 s.11                 True
# initial_seasons.12            0.3792469                 s.12                 True
# initial_seasons.13            0.1831232                 s.13                 True
# initial_seasons.14            1.9208605                 s.14                 True
# initial_seasons.15            0.9609115                 s.15                 True
# initial_seasons.16            0.5280764                 s.16                 True
# initial_seasons.17            0.8553218                 s.17                 True
# initial_seasons.18            0.7117200                 s.18                 True
# initial_seasons.19            0.9758300                 s.19                 True
# initial_seasons.20            1.5397562                 s.20                 True
# initial_seasons.21            2.0804963                 s.21                 True
# initial_seasons.22            0.1429638                 s.22                 True
# initial_seasons.23            0.6324642                 s.23                 True
# initial_seasons.24            0.4425515                 s.24                 True
# initial_seasons.25            1.4731996                 s.25                 True
# initial_seasons.26            2.6095630                 s.26                 True
# initial_seasons.27            0.1200843                 s.27                 True
# initial_seasons.28            0.9672059                 s.28                 True
# initial_seasons.29            1.0475435                 s.29                 True
# initial_seasons.30            0.3762993                 s.30                 True
# initial_seasons.31            0.6354004                 s.31                 True
# initial_seasons.32            1.6121071                 s.32                 True
# initial_seasons.33            1.4655718                 s.33                 True
# initial_seasons.34            1.3694953                 s.34                 True
# initial_seasons.35            0.6788092                 s.35                 True
# initial_seasons.36            0.7833396                 s.36                 True
# initial_seasons.37            1.2054130                 s.37                 True
# initial_seasons.38            0.9219480                 s.38                 True
# initial_seasons.39            1.2277697                 s.39                 True
# initial_seasons.40            1.0540187                 s.40                 True
# initial_seasons.41            0.1570440                 s.41                 True
# initial_seasons.42            0.7594438                 s.42                 True
# initial_seasons.43            0.8974292                 s.43                 True
# initial_seasons.44            0.4091207                 s.44                 True
# initial_seasons.45            0.6023638                 s.45                 True
# initial_seasons.46            2.1843871                 s.46                 True
# initial_seasons.47            0.2929099                 s.47                 True
# initial_seasons.48            1.4271519                 s.48                 True
# initial_seasons.49            0.4084626                 s.49                 True
# initial_seasons.50            0.9751503                 s.50                 True
# initial_seasons.51            0.7207332                 s.51                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m52'] = hw_m52.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  chan_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    23.467663         1.0
# 2020-01-02             4         40.29  0.232275    23.467663         1.0
#
#                  seasonal_52  seasonal_364       ses     hw_m52
# Date_of_Payment
# 2020-01-01              1.00         28.50  1.036303  23.179055
# 2020-01-02             38.53         45.81  1.036303  26.224680

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['chan_dollars'], label='Train')
plt.plot(test.index, test['chan_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m52'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative with Seasonality of 52 for Chantix Daily Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 52 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['hw_m52']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 52 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['hw_m52'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 52 Model: 142.21459369641607
# RMSE for Holt-Winters Multiplicative with Seasonality of 52 Model: 198.63031899763936

# %% [markdown]
# This is not as good as the baseline or the seasonal models!

# %%
hw_m364 = ExponentialSmoothing(
    train['chan_dollars'],
    seasonal_periods=364, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m364.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             chan_dollars   No. Observations:                 1091
# Model:             ExponentialSmoothing   SSE                       17009348.166
# Optimized:                         True   AIC                          11268.976
# Trend:                   Multiplicative   BIC                          13107.081
# Seasonal:                Multiplicative   AICC                         11650.282
# Seasonal Periods:                   364   Date:                 Mon, 14 Mar 2022
# Box-Cox:                          False   Time:                         00:27:14
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.0050000                alpha                 True
# smoothing_trend                   0.0001                 beta                 True
# smoothing_seasonal             0.4619643                gamma                 True
# initial_level                  9.4152683                  l.0                 True
# initial_trend                  1.0014844                  b.0                 True
# initial_seasons.0              0.0531003                  s.0                 True
# initial_seasons.1              0.0530117                  s.1                 True
# initial_seasons.2              0.0529356                  s.2                 True
# initial_seasons.3              0.0529356                  s.3                 True
# initial_seasons.4              0.6225888                  s.4                 True
# initial_seasons.5              0.2226526                  s.5                 True
# initial_seasons.6              0.0522502                  s.6                 True
# initial_seasons.7              1.5752908                  s.7                 True
# initial_seasons.8              0.0515717                  s.8                 True
# initial_seasons.9              0.0513847                  s.9                 True
# initial_seasons.10             0.0513797                 s.10                 True
# initial_seasons.11             0.0512767                 s.11                 True
# initial_seasons.12             1.5793874                 s.12                 True
# initial_seasons.13             0.0510648                 s.13                 True
# initial_seasons.14             1.0622689                 s.14                 True
# initial_seasons.15             0.6128876                 s.15                 True
# initial_seasons.16             1.3978492                 s.16                 True
# initial_seasons.17             0.0502823                 s.17                 True
# initial_seasons.18             1.6274320                 s.18                 True
# initial_seasons.19             2.5387424                 s.19                 True
# initial_seasons.20             3.9885186                 s.20                 True
# initial_seasons.21             3.6166668                 s.21                 True
# initial_seasons.22             0.0491136                 s.22                 True
# initial_seasons.23             0.0489946                 s.23                 True
# initial_seasons.24             0.0489946                 s.24                 True
# initial_seasons.25             1.5571558                 s.25                 True
# initial_seasons.26             1.6996504                 s.26                 True
# initial_seasons.27             0.4650442                 s.27                 True
# initial_seasons.28             4.6079841                 s.28                 True
# initial_seasons.29             0.5557998                 s.29                 True
# initial_seasons.30             0.0473426                 s.30                 True
# initial_seasons.31             0.0473426                 s.31                 True
# initial_seasons.32             0.5215393                 s.32                 True
# initial_seasons.33             1.9048664                 s.33                 True
# initial_seasons.34             0.5167772                 s.34                 True
# initial_seasons.35             1.7397633                 s.35                 True
# initial_seasons.36             0.0462762                 s.36                 True
# initial_seasons.37             0.0462605                 s.37                 True
# initial_seasons.38             0.0462550                 s.38                 True
# initial_seasons.39             1.2924880                 s.39                 True
# initial_seasons.40             2.7333905                 s.40                 True
# initial_seasons.41             0.4662124                 s.41                 True
# initial_seasons.42             6.8753166                 s.42                 True
# initial_seasons.43             3.0790682                 s.43                 True
# initial_seasons.44             0.0454524                 s.44                 True
# initial_seasons.45             0.0454524                 s.45                 True
# initial_seasons.46             2.7457681                 s.46                 True
# initial_seasons.47             2.8442959                 s.47                 True
# initial_seasons.48             2.1754129                 s.48                 True
# initial_seasons.49             3.0998275                 s.49                 True
# initial_seasons.50             0.1770603                 s.50                 True
# initial_seasons.51             0.0443478                 s.51                 True
# initial_seasons.52             0.0443478                 s.52                 True
# initial_seasons.53             2.2453785                 s.53                 True
# initial_seasons.54             4.0535438                 s.54                 True
# initial_seasons.55             3.4504681                 s.55                 True
# initial_seasons.56             1.8803093                 s.56                 True
# initial_seasons.57             1.4471601                 s.57                 True
# initial_seasons.58             1.8152146                 s.58                 True
# initial_seasons.59             0.0435095                 s.59                 True
# initial_seasons.60             0.0435095                 s.60                 True
# initial_seasons.61             5.5801650                 s.61                 True
# initial_seasons.62             0.5713653                 s.62                 True
# initial_seasons.63             1.0534806                 s.63                 True
# initial_seasons.64             0.3650055                 s.64                 True
# initial_seasons.65             0.0429008                 s.65                 True
# initial_seasons.66             0.0429008                 s.66                 True
# initial_seasons.67             2.6615005                 s.67                 True
# initial_seasons.68             3.4820132                 s.68                 True
# initial_seasons.69             0.4241600                 s.69                 True
# initial_seasons.70             4.3193971                 s.70                 True
# initial_seasons.71             0.9497949                 s.71                 True
# initial_seasons.72             1.1672376                 s.72                 True
# initial_seasons.73             0.0418065                 s.73                 True
# initial_seasons.74             2.3468843                 s.74                 True
# initial_seasons.75             1.3524205                 s.75                 True
# initial_seasons.76             5.4380824                 s.76                 True
# initial_seasons.77             3.5196125                 s.77                 True
# initial_seasons.78             2.8355633                 s.78                 True
# initial_seasons.79             0.0409335                 s.79                 True
# initial_seasons.80             0.0409335                 s.80                 True
# initial_seasons.81             0.6638187                 s.81                 True
# initial_seasons.82             8.0815029                 s.82                 True
# initial_seasons.83             1.9270958                 s.83                 True
# initial_seasons.84             6.1769355                 s.84                 True
# initial_seasons.85             4.0700879                 s.85                 True
# initial_seasons.86             0.0404432                 s.86                 True
# initial_seasons.87             0.0404432                 s.87                 True
# initial_seasons.88             0.4822993                 s.88                 True
# initial_seasons.89             0.7888388                 s.89                 True
# initial_seasons.90             0.8925534                 s.90                 True
# initial_seasons.91             1.8330516                 s.91                 True
# initial_seasons.92             2.6734600                 s.92                 True
# initial_seasons.93             0.0404349                 s.93                 True
# initial_seasons.94             0.0404349                 s.94                 True
# initial_seasons.95             1.0593109                 s.95                 True
# initial_seasons.96             0.9964706                 s.96                 True
# initial_seasons.97             0.0400520                 s.97                 True
# initial_seasons.98             0.5704690                 s.98                 True
# initial_seasons.99             1.1809152                 s.99                 True
# initial_seasons.100            0.0396542                s.100                 True
# initial_seasons.101            0.0396542                s.101                 True
# initial_seasons.102            3.2177284                s.102                 True
# initial_seasons.103            1.5154126                s.103                 True
# initial_seasons.104            2.4173582                s.104                 True
# initial_seasons.105            2.8700489                s.105                 True
# initial_seasons.106            1.4078336                s.106                 True
# initial_seasons.107            0.0391263                s.107                 True
# initial_seasons.108            0.0391263                s.108                 True
# initial_seasons.109            3.6084879                s.109                 True
# initial_seasons.110            0.0697047                s.110                 True
# initial_seasons.111            4.2078407                s.111                 True
# initial_seasons.112            2.1182919                s.112                 True
# initial_seasons.113            0.0391675                s.113                 True
# initial_seasons.114            0.0390628                s.114                 True
# initial_seasons.115            0.0390628                s.115                 True
# initial_seasons.116            2.6057130                s.116                 True
# initial_seasons.117            0.5157937                s.117                 True
# initial_seasons.118            3.3979149                s.118                 True
# initial_seasons.119            2.2957121                s.119                 True
# initial_seasons.120            0.0389454                s.120                 True
# initial_seasons.121            0.0388422                s.121                 True
# initial_seasons.122            0.0388422                s.122                 True
# initial_seasons.123            2.1939788                s.123                 True
# initial_seasons.124            1.4118253                s.124                 True
# initial_seasons.125            2.5303024                s.125                 True
# initial_seasons.126            0.9993236                s.126                 True
# initial_seasons.127            3.5856605                s.127                 True
# initial_seasons.128            0.0378350                s.128                 True
# initial_seasons.129            0.0377876                s.129                 True
# initial_seasons.130            0.0377035                s.130                 True
# initial_seasons.131            1.6819566                s.131                 True
# initial_seasons.132            2.3698561                s.132                 True
# initial_seasons.133            1.4103544                s.133                 True
# initial_seasons.134            0.4306457                s.134                 True
# initial_seasons.135            0.0374889                s.135                 True
# initial_seasons.136            0.0374652                s.136                 True
# initial_seasons.137            1.3767673                s.137                 True
# initial_seasons.138            2.4482615                s.138                 True
# initial_seasons.139            2.9516005                s.139                 True
# initial_seasons.140            0.8671537                s.140                 True
# initial_seasons.141            1.0802172                s.141                 True
# initial_seasons.142            0.0372489                s.142                 True
# initial_seasons.143            0.0372489                s.143                 True
# initial_seasons.144            0.0371780                s.144                 True
# initial_seasons.145            0.7877088                s.145                 True
# initial_seasons.146            1.6279611                s.146                 True
# initial_seasons.147            1.8001400                s.147                 True
# initial_seasons.148            1.7513397                s.148                 True
# initial_seasons.149            0.0370632                s.149                 True
# initial_seasons.150            0.0370632                s.150                 True
# initial_seasons.151            0.8206096                s.151                 True
# initial_seasons.152            1.4065747                s.152                 True
# initial_seasons.153            4.3421749                s.153                 True
# initial_seasons.154            2.1151791                s.154                 True
# initial_seasons.155            1.8283436                s.155                 True
# initial_seasons.156            0.0367520                s.156                 True
# initial_seasons.157            0.0367520                s.157                 True
# initial_seasons.158            0.9553138                s.158                 True
# initial_seasons.159            0.4085389                s.159                 True
# initial_seasons.160            2.3114021                s.160                 True
# initial_seasons.161            1.5336958                s.161                 True
# initial_seasons.162            0.2108393                s.162                 True
# initial_seasons.163            0.0363295                s.163                 True
# initial_seasons.164            0.0363295                s.164                 True
# initial_seasons.165            0.0362501                s.165                 True
# initial_seasons.166            1.2061976                s.166                 True
# initial_seasons.167            0.4062149                s.167                 True
# initial_seasons.168            2.7495354                s.168                 True
# initial_seasons.169            0.6075331                s.169                 True
# initial_seasons.170            0.0360690                s.170                 True
# initial_seasons.171            0.0360690                s.171                 True
# initial_seasons.172            1.1686352                s.172                 True
# initial_seasons.173            4.8711167                s.173                 True
# initial_seasons.174            2.7217658                s.174                 True
# initial_seasons.175            2.8884045                s.175                 True
# initial_seasons.176            4.4211571                s.176                 True
# initial_seasons.177            0.0360132                s.177                 True
# initial_seasons.178            0.0360132                s.178                 True
# initial_seasons.179            0.3651736                s.179                 True
# initial_seasons.180            1.7222441                s.180                 True
# initial_seasons.181            1.3067292                s.181                 True
# initial_seasons.182            2.8968516                s.182                 True
# initial_seasons.183            0.1176000                s.183                 True
# initial_seasons.184            0.1176000                s.184                 True
# initial_seasons.185            0.1176000                s.185                 True
# initial_seasons.186            0.1174162                s.186                 True
# initial_seasons.187            1.1342845                s.187                 True
# initial_seasons.188            0.1171234                s.188                 True
# initial_seasons.189            0.1166280                s.189                 True
# initial_seasons.190            0.1161368                s.190                 True
# initial_seasons.191            0.1161368                s.191                 True
# initial_seasons.192            0.1161368                s.192                 True
# initial_seasons.193            1.3669302                s.193                 True
# initial_seasons.194            0.1156411                s.194                 True
# initial_seasons.195            0.1153580                s.195                 True
# initial_seasons.196            0.1152392                s.196                 True
# initial_seasons.197            0.1147315                s.197                 True
# initial_seasons.198            0.1141174                s.198                 True
# initial_seasons.199            0.1136876                s.199                 True
# initial_seasons.200            0.1134226                s.200                 True
# initial_seasons.201            0.1123803                s.201                 True
# initial_seasons.202            0.1103990                s.202                 True
# initial_seasons.203            0.1084184                s.203                 True
# initial_seasons.204            0.9267504                s.204                 True
# initial_seasons.205            0.1076365                s.205                 True
# initial_seasons.206            0.1076365                s.206                 True
# initial_seasons.207            0.1071964                s.207                 True
# initial_seasons.208            0.1067472                s.208                 True
# initial_seasons.209            1.2495030                s.209                 True
# initial_seasons.210            0.1054843                s.210                 True
# initial_seasons.211            0.1047976                s.211                 True
# initial_seasons.212            0.1051009                s.212                 True
# initial_seasons.213            0.1051009                s.213                 True
# initial_seasons.214            0.1057072                s.214                 True
# initial_seasons.215            0.1062095                s.215                 True
# initial_seasons.216            0.8084694                s.216                 True
# initial_seasons.217            0.1054892                s.217                 True
# initial_seasons.218            0.1051602                s.218                 True
# initial_seasons.219            0.1051602                s.219                 True
# initial_seasons.220            0.1051602                s.220                 True
# initial_seasons.221            0.1053470                s.221                 True
# initial_seasons.222            0.2966444                s.222                 True
# initial_seasons.223            0.7624280                s.223                 True
# initial_seasons.224            0.1029168                s.224                 True
# initial_seasons.225            0.1005358                s.225                 True
# initial_seasons.226            0.0998001                s.226                 True
# initial_seasons.227            0.0998001                s.227                 True
# initial_seasons.228            1.8470285                s.228                 True
# initial_seasons.229            1.2142844                s.229                 True
# initial_seasons.230            0.0973410                s.230                 True
# initial_seasons.231            0.0964299                s.231                 True
# initial_seasons.232            0.0957561                s.232                 True
# initial_seasons.233            0.0957469                s.233                 True
# initial_seasons.234            0.0957469                s.234                 True
# initial_seasons.235            1.2412172                s.235                 True
# initial_seasons.236            3.8824207                s.236                 True
# initial_seasons.237            0.0921356                s.237                 True
# initial_seasons.238            5.1646400                s.238                 True
# initial_seasons.239            0.0904101                s.239                 True
# initial_seasons.240            0.0896791                s.240                 True
# initial_seasons.241            0.0892762                s.241                 True
# initial_seasons.242            0.0892762                s.242                 True
# initial_seasons.243            0.0882038                s.243                 True
# initial_seasons.244            0.0870423                s.244                 True
# initial_seasons.245            0.0867097                s.245                 True
# initial_seasons.246            0.0864809                s.246                 True
# initial_seasons.247            0.0864695                s.247                 True
# initial_seasons.248            0.0864695                s.248                 True
# initial_seasons.249            1.4466771                s.249                 True
# initial_seasons.250            1.7595818                s.250                 True
# initial_seasons.251            0.0841741                s.251                 True
# initial_seasons.252            0.0835098                s.252                 True
# initial_seasons.253            0.4148553                s.253                 True
# initial_seasons.254            0.0822791                s.254                 True
# initial_seasons.255            0.0820545                s.255                 True
# initial_seasons.256            1.8734826                s.256                 True
# initial_seasons.257            0.0810136                s.257                 True
# initial_seasons.258            0.0799182                s.258                 True
# initial_seasons.259            0.0784937                s.259                 True
# initial_seasons.260            0.0775067                s.260                 True
# initial_seasons.261            0.0770041                s.261                 True
# initial_seasons.262            0.0770041                s.262                 True
# initial_seasons.263            5.5408811                s.263                 True
# initial_seasons.264            0.0754356                s.264                 True
# initial_seasons.265            0.0738224                s.265                 True
# initial_seasons.266            6.9359710                s.266                 True
# initial_seasons.267            0.0709262                s.267                 True
# initial_seasons.268            0.0703195                s.268                 True
# initial_seasons.269            0.0703195                s.269                 True
# initial_seasons.270            0.0702528                s.270                 True
# initial_seasons.271            2.1970459                s.271                 True
# initial_seasons.272            0.7785532                s.272                 True
# initial_seasons.273            0.3949528                s.273                 True
# initial_seasons.274            0.0693712                s.274                 True
# initial_seasons.275            0.0689866                s.275                 True
# initial_seasons.276            0.0689866                s.276                 True
# initial_seasons.277            2.6849219                s.277                 True
# initial_seasons.278            5.6771456                s.278                 True
# initial_seasons.279            0.0690479                s.279                 True
# initial_seasons.280            0.6742771                s.280                 True
# initial_seasons.281            0.0698110                s.281                 True
# initial_seasons.282            0.0696383                s.282                 True
# initial_seasons.283            0.0696383                s.283                 True
# initial_seasons.284            1.1317711                s.284                 True
# initial_seasons.285            0.9107507                s.285                 True
# initial_seasons.286            0.0688259                s.286                 True
# initial_seasons.287            2.5804244                s.287                 True
# initial_seasons.288            0.0677514                s.288                 True
# initial_seasons.289            0.0675538                s.289                 True
# initial_seasons.290            0.0675538                s.290                 True
# initial_seasons.291            1.8604338                s.291                 True
# initial_seasons.292            6.6767026                s.292                 True
# initial_seasons.293            0.0673964                s.293                 True
# initial_seasons.294            2.9890917                s.294                 True
# initial_seasons.295            0.0665928                s.295                 True
# initial_seasons.296            0.0665976                s.296                 True
# initial_seasons.297            0.0665976                s.297                 True
# initial_seasons.298            0.0662486                s.298                 True
# initial_seasons.299            4.2801545                s.299                 True
# initial_seasons.300            0.0659021                s.300                 True
# initial_seasons.301            4.8033241                s.301                 True
# initial_seasons.302            0.0656963                s.302                 True
# initial_seasons.303            0.0656963                s.303                 True
# initial_seasons.304            0.0656963                s.304                 True
# initial_seasons.305            0.5657679                s.305                 True
# initial_seasons.306            0.0650825                s.306                 True
# initial_seasons.307            1.3485373                s.307                 True
# initial_seasons.308            1.8522136                s.308                 True
# initial_seasons.309            0.0643756                s.309                 True
# initial_seasons.310            0.0639002                s.310                 True
# initial_seasons.311            0.0639002                s.311                 True
# initial_seasons.312            0.0640217                s.312                 True
# initial_seasons.313            2.3139908                s.313                 True
# initial_seasons.314            0.0634376                s.314                 True
# initial_seasons.315            0.9688641                s.315                 True
# initial_seasons.316            0.0627653                s.316                 True
# initial_seasons.317            0.0627143                s.317                 True
# initial_seasons.318            0.0627143                s.318                 True
# initial_seasons.319            0.0626339                s.319                 True
# initial_seasons.320            0.0624875                s.320                 True
# initial_seasons.321            0.0620880                s.321                 True
# initial_seasons.322            0.0617797                s.322                 True
# initial_seasons.323            0.0616694                s.323                 True
# initial_seasons.324            0.0615381                s.324                 True
# initial_seasons.325            0.0615381                s.325                 True
# initial_seasons.326            0.7975336                s.326                 True
# initial_seasons.327            0.9124359                s.327                 True
# initial_seasons.328            0.9441545                s.328                 True
# initial_seasons.329            4.2501605                s.329                 True
# initial_seasons.330            1.1267176                s.330                 True
# initial_seasons.331            0.0601174                s.331                 True
# initial_seasons.332            0.0601174                s.332                 True
# initial_seasons.333            0.0600229                s.333                 True
# initial_seasons.334            1.9554982                s.334                 True
# initial_seasons.335            0.0590937                s.335                 True
# initial_seasons.336            0.5894004                s.336                 True
# initial_seasons.337            0.4604455                s.337                 True
# initial_seasons.338            0.0577165                s.338                 True
# initial_seasons.339            0.0577165                s.339                 True
# initial_seasons.340            0.5577007                s.340                 True
# initial_seasons.341            4.1646517                s.341                 True
# initial_seasons.342            0.0577585                s.342                 True
# initial_seasons.343            1.9053190                s.343                 True
# initial_seasons.344            1.1524567                s.344                 True
# initial_seasons.345            0.0573737                s.345                 True
# initial_seasons.346            0.0573737                s.346                 True
# initial_seasons.347            0.0574358                s.347                 True
# initial_seasons.348            1.6705085                s.348                 True
# initial_seasons.349            0.0574126                s.349                 True
# initial_seasons.350            0.0572847                s.350                 True
# initial_seasons.351            1.5236979                s.351                 True
# initial_seasons.352            0.0568548                s.352                 True
# initial_seasons.353            0.0568548                s.353                 True
# initial_seasons.354            0.0567296                s.354                 True
# initial_seasons.355            0.0560790                s.355                 True
# initial_seasons.356            0.0552801                s.356                 True
# initial_seasons.357            0.0547574                s.357                 True
# initial_seasons.358            0.0540734                s.358                 True
# initial_seasons.359            0.0536372                s.359                 True
# initial_seasons.360            0.0536372                s.360                 True
# initial_seasons.361            0.0536047                s.361                 True
# initial_seasons.362            0.6205870                s.362                 True
# initial_seasons.363            0.5424092                s.363                 True
# ----------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m364'] = hw_m364.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  chan_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    23.467663         1.0
# 2020-01-02             4         40.29  0.232275    23.467663         1.0
#
#                  seasonal_52  seasonal_364       ses     hw_m52    hw_m364
# Date_of_Payment
# 2020-01-01              1.00         28.50  1.036303  23.179055  77.201856
# 2020-01-02             38.53         45.81  1.036303  26.224680  69.074338

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['chan_dollars'], label='Train')
plt.plot(test.index, test['chan_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m364'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative with Seasonality of 364 for Chantix Daily Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 364 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['hw_m364']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 364 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['hw_m364'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 364 Model: 131.30663273581757
# RMSE for Holt-Winters Multiplicative with Seasonality of 364 Model: 198.3559925482941

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 52.

# %%
hw_a52 = ExponentialSmoothing(
    train['chan_dollars'],
    seasonal_periods=52, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a52.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             chan_dollars   No. Observations:                 1091
# Model:             ExponentialSmoothing   SSE                         995159.012
# Optimized:                         True   AIC                           7548.046
# Trend:                         Additive   BIC                           7827.758
# Seasonal:                      Additive   AICC                          7554.678
# Seasonal Periods:                    52   Date:                 Mon, 14 Mar 2022
# Box-Cox:                          False   Time:                         00:27:15
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0552436                alpha                 True
# smoothing_trend               0.0005478                 beta                 True
# smoothing_seasonal            0.0502419                gamma                 True
# initial_level                 5.6475119                  l.0                 True
# initial_trend                 0.0161437                  b.0                 True
# initial_seasons.0             1.0527799                  s.0                 True
# initial_seasons.1             5.8600941                  s.1                 True
# initial_seasons.2            -4.6937142                  s.2                 True
# initial_seasons.3             14.246193                  s.3                 True
# initial_seasons.4            -9.2112693                  s.4                 True
# initial_seasons.5             0.6841516                  s.5                 True
# initial_seasons.6             7.4867381                  s.6                 True
# initial_seasons.7            -0.3483304                  s.7                 True
# initial_seasons.8             0.3480021                  s.8                 True
# initial_seasons.9            -6.4806098                  s.9                 True
# initial_seasons.10           -15.472627                 s.10                 True
# initial_seasons.11           -6.1057419                 s.11                 True
# initial_seasons.12           -4.0972451                 s.12                 True
# initial_seasons.13           -11.286140                 s.13                 True
# initial_seasons.14            1.4625678                 s.14                 True
# initial_seasons.15           -1.8508549                 s.15                 True
# initial_seasons.16           -5.9758610                 s.16                 True
# initial_seasons.17            3.7673421                 s.17                 True
# initial_seasons.18            21.112350                 s.18                 True
# initial_seasons.19           -5.7781827                 s.19                 True
# initial_seasons.20            5.9102343                 s.20                 True
# initial_seasons.21           -1.3551873                 s.21                 True
# initial_seasons.22           -1.4887504                 s.22                 True
# initial_seasons.23            3.4744082                 s.23                 True
# initial_seasons.24            2.0251351                 s.24                 True
# initial_seasons.25            3.8891201                 s.25                 True
# initial_seasons.26           -3.2494472                 s.26                 True
# initial_seasons.27            2.4823102                 s.27                 True
# initial_seasons.28            5.4058256                 s.28                 True
# initial_seasons.29            5.7548179                 s.29                 True
# initial_seasons.30            5.8603689                 s.30                 True
# initial_seasons.31            3.7297750                 s.31                 True
# initial_seasons.32            5.4851258                 s.32                 True
# initial_seasons.33            4.0567934                 s.33                 True
# initial_seasons.34           -3.1496722                 s.34                 True
# initial_seasons.35           -0.9159115                 s.35                 True
# initial_seasons.36           -6.3006298                 s.36                 True
# initial_seasons.37           -11.781021                 s.37                 True
# initial_seasons.38            1.2750941                 s.38                 True
# initial_seasons.39            2.7024357                 s.39                 True
# initial_seasons.40           -1.5665904                 s.40                 True
# initial_seasons.41            0.5892931                 s.41                 True
# initial_seasons.42           -1.1048612                 s.42                 True
# initial_seasons.43            0.0102455                 s.43                 True
# initial_seasons.44           -6.2782337                 s.44                 True
# initial_seasons.45           -5.3615440                 s.45                 True
# initial_seasons.46            6.9624012                 s.46                 True
# initial_seasons.47            1.5827559                 s.47                 True
# initial_seasons.48            3.1207090                 s.48                 True
# initial_seasons.49           -2.8959150                 s.49                 True
# initial_seasons.50           -6.0064934                 s.50                 True
# initial_seasons.51           -0.6673361                 s.51                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a52'] = hw_a52.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  chan_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    23.467663         1.0
# 2020-01-02             4         40.29  0.232275    23.467663         1.0
#
#                  seasonal_52  seasonal_364       ses     hw_m52    hw_m364  \
# Date_of_Payment
# 2020-01-01              1.00         28.50  1.036303  23.179055  77.201856
# 2020-01-02             38.53         45.81  1.036303  26.224680  69.074338
#
#                     hw_a52
# Date_of_Payment
# 2020-01-01       21.655418
# 2020-01-02       24.767380

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['chan_dollars'], label='Train')
plt.plot(test.index, test['chan_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a52'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 52 for Daily Chantix Payments");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 52 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['hw_a52']))
print("RMSE for Holt-Winters Additive with Seasonality of 52 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['hw_a52'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 52 Model: 23.31989515284185
# RMSE for Holt-Winters Additive with Seasonality of 52 Model: 28.48139915097091

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 7.

# %%
hw_a7 = ExponentialSmoothing(
    train['chan_dollars'],
    seasonal_periods=7, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             chan_dollars   No. Observations:                 1091
# Model:             ExponentialSmoothing   SSE                         776560.734
# Optimized:                         True   AIC                           7187.448
# Trend:                         Additive   BIC                           7242.391
# Seasonal:                      Additive   AICC                          7187.786
# Seasonal Periods:                     7   Date:                 Mon, 14 Mar 2022
# Box-Cox:                          False   Time:                         00:27:17
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.0391086                alpha                 True
# smoothing_trend               0.0074876                 beta                 True
# smoothing_seasonal            0.0704030                gamma                 True
# initial_level                 4.8825579                  l.0                 True
# initial_trend                 0.0359827                  b.0                 True
# initial_seasons.0             6.1304292                  s.0                 True
# initial_seasons.1            -4.1315460                  s.1                 True
# initial_seasons.2            -7.7648790                  s.2                 True
# initial_seasons.3            -7.7378417                  s.3                 True
# initial_seasons.4             4.3154988                  s.4                 True
# initial_seasons.5             8.7224310                  s.5                 True
# initial_seasons.6             4.4858057                  s.6                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a7'] = hw_a7.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  chan_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    23.467663         1.0
# 2020-01-02             4         40.29  0.232275    23.467663         1.0
#
#                  seasonal_52  seasonal_364       ses     hw_m52    hw_m364  \
# Date_of_Payment
# 2020-01-01              1.00         28.50  1.036303  23.179055  77.201856
# 2020-01-02             38.53         45.81  1.036303  26.224680  69.074338
#
#                     hw_a52      hw_a7
# Date_of_Payment
# 2020-01-01       21.655418  40.624485
# 2020-01-02       24.767380  26.361581

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['chan_dollars'], label='Train')
plt.plot(test.index, test['chan_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a7'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 7 for Daily Payments for Chantix");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 7 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['hw_a7']))
print("RMSE for Holt-Winters Additive with Seasonality of 7 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['hw_a7'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 7 Model: 20.59799117644779
# RMSE for Holt-Winters Additive with Seasonality of 7 Model: 25.688543607105416

# %%
hw_a364 = ExponentialSmoothing(
    train['chan_dollars'],
    seasonal_periods=364, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a364.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             chan_dollars   No. Observations:                 1091
# Model:             ExponentialSmoothing   SSE                         661745.208
# Optimized:                         True   AIC                           7726.894
# Trend:                         Additive   BIC                           9564.999
# Seasonal:                      Additive   AICC                          8108.200
# Seasonal Periods:                   364   Date:                 Mon, 14 Mar 2022
# Box-Cox:                          False   Time:                         00:27:18
# Box-Cox Coeff.:                    None
# ==================================================================================
#                            coeff                 code              optimized
# ----------------------------------------------------------------------------------
# smoothing_level                0.2042098                alpha                 True
# smoothing_trend                0.0003401                 beta                 True
# smoothing_seasonal             0.1715187                gamma                 True
# initial_level                  34.566217                  l.0                 True
# initial_trend                  0.0032106                  b.0                 True
# initial_seasons.0             -1.0402616                  s.0                 True
# initial_seasons.1             -13.878944                  s.1                 True
# initial_seasons.2             -16.138217                  s.2                 True
# initial_seasons.3             -15.982363                  s.3                 True
# initial_seasons.4             -1.7478932                  s.4                 True
# initial_seasons.5             -14.558414                  s.5                 True
# initial_seasons.6              4.9717352                  s.6                 True
# initial_seasons.7              6.8739502                  s.7                 True
# initial_seasons.8             -3.5237261                  s.8                 True
# initial_seasons.9             -16.562978                  s.9                 True
# initial_seasons.10            -16.390586                 s.10                 True
# initial_seasons.11            -15.974105                 s.11                 True
# initial_seasons.12             0.6739650                 s.12                 True
# initial_seasons.13            -11.632855                 s.13                 True
# initial_seasons.14            -7.8788787                 s.14                 True
# initial_seasons.15             9.1352727                 s.15                 True
# initial_seasons.16            -5.3787229                 s.16                 True
# initial_seasons.17            -15.832025                 s.17                 True
# initial_seasons.18             1.9759757                 s.18                 True
# initial_seasons.19             6.6025959                 s.19                 True
# initial_seasons.20             40.404652                 s.20                 True
# initial_seasons.21             19.102685                 s.21                 True
# initial_seasons.22            -8.6396107                 s.22                 True
# initial_seasons.23            -15.504657                 s.23                 True
# initial_seasons.24            -15.492850                 s.24                 True
# initial_seasons.25             7.7781397                 s.25                 True
# initial_seasons.26             37.995082                 s.26                 True
# initial_seasons.27            -12.469762                 s.27                 True
# initial_seasons.28             50.597701                 s.28                 True
# initial_seasons.29            -0.3881523                 s.29                 True
# initial_seasons.30            -15.660756                 s.30                 True
# initial_seasons.31            -15.497434                 s.31                 True
# initial_seasons.32             23.816469                 s.32                 True
# initial_seasons.33             19.276531                 s.33                 True
# initial_seasons.34             0.1734977                 s.34                 True
# initial_seasons.35             11.579427                 s.35                 True
# initial_seasons.36            -8.9004423                 s.36                 True
# initial_seasons.37            -15.092884                 s.37                 True
# initial_seasons.38            -14.889614                 s.38                 True
# initial_seasons.39             13.362422                 s.39                 True
# initial_seasons.40             39.202107                 s.40                 True
# initial_seasons.41             3.9472509                 s.41                 True
# initial_seasons.42             52.715256                 s.42                 True
# initial_seasons.43             29.022591                 s.43                 True
# initial_seasons.44            -14.411684                 s.44                 True
# initial_seasons.45            -14.215758                 s.45                 True
# initial_seasons.46             26.740954                 s.46                 True
# initial_seasons.47             24.636445                 s.47                 True
# initial_seasons.48             52.046045                 s.48                 True
# initial_seasons.49             27.243657                 s.49                 True
# initial_seasons.50            -12.880287                 s.50                 True
# initial_seasons.51            -14.610276                 s.51                 True
# initial_seasons.52            -14.409579                 s.52                 True
# initial_seasons.53             28.161484                 s.53                 True
# initial_seasons.54             34.061493                 s.54                 True
# initial_seasons.55             43.477061                 s.55                 True
# initial_seasons.56             15.467664                 s.56                 True
# initial_seasons.57             25.905556                 s.57                 True
# initial_seasons.58             0.3658981                 s.58                 True
# initial_seasons.59            -15.613401                 s.59                 True
# initial_seasons.60            -11.032312                 s.60                 True
# initial_seasons.61             47.912783                 s.61                 True
# initial_seasons.62            -6.8809231                 s.62                 True
# initial_seasons.63             1.2723544                 s.63                 True
# initial_seasons.64             4.9218493                 s.64                 True
# initial_seasons.65            -15.545975                 s.65                 True
# initial_seasons.66            -15.377404                 s.66                 True
# initial_seasons.67             14.947738                 s.67                 True
# initial_seasons.68             23.469407                 s.68                 True
# initial_seasons.69             8.2017167                 s.69                 True
# initial_seasons.70             46.704046                 s.70                 True
# initial_seasons.71            -2.8075278                 s.71                 True
# initial_seasons.72            -4.7212806                 s.72                 True
# initial_seasons.73            -15.263468                 s.73                 True
# initial_seasons.74             10.687455                 s.74                 True
# initial_seasons.75             26.905291                 s.75                 True
# initial_seasons.76             52.342039                 s.76                 True
# initial_seasons.77             30.785382                 s.77                 True
# initial_seasons.78             11.606157                 s.78                 True
# initial_seasons.79            -5.5925413                 s.79                 True
# initial_seasons.80            -15.869695                 s.80                 True
# initial_seasons.81             4.7529608                 s.81                 True
# initial_seasons.82             71.605375                 s.82                 True
# initial_seasons.83             4.6413926                 s.83                 True
# initial_seasons.84             46.933892                 s.84                 True
# initial_seasons.85             35.197004                 s.85                 True
# initial_seasons.86            -16.773396                 s.86                 True
# initial_seasons.87            -16.783625                 s.87                 True
# initial_seasons.88            -0.2193999                 s.88                 True
# initial_seasons.89            -5.5405875                 s.89                 True
# initial_seasons.90             6.7614260                 s.90                 True
# initial_seasons.91             12.750104                 s.91                 True
# initial_seasons.92             23.779946                 s.92                 True
# initial_seasons.93            -17.670803                 s.93                 True
# initial_seasons.94            -17.685416                 s.94                 True
# initial_seasons.95             11.645882                 s.95                 True
# initial_seasons.96            -0.8678338                 s.96                 True
# initial_seasons.97            -0.9726465                 s.97                 True
# initial_seasons.98             32.081918                 s.98                 True
# initial_seasons.99             3.5147684                 s.99                 True
# initial_seasons.100           -17.987548                s.100                 True
# initial_seasons.101           -17.969018                s.101                 True
# initial_seasons.102            46.980250                s.102                 True
# initial_seasons.103            12.810665                s.103                 True
# initial_seasons.104            14.597299                s.104                 True
# initial_seasons.105            19.517781                s.105                 True
# initial_seasons.106            1.8352154                s.106                 True
# initial_seasons.107           -18.268873                s.107                 True
# initial_seasons.108           -18.273404                s.108                 True
# initial_seasons.109            25.481525                s.109                 True
# initial_seasons.110            31.364325                s.110                 True
# initial_seasons.111            41.637135                s.111                 True
# initial_seasons.112            24.097899                s.112                 True
# initial_seasons.113           -11.224864                s.113                 True
# initial_seasons.114           -18.408155                s.114                 True
# initial_seasons.115           -18.408867                s.115                 True
# initial_seasons.116            8.2578344                s.116                 True
# initial_seasons.117           -9.6696501                s.117                 True
# initial_seasons.118            52.420768                s.118                 True
# initial_seasons.119            18.816594                s.119                 True
# initial_seasons.120           -17.710805                s.120                 True
# initial_seasons.121           -17.721347                s.121                 True
# initial_seasons.122           -17.717891                s.122                 True
# initial_seasons.123            13.356522                s.123                 True
# initial_seasons.124            16.152875                s.124                 True
# initial_seasons.125            37.775594                s.125                 True
# initial_seasons.126           -4.6565848                s.126                 True
# initial_seasons.127            29.802041                s.127                 True
# initial_seasons.128           -18.124933                s.128                 True
# initial_seasons.129           -18.126227                s.129                 True
# initial_seasons.130           -2.5834920                s.130                 True
# initial_seasons.131            10.139130                s.131                 True
# initial_seasons.132            10.018062                s.132                 True
# initial_seasons.133            20.094090                s.133                 True
# initial_seasons.134           -14.888811                s.134                 True
# initial_seasons.135           -19.033508                s.135                 True
# initial_seasons.136           -19.012838                s.136                 True
# initial_seasons.137            7.9958376                s.137                 True
# initial_seasons.138            28.428930                s.138                 True
# initial_seasons.139            15.249686                s.139                 True
# initial_seasons.140            4.4207242                s.140                 True
# initial_seasons.141           -2.9438917                s.141                 True
# initial_seasons.142           -18.731940                s.142                 True
# initial_seasons.143           -18.699601                s.143                 True
# initial_seasons.144           -18.666472                s.144                 True
# initial_seasons.145            7.0046532                s.145                 True
# initial_seasons.146            5.0920730                s.146                 True
# initial_seasons.147            28.846131                s.147                 True
# initial_seasons.148            12.879196                s.148                 True
# initial_seasons.149           -20.301373                s.149                 True
# initial_seasons.150           -20.250180                s.150                 True
# initial_seasons.151            4.7301956                s.151                 True
# initial_seasons.152           -3.4799818                s.152                 True
# initial_seasons.153            31.713999                s.153                 True
# initial_seasons.154            1.5283374                s.154                 True
# initial_seasons.155           -1.5226826                s.155                 True
# initial_seasons.156           -20.826574                s.156                 True
# initial_seasons.157           -20.809292                s.157                 True
# initial_seasons.158           -10.876002                s.158                 True
# initial_seasons.159            10.761746                s.159                 True
# initial_seasons.160            4.2633825                s.160                 True
# initial_seasons.161            6.2764860                s.161                 True
# initial_seasons.162           -18.197471                s.162                 True
# initial_seasons.163           -20.067216                s.163                 True
# initial_seasons.164           -20.023890                s.164                 True
# initial_seasons.165           -10.831039                s.165                 True
# initial_seasons.166           -4.2438756                s.166                 True
# initial_seasons.167            13.664746                s.167                 True
# initial_seasons.168            10.001011                s.168                 True
# initial_seasons.169           -4.9342886                s.169                 True
# initial_seasons.170           -19.888080                s.170                 True
# initial_seasons.171           -19.802674                s.171                 True
# initial_seasons.172           -7.2639598                s.172                 True
# initial_seasons.173            48.750010                s.173                 True
# initial_seasons.174            16.731370                s.174                 True
# initial_seasons.175            22.108849                s.175                 True
# initial_seasons.176            30.446365                s.176                 True
# initial_seasons.177           -20.286138                s.177                 True
# initial_seasons.178           -20.244959                s.178                 True
# initial_seasons.179            0.1833056                s.179                 True
# initial_seasons.180            15.318321                s.180                 True
# initial_seasons.181            3.5757960                s.181                 True
# initial_seasons.182           -0.0233161                s.182                 True
# initial_seasons.183           -4.6676331                s.183                 True
# initial_seasons.184           -18.525051                s.184                 True
# initial_seasons.185           -18.450250                s.185                 True
# initial_seasons.186            17.377190                s.186                 True
# initial_seasons.187            26.181031                s.187                 True
# initial_seasons.188            0.8648931                s.188                 True
# initial_seasons.189            16.420771                s.189                 True
# initial_seasons.190            17.442235                s.190                 True
# initial_seasons.191           -3.7128298                s.191                 True
# initial_seasons.192           -20.550322                s.192                 True
# initial_seasons.193           -4.2473216                s.193                 True
# initial_seasons.194           -2.9895117                s.194                 True
# initial_seasons.195            11.255995                s.195                 True
# initial_seasons.196            3.5807167                s.196                 True
# initial_seasons.197           -3.9061128                s.197                 True
# initial_seasons.198           -21.654837                s.198                 True
# initial_seasons.199           -21.525995                s.199                 True
# initial_seasons.200           -2.2666158                s.200                 True
# initial_seasons.201            17.685600                s.201                 True
# initial_seasons.202            1.8651061                s.202                 True
# initial_seasons.203           -6.4967345                s.203                 True
# initial_seasons.204           -5.1145348                s.204                 True
# initial_seasons.205           -22.054083                s.205                 True
# initial_seasons.206           -21.904613                s.206                 True
# initial_seasons.207            17.769222                s.207                 True
# initial_seasons.208            11.623005                s.208                 True
# initial_seasons.209            39.518585                s.209                 True
# initial_seasons.210           -0.5361569                s.210                 True
# initial_seasons.211            22.274226                s.211                 True
# initial_seasons.212           -24.043904                s.212                 True
# initial_seasons.213           -23.873335                s.213                 True
# initial_seasons.214           -4.5479476                s.214                 True
# initial_seasons.215           -0.3601111                s.215                 True
# initial_seasons.216            20.112354                s.216                 True
# initial_seasons.217           -2.5783658                s.217                 True
# initial_seasons.218           -22.635100                s.218                 True
# initial_seasons.219           -21.404565                s.219                 True
# initial_seasons.220           -23.483814                s.220                 True
# initial_seasons.221            1.3980186                s.221                 True
# initial_seasons.222           -4.4906303                s.222                 True
# initial_seasons.223           -3.0320151                s.223                 True
# initial_seasons.224           -18.784449                s.224                 True
# initial_seasons.225           -14.916063                s.225                 True
# initial_seasons.226           -16.739275                s.226                 True
# initial_seasons.227           -24.006780                s.227                 True
# initial_seasons.228           -15.829761                s.228                 True
# initial_seasons.229            6.0924704                s.229                 True
# initial_seasons.230            20.768331                s.230                 True
# initial_seasons.231           -5.9285535                s.231                 True
# initial_seasons.232           -7.5192451                s.232                 True
# initial_seasons.233           -8.0601321                s.233                 True
# initial_seasons.234           -24.071606                s.234                 True
# initial_seasons.235            30.095398                s.235                 True
# initial_seasons.236            26.957499                s.236                 True
# initial_seasons.237            26.107693                s.237                 True
# initial_seasons.238            30.740106                s.238                 True
# initial_seasons.239           -18.397364                s.239                 True
# initial_seasons.240           -24.793212                s.240                 True
# initial_seasons.241           -24.629263                s.241                 True
# initial_seasons.242           -24.461369                s.242                 True
# initial_seasons.243            5.2980963                s.243                 True
# initial_seasons.244           -0.8941099                s.244                 True
# initial_seasons.245           -19.236587                s.245                 True
# initial_seasons.246            14.852668                s.246                 True
# initial_seasons.247           -25.323728                s.247                 True
# initial_seasons.248           -25.150222                s.248                 True
# initial_seasons.249            13.535347                s.249                 True
# initial_seasons.250            16.068458                s.250                 True
# initial_seasons.251            1.2137379                s.251                 True
# initial_seasons.252            9.3911988                s.252                 True
# initial_seasons.253           -1.1492406                s.253                 True
# initial_seasons.254           -8.6579043                s.254                 True
# initial_seasons.255           -26.038369                s.255                 True
# initial_seasons.256            14.616033                s.256                 True
# initial_seasons.257           -7.1143910                s.257                 True
# initial_seasons.258           -12.614449                s.258                 True
# initial_seasons.259            6.6676259                s.259                 True
# initial_seasons.260            10.541871                s.260                 True
# initial_seasons.261           -26.829515                s.261                 True
# initial_seasons.262           -26.662163                s.262                 True
# initial_seasons.263            34.725998                s.263                 True
# initial_seasons.264           -25.905800                s.264                 True
# initial_seasons.265            10.994412                s.265                 True
# initial_seasons.266            61.950429                s.266                 True
# initial_seasons.267           -7.3711015                s.267                 True
# initial_seasons.268           -26.048260                s.268                 True
# initial_seasons.269           -25.899385                s.269                 True
# initial_seasons.270           -12.966648                s.270                 True
# initial_seasons.271           -0.6191481                s.271                 True
# initial_seasons.272           -8.5022259                s.272                 True
# initial_seasons.273           -13.799879                s.273                 True
# initial_seasons.274            2.2726883                s.274                 True
# initial_seasons.275           -26.397846                s.275                 True
# initial_seasons.276           -26.252261                s.276                 True
# initial_seasons.277            15.641444                s.277                 True
# initial_seasons.278            69.272414                s.278                 True
# initial_seasons.279           -14.806878                s.279                 True
# initial_seasons.280            14.832921                s.280                 True
# initial_seasons.281           -19.901426                s.281                 True
# initial_seasons.282           -25.736155                s.282                 True
# initial_seasons.283           -25.601054                s.283                 True
# initial_seasons.284            3.0091302                s.284                 True
# initial_seasons.285            4.5652594                s.285                 True
# initial_seasons.286           -14.106664                s.286                 True
# initial_seasons.287            25.506714                s.287                 True
# initial_seasons.288           -17.168044                s.288                 True
# initial_seasons.289           -25.582895                s.289                 True
# initial_seasons.290           -25.448907                s.290                 True
# initial_seasons.291            23.173424                s.291                 True
# initial_seasons.292            35.963420                s.292                 True
# initial_seasons.293            1.9512913                s.293                 True
# initial_seasons.294            3.7225737                s.294                 True
# initial_seasons.295           -5.5604868                s.295                 True
# initial_seasons.296           -18.009972                s.296                 True
# initial_seasons.297           -25.043907                s.297                 True
# initial_seasons.298            15.604835                s.298                 True
# initial_seasons.299            29.690014                s.299                 True
# initial_seasons.300           -8.1747320                s.300                 True
# initial_seasons.301            28.410838                s.301                 True
# initial_seasons.302           -9.3211888                s.302                 True
# initial_seasons.303           -25.039006                s.303                 True
# initial_seasons.304           -24.893816                s.304                 True
# initial_seasons.305           -1.7769303                s.305                 True
# initial_seasons.306            23.165316                s.306                 True
# initial_seasons.307            33.035487                s.307                 True
# initial_seasons.308            3.5525359                s.308                 True
# initial_seasons.309           -1.7969488                s.309                 True
# initial_seasons.310           -17.781315                s.310                 True
# initial_seasons.311           -25.324118                s.311                 True
# initial_seasons.312           -1.8107334                s.312                 True
# initial_seasons.313            14.463954                s.313                 True
# initial_seasons.314           -9.3547406                s.314                 True
# initial_seasons.315            19.620795                s.315                 True
# initial_seasons.316           -9.4754419                s.316                 True
# initial_seasons.317           -22.257948                s.317                 True
# initial_seasons.318           -26.006427                s.318                 True
# initial_seasons.319           -8.0915022                s.319                 True
# initial_seasons.320            9.2120464                s.320                 True
# initial_seasons.321           -22.445921                s.321                 True
# initial_seasons.322           -24.122684                s.322                 True
# initial_seasons.323           -3.1047292                s.323                 True
# initial_seasons.324           -12.585699                s.324                 True
# initial_seasons.325           -26.838461                s.325                 True
# initial_seasons.326            2.3827731                s.326                 True
# initial_seasons.327           -3.6281735                s.327                 True
# initial_seasons.328            17.395761                s.328                 True
# initial_seasons.329            17.080956                s.329                 True
# initial_seasons.330            50.888483                s.330                 True
# initial_seasons.331           -27.743227                s.331                 True
# initial_seasons.332           -27.542573                s.332                 True
# initial_seasons.333           -12.853525                s.333                 True
# initial_seasons.334            17.667362                s.334                 True
# initial_seasons.335            10.172711                s.335                 True
# initial_seasons.336           -8.8495739                s.336                 True
# initial_seasons.337            6.9257245                s.337                 True
# initial_seasons.338           -28.561298                s.338                 True
# initial_seasons.339           -28.369555                s.339                 True
# initial_seasons.340            7.0340794                s.340                 True
# initial_seasons.341            31.933903                s.341                 True
# initial_seasons.342           -12.352200                s.342                 True
# initial_seasons.343            24.722728                s.343                 True
# initial_seasons.344           -9.9915684                s.344                 True
# initial_seasons.345           -27.750338                s.345                 True
# initial_seasons.346           -27.582382                s.346                 True
# initial_seasons.347           -13.426095                s.347                 True
# initial_seasons.348           -1.6979433                s.348                 True
# initial_seasons.349           -7.7763821                s.349                 True
# initial_seasons.350           -5.7767602                s.350                 True
# initial_seasons.351           -0.9170964                s.351                 True
# initial_seasons.352           -27.500806                s.352                 True
# initial_seasons.353           -27.353577                s.353                 True
# initial_seasons.354           -24.692282                s.354                 True
# initial_seasons.355           -27.157347                s.355                 True
# initial_seasons.356           -27.049197                s.356                 True
# initial_seasons.357           -26.929483                s.357                 True
# initial_seasons.358           -21.836072                s.358                 True
# initial_seasons.359           -26.710048                s.359                 True
# initial_seasons.360           -26.578350                s.360                 True
# initial_seasons.361           -26.448516                s.361                 True
# initial_seasons.362           -21.481440                s.362                 True
# initial_seasons.363           -6.0304187                s.363                 True
# ----------------------------------------------------------------------------------
# """

# %%
df_preds['hw_a364'] = hw_a364.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  chan_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    23.467663         1.0
# 2020-01-02             4         40.29  0.232275    23.467663         1.0
#
#                  seasonal_52  seasonal_364       ses     hw_m52    hw_m364  \
# Date_of_Payment
# 2020-01-01              1.00         28.50  1.036303  23.179055  77.201856
# 2020-01-02             38.53         45.81  1.036303  26.224680  69.074338
#
#                     hw_a52      hw_a7    hw_a364
# Date_of_Payment
# 2020-01-01       21.655418  40.624485  20.931954
# 2020-01-02       24.767380  26.361581  23.425518

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['chan_dollars'], label='Train')
plt.plot(test.index, test['chan_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a364'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 364 for Daily Payments for Chantix");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 364 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['hw_a364']))
print("RMSE for Holt-Winters Additive with Seasonality of 364 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['hw_a364'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 364 Model: 23.39989224189589
# RMSE for Holt-Winters Additive with Seasonality of 364 Model: 30.864830546413515

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 7.

# %%
hw_m7 = ExponentialSmoothing(
    train['chan_dollars'],
    seasonal_periods=7, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err

# %%
hw_m7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:             chan_dollars   No. Observations:                 1091
# Model:             ExponentialSmoothing   SSE                         796295.713
# Optimized:                         True   AIC                           7214.828
# Trend:                   Multiplicative   BIC                           7269.771
# Seasonal:                Multiplicative   AICC                          7215.166
# Seasonal Periods:                     7   Date:                 Mon, 14 Mar 2022
# Box-Cox:                          False   Time:                         00:27:19
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.1121506                alpha                 True
# smoothing_trend               0.0491242                 beta                 True
# smoothing_seasonal            0.0045225                gamma                 True
# initial_level                 2.1388805                  l.0                 True
# initial_trend                 1.1890999                  b.0                 True
# initial_seasons.0             2.9427478                  s.0                 True
# initial_seasons.1             2.7486680                  s.1                 True
# initial_seasons.2             1.2063073                  s.2                 True
# initial_seasons.3             0.2660466                  s.3                 True
# initial_seasons.4             2.4426964                  s.4                 True
# initial_seasons.5             2.8544967                  s.5                 True
# initial_seasons.6             3.1468663                  s.6                 True
# ---------------------------------------------------------------------------------
# """

# %%
df_preds['hw_m7'] = hw_m7.forecast(len(test))
df_preds.head(2)
# Out:
#                  chantix  chan_dollars   z_score  simple_mean  seasonal_7  \
# Date_of_Payment
# 2020-01-01             0          1.00  0.000000    23.467663         1.0
# 2020-01-02             4         40.29  0.232275    23.467663         1.0
#
#                  seasonal_52  seasonal_364       ses     hw_m52    hw_m364  \
# Date_of_Payment
# 2020-01-01              1.00         28.50  1.036303  23.179055  77.201856
# 2020-01-02             38.53         45.81  1.036303  26.224680  69.074338
#
#                     hw_a52      hw_a7    hw_a364      hw_m7
# Date_of_Payment
# 2020-01-01       21.655418  40.624485  20.931954  10.628392
# 2020-01-02       24.767380  26.361581  23.425518  10.029518

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['chan_dollars'], label='Train')
plt.plot(test.index, test['chan_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m7'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 7 Model for Chantix Daily Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 7 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['hw_m7']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 7 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['hw_m7'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 7 Model: 16.397713006027285
# RMSE for Holt-Winters Multiplicative with Seasonality of 7 Model: 30.729188448467742

# %% [markdown]
# Beats seasonal 52 and baseline mean models, but prediction curve just looks all wrong!

# %% [markdown]
# Try a SARIMA Model

# %%
from pmdarima.utils import tsdisplay

# %%
traina = train['chan_dollars']

# %%
tsdisplay(traina)
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\pmdarima\utils\visualization.py:220: FutureWarning: the 'unbiased'' keyword is deprecated, use 'adjusted' instead
#   res = tsaplots.plot_acf(

# %%
import pmdarima as pmd
model_s7 = pmd.auto_arima(train['chan_dollars'], m=7, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=2.53 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=11101.373, Time=0.02 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=10786.318, Time=0.29 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=10460.674, Time=0.51 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=11099.374, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,0)[7] intercept   : AIC=10533.479, Time=0.20 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=1.57 sec
#  ARIMA(0,1,1)(0,0,2)[7] intercept   : AIC=10432.196, Time=4.05 sec
#  ARIMA(0,1,1)(1,0,2)[7] intercept   : AIC=inf, Time=7.13 sec
#  ARIMA(0,1,0)(0,0,2)[7] intercept   : AIC=11052.589, Time=0.46 sec
#  ARIMA(1,1,1)(0,0,2)[7] intercept   : AIC=inf, Time=2.72 sec
#  ARIMA(0,1,2)(0,0,2)[7] intercept   : AIC=10425.725, Time=3.43 sec
#  ARIMA(0,1,2)(0,0,1)[7] intercept   : AIC=10453.157, Time=0.86 sec
#  ARIMA(0,1,2)(1,0,2)[7] intercept   : AIC=inf, Time=4.82 sec
#  ARIMA(0,1,2)(1,0,1)[7] intercept   : AIC=inf, Time=1.61 sec
#  ARIMA(1,1,2)(0,0,2)[7] intercept   : AIC=10436.196, Time=3.65 sec
#  ARIMA(0,1,3)(0,0,2)[7] intercept   : AIC=10423.565, Time=4.43 sec
#  ARIMA(0,1,3)(0,0,1)[7] intercept   : AIC=10452.256, Time=0.82 sec
#  ARIMA(0,1,3)(1,0,2)[7] intercept   : AIC=inf, Time=13.21 sec
#  ARIMA(0,1,3)(1,0,1)[7] intercept   : AIC=inf, Time=1.72 sec
#  ARIMA(1,1,3)(0,0,2)[7] intercept   : AIC=10421.331, Time=6.17 sec
#  ARIMA(1,1,3)(0,0,1)[7] intercept   : AIC=10445.713, Time=1.22 sec
#  ARIMA(1,1,3)(1,0,2)[7] intercept   : AIC=inf, Time=10.08 sec
#  ARIMA(1,1,3)(1,0,1)[7] intercept   : AIC=inf, Time=1.82 sec
#  ARIMA(2,1,3)(0,0,2)[7] intercept   : AIC=10423.255, Time=8.46 sec
#  ARIMA(1,1,4)(0,0,2)[7] intercept   : AIC=10422.899, Time=8.09 sec
#  ARIMA(0,1,4)(0,0,2)[7] intercept   : AIC=10422.624, Time=4.66 sec
#  ARIMA(2,1,2)(0,0,2)[7] intercept   : AIC=10421.411, Time=5.73 sec
#  ARIMA(2,1,4)(0,0,2)[7] intercept   : AIC=inf, Time=12.18 sec
#  ARIMA(1,1,3)(0,0,2)[7]             : AIC=10420.264, Time=3.12 sec
#  ARIMA(1,1,3)(0,0,1)[7]             : AIC=10444.516, Time=0.79 sec
#  ARIMA(1,1,3)(1,0,2)[7]             : AIC=inf, Time=8.55 sec
#  ARIMA(1,1,3)(1,0,1)[7]             : AIC=inf, Time=1.87 sec
#  ARIMA(0,1,3)(0,0,2)[7]             : AIC=10422.603, Time=1.78 sec
#  ARIMA(1,1,2)(0,0,2)[7]             : AIC=10434.815, Time=1.69 sec
#  ARIMA(2,1,3)(0,0,2)[7]             : AIC=10422.209, Time=5.00 sec
#  ARIMA(1,1,4)(0,0,2)[7]             : AIC=10421.597, Time=3.76 sec
#  ARIMA(0,1,2)(0,0,2)[7]             : AIC=10424.555, Time=1.38 sec
#  ARIMA(0,1,4)(0,0,2)[7]             : AIC=10421.459, Time=2.16 sec
#  ARIMA(2,1,2)(0,0,2)[7]             : AIC=10420.394, Time=2.81 sec
#  ARIMA(2,1,4)(0,0,2)[7]             : AIC=10317.211, Time=6.42 sec
#  ARIMA(2,1,4)(0,0,1)[7]             : AIC=inf, Time=2.29 sec
#  ARIMA(2,1,4)(1,0,2)[7]             : AIC=inf, Time=10.68 sec
#  ARIMA(2,1,4)(1,0,1)[7]             : AIC=inf, Time=3.03 sec
#  ARIMA(3,1,4)(0,0,2)[7]             : AIC=10346.387, Time=8.89 sec
#  ARIMA(2,1,5)(0,0,2)[7]             : AIC=10315.125, Time=11.98 sec
#  ARIMA(2,1,5)(0,0,1)[7]             : AIC=10315.379, Time=2.74 sec
#  ARIMA(2,1,5)(1,0,2)[7]             : AIC=inf, Time=12.05 sec
#  ARIMA(2,1,5)(1,0,1)[7]             : AIC=inf, Time=3.49 sec
#  ARIMA(1,1,5)(0,0,2)[7]             : AIC=10422.134, Time=4.94 sec
#  ARIMA(3,1,5)(0,0,2)[7]             : AIC=10334.588, Time=10.27 sec
#  ARIMA(2,1,5)(0,0,2)[7] intercept   : AIC=inf, Time=13.95 sec
#
# Best model:  ARIMA(2,1,5)(0,0,2)[7]
# Total fit time: 236.135 seconds

# %%
model_s7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                        SARIMAX Results
# ==============================================================================================
# Dep. Variable:                                      y   No. Observations:                 1091
# Model:             SARIMAX(2, 1, 5)x(0, 0, [1, 2], 7)   Log Likelihood               -5147.563
# Date:                                Mon, 14 Mar 2022   AIC                          10315.125
# Time:                                        00:31:18   BIC                          10365.065
# Sample:                                             0   HQIC                         10334.026
#                                                - 1091
# Covariance Type:                                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2406      0.005    261.154      0.000       1.231       1.250
# ar.L2         -0.9912      0.005   -199.855      0.000      -1.001      -0.981
# ma.L1         -2.1910      0.027    -80.000      0.000      -2.245      -2.137
# ma.L2          2.1952      0.064     34.201      0.000       2.069       2.321
# ma.L3         -1.0338      0.078    -13.326      0.000      -1.186      -0.882
# ma.L4          0.0854      0.061      1.395      0.163      -0.035       0.205
# ma.L5         -0.0331      0.027     -1.246      0.213      -0.085       0.019
# ma.S.L7        0.1132      0.025      4.498      0.000       0.064       0.163
# ma.S.L14       0.0478      0.024      2.022      0.043       0.001       0.094
# sigma2       701.0942     16.577     42.294      0.000     668.605     733.584
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):              2341.18
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.80   Skew:                             1.80
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
preds_sar7 = model_s7.predict(test.shape[0])
preds_sar7
# Out:
# array([37.47579459, 34.15039185, 24.16313389, 13.83603132, 12.23643096,
#        19.86583629, 29.83827284, 40.01568394, 36.28789117, 25.65098725,
#        15.57610933, 13.88416265, 21.84154091, 33.3711605 , 41.56176989,
#        37.90798203, 26.7822028 , 16.5022889 , 14.82780449, 22.93998239,
#        34.66387829, 41.16788317, 37.61601024, 26.76263829, 16.81839256,
#        15.23936145, 23.1372422 , 34.5006624 , 40.76986801, 37.28400643,
#        26.74526535, 17.12592558, 15.6381132 , 23.32711094, 34.34096967,
#        40.38354988, 36.96302198, 26.72996901, 17.42511233, 16.02445206,
#        23.50985292, 34.18473916, 40.00859117, 36.65269847, 26.71663923,
#        17.7161716 , 16.39875852, 23.68572335, 34.03191032, 39.64466381,
#        36.35268888, 26.7051707 , 17.99931668, 16.76140159, 23.85496857,
#        33.88242302, 39.29144902, 36.06265733, 26.6954627 , 18.27475556,
#        17.11273913, 24.01782642, 33.7362176 , 38.94863703, 35.78227867,
#        26.68741887, 18.54269097, 17.45311819, 24.17452649, 33.5932349 ,
#        38.61592687, 35.51123814, 26.68094706, 18.80332059, 17.78287533,
#        24.32529039, 33.45341624, 38.2930261 , 35.24923108, 26.67595916,
#        19.0568371 , 18.10233693, 24.47033205, 33.31670352, 37.97965056,
#        34.99596258, 26.67237096, 19.30342833, 18.41181951, 24.60985795,
#        33.18303918, 37.67552419, 34.75114718, 26.67010196, 19.54327737,
#        18.71162997, 24.74406739, 33.05236625, 37.38037876, 34.5145086 ,
#        26.66907525, 19.77656266, 19.00206596, 24.87315272, 32.92462834,
#        37.09395366, 34.28577938, 26.66921736, 20.00345816, 19.28341609,
#        24.99729961, 32.79976972, 36.81599571, 34.0647007 , 26.67045814,
#        20.22413338, 19.5559602 , 25.1166872 , 32.67773526, 36.54625893,
#        33.85102202, 26.67273058, 20.43875352, 19.81996968, 25.23148842,
#        32.55847047, 36.28450434, 33.64450087, 26.67597074, 20.64747961,
#        20.07570766, 25.34187012, 32.44192156, 36.0304998 , 33.44490257,
#        26.68011758, 20.85046853, 20.32342929, 25.44799332, 32.32803538,
#        35.78401976, 33.25199999, 26.68511289, 21.0478732 , 20.56338197,
#        25.55001339, 32.21675946, 35.54484514, 33.06557332, 26.69090112,
#        21.23984258, 20.79580557, 25.64808026, 32.10804204, 35.3127631 ,
#        32.88540984, 26.69742933, 21.42652184, 21.02093268, 25.74233859,
#        32.00183203, 35.08756688, 32.71130366, 26.70464704, 21.60805244,
#        21.2389888 , 25.83292794, 31.89807905, 34.86905564, 32.54305556,
#        26.71250616, 21.78457219, 21.4501926 , 25.91998298, 31.79673346,
#        34.6570343 , 32.38047273, 26.72096086, 21.95621534, 21.65475604,
#        26.00363361, 31.69774628, 34.45131335, 32.22336859, 26.7299675 ,
#        22.1231127 , 21.85288467, 26.08400516, 31.60106929, 34.25170872,
#        32.0715626 , 26.73948456, 22.2853917 , 22.04477775, 26.16121854,
#        31.50665496, 34.05804161, 31.92488003, 26.7494725 , 22.44317648,
#        22.23062847, 26.23539038, 31.4144565 , 33.87013837, 31.78315183,
#        26.75989371, 22.59658796, 22.41062412, 26.30663318, 31.32442782,
#        33.6878303 , 31.6462144 , 26.77071244, 22.74574393, 22.58494629,
#        26.37505544, 31.23652356, 33.51095358, 31.51390945, 26.78189469,
#        22.89075913, 22.753771  , 26.44076184, 31.1506991 , 33.33934908,
#        31.38608381, 26.79340818, 23.03174532, 22.9172689 , 26.50385332,
#        31.0669105 , 33.17286226, 31.26258929, 26.80522222, 23.16881133,
#        23.07560545, 26.56442723, 30.98511456, 33.01134303, 31.1432825 ,
#        26.81730771, 23.30206318, 23.22894102, 26.62257748, 30.90526881,
#        32.8546456 , 31.02802468, 26.82963702, 23.43160411, 23.37743107,
#        26.67839459, 30.82733146, 32.7026284 , 30.91668162, 26.84218394,
#        23.55753467, 23.52122632, 26.73196588, 30.75126145, 32.55515393,
#        30.80912344, 26.85492365, 23.67995277, 23.66047286, 26.78337555,
#        30.67701842, 32.41208868, 30.70522449, 26.8678326 , 23.79895377,
#        23.79531232, 26.83270478, 30.60456271, 32.27330298, 30.60486322,
#        26.88088853, 23.91463053, 23.92588197, 26.88003183, 30.53385534,
#        32.13867089, 30.50792202, 26.89407035, 24.02707345, 24.05231488,
#        26.92543217, 30.46485806, 32.00807013, 30.41428712, 26.90735812,
#        24.13637058, 24.17474003, 26.96897857, 30.39753326, 31.88138195,
#        30.32384845, 26.920733  , 24.24260763, 24.29328245, 27.01074114,
#        30.33184404, 31.75849105, 30.23649954, 26.93417721, 24.34586808,
#        24.40806332, 27.05078752, 30.26775416, 31.63928544, 30.1521374 ,
#        26.94767393, 24.44623317, 24.51920009, 27.08918287, 30.20522807,
#        31.5236564 , 30.07066238, 26.96120735, 24.54378202, 24.62680662,
#        27.12599003, 30.14423084, 31.41149834, 29.9919781 , 26.97476252,
#        24.63859165, 24.73099325, 27.16126953, 30.08472822, 31.30270876,
#        29.91599134, 26.98832542, 24.73073705, 24.83186692, 27.19507974,
#        30.02668662, 31.19718811, 29.8426119 , 27.00188281, 24.8202912 ,
#        24.92953131, 27.22747692, 29.97007306, 31.09483975, 29.77175257,
#        27.01542229, 24.90732517, 25.02408686, 27.25851525, 29.9148552 ,
#        30.99556983, 29.70332898, 27.02893219, 24.99190813, 25.11563094,
#        27.28824698, 29.86100135, 30.89928724, 29.6372595 , 27.04240159,
#        25.0741074 , 25.20425793, 27.31672243, 29.80848041, 30.80590351])

# %%
df_preds['sarima7_auto'] = preds_sar7
df_preds['sarima7_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-01    37.475795
# 2020-01-02    34.150392
# Freq: D, Name: sarima7_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['chan_dollars'], label='Train')
plt.plot(test['chan_dollars'], label='Test')
plt.plot(df_preds['sarima7_auto'], label='SARIMA_7_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 7 Model for Chantix Daily Payments");

# %%
print("MAE for SARIMA with Seasonality of 7 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['sarima7_auto']))
print("RMSE for SARIMA with Seasonality of 7 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['sarima7_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 7 Model: 23.56757839182881
# RMSE for SARIMA with Seasonality of 7 Model: 27.288300009382684

# %% [markdown]
# Try a SARIMA Model with m = 52 - Ran out of memory after 11m 58.4s!

# %%
#model_s52 = pmd.auto_arima(train['chan_dollars'], m=52, trace=True)

# %%
#model_s52.summary()

# %%
#preds_sar52 = model_s52.predict(test.shape[0])
#preds_sar52

# %%
#df_preds['sarima52_auto'] = preds_sar52
#df_preds['sarima52_auto'].head(2)

# %%
#plt.figure(figsize=(16,8))
#plt.plot(train['chan_dollars'], label='Train')
#plt.plot(test['chan_dollars'], label='Test')
#plt.plot(df_preds['sarima52_auto'], label='SARIMA_52_auto')
#plt.legend(loc='best')
#plt.title("SARIMA Seasonality of 7 Model for Chantix Daily Payments");

# %%
#print("MAE for Holt-Winters Additive with Seasonality of 52 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['sarima52_auto']))
#print("RMSE for Holt-Winters Additive with Seasonality of 52 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['sarima52_auto'], squared=False))

# %%
print("Summary of Metrics for Daily Chantix CMS Payments")
print("_________________________________________________")
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['simple_mean'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 7 Shift Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['seasonal_7']))
print("RMSE for Seasonal Baseline 7 Shift Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['seasonal_7'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 52 Shift Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['seasonal_52']))
print("RMSE for Seasonal Baseline 52 Shift Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['seasonal_52'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 364 Shift Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['seasonal_364']))
print("RMSE for Seasonal Baseline 364 Shift Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['seasonal_364'], squared=False))
print("_________________________________________________")
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['ses'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 7 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['hw_m7']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 7 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['hw_m7'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 52 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['hw_m52']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 52 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['hw_m52'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 364 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['hw_m364']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 364 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['hw_m364'], squared=False))
print("_________________________________________________")
# Out:
# Summary of Metrics for Daily Chantix CMS Payments
# _________________________________________________
# MAE for Simple Mean Baseline Model: 22.556548824127677
# RMSE for Simple Mean Baseline Model: 27.221764975567535
# _________________________________________________
# MAE for Seasonal Baseline 7 Shift Model: 16.649561643835618
# RMSE for Seasonal Baseline 7 Shift Model: 31.17463479369964
# _________________________________________________
# MAE for Seasonal Baseline 52 Shift Model: 17.96202739726027
# RMSE for Seasonal Baseline 52 Shift Model: 34.508197676049605
# _________________________________________________
# MAE for Seasonal Baseline 364 Shift Model: 27.78345205479452
# RMSE for Seasonal Baseline 364 Shift Model: 42.209450860178315
# _________________________________________________
# MAE for Simple Exponential Smoothing Model: 15.676596990133909
# RMSE for Simple Exponential Smoothing Model: 30.645916970009907
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 7 Model: 16.397713006027285
# RMSE for Holt-Winters Multiplicative with Seasonality of 7 Model: 30.729188448467742
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 52 Model: 142.21459369641607
# RMSE for Holt-Winters Multiplicative with Seasonality of 52 Model: 198.63031899763936
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 364 Model: 131.30663273581757
# RMSE for Holt-Winters Multiplicative with Seasonality of 364 Model: 198.3559925482941
# _________________________________________________

# %%
print("Continued Summary of Metrics for Daily Chantix CMS Payments")
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 7 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['hw_a7']))
print("RMSE for Holt-Winters Additive with Seasonality of 7 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['hw_a7'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 52 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['hw_a52']))
print("RMSE for Holt-Winters Additive with Seasonality of 52 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['hw_a52'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 364 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['hw_a364']))
print("RMSE for Holt-Winters Additive with Seasonality of 364 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['hw_a364'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 7 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['sarima7_auto']))
print("RMSE for SARIMA with Seasonality of 7 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['sarima7_auto'], squared=False))
print("_________________________________________________")
#print("MAE for SARIMA with Seasonality of 52 Model:", mean_absolute_error(df_preds['chan_dollars'], df_preds['sarima52_auto']))
#print("RMSE for SARIMA with Seasonality of 52 Model:", mean_squared_error(df_preds['chan_dollars'], df_preds['sarima52_auto'], squared=False))
# Out:
# Continued Summary of Metrics for Daily Chantix CMS Payments
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 7 Model: 20.59799117644779
# RMSE for Holt-Winters Additive with Seasonality of 7 Model: 25.688543607105416
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 52 Model: 23.31989515284185
# RMSE for Holt-Winters Additive with Seasonality of 52 Model: 28.48139915097091
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 364 Model: 23.39989224189589
# RMSE for Holt-Winters Additive with Seasonality of 364 Model: 30.864830546413515
# _________________________________________________
# MAE for SARIMA with Seasonality of 7 Model: 23.56757839182881
# RMSE for SARIMA with Seasonality of 7 Model: 27.288300009382684
# _________________________________________________

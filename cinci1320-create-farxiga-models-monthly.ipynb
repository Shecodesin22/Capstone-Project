# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cinci_1320 = pd.read_csv('./data/cinci1320.csv', index_col='Date_of_Payment', parse_dates=True).sort_index()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,18,19,47,48,49,50,51,52,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
cinci_1320.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
# 2013-08-01        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2013-08-01                     148974               RODNEY
# 2013-08-01                      58931                 PAUL
# 2013-08-01                     812462               ALFRED
# 2013-08-01                     108863                 MARK
# 2013-08-01                     195441           MANOJKUMAR
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2013-08-01                        NaN              VIVIAN
# 2013-08-01                     JOSEPH            FAVORITO
# ...

# %%
cinci_1320['Change_Type'].value_counts()
# Out:
# UNCHANGED    364686
# CHANGED         726
# ADD               1
# Name: Change_Type, dtype: int64

# %%
cinci_1320['farxiga'].value_counts()
# Out:
# 0    361702
# 1      3711
# Name: farxiga, dtype: int64

# %%
farxiga = cinci_1320[(cinci_1320['farxiga']==1) & (cinci_1320['Number_of_Payments_Included_in_Total_Amount']==1)].copy()

# %%
farxiga.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2014-02-07        UNCHANGED  Covered Recipient Physician
# 2014-02-07        UNCHANGED  Covered Recipient Physician
# 2014-02-10        UNCHANGED  Covered Recipient Physician
# 2014-02-10        UNCHANGED  Covered Recipient Physician
# 2014-02-10        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2014-02-07                     261294                Peter
# 2014-02-07                     116125                 Ming
# 2014-02-10                     204210                 Rosa
# 2014-02-10                     688851                Vikas
# 2014-02-10                      11601                James
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2014-02-07                          K                Wong
# 2014-02-07                          E            Ashworth
# ...

# %%
farxiga['farxiga'].value_counts()
# Out:
# 1    3453
# Name: farxiga, dtype: int64

# %%
farxiga['Change_Type'].value_counts()
# Out:
# UNCHANGED    3453
# Name: Change_Type, dtype: int64

# %%
farxiga['farx_dollars'] = [k if ((i ==1) & (j ==1)) else 0 for i, j, k in zip(farxiga['farxiga'], farxiga['Number_of_Payments_Included_in_Total_Amount'], farxiga['Total_Amount_of_Payment_USDollars'])]

#Ben Peck helped me with this during office hours.  I was oh-so-close but not quite there!

# %%
farxiga['farx_dollars'].sum()
# Out:
# 179826.00999999998

# %%
farxiga.head()
# Out:
#                 Change_Type       Covered_Recipient_Type  \
# Date_of_Payment
# 2014-02-07        UNCHANGED  Covered Recipient Physician
# 2014-02-07        UNCHANGED  Covered Recipient Physician
# 2014-02-10        UNCHANGED  Covered Recipient Physician
# 2014-02-10        UNCHANGED  Covered Recipient Physician
# 2014-02-10        UNCHANGED  Covered Recipient Physician
#
#                  Physician_Profile_ID Physician_First_Name  \
# Date_of_Payment
# 2014-02-07                     261294                Peter
# 2014-02-07                     116125                 Ming
# 2014-02-10                     204210                 Rosa
# 2014-02-10                     688851                Vikas
# 2014-02-10                      11601                James
#
#                 Physician_Middle_Name Physician_Last_Name  \
# Date_of_Payment
# 2014-02-07                          K                Wong
# 2014-02-07                          E            Ashworth
# ...

# %%
drop_cols = ['Change_Type','Covered_Recipient_Type',
'Physician_First_Name',
'Physician_Middle_Name',
'Physician_Last_Name',
'Physician_Name_Suffix',
'Recipient_Primary_Business_Street_Address_Line1',
'Recipient_Primary_Business_Street_Address_Line2',
'Recipient_City',
'Recipient_State',
'Recipient_Zip_Code',
'Recipient_Country',
'Physician_Primary_Type',
'Physician_Specialty',
'Physician_License_State_code1',
'Physician_License_State_code2',
'Physician_License_State_code3',
'Physician_License_State_code4',
'Physician_License_State_code5',
'Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Name',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_State',
'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_Country',
'Form_of_Payment_or_Transfer_of_Value',
'City_of_Travel',
'State_of_Travel',
'Country_of_Travel',
'Physician_Ownership_Indicator',
'Third_Party_Payment_Recipient_Indicator',
'Name_of_Third_Party_Entity_Receiving_Payment_or_Transfer_of_Value',
'Charity_Indicator',
'Third_Party_Equals_Covered_Recipient_Indicator',
'Contextual_Information',
'Delay_in_Publication_Indicator',
'Dispute_Status_for_Publication',
'Related_Product_Indicator',
'Covered_or_Noncovered_Indicator_1',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Product_Category_or_Therapeutic_Area_1',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
'Associated_Drug_or_Biological_NDC_1',
'Covered_or_Noncovered_Indicator_2',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Product_Category_or_Therapeutic_Area_2',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
'Associated_Drug_or_Biological_NDC_2',
'Covered_or_Noncovered_Indicator_3',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Product_Category_or_Therapeutic_Area_3',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
'Associated_Drug_or_Biological_NDC_3',
'Covered_or_Noncovered_Indicator_4',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Product_Category_or_Therapeutic_Area_4',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
'Associated_Drug_or_Biological_NDC_4',
'Covered_or_Noncovered_Indicator_5',
'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Product_Category_or_Therapeutic_Area_5',
'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5',
'Associated_Drug_or_Biological_NDC_5', 
'Physician_Profile_ID', 'Applicable_Manufacturer_or_Applicable_GPO_Making_Payment_ID',
'Total_Amount_of_Payment_USDollars','Number_of_Payments_Included_in_Total_Amount', 
'Nature_of_Payment_or_Transfer_of_Value', 'Record_ID', 
'Payment_Publication_Date', 'Program_Year',
'NDC_of_Associated_Covered_Drug_or_Biological1',
'NDC_of_Associated_Covered_Drug_or_Biological2',
'NDC_of_Associated_Covered_Drug_or_Biological3',
'NDC_of_Associated_Covered_Drug_or_Biological4',
'NDC_of_Associated_Covered_Drug_or_Biological5',
'Name_of_Associated_Covered_Device_or_Medical_Supply1',
'Name_of_Associated_Covered_Device_or_Medical_Supply2',
'Name_of_Associated_Covered_Device_or_Medical_Supply3',
'Name_of_Associated_Covered_Device_or_Medical_Supply4',
'Name_of_Associated_Covered_Device_or_Medical_Supply5',
'xarelto', 'invokana', 'victoza', 'humira', 'levemir',
'entresto', 'chantix', 'myrbetriq', 'toujeo']

# %%
farxiga.drop(columns = drop_cols, inplace = True)

# %%
farxiga.head()
# Out:
#                  farxiga  farx_dollars
# Date_of_Payment
# 2014-02-07             1         10.40
# 2014-02-07             1         10.40
# 2014-02-10             1         15.11
# 2014-02-10             1         12.00
# 2014-02-10             1         12.23

# %% [markdown]
# Was reminded of the importance of checking data for outliers by this article, and modeled my filtering code below on this article:
# https://www.analyticsvidhya.com/blog/2021/08/holt-winters-method-for-time-series-analysis/

# %%
sns.boxplot(x = farxiga['farx_dollars']);

# %%
farxiga['z_score'] = [ ((i - farxiga['farx_dollars'].mean())/farxiga['farx_dollars'].std()) for i in farxiga['farx_dollars']]

# %%
farxiga.shape
# Out:
# (3453, 3)

# %% [markdown]
# Add chart to see data before dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(farxiga.index, farxiga['farx_dollars'], label='Before Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Farxiga Drug - Before Outliers Dropped");

# %%
farxigab = farxiga[(np.abs(farxiga['z_score']) < 3)].copy()

# %%
farxigab.shape
# Out:
# (3403, 3)

# %% [markdown]
# Add chart to see data after dropping outliers

# %%
plt.figure(figsize=(12,8))

plt.plot(farxigab.index, farxigab['farx_dollars'], label='After Dropping Outliers')


plt.legend(loc='best')
plt.title("Monthly Payments for Farxiga Drug - After Outliers Dropped");

# %% [markdown]
# Drop Z-score before aggregating

# %%
farxigab.drop(columns='z_score', inplace=True)

# %%
farxiga_monthly = farxigab.resample('m').sum()

# %%
farxiga_monthly.head()
# Out:
#                  farxiga  farx_dollars
# Date_of_Payment
# 2014-02-28            59        873.18
# 2014-03-31            54       1139.35
# 2014-04-30            48        879.65
# 2014-05-31            34        687.73
# 2014-06-30            52        688.48

# %%
farxiga_monthly.sort_index()
# Out:
#                  farxiga  farx_dollars
# Date_of_Payment
# 2014-02-28            59        873.18
# 2014-03-31            54       1139.35
# 2014-04-30            48        879.65
# 2014-05-31            34        687.73
# 2014-06-30            52        688.48
# ...                  ...           ...
# 2020-08-31            18        243.79
# 2020-09-30            51       2574.87
# 2020-10-31            51       1477.64
# 2020-11-30            32        754.09
# 2020-12-31            10        128.06
#
# [83 rows x 2 columns]

# %% [markdown]
# Look at some plots

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf, pacf

# %%
plot_acf(farxiga_monthly['farx_dollars'], alpha=None, lags=24);

# %%
plot_pacf(farxiga_monthly['farx_dollars'], alpha=None, lags=24);
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# Adding 1 to the weekly sales for each observation so that Holt_winters will work.

# %%
farxiga_monthly['farx_dollars'] = [i+1 for i in farxiga_monthly['farx_dollars']]

# %% [markdown]
# Set up Train and Test Sets using 2013 - 2020 Data

# %%
train = farxiga_monthly.loc[:'2019-12-31']
train
# Out:
#                  farxiga  farx_dollars
# Date_of_Payment
# 2014-02-28            59        874.18
# 2014-03-31            54       1140.35
# 2014-04-30            48        880.65
# 2014-05-31            34        688.73
# 2014-06-30            52        689.48
# ...                  ...           ...
# 2019-08-31            47        581.99
# 2019-09-30            59       1518.36
# 2019-10-31            74       2707.77
# 2019-11-30            75       1776.24
# 2019-12-31            56       1324.72
#
# [71 rows x 2 columns]

# %%
train['farx_dollars'].max()
# Out:
# 2778.34

# %%
train.describe()
# Out:
#          farxiga  farx_dollars
# count  71.000000     71.000000
# mean   41.408451    744.870704
# std    20.479661    529.956651
# min     4.000000     45.940000
# 25%    28.000000    415.985000
# 50%    44.000000    647.220000
# 75%    55.500000    965.965000
# max    92.000000   2778.340000

# %%
train.index.freq = 'M'

# %%
train.shape
# Out:
# (71, 2)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 71 entries, 2014-02-28 to 2019-12-31
# Freq: M
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   farxiga       71 non-null     int64
#  1   farx_dollars  71 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.7 KB

# %%
train.index
# Out:
# DatetimeIndex(['2014-02-28', '2014-03-31', '2014-04-30', '2014-05-31',
#                '2014-06-30', '2014-07-31', '2014-08-31', '2014-09-30',
#                '2014-10-31', '2014-11-30', '2014-12-31', '2015-01-31',
#                '2015-02-28', '2015-03-31', '2015-04-30', '2015-05-31',
#                '2015-06-30', '2015-07-31', '2015-08-31', '2015-09-30',
#                '2015-10-31', '2015-11-30', '2015-12-31', '2016-01-31',
#                '2016-02-29', '2016-03-31', '2016-04-30', '2016-05-31',
#                '2016-06-30', '2016-07-31', '2016-08-31', '2016-09-30',
#                '2016-10-31', '2016-11-30', '2016-12-31', '2017-01-31',
#                '2017-02-28', '2017-03-31', '2017-04-30', '2017-05-31',
#                '2017-06-30', '2017-07-31', '2017-08-31', '2017-09-30',
#                '2017-10-31', '2017-11-30', '2017-12-31', '2018-01-31',
#                '2018-02-28', '2018-03-31', '2018-04-30', '2018-05-31',
# ...

# %%
test = farxiga_monthly.loc['2020-01-01':]
test
# Out:
#                  farxiga  farx_dollars
# Date_of_Payment
# 2020-01-31            69       2014.74
# 2020-02-29            63       1163.89
# 2020-03-31            30        586.67
# 2020-04-30            14        187.67
# 2020-05-31            39       6135.76
# 2020-06-30            42       1799.79
# 2020-07-31            44       1119.88
# 2020-08-31            18        244.79
# 2020-09-30            51       2575.87
# 2020-10-31            51       1478.64
# 2020-11-30            32        755.09
# 2020-12-31            10        129.06

# %%
test.describe()
# Out:
#          farxiga  farx_dollars
# count  12.000000     12.000000
# mean   38.583333   1515.987500
# std    18.666734   1646.587374
# min    10.000000    129.060000
# 25%    27.000000    501.200000
# 50%    40.500000   1141.885000
# 75%    51.000000   1853.527500
# max    69.000000   6135.760000

# %%
test.shape
# Out:
# (12, 2)

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')

plt.legend(loc='best')
plt.title("Monthly Payments for Farxiga Drug");

# %% [markdown]
# Baseline - Simple Mean (Naive Model)

# %%
df_preds = test.copy(deep=True)
df_preds
# Out:
#                  farxiga  farx_dollars
# Date_of_Payment
# 2020-01-31            69       2014.74
# 2020-02-29            63       1163.89
# 2020-03-31            30        586.67
# 2020-04-30            14        187.67
# 2020-05-31            39       6135.76
# 2020-06-30            42       1799.79
# 2020-07-31            44       1119.88
# 2020-08-31            18        244.79
# 2020-09-30            51       2575.87
# 2020-10-31            51       1478.64
# 2020-11-30            32        755.09
# 2020-12-31            10        129.06

# %%
df_preds['simple_mean'] = train['farx_dollars'].mean()
df_preds
# Out:
#                  farxiga  farx_dollars  simple_mean
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704
# 2020-02-29            63       1163.89   744.870704
# 2020-03-31            30        586.67   744.870704
# 2020-04-30            14        187.67   744.870704
# 2020-05-31            39       6135.76   744.870704
# 2020-06-30            42       1799.79   744.870704
# 2020-07-31            44       1119.88   744.870704
# 2020-08-31            18        244.79   744.870704
# 2020-09-30            51       2575.87   744.870704
# 2020-10-31            51       1478.64   744.870704
# 2020-11-30            32        755.09   744.870704
# 2020-12-31            10        129.06   744.870704

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['simple_mean'], label="Baseline (Mean)")

plt.legend(loc='best')
plt.title("Baseline (Mean) Forecast for Monthly Farxiga Payments");

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['simple_mean'], squared=False))
# Out:
# MAE for Simple Mean Baseline Model: 1076.332265258216
# RMSE for Simple Mean Baseline Model: 1754.973958656133

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 4

# %%
df_preds['seasonal_4'] = train['farx_dollars'].shift(4, freq='M') 
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars  simple_mean  seasonal_4
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704     1518.36
# 2020-02-29            63       1163.89   744.870704     2707.77

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_4'], label='Seasonal 4')

plt.legend(loc='best')
plt.title("Seasonal 4 Forecast for Monthly Farxiga Payments");

# %%
df_preds['seasonal_4'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_4'], squared=False))
# Out:
# MAE for Seasonal Baseline 4 Shift Model: 1550.4799999999998
# RMSE for Seasonal Baseline 4 Shift Model: 2178.4372480557404

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 6

# %%
df_preds['seasonal_6'] = train['farx_dollars'].shift(6, freq='M') 
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars  simple_mean  seasonal_4  seasonal_6
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704     1518.36      573.45
# 2020-02-29            63       1163.89   744.870704     2707.77      581.99

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_6'], label='Seasonal 6')

plt.legend(loc='best')
plt.title("Seasonal 6 Forecast for Monthly Farxiga Payments");

# %%
df_preds['seasonal_6'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_6'], squared=False))
# Out:
# MAE for Seasonal Baseline 6 Shift Model: 1384.4083333333335
# RMSE for Seasonal Baseline 6 Shift Model: 1816.3226157128586

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 12

# %%
df_preds['seasonal_12'] = train['farx_dollars'].shift(12, freq='M') 
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704     1518.36      573.45
# 2020-02-29            63       1163.89   744.870704     2707.77      581.99
#
#                  seasonal_12
# Date_of_Payment
# 2020-01-31            647.22
# 2020-02-29            620.24

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_12'], label='Seasonal 12')

plt.legend(loc='best')
plt.title("Seasonal 12 Forecast for Monthly Farxiga Payments");

# %%
df_preds['seasonal_12'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_12'], squared=False))
# Out:
# MAE for Seasonal Baseline 12 Shift Model: 1230.7075
# RMSE for Seasonal Baseline 12 Shift Model: 1827.3630654921863

# %% [markdown]
# Make a Seasonal Baseline Model with shift of 18

# %%
df_preds['seasonal_18'] = train['farx_dollars'].shift(18, freq='M') 
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704     1518.36      573.45
# 2020-02-29            63       1163.89   744.870704     2707.77      581.99
#
#                  seasonal_12  seasonal_18
# Date_of_Payment
# 2020-01-31            647.22       746.39
# 2020-02-29            620.24       552.58

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['seasonal_18'], label='Seasonal 18')

plt.legend(loc='best')
plt.title("Seasonal 18 Forecast for Monthly Farxiga Payments");

# %%
df_preds['seasonal_18'].fillna(0, inplace=True)

# %%
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_18'], squared=False))
# Out:
# MAE for Seasonal Baseline 18 Shift Model: 1133.6825
# RMSE for Seasonal Baseline 18 Shift Model: 1773.593892428121

# %% [markdown]
# Simple Exponential Smoothing Model

# %%
from statsmodels.tsa.api import SimpleExpSmoothing, ExponentialSmoothing

# %%
ses = SimpleExpSmoothing(train['farx_dollars']).fit(smoothing_level=.5)

# %%
ses.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        SimpleExpSmoothing Model Results
# ...
# Dep. Variable:           farx_dollars   No. Observations:                   71
# Model:             SimpleExpSmoothing   SSE                       15509396.143
# Optimized:                       True   AIC                            876.894
# Trend:                           None   BIC                            881.419
# Seasonal:                        None   AICC                           877.500
# Seasonal Periods:                None   Date:                 Tue, 15 Mar 2022
# Box-Cox:                        False   Time:                         19:36:54
# Box-Cox Coeff.:                  None
# ...
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.5000000                alpha                False
# ...

# %%
ses_forecast = ses.forecast(len(test))

# %%
df_preds['ses'] = ses_forecast

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['ses'], label='Simple Exponential Smoothing')

plt.legend(loc='best')
plt.title("Simple Exponential Smoothing for Farxiga Monthly Payments");

# %%
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['ses'], squared=False))
# Out:
# MAE for Simple Exponential Smoothing Model: 1097.430667221106
# RMSE for Simple Exponential Smoothing Model: 1577.6743428248951

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 4.

# %%
hw_a4 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=4, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             farx_dollars   No. Observations:                   71
# Model:             ExponentialSmoothing   SSE                       15306664.897
# Optimized:                         True   AIC                            887.959
# Trend:                         Additive   BIC                            906.061
# Seasonal:                      Additive   AICC                           891.626
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:36:55
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.5034846                alpha                 True
# ...

# %%
df_preds['hw_a4'] = hw_a4.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704     1518.36      573.45
# 2020-02-29            63       1163.89   744.870704     2707.77      581.99
#
#                  seasonal_12  seasonal_18          ses        hw_a4
# Date_of_Payment
# 2020-01-31            647.22       746.39  1577.174502  1660.831067
# 2020-02-29            620.24       552.58  1577.174502  1772.802652

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a4'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 4 for Monthly Payments for Farxiga");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a4'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 1199.052146599193
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 1607.814114439323

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 6.

# %%
hw_a6 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=6, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             farx_dollars   No. Observations:                   71
# Model:             ExponentialSmoothing   SSE                       14489415.876
# Optimized:                         True   AIC                            888.064
# Trend:                         Additive   BIC                            910.690
# Seasonal:                      Additive   AICC                           893.443
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:36:55
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.4703016                alpha                 True
# ...

# %%
df_preds['hw_a6'] = hw_a6.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704     1518.36      573.45
# 2020-02-29            63       1163.89   744.870704     2707.77      581.99
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            647.22       746.39  1577.174502  1660.831067
# 2020-02-29            620.24       552.58  1577.174502  1772.802652
#
#                        hw_a6
# Date_of_Payment
# 2020-01-31       1609.129537
# 2020-02-29       1802.283266

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a6'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 6 for Monthly Payments for Farxiga");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a6'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 1190.9835525232886
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 1621.859800101595

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 12.

# %%
hw_a12 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=12, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             farx_dollars   No. Observations:                   71
# Model:             ExponentialSmoothing   SSE                       13556413.642
# Optimized:                         True   AIC                            895.338
# Trend:                         Additive   BIC                            931.541
# Seasonal:                      Additive   AICC                           908.492
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:36:56
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.5313456                alpha                 True
# ...

# %%
df_preds['hw_a12'] = hw_a12.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704     1518.36      573.45
# 2020-02-29            63       1163.89   744.870704     2707.77      581.99
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            647.22       746.39  1577.174502  1660.831067
# 2020-02-29            620.24       552.58  1577.174502  1772.802652
#
#                        hw_a6       hw_a12
# Date_of_Payment
# 2020-01-31       1609.129537  1771.939229
# 2020-02-29       1802.283266  2049.642179

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a12'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 12 for Monthly Payments for Farxiga");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a12'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 1234.5805896855338
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 1625.299770068615

# %% [markdown]
# Now, try an additive Holt-Winters Model with a seasonal period of 18.

# %%
hw_a18 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=18, 
    trend='add',
    seasonal='add'
).fit()

# %%
hw_a18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             farx_dollars   No. Observations:                   71
# Model:             ExponentialSmoothing   SSE                       15816084.083
# Optimized:                         True   AIC                            918.284
# Trend:                         Additive   BIC                            968.063
# Seasonal:                      Additive   AICC                           944.371
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:36:56
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.4219964                alpha                 True
# ...

# %%
df_preds['hw_a18'] = hw_a18.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704     1518.36      573.45
# 2020-02-29            63       1163.89   744.870704     2707.77      581.99
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            647.22       746.39  1577.174502  1660.831067
# 2020-02-29            620.24       552.58  1577.174502  1772.802652
#
#                        hw_a6       hw_a12       hw_a18
# Date_of_Payment
# 2020-01-31       1609.129537  1771.939229  1562.668611
# 2020-02-29       1802.283266  2049.642179  1608.068756

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_a18'], label='Holt-Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Additive Model with Seasonality of 18 for Monthly Payments for Farxiga");

# %%
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a18'], squared=False))
# Out:
# MAE for Holt-Winters Additive with Seasonality of 18 Model: 1142.9334760844638
# RMSE for Holt-Winters Additive with Seasonality of 18 Model: 1590.602350931209

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 4.

# %%
hw_m4 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=4, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:915: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   warnings.warn(

# %%
hw_m4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             farx_dollars   No. Observations:                   71
# Model:             ExponentialSmoothing   SSE                       15609166.521
# Optimized:                         True   AIC                            889.349
# Trend:                   Multiplicative   BIC                            907.450
# Seasonal:                Multiplicative   AICC                           893.016
# Seasonal Periods:                     4   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:36:57
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.5707143                alpha                 True
# ...

# %%
df_preds['hw_m4'] = hw_m4.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704     1518.36      573.45
# 2020-02-29            63       1163.89   744.870704     2707.77      581.99
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            647.22       746.39  1577.174502  1660.831067
# 2020-02-29            620.24       552.58  1577.174502  1772.802652
#
#                        hw_a6       hw_a12       hw_a18        hw_m4
# Date_of_Payment
# 2020-01-31       1609.129537  1771.939229  1562.668611  1480.760493
# 2020-02-29       1802.283266  2049.642179  1608.068756  1815.535397

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m4'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 4 Model for Farxiga Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m4'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 4 Model: 989.7582736995774
# RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model: 1568.1254821615535

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 6.

# %%
hw_m6 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=6, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err

# %%
hw_m6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             farx_dollars   No. Observations:                   71
# Model:             ExponentialSmoothing   SSE                       13892822.517
# Optimized:                         True   AIC                            885.078
# Trend:                   Multiplicative   BIC                            907.705
# Seasonal:                Multiplicative   AICC                           890.458
# Seasonal Periods:                     6   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:36:58
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.4646431                alpha                 True
# ...

# %%
df_preds['hw_m6'] = hw_m6.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704     1518.36      573.45
# 2020-02-29            63       1163.89   744.870704     2707.77      581.99
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            647.22       746.39  1577.174502  1660.831067
# 2020-02-29            620.24       552.58  1577.174502  1772.802652
#
#                        hw_a6       hw_a12       hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31       1609.129537  1771.939229  1562.668611  1480.760493
# 2020-02-29       1802.283266  2049.642179  1608.068756  1815.535397
#
#                        hw_m6
# Date_of_Payment
# 2020-01-31       1412.559881
# 2020-02-29       2099.766293

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m6'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 6 Model for Farxiga Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m6'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 6 Model: 1256.995763302603
# RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model: 1672.978114055939

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 12.

# %%
hw_m12 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=12, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err

# %%
hw_m12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             farx_dollars   No. Observations:                   71
# Model:             ExponentialSmoothing   SSE                       12646957.341
# Optimized:                         True   AIC                            890.408
# Trend:                   Multiplicative   BIC                            926.610
# Seasonal:                Multiplicative   AICC                           903.561
# Seasonal Periods:                    12   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:36:58
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.7474999                alpha                 True
# ...

# %%
df_preds['hw_m12'] = hw_m12.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704     1518.36      573.45
# 2020-02-29            63       1163.89   744.870704     2707.77      581.99
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            647.22       746.39  1577.174502  1660.831067
# 2020-02-29            620.24       552.58  1577.174502  1772.802652
#
#                        hw_a6       hw_a12       hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31       1609.129537  1771.939229  1562.668611  1480.760493
# 2020-02-29       1802.283266  2049.642179  1608.068756  1815.535397
#
#                        hw_m6       hw_m12
# Date_of_Payment
# 2020-01-31       1412.559881  2024.133394
# 2020-02-29       2099.766293  2701.572833

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m12'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 12 Model for Farxiga Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m12'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 12 Model: 1287.842211972624
# RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model: 1695.2329540013052

# %% [markdown]
# Now, try a multiplicative Holt-Winters Model with a seasonal period of 18.

# %%
hw_m18 = ExponentialSmoothing(
    train['farx_dollars'],
    seasonal_periods=18, 
    trend='mul',
    seasonal='mul'
).fit()
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\statsmodels\tsa\holtwinters\model.py:83: RuntimeWarning: overflow encountered in matmul
#   return err.T @ err

# %%
hw_m18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                        ExponentialSmoothing Model Results
# ...
# Dep. Variable:             farx_dollars   No. Observations:                   71
# Model:             ExponentialSmoothing   SSE                       10896899.090
# Optimized:                         True   AIC                            891.833
# Trend:                   Multiplicative   BIC                            941.612
# Seasonal:                Multiplicative   AICC                           917.920
# Seasonal Periods:                    18   Date:                 Tue, 15 Mar 2022
# Box-Cox:                          False   Time:                         19:36:59
# Box-Cox Coeff.:                    None
# ...
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.6060696                alpha                 True
# ...

# %%
df_preds['hw_m18'] = hw_m18.forecast(len(test))
df_preds.head(2)
# Out:
#                  farxiga  farx_dollars  simple_mean  seasonal_4  seasonal_6  \
# Date_of_Payment
# 2020-01-31            69       2014.74   744.870704     1518.36      573.45
# 2020-02-29            63       1163.89   744.870704     2707.77      581.99
#
#                  seasonal_12  seasonal_18          ses        hw_a4  \
# Date_of_Payment
# 2020-01-31            647.22       746.39  1577.174502  1660.831067
# 2020-02-29            620.24       552.58  1577.174502  1772.802652
#
#                        hw_a6       hw_a12       hw_a18        hw_m4  \
# Date_of_Payment
# 2020-01-31       1609.129537  1771.939229  1562.668611  1480.760493
# 2020-02-29       1802.283266  2049.642179  1608.068756  1815.535397
#
#                        hw_m6       hw_m12       hw_m18
# Date_of_Payment
# 2020-01-31       1412.559881  2024.133394  2154.512730
# 2020-02-29       2099.766293  2701.572833  2017.578115

# %%
plt.figure(figsize=(12,8))

plt.plot(train.index, train['farx_dollars'], label='Train')
plt.plot(test.index, test['farx_dollars'], label='Test')
plt.plot(df_preds.index, df_preds['hw_m18'], label='Holt Winters')

plt.legend(loc='best')
plt.title("Holt-Winters Multiplicative Seasonality of 18 Model for Farxiga Monthly Payments");

# %%
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m18'], squared=False))
# Out:
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 1342.5078356479316
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 1693.5513643963804

# %% [markdown]
# Try a SARIMA Model

# %%
from pmdarima.utils import tsdisplay

# %%
traina = train['farx_dollars']

# %%
tsdisplay(traina)
# Out:
# C:\Users\sarah\anaconda3\lib\site-packages\pmdarima\utils\visualization.py:220: FutureWarning: the 'unbiased'' keyword is deprecated, use 'adjusted' instead
#   res = tsaplots.plot_acf(

# %% [markdown]
# SARIMA Model with Seasonality of 4

# %%
import pmdarima as pmd
model_s4 = pmd.auto_arima(train['farx_dollars'], m=4, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[4] intercept   : AIC=inf, Time=0.29 sec
#  ARIMA(0,1,0)(0,0,0)[4] intercept   : AIC=1073.145, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[4] intercept   : AIC=1074.253, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[4] intercept   : AIC=1067.670, Time=0.08 sec
#  ARIMA(0,1,0)(0,0,0)[4]             : AIC=1071.157, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[4] intercept   : AIC=1066.226, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,0)[4] intercept   : AIC=1067.704, Time=0.07 sec
#  ARIMA(0,1,1)(1,0,1)[4] intercept   : AIC=1069.664, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[4] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[4] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[4] intercept   : AIC=1072.399, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[4] intercept   : AIC=1060.681, Time=0.13 sec
#  ARIMA(1,1,2)(1,0,0)[4] intercept   : AIC=1062.667, Time=0.18 sec
#  ARIMA(1,1,2)(0,0,1)[4] intercept   : AIC=1062.672, Time=0.18 sec
# ...

# %%
model_s4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   71
# Model:               SARIMAX(0, 1, 2)   Log Likelihood                -525.892
# Date:                Tue, 15 Mar 2022   AIC                           1057.785
# Time:                        19:37:03   BIC                           1064.530
# Sample:                             0   HQIC                          1060.464
#                                  - 71
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.3328      0.138     -2.418      0.016      -0.603      -0.063
# ma.L2         -0.4272      0.129     -3.305      0.001      -0.681      -0.174
# sigma2      1.948e+05    2.5e+04      7.801      0.000    1.46e+05    2.44e+05
# ...

# %%
preds_sar4 = model_s4.predict(test.shape[0])
preds_sar4
# Out:
# array([1302.3071616 , 1238.14310721, 1238.14310721, 1238.14310721,
#        1238.14310721, 1238.14310721, 1238.14310721, 1238.14310721,
#        1238.14310721, 1238.14310721, 1238.14310721, 1238.14310721])

# %%
df_preds['sarima4_auto'] = preds_sar4
df_preds['sarima4_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    1302.307162
# 2020-02-29    1238.143107
# Freq: M, Name: sarima4_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['farx_dollars'], label='Train')
plt.plot(test['farx_dollars'], label='Test')
plt.plot(df_preds['sarima4_auto'], label='SARIMA_4_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 4 Model for Farxiga Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['sarima4_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 4 Model: 1019.1560133368611
# RMSE for SARIMA with Seasonality of 4 Model: 1598.2953859401032

# %% [markdown]
# SARIMA Model with Seasonality of 6

# %%
model_s6 = pmd.auto_arima(train['farx_dollars'], m=6, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[6] intercept   : AIC=inf, Time=0.31 sec
#  ARIMA(0,1,0)(0,0,0)[6] intercept   : AIC=1073.145, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[6] intercept   : AIC=1074.321, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[6] intercept   : AIC=1068.053, Time=0.09 sec
#  ARIMA(0,1,0)(0,0,0)[6]             : AIC=1071.157, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[6] intercept   : AIC=1066.226, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,0)[6] intercept   : AIC=1068.012, Time=0.07 sec
#  ARIMA(0,1,1)(1,0,1)[6] intercept   : AIC=1069.868, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[6] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[6] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[6] intercept   : AIC=1072.399, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[6] intercept   : AIC=1060.681, Time=0.14 sec
#  ARIMA(1,1,2)(1,0,0)[6] intercept   : AIC=1062.703, Time=0.20 sec
#  ARIMA(1,1,2)(0,0,1)[6] intercept   : AIC=1062.690, Time=0.15 sec
# ...

# %%
model_s6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   71
# Model:               SARIMAX(0, 1, 2)   Log Likelihood                -525.892
# Date:                Tue, 15 Mar 2022   AIC                           1057.785
# Time:                        19:37:07   BIC                           1064.530
# Sample:                             0   HQIC                          1060.464
#                                  - 71
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.3328      0.138     -2.418      0.016      -0.603      -0.063
# ma.L2         -0.4272      0.129     -3.305      0.001      -0.681      -0.174
# sigma2      1.948e+05    2.5e+04      7.801      0.000    1.46e+05    2.44e+05
# ...

# %%
preds_sar6 = model_s6.predict(test.shape[0])
preds_sar6
# Out:
# array([1302.3071616 , 1238.14310721, 1238.14310721, 1238.14310721,
#        1238.14310721, 1238.14310721, 1238.14310721, 1238.14310721,
#        1238.14310721, 1238.14310721, 1238.14310721, 1238.14310721])

# %%
df_preds['sarima6_auto'] = preds_sar6
df_preds['sarima6_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    1302.307162
# 2020-02-29    1238.143107
# Freq: M, Name: sarima6_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['farx_dollars'], label='Train')
plt.plot(test['farx_dollars'], label='Test')
plt.plot(df_preds['sarima6_auto'], label='SARIMA_6_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 6 Model for Farxiga Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['sarima6_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 6 Model: 1019.1560133368611
# RMSE for SARIMA with Seasonality of 6 Model: 1598.2953859401032

# %% [markdown]
# Try a SARIMA Model with m = 12

# %%
model_s12 = pmd.auto_arima(train['farx_dollars'], m=12, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=inf, Time=0.52 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=1073.145, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=1073.869, Time=0.02 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=1067.452, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=1071.157, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[12] intercept   : AIC=1066.226, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,0)[12] intercept   : AIC=1067.553, Time=0.11 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=1069.423, Time=0.12 sec
#  ARIMA(1,1,1)(0,0,0)[12] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[12] intercept   : AIC=1072.399, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=1060.681, Time=0.13 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=1062.430, Time=0.32 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=1062.348, Time=0.16 sec
# ...

# %%
model_s12.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   71
# Model:               SARIMAX(0, 1, 2)   Log Likelihood                -525.892
# Date:                Tue, 15 Mar 2022   AIC                           1057.785
# Time:                        19:37:11   BIC                           1064.530
# Sample:                             0   HQIC                          1060.464
#                                  - 71
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.3328      0.138     -2.418      0.016      -0.603      -0.063
# ma.L2         -0.4272      0.129     -3.305      0.001      -0.681      -0.174
# sigma2      1.948e+05    2.5e+04      7.801      0.000    1.46e+05    2.44e+05
# ...

# %%
preds_sar12 = model_s12.predict(test.shape[0])
preds_sar12
# Out:
# array([1302.3071616 , 1238.14310721, 1238.14310721, 1238.14310721,
#        1238.14310721, 1238.14310721, 1238.14310721, 1238.14310721,
#        1238.14310721, 1238.14310721, 1238.14310721, 1238.14310721])

# %%
df_preds['sarima12_auto'] = preds_sar12
df_preds['sarima12_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    1302.307162
# 2020-02-29    1238.143107
# Freq: M, Name: sarima12_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['farx_dollars'], label='Train')
plt.plot(test['farx_dollars'], label='Test')
plt.plot(df_preds['sarima12_auto'], label='SARIMA_12_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 12 Model for Farxiga Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['sarima12_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 12 Model: 1019.1560133368611
# RMSE for SARIMA with Seasonality of 12 Model: 1598.2953859401032

# %% [markdown]
# Try a SARIMA Model with m = 18

# %%
model_s18 = pmd.auto_arima(train['farx_dollars'], m=18, trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[18] intercept   : AIC=inf, Time=1.39 sec
#  ARIMA(0,1,0)(0,0,0)[18] intercept   : AIC=1073.145, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[18] intercept   : AIC=1074.085, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,1)[18] intercept   : AIC=1067.509, Time=0.32 sec
#  ARIMA(0,1,0)(0,0,0)[18]             : AIC=1071.157, Time=0.01 sec
#  ARIMA(0,1,1)(0,0,0)[18] intercept   : AIC=1066.226, Time=0.03 sec
#  ARIMA(0,1,1)(1,0,0)[18] intercept   : AIC=1067.683, Time=0.27 sec
#  ARIMA(0,1,1)(1,0,1)[18] intercept   : AIC=1068.867, Time=0.44 sec
#  ARIMA(1,1,1)(0,0,0)[18] intercept   : AIC=inf, Time=0.06 sec
#  ARIMA(0,1,2)(0,0,0)[18] intercept   : AIC=inf, Time=0.07 sec
#  ARIMA(1,1,0)(0,0,0)[18] intercept   : AIC=1072.399, Time=0.01 sec
#  ARIMA(1,1,2)(0,0,0)[18] intercept   : AIC=1060.681, Time=0.14 sec
#  ARIMA(1,1,2)(1,0,0)[18] intercept   : AIC=1062.688, Time=0.42 sec
#  ARIMA(1,1,2)(0,0,1)[18] intercept   : AIC=1062.678, Time=0.59 sec
# ...

# %%
model_s18.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   71
# Model:               SARIMAX(0, 1, 2)   Log Likelihood                -525.892
# Date:                Tue, 15 Mar 2022   AIC                           1057.785
# Time:                        19:37:19   BIC                           1064.530
# Sample:                             0   HQIC                          1060.464
#                                  - 71
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.3328      0.138     -2.418      0.016      -0.603      -0.063
# ma.L2         -0.4272      0.129     -3.305      0.001      -0.681      -0.174
# sigma2      1.948e+05    2.5e+04      7.801      0.000    1.46e+05    2.44e+05
# ...

# %%
preds_sar18 = model_s18.predict(test.shape[0])
preds_sar18
# Out:
# array([1302.3071616 , 1238.14310721, 1238.14310721, 1238.14310721,
#        1238.14310721, 1238.14310721, 1238.14310721, 1238.14310721,
#        1238.14310721, 1238.14310721, 1238.14310721, 1238.14310721])

# %%
df_preds['sarima18_auto'] = preds_sar18
df_preds['sarima18_auto'].head(2)
# Out:
# Date_of_Payment
# 2020-01-31    1302.307162
# 2020-02-29    1238.143107
# Freq: M, Name: sarima18_auto, dtype: float64

# %%
plt.figure(figsize=(16,8))
plt.plot(train['farx_dollars'], label='Train')
plt.plot(test['farx_dollars'], label='Test')
plt.plot(df_preds['sarima18_auto'], label='SARIMA_18_auto')
plt.legend(loc='best')
plt.title("SARIMA Seasonality of 18 Model for Farxiga Monthly Payments");

# %%
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# MAE for SARIMA with Seasonality of 18 Model: 1019.1560133368611
# RMSE for SARIMA with Seasonality of 18 Model: 1598.2953859401032

# %%
print("Summary of Metrics for Monthly Farxiga CMS Payments")
print("_________________________________________________")
print("MAE for Simple Mean Baseline Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['simple_mean']))
print("RMSE for Simple Mean Baseline Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['simple_mean'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 4 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_4']))
print("RMSE for Seasonal Baseline 4 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_4'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 6 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_6']))
print("RMSE for Seasonal Baseline 6 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_6'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 12 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_12']))
print("RMSE for Seasonal Baseline 12 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_12'], squared=False))
print("_________________________________________________")
print("MAE for Seasonal Baseline 18 Shift Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['seasonal_18']))
print("RMSE for Seasonal Baseline 18 Shift Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['seasonal_18'], squared=False))
print("_________________________________________________")
print("MAE for Simple Exponential Smoothing Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['ses']))
print("RMSE for Simple Exponential Smoothing Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['ses'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m4']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 4 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m6']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 6 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m12']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 12 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m12'], squared=False))
print("_________________________________________________")
# Out:
# Summary of Metrics for Monthly Farxiga CMS Payments
# _________________________________________________
# MAE for Simple Mean Baseline Model: 1076.332265258216
# RMSE for Simple Mean Baseline Model: 1754.973958656133
# _________________________________________________
# MAE for Seasonal Baseline 4 Shift Model: 1550.4799999999998
# RMSE for Seasonal Baseline 4 Shift Model: 2178.4372480557404
# _________________________________________________
# MAE for Seasonal Baseline 6 Shift Model: 1384.4083333333335
# RMSE for Seasonal Baseline 6 Shift Model: 1816.3226157128586
# _________________________________________________
# MAE for Seasonal Baseline 12 Shift Model: 1230.7075
# RMSE for Seasonal Baseline 12 Shift Model: 1827.3630654921863
# _________________________________________________
# MAE for Seasonal Baseline 18 Shift Model: 1133.6825
# RMSE for Seasonal Baseline 18 Shift Model: 1773.593892428121
# _________________________________________________
# ...

# %%
print("Continued Summary of Metrics for Monthly Farxiga CMS Payments")
print("_________________________________________________")
print("MAE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_m18']))
print("RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_m18'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 4 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a4']))
print("RMSE for Holt-Winters Additive with Seasonality of 4 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a4'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 6 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a6']))
print("RMSE for Holt-Winters Additive with Seasonality of 6 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a6'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 12 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a12']))
print("RMSE for Holt-Winters Additive with Seasonality of 12 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a12'], squared=False))
print("_________________________________________________")
print("MAE for Holt-Winters Additive with Seasonality of 18 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['hw_a18']))
print("RMSE for Holt-Winters Additive with Seasonality of 18 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['hw_a18'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 4 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['sarima4_auto']))
print("RMSE for SARIMA with Seasonality of 4 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['sarima4_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 6 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['sarima6_auto']))
print("RMSE for SARIMA with Seasonality of 6 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['sarima6_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 12 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['sarima12_auto']))
print("RMSE for SARIMA with Seasonality of 12 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['sarima12_auto'], squared=False))
print("_________________________________________________")
print("MAE for SARIMA with Seasonality of 18 Model:", mean_absolute_error(df_preds['farx_dollars'], df_preds['sarima18_auto']))
print("RMSE for SARIMA with Seasonality of 18 Model:", mean_squared_error(df_preds['farx_dollars'], df_preds['sarima18_auto'], squared=False))
# Out:
# Continued Summary of Metrics for Monthly Farxiga CMS Payments
# _________________________________________________
# MAE for Holt-Winters Multiplicative with Seasonality of 18 Model: 1342.5078356479316
# RMSE for Holt-Winters Multiplicative with Seasonality of 18 Model: 1693.5513643963804
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 4 Model: 1199.052146599193
# RMSE for Holt-Winters Additive with Seasonality of 4 Model: 1607.814114439323
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 6 Model: 1190.9835525232886
# RMSE for Holt-Winters Additive with Seasonality of 6 Model: 1621.859800101595
# _________________________________________________
# MAE for Holt-Winters Additive with Seasonality of 12 Model: 1234.5805896855338
# RMSE for Holt-Winters Additive with Seasonality of 12 Model: 1625.299770068615
# _________________________________________________
# ...
